# %%
import pandas as pd

# %%
data = pd.read_csv('data/jeju_Tourism1.csv')
data.dropna(inplace=True)

# %%
data
# Out:
#                  ﻿name keyword  \
# 0      더럭초등학교(구, 더럭분교)      문화
# 1      더럭초등학교(구, 더럭분교)      문화
# 2      더럭초등학교(구, 더럭분교)      문화
# 3      더럭초등학교(구, 더럭분교)      문화
# 4      더럭초등학교(구, 더럭분교)      문화
# ...                ...     ...
# 14929     서광리 곶자왈생태탐방로      도보
# 14930        제주올레 12코스      도보
# 14931        제주올레 13코스      도보
# 14932      제주올레 15-B코스      도보
# 14933      제주올레 18-1코스      도보
#
#                                                  content  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                       무지개빛 아름다운 더럭초등학교
# 2                                       무지개빛 아름다운 더럭초등학교
# 3              알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4      #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                                                  ...
# 14929                                      서광리 곶자왈 생태탐방로
# 14930  제주 올레길 12코스 수월봉 화산쇄설층\n정상의 지형은 완만한 편이지만 해안 절벽을...
# 14931  올레길 13코스를 꼬닥꼬닥 걸으며... 이날은 클린올레로 올레길을 청소해서 마음도 ...
# 14932              #올레길 #15-b #담장을 #벗삼아 #태양을 #바라보는 #난제주개
# 14933                              용듬벙에서 바로보는 나발론절벽과 하늘길
#
#                                                     tags  \
# 0           ['#제주컬러어택', '#더럭분교', '#초등동창가을여행', '#무지개빛우정']
# 1                        ['##더럭초등학교', '##더럭분교', '##애월읍']
# 2             ['##더럭초등학교', '##더럭분교', '##무지개학교', '##애월읍']
# 3                      ['##5월엔제주', '##더럭분교', '##더럭초등학교']
# 4                     ['#제주도', '#더럭분교', '#연화못', '#연꽃마을']
# ...                                                  ...
# 14929                                                 []
# 14930                                                 []
# 14931                                                 []
# 14932  ['#올레길', '#15', '#담장을', '#벗삼아', '#태양을', '#바라보는...
# 14933  ['#알파캠프', '#올레캠프본점알파캠프', '#제주', '#제주도', '#제주올레...
#
#                            address address1
# 0          제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 1          제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 2          제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 3          제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 4          제주특별자치도 제주시 애월읍 하가로 195     애월읍
# ...                            ...      ...
# 14929         제주특별자치도 서귀포시 안덕면 서광리     안덕면
# 14930  제주특별자치도 서귀포시 대정읍 신도리 2883-2     대정읍
# 14931   제주특별자치도 제주시 한경면 조수리 2137-2     한경면
# 14932    제주특별자치도 제주시 한림읍 한림해안로 192     한림읍
# 14933     제주특별자치도 제주시 추자면 묵리 산 133     추자면
#
# [11287 rows x 6 columns]

# %%
sum_data=pd.DataFrame(data.groupby(['﻿name','keyword','address1'])['content'].sum())

# %%
sum_data
# Out:
#                                                                                 content
# ﻿name               keyword address1
# 5.16도로숲터널           자연       남원읍      #가을가을한제주#5.16도로숲터널개인적으로 봄 계절, 제주시->서귀포로 넘어가는 방...
# 9.81 파크             테마관광     애월읍      강추!! 981어플설치하니까 누가 잘탔는지 내기도 하고 레이싱한 영상도 다운받을 수...
# 가뫼물                 레저/체험    남원읍      #6월 #감귤대신블루베리 #감귤밭 #모노레일 #감귤비누만들기 #동물먹이주기 #알찬체...
# 개오름                 자연       표선면                                             #산과오름 #개오름
# 거문오름(UNESCO 세계자연유산) 자연       조천읍      유네스코 자연유산을 직접 체험하는 기회가 있어 좋았습니다.딱 좋은 기분은 거기까지 ...
# ...                                                                                 ...
# 화순리 유채꽃길            자연       안덕면      #봄 #제주봄 #유채꽃 #제주유체꽃 #산방산 #노오란밭제주도 유채 꽃제주로 떠난 태...
# 화조원                 테마관광     애월읍      애월에 가면 꼭 가봐야 할 곳 입니다. 깨끗하고 동물이 많아서 볼거리도 많구요, 아...
# 환상숲 곶자왈공원           도보       한경면      식물들이 직접 자생하며 만든 곳. 선생님의 설명을 통해 곶자왈의 깊이가 더욱 깊어졌...
#                     자연       한경면      식물들이 직접 자생하며 만든 곳. 선생님의 설명을 통해 곶자왈의 깊이가 더욱 깊어졌...
# 휴애리 자연생활공원          테마관광     남원읍      응 동물학대휴애리 핑크뮬리 넘넘 예쁘다! 동물도 보고 산책도 하고 볼거리 많은 이곳...
#
# [342 rows x 1 columns]

# %%
data['content']=[x.replace('\n',' ') for x in data['content']]

# %%
data.to_csv('ddd.csv')
