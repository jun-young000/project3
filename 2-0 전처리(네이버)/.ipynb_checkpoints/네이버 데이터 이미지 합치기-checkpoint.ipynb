# %%
import json
import pandas as pd
import numpy as np
import os

# %%
# json 파일 불러오기

with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1 crow\\1회차\\image.json", "r", encoding="utf-8") as json_file:
    json_sample_1 = json.load(json_file)
    
print(json.dumps(json_sample_1))
# Out:
# {"\ubcc4\ub3c4\ubd09\uc624\ub9ac\uc0ac\ub0e5": {}, "\uc624\uc870\ud30c\uc2a4\ud0c0\uc564\ud53c\uc790": {"36882244_5cbb032177919be02c5c6020": "", "36882244_5f05b980699d39675d9e41c6": "https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210930_247%2F1632981733440oeXqX_JPEG%2Fupload_0d5376f3cff67e95ff20b237781750fe.jpeg", "36882244_5c0fc6cce73c45340680bf88": "https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210923_73%2F16323577746593uJtl_JPEG%2Fupload_d5428ae8ba0496eac99c9616f0e73ad1.jpg", "36882244_5f068060ace692ef62457a68": "", "36882244_5e91be4f8f87a842bcc10228": "https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210902_139%2F1630556635352GaJ50_JPEG%2Fupload_91dc4ae9149100663ec1b50364ec88c3.jpg", "36882244_5db015e18f87a842bcc79dc3": "", "36882244_5b
# ...

# %%
with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1 crow\\1회차\\image.json", "r", encoding="utf-8") as json_file:
    json_sample_1 = json.load(json_file)
    

with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1 crow\\2회차\\image.json", "r", encoding="utf-8") as json_file:
    json_sample_2 = json.load(json_file)
    
with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1 crow\\3회차\\image.json", "r", encoding="utf-8") as json_file:
    json_sample_3 = json.load(json_file)
    
with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1 crow\\4회차\\image.json", "r", encoding="utf-8") as json_file:
    json_sample_4 = json.load(json_file)
    
    
with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1_1 crow\\1회차\\image.json", "r", encoding="utf-8") as json_file:
    json_sample_5 = json.load(json_file)
        
    
with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1_1 crow\\2회차\\image.json", "r", encoding="utf-8") as json_file:
    json_sample_6 = json.load(json_file)
        
    
with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1_1 crow\\3회차\\image.json", "r", encoding="utf-8") as json_file:
    json_sample_7 = json.load(json_file)
        
    
with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1_1 crow\\4회차\\image.json", "r", encoding="utf-8") as json_file:
    json_sample_8 = json.load(json_file)

with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1_2 crow\\1회차\\image.json", "r", encoding="utf-8") as json_file:
    json_sample_9 = json.load(json_file)

with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1_2 crow\\2회차\\image.json", "r", encoding="utf-8") as json_file:

    json_sample_10 = json.load(json_file)

with open("C:\\Users\\ui\\Documents\\GitHub\\project3\\0_1_2 crow\\3회차\\image.json", "r", encoding="utf-8") as json_file:
    json_sample_11 = json.load(json_file)
    
    
    
    
json_sample_1.update(json_sample_2)
json_sample_1.update(json_sample_3)
json_sample_1.update(json_sample_4)
json_sample_1.update(json_sample_5)
json_sample_1.update(json_sample_6)
json_sample_1.update(json_sample_7)
json_sample_1.update(json_sample_8)
json_sample_1.update(json_sample_8)
json_sample_1.update(json_sample_8)

json_sample_1.update(json_sample_8)

# %%
type(json_sample_1)
# Out:
# dict

# %%
json_data_1 = pd.json_normalize(json_sample_1)

# %%
json_data_1 = json_data_1.T

# %%
json_data_1.reset_index(inplace=True)
json_data_1
# Out:
#                                              index  \
# 0       오조파스타앤피자.36882244_5cbb032177919be02c5c6020
# 1       오조파스타앤피자.36882244_5f05b980699d39675d9e41c6
# 2       오조파스타앤피자.36882244_5c0fc6cce73c45340680bf88
# 3       오조파스타앤피자.36882244_5f068060ace692ef62457a68
# 4       오조파스타앤피자.36882244_5e91be4f8f87a842bcc10228
# ...                                            ...
# 186762    수구레해장국.36843989_5b945daf148d886dc6fd4dc6
# 186763    수구레해장국.36843989_5b780f8dc1f02b5b65991cfa
# 186764   페리카나연동점.11800491_5f3ce0f278e8a28c2ca0f4d8
# 186765   페리카나연동점.11800491_5ee46b9c8f87a842bcb83ca4
# 186766   페리카나연동점.11800491_5c18eb350a8e0f69d74a52aa
#
#                                                         0
# 0
# 1       https://search.pstatic.net/common/?autoRotate=...
# 2       https://search.pstatic.net/common/?autoRotate=...
# 3
# 4       https://search.pstatic.net/common/?autoRotate=...
# ...                                                   ...
# 186762
# ...

# %%
json_data_1.columns = ['name', 'url']

# %%
json_data_1['url'].replace('', np.nan, inplace=True)
json_data_1= json_data_1.dropna(subset = ['url'])

# %%
json_data_1.reset_index(inplace=True)

# %%
del json_data_1['index']

# %%
json_data_1
# Out:
#                                              name  \
# 0      오조파스타앤피자.36882244_5f05b980699d39675d9e41c6
# 1      오조파스타앤피자.36882244_5c0fc6cce73c45340680bf88
# 2      오조파스타앤피자.36882244_5e91be4f8f87a842bcc10228
# 3      오조파스타앤피자.36882244_5e7866288f87a842bccc6273
# 4      오조파스타앤피자.36882244_5e19da708f87a842bc805f81
# ...                                           ...
# 54132    우수미회센타.35591021_5c246a48bbb3d3cae3bf3ff7
# 54133    우수미회센타.35591021_5c5e0c8e5ed9e6fa2f522201
# 54134    수구레해장국.36843989_5bde69fc78ddbca19994ca56
# 54135    수구레해장국.36843989_5c87b741559c39f600464673
# 54136    수구레해장국.36843989_5b780f8dc1f02b5b65991cfa
#
#                                                      url
# 0      https://search.pstatic.net/common/?autoRotate=...
# 1      https://search.pstatic.net/common/?autoRotate=...
# 2      https://search.pstatic.net/common/?autoRotate=...
# 3      https://search.pstatic.net/common/?autoRotate=...
# 4      https://search.pstatic.net/common/?autoRotate=...
# ...

# %%
json_data_1['rest_name'] = json_data_1.name.str.split('.').str[0]
json_data_1
# Out:
# <ipython-input-37-27996bdd0ff0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   json_data_1['rest_name'] = json_data_1.name.str.split('.').str[0]
#                                              name  \
# 0      오조파스타앤피자.36882244_5f05b980699d39675d9e41c6
# 1      오조파스타앤피자.36882244_5c0fc6cce73c45340680bf88
# 2      오조파스타앤피자.36882244_5e91be4f8f87a842bcc10228
# 3      오조파스타앤피자.36882244_5e7866288f87a842bccc6273
# 4      오조파스타앤피자.36882244_5e19da708f87a842bc805f81
# ...                                           ...
# 54132    우수미회센타.35591021_5c246a48bbb3d3cae3bf3ff7
# 54133    우수미회센타.35591021_5c5e0c8e5ed9e6fa2f522201
# 54134    수구레해장국.36843989_5bde69fc78ddbca19994ca56
# 54135    수구레해장국.36843989_5c87b741559c39f600464673
# ...

# %%
del json_data_1['name']

# %%
json_data_1.columns = ['url', 'rest_name']

# %%
json_data_1 = json_data_1[['rest_name', 'url']]
json_data_1
# Out:
#       rest_name                                                url
# 0      오조파스타앤피자  https://search.pstatic.net/common/?autoRotate=...
# 1      오조파스타앤피자  https://search.pstatic.net/common/?autoRotate=...
# 2      오조파스타앤피자  https://search.pstatic.net/common/?autoRotate=...
# 3      오조파스타앤피자  https://search.pstatic.net/common/?autoRotate=...
# 4      오조파스타앤피자  https://search.pstatic.net/common/?autoRotate=...
# ...         ...                                                ...
# 54132    우수미회센타  https://search.pstatic.net/common/?autoRotate=...
# 54133    우수미회센타  https://search.pstatic.net/common/?autoRotate=...
# 54134    수구레해장국  https://search.pstatic.net/common/?autoRotate=...
# 54135    수구레해장국  https://search.pstatic.net/common/?autoRotate=...
# 54136    수구레해장국  https://search.pstatic.net/common/?autoRotate=...
#
# [54137 rows x 2 columns]

# %%
json_data_1.to_csv("음식점이미지url.csv", mode='w')
