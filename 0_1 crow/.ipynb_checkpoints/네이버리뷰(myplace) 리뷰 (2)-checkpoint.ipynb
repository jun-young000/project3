# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import time
import re
from bs4 import BeautifulSoup 
import random 
import multiprocessing
from tqdm import tqdm


df = pd.read_csv('./제주특별자치도음식점목록(통합).csv', sep=',', encoding='CP949')
df['naver_map_url'] = '' # 미리 url을 담을 column을 만들어줌

chromedriver = './chromedriver' 
driver = webdriver.Chrome(chromedriver) 

# driver = webdriver.Chrome(executable_path=r'C:\\Users\\ui\\Desktop\chromedriver.exe') # 웹드라이버가 설치된 경로를 지정해주시면 됩니다.

# %%
df = df[df.영업상태명 != '폐업']

# %%
df = df.reset_index()

# %%
del df['index']

# %%
# df = df.iloc[9576:12768]
df = df.iloc[12768:15961]

# %%
df = df.reset_index()
del df['index']

# %%
df
# Out:
#                 사업장명 업종구분대분류   업종구분소분류     인허가일자  인허가취소일자  영업상태명 상세영업상태명  \
# 0                파파야   일반음식점        기타  20160412      NaN  영업/정상      영업
# 1               청우식당   일반음식점        분식  20160414      NaN  영업/정상      영업
# 2              이승악식당   일반음식점        한식  20160415      NaN  영업/정상      영업
# 3              당포회센타   일반음식점        회집  20160908      NaN  영업/정상      영업
# 4               할매곱창   일반음식점        한식  20170317      NaN  영업/정상      영업
# ...              ...     ...       ...       ...      ...    ...     ...
# 3188        쥬씨제주한라대점   휴게음식점       커피숍  20160215      NaN  영업/정상      영업
# 3189  써브웨이신제주연동신시가지점   휴게음식점     패스트푸드  20160215      NaN  영업/정상      영업
# 3190          서제니의시간   휴게음식점       커피숍  20160216      NaN  영업/정상      영업
# 3191           보리빵마을   휴게음식점  기타 휴게음식점  20040413      NaN  영업/정상      영업
# 3192      씨유제주일중사거리점   휴게음식점  기타 휴게음식점  20171215      NaN  영업/정상      영업
#
#       폐업일자  휴업시작일자  휴업종료일자  재개업일자   소재지면적                         소재지전체주소  \
# 0      NaN     NaN     NaN    NaN      32  제주특별자치도 서귀포시 성산읍 성산리 230-22번지
# 1      NaN     NaN     NaN    NaN    93.5       제주특별자치도 서귀포시 강정동 165-7번지
# 2      NaN     NaN     NaN    NaN      33  제주특별자치도 서귀포시 남원읍 신례리 2162-8번지
# 3      NaN     NaN     NaN    NaN  162.08    제주특별자치도 서귀포시 표선면 표선리 45-6번지
# 4      NaN     NaN     NaN    NaN     115       제주특별자치도 서귀포시 동홍동 472-1번지
# ...    ...     ...     ...    ...     ...                             ...
# 3188   NaN     NaN     NaN    NaN    32.3        제주특별자치도 제주시 노형동 755-2번지
# 3189   NaN     NaN     NaN    NaN   47.96          제주특별자치도 제주시 연동 1482번지
# 3190   NaN     NaN     NaN    NaN      22   제주특별자치도 제주시 애월읍 하귀1리 166-1번지
# 3191   NaN     NaN     NaN    NaN   47.17        제주특별자치도 제주시 연동 2514-3번지
# 3192   NaN     NaN     NaN    NaN     8.8     제주특별자치도 제주시 이도이동 1970-11번지
#
#                                   도로명전체주소  도로명우편번호           데이터갱신일자  \
# 0                제주특별자치도 서귀포시 성산읍 성산등용로 7  63643.0  2018-08-31 23:59
# 1     제주특별자치도 서귀포시 신서로48번길 20-9, 1층 (강정동)  63566.0   2020-05-14 2:40
# 2                제주특별자치도 서귀포시 남원읍 서성로 308  63608.0   2019-04-24 2:40
# 3               제주특별자치도 서귀포시 표선면 표선당포로 29  63629.0   2019-10-04 2:40
# 4      제주특별자치도 서귀포시 동홍중앙로66번길 22-10 (동홍동)  63587.0  2018-08-31 23:59
# ...                                   ...      ...               ...
# 3188         제주특별자치도 제주시 정원로 51, 1층 (노형동)  63089.0  2018-08-31 23:59
# 3189     제주특별자치도 제주시 국기로1길 2, 지하1~1층 (연동)  63139.0  2018-08-31 23:59
# 3190     제주특별자치도 제주시 애월읍 하귀9길 71, 1층 101호  63052.0  2018-08-31 23:59
# 3191             제주특별자치도 제주시 도령로 170 (연동)  63117.0  2018-08-31 23:59
# 3192  제주특별자치도 제주시 신설로2길 5-9, 지하 1층 (이도이동)  63227.0   2020-03-01 2:40
#
#      naver_map_url
# 0
# 1
# 2
# 3
# 4
# ...            ...
# 3188
# 3189
# 3190
# 3191
# 3192
#
# [3193 rows x 17 columns]

# %%
# df["사업장명add"]=df[['사업장명','도로명전체주소']].apply(' '.join, axis=1)

# %%
df["사업장명add"]=df['사업장명']+""+df['도로명전체주소'] #정정코드

# %%
df = df[['사업장명', '업종구분대분류', '업종구분소분류', '도로명전체주소', 'naver_map_url']]
df
# Out:
#                 사업장명 업종구분대분류   업종구분소분류                         소재지전체주소  \
# 0                파파야   일반음식점        기타  제주특별자치도 서귀포시 성산읍 성산리 230-22번지
# 1               청우식당   일반음식점        분식       제주특별자치도 서귀포시 강정동 165-7번지
# 2              이승악식당   일반음식점        한식  제주특별자치도 서귀포시 남원읍 신례리 2162-8번지
# 3              당포회센타   일반음식점        회집    제주특별자치도 서귀포시 표선면 표선리 45-6번지
# 4               할매곱창   일반음식점        한식       제주특별자치도 서귀포시 동홍동 472-1번지
# ...              ...     ...       ...                             ...
# 3188        쥬씨제주한라대점   휴게음식점       커피숍        제주특별자치도 제주시 노형동 755-2번지
# 3189  써브웨이신제주연동신시가지점   휴게음식점     패스트푸드          제주특별자치도 제주시 연동 1482번지
# 3190          서제니의시간   휴게음식점       커피숍   제주특별자치도 제주시 애월읍 하귀1리 166-1번지
# 3191           보리빵마을   휴게음식점  기타 휴게음식점        제주특별자치도 제주시 연동 2514-3번지
# 3192      씨유제주일중사거리점   휴게음식점  기타 휴게음식점     제주특별자치도 제주시 이도이동 1970-11번지
#
#      naver_map_url
# 0
# 1
# 2
# 3
# 4
# ...            ...
# 3188
# 3189
# 3190
# 3191
# 3192
#
# [3193 rows x 5 columns]

# %%
df = df[['사업장명',"사업장명add",'업종구분대분류', '업종구분소분류', '도로명전체주소', 'naver_map_url']  #정정코드

# %%
for i, keyword in enumerate(df['사업장명add'].tolist()):  #정정코드
    print("이번에 찾을 키워드 :", i, f"/ {df.shape[0]} 행",keyword)
    
    try:
        naver_map_search_url = f"https://map.naver.com/v5/search/{keyword}/place" # 검색 url 만들기
        driver.get(naver_map_search_url) # 검색 url 접속, 즉 검색하기
        
        time.sleep(2) # 중요함
        cu = driver.current_url # 검색이 성공된 플레이스에 대한 개별 페이지
        
        res_code = re.findall(r"place/(\d+)", cu)
        final_url = 'https://pcmap.place.naver.com/restaurant/'+res_code[0]+'/review/visitor#'
        
        print(final_url)
        df['naver_map_url'][i]=final_url
        
    except IndexError:
        df['naver_map_url'][i]= ''
        print('none')

# %%
for i, keyword in enumerate(df['사업장명'].tolist()):
    print("이번에 찾을 키워드 :", i, f"/ {df.shape[0]} 행",keyword)
    
    try:
        naver_map_search_url = f"https://map.naver.com/v5/search/제주&{keyword}/place" # 검색 url 만들기
        driver.get(naver_map_search_url) # 검색 url 접속, 즉 검색하기
        
        time.sleep(2) # 중요함
        cu = driver.current_url # 검색이 성공된 플레이스에 대한 개별 페이지
        
        res_code = re.findall(r"place/(\d+)", cu)
        final_url = 'https://pcmap.place.naver.com/restaurant/'+res_code[0]+'/review/visitor#'
        
        print(final_url)
        df['naver_map_url'][i]=final_url
        
    except IndexError:
        df['naver_map_url'][i]= ''
        print('none')

# %%
# df
df['naver_map_url'].replace('', np.nan, inplace=True)
# Out:
# C:\Users\ui\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
df = df.dropna(subset=['naver_map_url'])

# %%
df.to_csv('url_completed.csv', encoding = 'utf-8-sig')

# %%
df
# Out:
#       Unnamed: 0        사업장명 업종구분대분류   업종구분소분류  \
# 0              1         파파야   일반음식점        기타
# 1              2       당포회센타   일반음식점        회집
# 2              3     해민이네양곱창   일반음식점        한식
# 3              4       농부의밥상   일반음식점  식육(숯불구이)
# 4              5     팔미돈가2호점   일반음식점        한식
# ...          ...         ...     ...       ...
# 1607        1608         미소천   휴게음식점      전통찻집
# 1608        1609     플레이스626   휴게음식점  기타 휴게음식점
# 1609        1610     아띠마루커피랩   휴게음식점       커피숍
# 1610        1611   GS25연동국기점   휴게음식점       편의점
# 1611        1612  씨유제주일중사거리점   휴게음식점  기타 휴게음식점
#
#                              소재지전체주소  \
# 0     제주특별자치도 서귀포시 성산읍 성산리 230-22번지
# 1       제주특별자치도 서귀포시 표선면 표선리 45-6번지
# 2          제주특별자치도 서귀포시 법환동 737-3번지
# 3        제주특별자치도 서귀포시 성산읍 수산리 669-3
# 4       제주특별자치도 서귀포시 성산읍 난산리 2625-4
# ...                              ...
# 1607      제주특별자치도 제주시 일도이동 109-20번지
# 1608      제주특별자치도 제주시 구좌읍 평대리 626번지
# 1609      제주특별자치도 제주시 용담일동 2827-3번지
# 1610        제주특별자치도 제주시 연동 1503-4번지
# 1611     제주특별자치도 제주시 이도이동 1970-11번지
#
#                                           naver_map_url
# 0     https://pcmap.place.naver.com/restaurant/37890...
# 1     https://pcmap.place.naver.com/restaurant/14656...
# 2     https://pcmap.place.naver.com/restaurant/93708...
# 3     https://pcmap.place.naver.com/restaurant/11220...
# 4     https://pcmap.place.naver.com/restaurant/11366...
# ...                                                 ...
# 1607  https://pcmap.place.naver.com/restaurant/17949...
# 1608  https://pcmap.place.naver.com/restaurant/10636...
# 1609  https://pcmap.place.naver.com/restaurant/13496...
# 1610  https://pcmap.place.naver.com/restaurant/21759...
# 1611  https://pcmap.place.naver.com/restaurant/14569...
#
# [1612 rows x 6 columns]

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import time
import re

from bs4 import BeautifulSoup
from tqdm import tqdm

# 웹드라이버 접속
driver = webdriver.Chrome(executable_path='./chromedriver.exe')

df = pd.read_csv('url_completed.csv') #null값 처리 완료 데이터

# 수집할 정보들
rating_list = [] # 평점
user_review_id = {} # 유저의 id - 추천시스템에서는 필수
review_json = {} # 리뷰
image_json = {} # 이미지

# %%
# for i in range(len(df)):
    
#     print('======================================================')
#     print(str(i)+'번째 식당')
    
#     # 식당 리뷰 개별 url 접속
#     driver.get(df['naver_map_url'][i])
#     thisurl = df['naver_map_url'][i]
#     time.sleep(2)
#     # 더보기 버튼 다 누르기
#     # 더보기 버튼 누르기까지 10개
#     # 더보기 버튼 누르면 10개 추가됨
#     while True:
#         try:
#             time.sleep(2)
#             driver.find_element_by_tag_name('body').send_keys(Keys.END)
#             time.sleep(5)
#             driver.find_element_by_css_selector('#app-root > div > div.place_detail_wrapper > div:nth-child(5) > div:nth-child(4) > div:nth-child(4) > div._2kAri > a').click()
#             time.sleep(5)  -->이줄변경해야됨
#                    
#             driver.find_element_by_tag_name('body').send_keys(Keys.END)
#             time.sleep(2)
            
#         except NoSuchElementException:
#             print('-더보기 버튼 모두 클릭 완료-')
#             break

    
#     # 파싱
#     html = driver.page_source
#     soup = BeautifulSoup(html, 'lxml')
#     time.sleep(1)
    
#     # 식당 구분
#     restaurant_name = df['사업장명'][i]
#     print('식당 이름 : '+restaurant_name)
    
#     user_review_id[restaurant_name] = {}
#     review_json[restaurant_name] = {}
#     image_json[restaurant_name] = {}
    
#     try:
#         restaurant_classificaton = soup.find_all('span',attrs = {'class':'_3ocDE'})[0].text
#     except:
#         restaurant_classificaton = 'none'
#     print('식당 구분 : '+restaurant_classificaton)
#     print('----------------------------------------------')
    
#     try:
#         one_review = soup.find_all('div', attrs = {'class':'_1Z_GL'})
#         review_num = len(one_review) # 특정 식당의 리뷰 총 개수
#         print('리뷰 총 개수 : '+str(review_num))
    
#         # 리뷰 개수
#         for i in range(len(one_review)):
        
#             # user url
#             user_url = one_review[i].find('div', attrs = {'class':'_23Rml'}).find('a').get('href')
#             print('user_url = '+user_url)
            
#             # user url로부터 user code 뽑아내기
#             user_code = re.findall(r"my/(\w+)", user_url)[0]
#             print('user_code = '+user_code)
            
#             # review 1개에 대한 id 만들기 
#             res_code = re.findall(r"restaurant/(\d+)", thisurl)[0]
#             review_id = str(res_code)+"_"+user_code
#             print('review_id = '+review_id)
            
#             # rating, 별점
#             rating = one_review[i].find('span', attrs = {'class':'_2tObC'}).text
#             print('rating = '+rating)
            
#             # 주의!!! 사진 리뷰 유무에 따라 날짜 파싱코드 다름
#             # ('span', attrs = {'class':'_3WqoL'})
#             # 사진 없는 경우 : 총 6개 중 4번째
#             # 사진 있는 경우 : 총 5개 중 3번째
            
#             # date
#             # 사진 리뷰 없음
#             if len(one_review[i].find_all('span', attrs = {'class':'_3WqoL'})) == 5:
#                 date = one_review[i].find_all('span', attrs = {'class':'_3WqoL'})[2].text
#             elif len(one_review[i].find_all('span', attrs = {'class':'_3WqoL'})) == 6:
#                 date = one_review[i].find_all('span', attrs = {'class':'_3WqoL'})[3].text
#             else:
#                 date = ""
#             print('date = '+date)
            
#             # review 내용
#             try : 
#                 review_content = one_review[i].find('span', attrs = {'class':'WoYOw'}).text
#             except: # 리뷰가 없다면
#                 review_content = ""
#             print('리뷰 내용 : '+review_content)
            
            
#             # image 내용
#             sliced_soup = one_review[i].find('div', attrs = {'class':'_1aFEL _2GO1Q'})

#             if (sliced_soup != None):
#                 sliced_soup = sliced_soup.find('div',attrs={'class':'dRZ2X'})
                
#                 try:
#                     img_url = 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src='+re.findall(r'src=(.*jpeg)', str(sliced_soup))[0]
#                 except :
#                     if (len(re.findall(r'src=(.*jpg)', str(sliced_soup)))!= 0):
#                         img_url = 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src='+re.findall(r'src=(.*jpg)', str(sliced_soup))[0]
#                     elif (len(re.findall(r'src=(.*png)', str(sliced_soup)))!= 0):
#                         img_url = 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src='+re.findall(r'src=(.*png)', str(sliced_soup))[0]
#                     else :
#                         img_url = ""
#             else:
#                 img_url = ""
                
#             print('이미지 url : '+img_url)
#             print('----------------------------------------------')
#             print('\n')

            
#             #리뷰정보
#             # user_review_id
#             user_review_id[restaurant_name][user_code] = review_id
            
#             # review_json
#             review_json[restaurant_name][review_id] = review_content
            
#             # image_json
#             image_json[restaurant_name][review_id] = img_url
            
#             # rating_df_list
#             naver_review = user_code, restaurant_name, rating, date
#             rating_list.append(naver_review)
            
            
    
    
#     except NoSuchElementException:
#             none_review = "네이버 리뷰 없음"
#             print(none_review)
#             review_num = 0
#             #리뷰정보 = restaurant_name, restaurant_classification, review_num, none_review
            
#             # rating_df_list
#             naver_review = user_code, restaurant_name, none_review, none_reivew
#             rating_list.append(naver_review)
            
            
#     print('\n')
# Out:
# ======================================================
# 0번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 파파야
# 식당 구분 : 햄버거
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5c7e8d37de390a6fed96c1e8/review
# user_code = 5c7e8d37de390a6fed96c1e8
# review_id = 37890576_5c7e8d37de390a6fed96c1e8
# rating = 5
# date = 2021.09.26
# 리뷰 내용 : 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5fdf23953ff5de346d0d0354/review
# user_code = 5fdf23953ff5de346d0d0354
# review_id = 37890576_5fdf23953ff5de346d0d0354
# rating = 5
# date = 2021.09.26
# 리뷰 내용 : 친절하고 음식이 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5de34c079ec8258e4a4848eb/review
# user_code = 5de34c079ec8258e4a4848eb
# review_id = 37890576_5de34c079ec8258e4a4848eb
# rating = 3
# date = 2021.08.17
# 리뷰 내용 : 사장님 사모님 친절하세요~
# 맛은 있지만 말고기수제버거는 살짝 패티에서 다른 이질적인 느낌?을 느낄 수 있었고 호불호는 있을고 같아요 흑돼지수제버거는 역시 맛있어요 ㅋㅋ 근데 일반 수제버거집에서 파는것하고 크게 다른점은 모르겠어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c4c5105676f45604bdecf18/review
# user_code = 5c4c5105676f45604bdecf18
# review_id = 37890576_5c4c5105676f45604bdecf18
# rating = 5
# date = 2021.08.08
# 리뷰 내용 : 굿
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f055b47d55dbc0b18086020/review
# user_code = 5f055b47d55dbc0b18086020
# review_id = 37890576_5f055b47d55dbc0b18086020
# rating = 5
# date = 2021.07.09
# 리뷰 내용 : G
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/60a6dea8068c35a9c8e1546d/review
# user_code = 60a6dea8068c35a9c8e1546d
# review_id = 37890576_60a6dea8068c35a9c8e1546d
# rating = 5
# date = 2021.07.04
# 리뷰 내용 : 양도 많고 맛있었어요 추천해요👍👍
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f222af69ec8258e4a816a02/review
# user_code = 5f222af69ec8258e4a816a02
# review_id = 37890576_5f222af69ec8258e4a816a02
# rating = 5
# date = 2021.06.20
# 리뷰 내용 : 사장님 너무 유쾌하시고 친절합니다.
# 말고기버거도 너무 맛있네요.
# 옆에 첨보는 사람이랑 합석해서 밥 같이 먹었는데 사장님이 유쾌한 덕분입니다. 번창하세요!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d189459ab9fa26e000c92c9/review
# user_code = 5d189459ab9fa26e000c92c9
# review_id = 37890576_5d189459ab9fa26e000c92c9
# rating = 5
# date =
# 리뷰 내용 : 말고기버거라길래 특이해서 먹으러갔는데 특이하고 맛있었고 무엇보다 친절하고 경험담 얘기해주시면서 해주신 조언이 너무 좋았어요! 좋은 기운 받고 2학년땐 주전 되서 다시 찾아오겠습니다!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210617_9%2F1623923023452Xq62J_JPEG%2Fupload_6570916e33508e437ab81b52abbc5bb0.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c64a901642bbfcc4a1fd9bb/review
# user_code = 5c64a901642bbfcc4a1fd9bb
# review_id = 37890576_5c64a901642bbfcc4a1fd9bb
# rating = 5
# date = 2021.05.16
# 리뷰 내용 : 말고기! 제주도 오면 꼭 먹어봐야지 했는데 사실 말고기라는게 흔하지 않잖아요 그래서 육회나 사시미에 도전하기는 조금 거부감이 들
# 어서 버거 먹었는데 소고기 맛이 나더라고요 맛있었어요! 사장님이 정말 정말 친절하고 호탕하세요 덕분에 재밌는 얘기도 많이 하고 제
# 주도에서 새로운 인연을 만나서 기뻐요. 다음에 또 올게요 !
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210516_14%2F1621141766288PXV3z_JPEG%2Fupload_cdb06f0a9268e15794c70fcae901e10e.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e7714608f87a842bc0d1aa8/review
# user_code = 5e7714608f87a842bc0d1aa8
# review_id = 37890576_5e7714608f87a842bc0d1aa8
# rating = 5
# date = 2021.04.23
# 리뷰 내용 : 버거 좋아해서 갔다가 이왕 제주온거 말고기 세트로 시켰는데 정말 맛있게 잘먹었어요. 처음 먹어보는건데 사시미 육회 다 신선해서 전
# 혀 안비리고 잘먹었어요. 그리고 가장 중요한 버거자체가 맛있어요. 패티도 소스도.  순식간에 먹었습니다.   그리고 혼자 갔는데도 사장
# 님 내외 두분 다 정말 친절하셨어요.  제주도 왔을때 관광지 식당이 아닌 휴양지 식당을 원한다면 여기는 꼭 가세요!!  맛도 분위...
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210423_58%2F1619180607867lsB1i_JPEG%2Fupload_33250d0edc6c7ac0cd5ed62f0f90ea19.jpeg
# ----------------------------------------------
#
#
#
#
# ======================================================
# 1번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 당포회센타
# 식당 구분 : 생선회
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5f062d93649bf957592e205b/review
# user_code = 5f062d93649bf957592e205b
# review_id = 1465642893_5f062d93649bf957592e205b
# rating = 5
# date = 2021.09.02
# 리뷰 내용 : ㆍ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c458e833cd80d3d7fc635b3/review
# user_code = 5c458e833cd80d3d7fc635b3
# review_id = 1465642893_5c458e833cd80d3d7fc635b3
# rating = 5
# date = 2021.07.31
# 리뷰 내용 : 숙소에서 먹으려고 회정식 2개 포장했습니다. 회가 정말 신선하고 감칠맛이 너무 좋았음!!  함께 포함된 전복, 한치, 키조개, 새우, 소라..
#   정말 모두 너무 맛있었네요. 완전 강추합니다!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d970d9b8f87a842bc57535c/review
# user_code = 5d970d9b8f87a842bc57535c
# review_id = 1465642893_5d970d9b8f87a842bc57535c
# rating = 5
# date = 2021.07.28
# 리뷰 내용 : 사장님이 너무 친절하시고 제철이라고 처음 먹어본 벤자리 너무 맛있었어요.
# 배부르게 잘 먹고 여름 야외 자리도 너무 시원하고 좋네요. 술 보통 묵는데 분위기에 취해 둘이서 한라산 3병시킨 넘 좋은곳♡
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210728_260%2F1627479001780VpSlY_JPEG%2Fupload_d90d3b6c6704ef9953d42afeeea7ff41.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dc8e4e08f87a842bc6d7b58/review
# user_code = 5dc8e4e08f87a842bc6d7b58
# review_id = 1465642893_5dc8e4e08f87a842bc6d7b58
# rating = 4
# date = 2021.07.18
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f13accc9ec8258e4aefcb95/review
# user_code = 5f13accc9ec8258e4aefcb95
# review_id = 1465642893_5f13accc9ec8258e4aefcb95
# rating = 3
# date = 2021.07.14
# 리뷰 내용 : 표선 2대천왕집만 가다가 리뷰가 좋길래 혹시나 하고 가봤는데 그냥저냥 좀 아쉽네요🤔역시 가던집 가던게 정답인것 같네요😓
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f87f819e0380a6d24450588/review
# user_code = 5f87f819e0380a6d24450588
# review_id = 1465642893_5f87f819e0380a6d24450588
# rating = 5
# date = 2021.07.01
# 리뷰 내용 : 회도 푸짐하게 잘나오고 기분좋게 먹고갑니다~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f92fb00985fec882eaa87a8/review
# user_code = 5f92fb00985fec882eaa87a8
# review_id = 1465642893_5f92fb00985fec882eaa87a8
# rating = 5
# date = 2021.07.01
# 리뷰 내용 : 신선한 회에 소주한잔~
# 넘 좋았어요~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e4015fb8f87a842bc7861ab/review
# user_code = 5e4015fb8f87a842bc7861ab
# review_id = 1465642893_5e4015fb8f87a842bc7861ab
# rating = 5
# date = 2021.06.30
# 리뷰 내용 : 친절하고 아주 좋아요! 완전 신선하고 깔끔합니다 ㅎㅎ
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210630_296%2F16250175250412tko3_JPEG%2Fupload_e0dfc7b740098ae6dbb9986d205de256.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5fa244692d9d68a584d3f9c1/review
# user_code = 5fa244692d9d68a584d3f9c1
# review_id = 1465642893_5fa244692d9d68a584d3f9c1
# rating = 5
# date = 2021.06.29
# 리뷰 내용 : 포장해갔는데 정말 꼼꼼히 잘 포장해주셨어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c00e09f79958e24336e846f/review
# user_code = 5c00e09f79958e24336e846f
# review_id = 1465642893_5c00e09f79958e24336e846f
# rating = 5
# date = 2021.06.29
# 리뷰 내용 : 회 정말 신선하고 스끼다시도 잘 나와서
# 하나씩 먹는 재미 좋아!
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 2번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 해민이네양곱창
# 식당 구분 : 곱창,막창,양
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5c8b9c0064b6dc727ccd665e/review
# user_code = 5c8b9c0064b6dc727ccd665e
# review_id = 93708698_5c8b9c0064b6dc727ccd665e
# rating = 5
# date = 2021.09.15
# 리뷰 내용 : 곱창이 부드럽고 고소하네요. 소스도 맛있고 모든메뉴가 맘에듭니다~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ba0ad206d1eab53281ea060/review
# user_code = 5ba0ad206d1eab53281ea060
# review_id = 93708698_5ba0ad206d1eab53281ea060
# rating = 5
# date = 2021.09.08
# 리뷰 내용 : 맛나요ㅎ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d6b7c068f87a842bca95482/review
# user_code = 5d6b7c068f87a842bca95482
# review_id = 93708698_5d6b7c068f87a842bca95482
# rating = 4
# date = 2021.08.10
# 리뷰 내용 : 굿
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d1b3556e856d8df70477439/review
# user_code = 5d1b3556e856d8df70477439
# review_id = 93708698_5d1b3556e856d8df70477439
# rating = 5
# date = 2021.07.15
# 리뷰 내용 : 굿
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c8cd722cb5b9cde5504a97d/review
# user_code = 5c8cd722cb5b9cde5504a97d
# review_id = 93708698_5c8cd722cb5b9cde5504a97d
# rating = 4.5
# date = 2021.06.22
# 리뷰 내용 : 친절하고 맛있어요.
# 근데 양이 좀 작아서 아쉽네요 ㅠㅠ
# 신시가지 양곱창은 여기네요 ㅋ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5cc6c9538f87a842bc257e1b/review
# user_code = 5cc6c9538f87a842bc257e1b
# review_id = 93708698_5cc6c9538f87a842bc257e1b
# rating = 4.5
# date = 2021.05.23
# 리뷰 내용 : 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dc539cb8f87a842bce2c940/review
# user_code = 5dc539cb8f87a842bce2c940
# review_id = 93708698_5dc539cb8f87a842bce2c940
# rating = 4
# date = 2021.05.16
# 리뷰 내용 : 양이너무 적어요 곱창전골은 굿입니다
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c23893a17dd427a35728126/review
# user_code = 5c23893a17dd427a35728126
# review_id = 93708698_5c23893a17dd427a35728126
# rating = 5
# date = 2021.04.03
# 리뷰 내용 : 너무 너무 맛있어욘ㅋㅋ 굳굳
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c60cf9e78b827c6e048a2d7/review
# user_code = 5c60cf9e78b827c6e048a2d7
# review_id = 93708698_5c60cf9e78b827c6e048a2d7
# rating = 5
# date = 2021.03.28
# 리뷰 내용 : 누구시키지않고 직접 구워주기 때문에 가족들이랑 왔을때 대화를 할수 있어 좋음  고기를 직접구워줍니다 대단합니다
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210328_265%2F1616911877080WSkHa_JPEG%2Fupload_0722e9cf683bbfb1f40891cae0d95bc5.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dd8af5c9ec8258e4aae81a0/review
# user_code = 5dd8af5c9ec8258e4aae81a0
# review_id = 93708698_5dd8af5c9ec8258e4aae81a0
# rating = 5
# date = 2021.03.14
# 리뷰 내용 : 한방전기구이 통닭  생매주와 딱이예요!!!!!!
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 3번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 농부의밥상
# 식당 구분 : 백반,가정식
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5c8e48f8bba64faa3e240e95/review
# user_code = 5c8e48f8bba64faa3e240e95
# review_id = 1122024164_5c8e48f8bba64faa3e240e95
# rating = 5
# date = 2021.10.06
# 리뷰 내용 : 이동네 아저씨들 핫플레이스
# 옥돔구이 크기는 작아보이나 통통하고 쵹쵹
# 전문점 옥돔구이보다 맛있어서 놀람....
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211006_273%2F16334924229706xCrh_JPEG%2Fupload_b8bfefad7a83e7c18f681566e02ffd2c.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e041c138f87a842bcaee156/review
# user_code = 5e041c138f87a842bcaee156
# review_id = 1122024164_5e041c138f87a842bcaee156
# rating = 5
# date = 2021.10.06
# 리뷰 내용 : 진짜 기분좋은 맛집! 된장찌개 제육 밑반찬 1인 1옥돔구이까지 8000원만 결제하기 미안해지는곳 사장님도 친절하시고 꼭 다시올밥집~
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211006_195%2F1633492154326B0BpR_JPEG%2Fupload_1e5e0bea2640dcfde520a6a6681bca2d.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b6d4ab282dfabae319f3c19/review
# user_code = 5b6d4ab282dfabae319f3c19
# review_id = 1122024164_5b6d4ab282dfabae319f3c19
# rating = 5
# date = 2021.10.03
# 리뷰 내용 : 지나가다가 드른 맛집입니다..  반찬이 너무 정갈하고 맛있어요  된장찌개, 제육 ,, 이백반이 8000원이라니 믿을 수 없습니다 ㅠㅠㅠ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e2cda308f87a842bc60d96b/review
# user_code = 5e2cda308f87a842bc60d96b
# review_id = 1122024164_5e2cda308f87a842bc60d96b
# rating = 5
# date = 2021.10.01
# 리뷰 내용 : 친절하고 맛도 있고 푸짐해요.
# 제주에 와서 제일 기분좋게 먹은 식당입니다.
# 진짜 집밥 먹는 기분
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b82fdd974d1ad87a900ada2/review
# user_code = 5b82fdd974d1ad87a900ada2
# review_id = 1122024164_5b82fdd974d1ad87a900ada2
# rating = 5
# date = 2021.09.07
# 리뷰 내용 : 성산일출봉 보고 우연히 들른 밥집에서 옥돔정식 먹었습니다.  제육볶음 해물된장찌개 쌈채소 옥돔구이 밑반찬까지 정말 하나하나 맛
# 있는 밥집 입니다. 무엇보다 밥이 찰지고 좋았어요~!! 밥을 먹으면서 생각 했습니다. 맛있다...  제주에 자주 오지만 이 곳에서의 한끼는
# 무조껀 들러가야 겠네요. 리뷰보시면 꼭 가세요! 열번 가세요!! 내돈내산 찐 리뷰 입니다.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5deb65019ec8258e4ade9087/review
# user_code = 5deb65019ec8258e4ade9087
# review_id = 1122024164_5deb65019ec8258e4ade9087
# rating = 5
# date = 2021.09.06
# 리뷰 내용 : 여행 중 찾은 편안히 식사할 수 있는 너무 좋은 곳이예요! 반찬 하나하나, 제육볶음, 찌개, 생선까지 다 맛있어서 완전 대만족하고 나왔어요😊
# 가격까지 너무 착해서 추천추천이요! 사장님 진짜로 적게일하고 많이버세요😭😭 다음 제주야행 때도 또 들릴게요!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210908_260%2F1631062982951yx1em_JPEG%2Fupload_8378b05e6273be1fda831b434507aa3b.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b9b73b3edd0d602ec5cd059/review
# user_code = 5b9b73b3edd0d602ec5cd059
# review_id = 1122024164_5b9b73b3edd0d602ec5cd059
# rating = 5
# date = 2021.09.04
# 리뷰 내용 : 주차장에 허, 호, 하 번호판 없어요. 관광객 거의 없는 레알 현지인 맛집입니다. 옥돔정식 점심에 먹고 하루종일 든든하게 여행다녔습니다. 주인분께서도 정말 친절하십니다. 밥도 푸짐하게 많이 주셔서 다 못먹고 남겼는데, 주인분께서 신경 많이 써주셨습니다. 제주도 동쪽 가게되면 무조건 가야하는 현지인식당입니다.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d3ad71fea9ddf5d32712389/review
# user_code = 5d3ad71fea9ddf5d32712389
# review_id = 1122024164_5d3ad71fea9ddf5d32712389
# rating = 5
# date = 2021.09.04
# 리뷰 내용 : 우연히 숙소근처라 점심을 먹으러 갔던 곳입니다.
# 제주도 여행 4일 중 기억에 남는 식당이었어요.
# 반찬도 깔끔하고 옥돔한마리씩 나오는데 가격이 정말 착해요! 강추해요~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b8a85edd70df334622032a0/review
# user_code = 5b8a85edd70df334622032a0
# review_id = 1122024164_5b8a85edd70df334622032a0
# rating = 5
# date = 2021.09.04
# 리뷰 내용 : 빛의 벙커 가는 길에 들린 식당인데, 넘 맛있어요. 8000원 옥돔정식 백반인데 옥돔+흑돼지두루치기+해물된장뚝배기까지 나오는 미친 가성비 맛집. 가성비만 좋은게 아니고 맛도 있음..솔직히 제주시에서 인당 2만원 주고 먹은 옥돔정식보다 나았음.된장찌개에 꽃게랑 전복도 들음..남편 밥 두그릇먹음..보통 식당 현금선호라 현금드렸더니, 카드가 더 좋다고 하심ㅋㅋ편하게 카드로 계산하고 옴..
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e4403128f87a842bc590ab2/review
# user_code = 5e4403128f87a842bc590ab2
# review_id = 1122024164_5e4403128f87a842bc590ab2
# rating = 5
# date = 2021.09.04
# 리뷰 내용 : 제주 한달살이 중 숙소 근처에서 발견한 찐로컬맛집! 👍 제주의 핫한 맛집에 미각과 지갑이 지쳤을 때 위로해주는 식당이랄까. 8천원 정식에 옥돔구이, 해물탕 마냥 푸짐한 된장찌개, 제육에 아침에 따님께서 직접 잡아오신 갈치까지! 나만 알고싶지만 소문내고 싶은 그런 곳. 강력크 추천!!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210904_131%2F1630728978681SxIiW_JPEG%2Fupload_d186c3a49b32ae4f7b182cbe9f5bc3eb.jpg
# ----------------------------------------------
#
#
#
#
# ======================================================
# 4번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 팔미돈가2호점
# 식당 구분 : 육류,고기요리
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/6145ca2775b192c608bf9a97/review
# user_code = 6145ca2775b192c608bf9a97
# review_id = 1136661174_6145ca2775b192c608bf9a97
# rating = 5
# date = 2021.09.18
# 리뷰 내용 : 고기를 삽겹살이랑 목살 먹었는데 삼겹살이 완전 다ㅁ백하고 맛있었고 목살도 부드럽고 굉장히 맛있었습니다 양도 많고 계란찜이 정말 부드럽고 된장찌개도 완전 추천드립니다. 반찬 양도 그렇고 맛도 정말 맛있었습니다.
# 제주도 와서 여기 온걸 정말 감사하게 생각하고 있습니다 든든하게 먹고 갑니당
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210918_133%2F1631969526811Xs4Qb_JPEG%2Fupload_4f6c784f9527e852219b10f5099438e4.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e27e2578f87a842bca392f7/review
# user_code = 5e27e2578f87a842bca392f7
# review_id = 1136661174_5e27e2578f87a842bca392f7
# rating = 5
# date = 2021.09.09
# 리뷰 내용 : 제주여행왔다가 저녁식사 맛있게하고가요!
# 파절이랑 쌈 세번이나 리필했네요ㅎㅎ
# 인테리어도 멋지고 깨끗해서 좋네요~ 사장님도 넘친절하셔요😄
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c00c5021eb04a017485661e/review
# user_code = 5c00c5021eb04a017485661e
# review_id = 1136661174_5c00c5021eb04a017485661e
# rating = 5
# date = 2021.09.07
# 리뷰 내용 : 사진을 못찍을 만큼 맛있게 먹었습니다 :) 아가들 데리고 같이 가서 먹었고, 깨끗하고 좋았습니다. 된장찌개 안맵게 부탁해서 아가들 냠냠 밥까지 두그릇 먹었습니다^^* 감사히 잘 먹었습니다~~~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f5f56f86c3d7f73344e372b/review
# user_code = 5f5f56f86c3d7f73344e372b
# review_id = 1136661174_5f5f56f86c3d7f73344e372b
# rating = 5
# date = 2021.09.07
# 리뷰 내용 : 진짜 너무 좋아요 ㅎㅎㅎ 사장님 직원분들 다 친절하시고 고기도 너무 맛있게 잘먹고 좋은 추억 만들고 갑니다:)ㅎㅎ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5da27db78f87a842bc8588c5/review
# user_code = 5da27db78f87a842bc8588c5
# review_id = 1136661174_5da27db78f87a842bc8588c5
# rating = 5
# date = 2021.09.06
# 리뷰 내용 : 고기 맛이 아주 좋고 가게분들도 아주 친절하고 좋아요!! 강추!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ccfb564c76ca8f27c5684a9/review
# user_code = 5ccfb564c76ca8f27c5684a9
# review_id = 1136661174_5ccfb564c76ca8f27c5684a9
# rating = 5
# date = 2021.09.05
# 리뷰 내용 : 너무너무 맛있습니다 서비스로 고기 한 덩이도 더 주시고  택시가 안 잡혀서 데려다 주시기까지 하셨어요 너무너무 감사합니다 다음에도 제주도 오면 먹으러 올 것 같아요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210905_39%2F1630843741069isoGJ_JPEG%2Fupload_e0957d9c6c654cdfb12a62863c4b7c8b.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f062afa05022b66f96344b6/review
# user_code = 5f062afa05022b66f96344b6
# review_id = 1136661174_5f062afa05022b66f96344b6
# rating = 5
# date = 2021.09.05
# 리뷰 내용 : 사비스 마인드가 최곱니다 다음에 꼭 다시 갈게요 감사합니다
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5efdf5ce0765f4dd1bac0a91/review
# user_code = 5efdf5ce0765f4dd1bac0a91
# review_id = 1136661174_5efdf5ce0765f4dd1bac0a91
# rating = 5
# date = 2021.09.01
# 리뷰 내용 : 스누피 가든에서 놀고 돌아가는길에 팔미돈가 2호점이 근처에 있다고 해서 들렀습니다. 고기가 진짜 쫄깃쫄깃하고 정말맛있어요 계란찜 된장찌개 사이드메뉴도 훌륭합니다 최고최고 직원분들도 넘 친절하시고ㅎㅎㅎ 배부르게 먹고가요ㅎㅎ
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210901_32%2F1630490439825t6sup_JPEG%2Fupload_b8eabf99e1e79f28e8b8f5406d9b23dd.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d906dd18f87a842bc021dc7/review
# user_code = 5d906dd18f87a842bc021dc7
# review_id = 1136661174_5d906dd18f87a842bc021dc7
# rating = 5
# date = 2021.08.28
# 리뷰 내용 : 흑돼지 오겹살이랑 목살 쫄깃하고 맛있고
# 가게바깥으로 보이는 풍경도 좋아요
# 초벌구이해주셔서 배고플때 빨리먹을수있다는점!!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210828_26%2F1630144052972YPbWG_JPEG%2Fupload_b216494569bb430da2151db24ac0b945.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f06c1e57a37f6ff5498c557/review
# user_code = 5f06c1e57a37f6ff5498c557
# review_id = 1136661174_5f06c1e57a37f6ff5498c557
# rating = 5
# date = 2021.08.26
# 리뷰 내용 : 지금까지 먹은 흑돼지 중에 제일맛있게 잘먹었어용 그리구 너무 친절해서 좋았습니다 제주도 오면 또 들릴게용 번창하세여~😀😀
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210826_198%2F1629982323755sckE9_JPEG%2Fupload_06e372c97cdbe5bbd109969d78af9487.jpeg
# ----------------------------------------------
#
#
#
#
# ======================================================
# 5번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 키다리네
# 식당 구분 : 와인
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5ea8e6ff8f87a842bc351efb/review
# user_code = 5ea8e6ff8f87a842bc351efb
# review_id = 1636682834_5ea8e6ff8f87a842bc351efb
# rating = 5
# date = 2021.08.01
# 리뷰 내용 : 사장님이 너무 친철하시고, 분위기도 좋습니다. 저는 알쓰라 와인바에 어울리지 않는 사람인데 아이스 뱅쇼 정말 엄지척!! 알콜 맛은 거
# 의 안 느껴지는데 달달하고 정말 맛있습니다 ㅜㅜ 같이 간 친구는 글라스 와인 시켰는데 와인도 맛있었어요. 요리들도 맛있어서 배부른
# 데 거의 다 먹고 나왔네요.. ☞☜ 제주 오면 다시 또 오고 싶은 곳입니다. 동네도 아담하니 조용하고 좋아요 :)
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c6e43e78595300f582ee6bd/review
# user_code = 5c6e43e78595300f582ee6bd
# review_id = 1636682834_5c6e43e78595300f582ee6bd
# rating = 5
# date = 2021.07.16
# 리뷰 내용 : 와인 추천도 너무 맛있었고
# 남은 음식 포장해주신것도 너무 감사합니다 !!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210717_221%2F16264888649300xRaz_JPEG%2Fupload_6c0725b26e36d963d08ac0aeecd77046.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e0f2ed88f87a842bc82c6de/review
# user_code = 5e0f2ed88f87a842bc82c6de
# review_id = 1636682834_5e0f2ed88f87a842bc82c6de
# rating = 5
# date = 2021.06.30
# 리뷰 내용 : 잘 먹고 갑니다 ☺️☺️❤️
# 감바스 짱짱!!!!!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b7be2fd46e02b8d1021b99d/review
# user_code = 5b7be2fd46e02b8d1021b99d
# review_id = 1636682834_5b7be2fd46e02b8d1021b99d
# rating = 5
# date = 2021.06.27
# 리뷰 내용 : 존맛탱! 강추합니다~~~~ 사장님이 하신 파스타 정말 맛있어여ㅠㅠㅠ 분위기도 좋아용 굿굿굿 아 제일 중요한건 가격이 너무 싸요ㅠㅠㅠ 이가격에 이 퀄리티 말이 안돼요~~~ 사장님 번창하세요ㅠㅠ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ce76350834b3325874695ee/review
# user_code = 5ce76350834b3325874695ee
# review_id = 1636682834_5ce76350834b3325874695ee
# rating = 5
# date = 2021.05.12
# 리뷰 내용 : 두번째 방문이에요, 처음에도 화순에 이렇게 숨겨진 곳이 있다는것에 놀랐어요^^ 근데 사장님이 와인 설명도 잘 해주시고, 저렴하게 가
# 성비 좋은 와인을 먹을수 있어서 좋았어요~~ 재방문 의사 있습니다!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210514_212%2F1620985213762a6y3x_JPEG%2Fupload_e991f493d313f6af144f6e8fff63a9d5.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ec8dc6b8f87a842bc6ea5ae/review
# user_code = 5ec8dc6b8f87a842bc6ea5ae
# review_id = 1636682834_5ec8dc6b8f87a842bc6ea5ae
# rating = 5
# date = 2021.03.02
# 리뷰 내용 : 너무나 친절하신 사장님 장사치가 아닌 손님을 생각하는곳 다음에 근처 가면 또 방문할게요 세상 스윗👍사장님 저 모임하는곳 여자 10
# 0명 넘는 단톡방이랑 지인들 한테 여기 얘기했어요 저만 알고 싶지만ㅋ 흠..너무 인기 많은 가게가 되면 안되는데..💦 가게사진 좀 찍을
# 걸 음식 사진만 찍었네요😁 리뷰 쓸 생각 없이 간거 였는데 좋은곳을 알게 되어 끄적이고 갑니다 다음에 가도 변하지 않았길 바...
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210303_249%2F1614751927379Po82l_JPEG%2Fupload_d9143ad988c61d6057d66a6fd898432f.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b778d866baa182faa866f30/review
# user_code = 5b778d866baa182faa866f30
# review_id = 1636682834_5b778d866baa182faa866f30
# rating = 5
# date = 2021.02.20
# 리뷰 내용 : 이런 감성 와인 맛집이 숨어 있었다니요!  가격. 맛. 분위기 모두 최고예요. 제주에 올 때마다 들려야할 맛집. 혼자만 알고 있고 싶은 집이지만 다시 제주갔을때 사라지지않기 위해 공개합니다.
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210220_144%2F1613829462633lMlYV_JPEG%2Fupload_1daec529bb1d1d83d1497fac86812def.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5eb6e3198f87a842bcdaa37a/review
# user_code = 5eb6e3198f87a842bcdaa37a
# review_id = 1636682834_5eb6e3198f87a842bcdaa37a
# rating = 5
# date = 2020.12.15
# 리뷰 내용 : 와인을 좀 알고 먹고 싶었는데 잘 모르는 초보 와린이에게 잘 설명해주시는 친절한 사장님  ㅎㅎㅎㅎㅎ
# 안주도 저렴한 가격에 너무 맛이써여 피자랑 감바스랑 견과류 꿀에 절인거,,,,짱 츄천1😍
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20201215_245%2F1608036812014ur2D9_JPEG%2Fupload_7605cead408f96d165adbf81a0085f9a.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c486db669c62c29927752ae/review
# user_code = 5c486db669c62c29927752ae
# review_id = 1636682834_5c486db669c62c29927752ae
# rating = 5
# date = 2020.11.27
# 리뷰 내용 : 사장님 완전 친절하고 가격도 착하고 완전강추👍🏻👍🏻👍🏻👍🏻👍🏻👍🏻👍🏻
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5efc176e8f87a842bcdce000/review
# user_code = 5efc176e8f87a842bcdce000
# review_id = 1636682834_5efc176e8f87a842bcdce000
# rating = 5
# date = 2020.09.12
# 리뷰 내용 : 조용한 시골길에 숨겨저 있는 반전 매력 🥰 처음에 길이 어두워서 없는줄 알고 돌아갈뻔했는데, 놓쳤으면 큰일날 뻔했어요^^ 사장님도
# 너무 친절하시고, 와인도 맛있고, 안주도 와인에 딱입니다. 다음날 또 가려고 했는데 일정이 갑자기 생겨서 못 갔지만, 진짜 강.추. 근처
# 에 술 마실데 찾고 계시다면 여기 무조건 방문하세요!
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 6번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 소랑밥상
# 식당 구분 : 한식
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5c28ca8b3a6a81cebb038e45/review
# user_code = 5c28ca8b3a6a81cebb038e45
# review_id = 38591445_5c28ca8b3a6a81cebb038e45
# rating = 4.5
# date = 2021.10.07
# 리뷰 내용 : 올레길 가는 중에 즉흥으로 들른 가게인데, 집밥 느낌으로 든든하게 잘 먹었습니다😆 주인분도 인심이 좋으세요,  딱새우 된장찌개 완
# 전 맛있습니다! 제주도 토속음식만 먹다가 일상적인 음식 그리울때 먹어도 좋을 것 같아요.
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211007_129%2F1633604548955ohnXe_JPEG%2Fupload_3c374abed18e41ada58f9c12d71a76e0.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b9b33b9d551b9e3094f595f/review
# user_code = 5b9b33b9d551b9e3094f595f
# review_id = 38591445_5b9b33b9d551b9e3094f595f
# rating = 5
# date = 2021.10.05
# 리뷰 내용 : 문 연 곳 찾아서 들어간건데, 음식이 참 맛있었어요. 아주머니도 친절하시고… 이런 집밥이 그리웠어요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211005_217%2F1633434349542TtTwG_JPEG%2Fupload_05edbfc28a9cce594fc7ecef06795446.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e2e5e028f87a842bcb0ac40/review
# user_code = 5e2e5e028f87a842bcb0ac40
# review_id = 38591445_5e2e5e028f87a842bcb0ac40
# rating = 5
# date = 2021.09.14
# 리뷰 내용 : 맛있는 집밥 잘먹었습니다
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210914_5%2F16315881935241gRKB_JPEG%2Fupload_e74bd21b287dcb908d7a141f0c665705.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dc7775a8f87a842bc1068d4/review
# user_code = 5dc7775a8f87a842bc1068d4
# review_id = 38591445_5dc7775a8f87a842bc1068d4
# rating = 5
# date = 2021.09.03
# 리뷰 내용 : 여기야말로 제주도 넘버원 맛집입니다 집밥처럼 깔끔하고 재료가 신선, 밑반찬까지 올클리어하고 나왔습니다 딱새우된장찌개가 일품이고 찐찐맛집 제주갈때마다 갈겁니다
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210925_130%2F1632563427355T8lEy_JPEG%2Fupload_1985d4eb15ccc37f56c0f232840b13bd.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e002cdb8f87a842bc93bd9d/review
# user_code = 5e002cdb8f87a842bc93bd9d
# review_id = 38591445_5e002cdb8f87a842bc93bd9d
# rating = 5
# date = 2021.08.22
# 리뷰 내용 : ^^
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c527c84970827261de99c30/review
# user_code = 5c527c84970827261de99c30
# review_id = 38591445_5c527c84970827261de99c30
# rating = 5
# date = 2021.08.10
# 리뷰 내용 : 집밥 느낌. 든든한 한끼.
# 거를 타선 없는 반찬과 메뉴.
# 친절.
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210810_27%2F1628589581418QOOrP_JPEG%2Fupload_fb421c1ee11cff88b3dec4dec9dc34fd.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5eafc1148f87a842bc881503/review
# user_code = 5eafc1148f87a842bc881503
# review_id = 38591445_5eafc1148f87a842bc881503
# rating = 5
# date = 2021.07.26
# 리뷰 내용 : 친절하고 맛있습니다. 2인세트 먹었는데 돼지숯불고기, 된장찌개 모두 맛있었어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b7bf51c2d13c6854d65d3fd/review
# user_code = 5b7bf51c2d13c6854d65d3fd
# review_id = 38591445_5b7bf51c2d13c6854d65d3fd
# rating = 5
# date = 2021.07.20
# 리뷰 내용 : 여행중 집밥이 그리울 때 딱!  딱새우된장, 차돌된장 흑돼지 불고기, 부침개 다 맛있었어요. 반찬들도 어느하나 빠짐없이 다 맛있다는.. 가족모두 만족!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210721_225%2F162683606878672Bs2_JPEG%2Fupload_f99e92f9ed23cc131292b2681804ea68.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/60d6e39e230abf0ab2c828c1/review
# user_code = 60d6e39e230abf0ab2c828c1
# review_id = 38591445_60d6e39e230abf0ab2c828c1
# rating = 5
# date = 2021.07.04
# 리뷰 내용 : ,
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5be98ebc270908db6c800b6d/review
# user_code = 5be98ebc270908db6c800b6d
# review_id = 38591445_5be98ebc270908db6c800b6d
# rating = 4.5
# date = 2021.06.23
# 리뷰 내용 : 맛있어요~
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 7번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 상효올레집
# 식당 구분 : 순대,순댓국
# ----------------------------------------------
# 리뷰 총 개수 : 2
# user_url = https://m.place.naver.com/my/5dc76eac8f87a842bce27af2/review
# user_code = 5dc76eac8f87a842bce27af2
# review_id = 582599548_5dc76eac8f87a842bce27af2
# rating = 5
# date = 2021.09.29
# 리뷰 내용 : 순대국밥 정말 맛있습니다
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f1665549ec8258e4a936c84/review
# user_code = 5f1665549ec8258e4a936c84
# review_id = 582599548_5f1665549ec8258e4a936c84
# rating = 3.5
# date = 2021.05.07
# 리뷰 내용 : 제육볶음 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 8번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 뽀르또
# 식당 구분 : 카페
# ----------------------------------------------
# 리뷰 총 개수 : 0
#
#
# ======================================================
# 9번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 중문레지나김밥
# 식당 구분 : 김밥
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5d1b3556e856d8df70477439/review
# user_code = 5d1b3556e856d8df70477439
# review_id = 38310744_5d1b3556e856d8df70477439
# rating = 5
# date = 2021.10.07
# 리뷰 내용 : 굿
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ed8bef78f87a842bc729de8/review
# user_code = 5ed8bef78f87a842bc729de8
# review_id = 38310744_5ed8bef78f87a842bc729de8
# rating = 5
# date = 2021.09.23
# 리뷰 내용 : 한라산갈때 가져가는데 새벽 부터 오픈해서 좋았어요 맛도 김밥 맛집이네욤
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c1cb82cba61f34d8bd0da0d/review
# user_code = 5c1cb82cba61f34d8bd0da0d
# review_id = 38310744_5c1cb82cba61f34d8bd0da0d
# rating = 5
# date = 2021.09.11
# 리뷰 내용 : ♥♥♥♥♥♥♥
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bc2f35576cacbbb7a166aef/review
# user_code = 5bc2f35576cacbbb7a166aef
# review_id = 38310744_5bc2f35576cacbbb7a166aef
# rating = 4.5
# date = 2021.06.20
# 리뷰 내용 : 중문에 있는 분식집 김밥 중에 젤 맛있어요
# 다른 메뉴도 믿고 먹을 수 있을 것 같아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d283db58e4f7054366e59ae/review
# user_code = 5d283db58e4f7054366e59ae
# review_id = 38310744_5d283db58e4f7054366e59ae
# rating = 3.5
# date = 2021.06.13
# 리뷰 내용 : 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f043b3c012fad32006d1d11/review
# user_code = 5f043b3c012fad32006d1d11
# review_id = 38310744_5f043b3c012fad32006d1d11
# rating = 4.5
# date = 2021.06.07
# 리뷰 내용 : 건강하고 맛있는 맛!! 친절하시기까지... 온가족이 가서 배터지게 먹고 왔어요!!^^
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bf27c33e2bd8ce08bbe59a4/review
# user_code = 5bf27c33e2bd8ce08bbe59a4
# review_id = 38310744_5bf27c33e2bd8ce08bbe59a4
# rating = 5
# date = 2021.05.22
# 리뷰 내용 : 김밥이 크고 맛있어요~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c0c86b17db131a47ff4d68c/review
# user_code = 5c0c86b17db131a47ff4d68c
# review_id = 38310744_5c0c86b17db131a47ff4d68c
# rating = 5
# date = 2021.05.03
# 리뷰 내용 : 굿
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f0438e00b8c7a1cdb6f0c23/review
# user_code = 5f0438e00b8c7a1cdb6f0c23
# review_id = 38310744_5f0438e00b8c7a1cdb6f0c23
# rating = 4.5
# date = 2021.04.11
# 리뷰 내용 : 김밥 알차고 맛있음
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/60293118b9ab0f2bf3f8c2df/review
# user_code = 60293118b9ab0f2bf3f8c2df
# review_id = 38310744_60293118b9ab0f2bf3f8c2df
# rating = 4
# date = 2021.04.02
# 리뷰 내용 : 굿
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 10번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 예원회수산
# 식당 구분 : 생선회
# ----------------------------------------------
# 리뷰 총 개수 : 0
#
#
# ======================================================
# 11번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 불닭공장서귀포신시가지점
# 식당 구분 : 불닭
# ----------------------------------------------
# 리뷰 총 개수 : 7
# user_url = https://m.place.naver.com/my/5d4e33bc0144072a7b774709/review
# user_code = 5d4e33bc0144072a7b774709
# review_id = 1123084536_5d4e33bc0144072a7b774709
# rating = 5
# date = 2021.10.04
# 리뷰 내용 : 여기 진짜 최고👍🏼
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211005_166%2F1633433488799WB8IN_JPEG%2Fupload_b666b1a8ba3f1e5fddc45360c7a1c0fa.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5fa368ca6c6bdf9334e84394/review
# user_code = 5fa368ca6c6bdf9334e84394
# review_id = 1123084536_5fa368ca6c6bdf9334e84394
# rating = 5
# date = 2021.09.24
# 리뷰 내용 : 역시 불닭공장! 맛있어요~~~^^
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5df8dc918f87a842bc24d47f/review
# user_code = 5df8dc918f87a842bc24d47f
# review_id = 1123084536_5df8dc918f87a842bc24d47f
# rating = 5
# date = 2021.08.12
# 리뷰 내용 : 닭발 맛있음ㅜㅜ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dcb812b8f87a842bcc94ee4/review
# user_code = 5dcb812b8f87a842bcc94ee4
# review_id = 1123084536_5dcb812b8f87a842bcc94ee4
# rating = 5
# date = 2021.07.07
# 리뷰 내용 :
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210707_232%2F1625655729433rnXCs_JPEG%2Fupload_ebde23137b01ace0d7212b3a782235f2.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c20cab733d2b4aa69ad572c/review
# user_code = 5c20cab733d2b4aa69ad572c
# review_id = 1123084536_5c20cab733d2b4aa69ad572c
# rating = 4
# date = 2021.06.27
# 리뷰 내용 : 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c20cab733d2b4aa69ad572c/review
# user_code = 5c20cab733d2b4aa69ad572c
# review_id = 1123084536_5c20cab733d2b4aa69ad572c
# rating = 5
# date = 2021.06.07
# 리뷰 내용 : 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d9dd2268f87a842bc69c683/review
# user_code = 5d9dd2268f87a842bc69c683
# review_id = 1123084536_5d9dd2268f87a842bc69c683
# rating = 4.5
# date = 2021.06.03
# 리뷰 내용 : 가격이 올라서 이것저것 먹다보면 좀 많이 나와요
# 맛있고 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 12번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 통돌이돈통가
# 식당 구분 : 육류,고기요리
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5ff17a1b665b23f1d2136f40/review
# user_code = 5ff17a1b665b23f1d2136f40
# review_id = 1130282337_5ff17a1b665b23f1d2136f40
# rating = 5
# date = 2021.09.25
# 리뷰 내용 : 굿.짱이예요.^^♡♡♡
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210925_263%2F1632574210745wKgVb_JPEG%2Fupload_7c99ae04a3528819fbbb241d7e484f3f.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d8194d18f87a842bcd2a65c/review
# user_code = 5d8194d18f87a842bcd2a65c
# review_id = 1130282337_5d8194d18f87a842bcd2a65c
# rating = 5
# date = 2021.08.29
# 리뷰 내용 : 숙소앞이라 한번 들려보자하고 갔는데..
# 너무 맛있어서 과식을 불렀네요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bea73d405a858679225bd29/review
# user_code = 5bea73d405a858679225bd29
# review_id = 1130282337_5bea73d405a858679225bd29
# rating = 5
# date = 2021.07.27
# 리뷰 내용 : 통돌이 바베큐 너무 맛있고 음식도 너무 정갈하고 특히 사장님께서 설명도 잘해주시고 부모님과의 저녁식사 였는데 만족스러웠어요
# 또 방문의사 있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d8317d58f87a842bc88fa00/review
# user_code = 5d8317d58f87a842bc88fa00
# review_id = 1130282337_5d8317d58f87a842bc88fa00
# rating = 1
# date = 2021.07.26
# 리뷰 내용 : 웬만하면 한끼 해결한 곳을 좋게 소개하려하지만 이건 정말 아니다는 생각에 한마디합니다. 대체 뭣땜에 식사를 이렇게 비싸게 받는지 이해할수 없어요. 돼지 바베큐 1인분에 2만원인데 제가 세어보니 딱 10조각 입니다. 돼지고기 한조각에 2천원인 셈인데 이건 폭리를 넘어 사기라는 생각이 드네요 ㅠㅠ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ceb29e869e1e0d2eb6047e8/review
# user_code = 5ceb29e869e1e0d2eb6047e8
# review_id = 1130282337_5ceb29e869e1e0d2eb6047e8
# rating = 5
# date = 2021.07.18
# 리뷰 내용 : 진짜 어른들이 감탄한 콩국수 조카가 맛집이라고하는곳이라 항시 믿고 먹어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d9a97a08f87a842bc21d6fc/review
# user_code = 5d9a97a08f87a842bc21d6fc
# review_id = 1130282337_5d9a97a08f87a842bc21d6fc
# rating = 5
# date = 2021.07.16
# 리뷰 내용 : 고기도 맛있고 사장님 친절하시고 식당 진짜 깨끗해요. 표선오면 무조건 또올게요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210716_202%2F1626407594905DqxQG_JPEG%2Fupload_c69f02ae09d6faeb9fa96736ca8e1514.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c36a261f3d8b758cf62615b/review
# user_code = 5c36a261f3d8b758cf62615b
# review_id = 1130282337_5c36a261f3d8b758cf62615b
# rating = 5
# date = 2021.06.30
# 리뷰 내용 : 고기도 다 알아서 구워주시고 옷에 냄새도 안 배서 좋아요! 고기도 부드럽고 맛있습니당👍 후식 수정과도 시원하고 맛있어요~
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210630_249%2F1625024214005loYP8_JPEG%2Fupload_04d994d3cd632db93605724bf18f48b3.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ee986be8f87a842bc98955d/review
# user_code = 5ee986be8f87a842bc98955d
# review_id = 1130282337_5ee986be8f87a842bc98955d
# rating = 5
# date = 2021.05.28
# 리뷰 내용 :
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b912cbbcd21e8e1923b3c94/review
# user_code = 5b912cbbcd21e8e1923b3c94
# review_id = 1130282337_5b912cbbcd21e8e1923b3c94
# rating = 5
# date = 2021.05.12
# 리뷰 내용 : 고기굽지않아 좋고 옷에 고기냄새 베지않아좋구 맛은 더 좋구.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c2ccade5bc30494939189de/review
# user_code = 5c2ccade5bc30494939189de
# review_id = 1130282337_5c2ccade5bc30494939189de
# rating = 5
# date = 2021.05.07
# 리뷰 내용 : 최고! 제주도에서 돼지고기가 가장 맛있는 곳!
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 13번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 홍교
# 식당 구분 : 중식당
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/60e18be9ed76f3173aa3602c/review
# user_code = 60e18be9ed76f3173aa3602c
# review_id = 1281515072_60e18be9ed76f3173aa3602c
# rating = 4.5
# date = 2021.10.03
# 리뷰 내용 : 문어짬뽕 강추
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/614bc7f5edc82600063b425b/review
# user_code = 614bc7f5edc82600063b425b
# review_id = 1281515072_614bc7f5edc82600063b425b
# rating = 5
# date = 2021.10.01
# 리뷰 내용 : 맛있고 친절해요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f5f33ba6c3d7f73341a0f14/review
# user_code = 5f5f33ba6c3d7f73341a0f14
# review_id = 1281515072_5f5f33ba6c3d7f73341a0f14
# rating = 3.5
# date = 2021.09.05
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c947dd9ae07a1eec63074c0/review
# user_code = 5c947dd9ae07a1eec63074c0
# review_id = 1281515072_5c947dd9ae07a1eec63074c0
# rating = 5
# date = 2021.08.08
# 리뷰 내용 : 운진항 가기 전에 들릴 만한 맛집
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d2dad7e82fb0fce486135d8/review
# user_code = 5d2dad7e82fb0fce486135d8
# review_id = 1281515072_5d2dad7e82fb0fce486135d8
# rating = 4
# date = 2021.08.05
# 리뷰 내용 : 비주얼은 좋았는데 솔직히 국물맛은 아쉬웠습니다. 해물도 신선도가 떨어지고 별로 없었구요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210814_194%2F1628952291681MxnyV_JPEG%2Fupload_f6cce9d595462383080f72ae978852b4.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c249c1da45d6eba01722930/review
# user_code = 5c249c1da45d6eba01722930
# review_id = 1281515072_5c249c1da45d6eba01722930
# rating = 4
# date = 2021.07.31
# 리뷰 내용 : 문어짬뽕이 참 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c947dd9ae07a1eec63074c0/review
# user_code = 5c947dd9ae07a1eec63074c0
# review_id = 1281515072_5c947dd9ae07a1eec63074c0
# rating = 5
# date = 2021.07.19
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ffaf6e20ba0d4a994113876/review
# user_code = 5ffaf6e20ba0d4a994113876
# review_id = 1281515072_5ffaf6e20ba0d4a994113876
# rating = 5
# date = 2021.07.10
# 리뷰 내용 : 완뽕  통문어짬뽕  강츄!!!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210710_16%2F1625889329088XH30A_JPEG%2Fupload_4e09d8e9683f51b3ee5b80f309b5c6e6.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d3eba8204d38a1e1b05a0d2/review
# user_code = 5d3eba8204d38a1e1b05a0d2
# review_id = 1281515072_5d3eba8204d38a1e1b05a0d2
# rating = 5
# date = 2021.07.01
# 리뷰 내용 :
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210701_204%2F1625105621855mLdU2_JPEG%2Fupload_2b94f0aca63cddaae024eec28ace6e85.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c947dd9ae07a1eec63074c0/review
# user_code = 5c947dd9ae07a1eec63074c0
# review_id = 1281515072_5c947dd9ae07a1eec63074c0
# rating = 5
# date = 2021.06.30
# 리뷰 내용 : 재료도 신선하고 맛있어요~
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 14번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 신산상회
# 식당 구분 : 맥주,호프
# ----------------------------------------------
# 리뷰 총 개수 : 3
# user_url = https://m.place.naver.com/my/5ec615e38f87a842bcbf0874/review
# user_code = 5ec615e38f87a842bcbf0874
# review_id = 1058593038_5ec615e38f87a842bcbf0874
# rating = 5
# date = 2021.02.05
# 리뷰 내용 : 너어어어무 맛잇어요:-)♡ 정신없이 먹다가 찍어서 엉성하긴한데 그만큼 존맛♡ 양념치킨 별루 안좋아하는데 짱 맛있고 튀김옷도 바삭
# 해요👍💕 제주도 사는 지인이 브랜드치킨 보다 맛있다구 해서 먹으러 왔는데 육지 가기전에 한번 더 먹고 싶어요^^ 제주에서 만들었
# 다는 홍차도 감사히 잘먹겠습니다♡ 더더욱 흥하세요!!!! ;-)
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bef6aca9ac5741755b58401/review
# user_code = 5bef6aca9ac5741755b58401
# review_id = 1058593038_5bef6aca9ac5741755b58401
# rating = 5
# date = 2020.11.10
# 리뷰 내용 : 꽤 맛있는 치킨! 옛날치킨인데 후라이드도 양념도 맛있네요!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20201112_118%2F1605181624961z65PP_JPEG%2Fupload_7940dbfb21ea9cc29dcb2cb9ee09a5ea.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ee70c418f87a842bc25474a/review
# user_code = 5ee70c418f87a842bc25474a
# review_id = 1058593038_5ee70c418f87a842bc25474a
# rating = 5
# date = 2020.09.11
# 리뷰 내용 : 인생 최고의 후라이드 치킨 여기 후라이드 치킨 정말 맛있어요 5점도 모자라네요 점수 짜게 주는 저한테 5점도 아쉽네요 사장님도 친절
# 하시고, 깨끗한 기름 쓰시는것 같아요 바삭바삭하고 깔끔하고 담백한 맛이라 후라이드만 놓고 보았을때 체인점 치킨이랑 비교 불가
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20200912_92%2F1599908060590a1pIi_JPEG%2Fupload_32ac302d0cef0dbcc8db4ce02eb94496.jpeg
# ----------------------------------------------
#
#
#
#
# ======================================================
# 15번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 팔도실비집신서귀포점
# 식당 구분 : 포장마차
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5dc55fd38f87a842bcd236ea/review
# user_code = 5dc55fd38f87a842bcd236ea
# review_id = 12948836_5dc55fd38f87a842bcd236ea
# rating = 4
# date = 2021.07.24
# 리뷰 내용 : 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f070cb8a36dc5e3fa605e5b/review
# user_code = 5f070cb8a36dc5e3fa605e5b
# review_id = 12948836_5f070cb8a36dc5e3fa605e5b
# rating = 4.5
# date = 2021.06.25
# 리뷰 내용 : 편하게 술마시기 좋아요. 안주도 괜찮습니다
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d35b584c325a690efd6539f/review
# user_code = 5d35b584c325a690efd6539f
# review_id = 12948836_5d35b584c325a690efd6539f
# rating = 5
# date = 2021.06.01
# 리뷰 내용 : 국물닭발 최고에요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5de5eb199ec8258e4a0d12c9/review
# user_code = 5de5eb199ec8258e4a0d12c9
# review_id = 12948836_5de5eb199ec8258e4a0d12c9
# rating = 3.5
# date = 2021.05.27
# 리뷰 내용 : 항상 손님이 많아서 기대하고 갔는데
# 개인적으로 안주들이 전반적으로 많이 짰습니다.
# 2차로 부담없이 가기에 좋은 곳이예요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c17560192d2e028abce7652/review
# user_code = 5c17560192d2e028abce7652
# review_id = 12948836_5c17560192d2e028abce7652
# rating = 5
# date = 2021.05.11
# 리뷰 내용 : 분위기도 좋고 음식도 빨리나오고 맛도좋고 굿굿 단골 찜요!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ed4939d8f87a842bca51420/review
# user_code = 5ed4939d8f87a842bca51420
# review_id = 12948836_5ed4939d8f87a842bca51420
# rating = 5
# date = 2021.05.11
# 리뷰 내용 : 여태껏. 먹어봤던 김치전중 단연 최고였습니다 해물오뎅탕은 소주 안주에. 딱이에요 강추합니다 여기서 마무리는 파인 샤베트👍 어린
# 아이부터 여성고객에게 인기 만점이에요🤗
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e14a42a8f87a842bc4538b1/review
# user_code = 5e14a42a8f87a842bc4538b1
# review_id = 12948836_5e14a42a8f87a842bc4538b1
# rating = 4
# date = 2021.02.26
# 리뷰 내용 : 맛나룡
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210226_112%2F1614316951176cYGMo_JPEG%2Fupload_bf8e1fd2052d7e6e6db7175583cda334.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5fbb9a2ce7c88b6eb2e05a0b/review
# user_code = 5fbb9a2ce7c88b6eb2e05a0b
# review_id = 12948836_5fbb9a2ce7c88b6eb2e05a0b
# rating = 5
# date = 2021.02.21
# 리뷰 내용 : 두루치기맛나요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c3419a16c331f8576687933/review
# user_code = 5c3419a16c331f8576687933
# review_id = 12948836_5c3419a16c331f8576687933
# rating = 3
# date = 2020.11.28
# 리뷰 내용 : 포장이라고 밥도 깜빡 안넣어 주시고 국도 없다고 사이다로 대체 해 주시고 ㅠㅠ 배는 고프고... 밥은 없고 화는 나고 먹다 소화가 안되네요
# 이미지 url :
# ----------------------------------------------
#
#
# ...
# rating = 5
# date = 2021.07.02
# 리뷰 내용 : 뷰 좋고 인테리어 예쁘고 조용해서 너무 좋았습니다.  근처 범일분식 맛있어서 제주도 올때마다 범일분식 순대국 +근처 카페투어 코스로 오는데 근처 카페들 중 가장 좋았어요 ^^  남편이 역대급 카페로 손꼽힌다네요. 근처 ㅅㄹㄷㅇ는 실내는 별로고 실외는 괜찮았는데 누구에게 추천해
# 준다면 여길 추천할거래요 ㅎㅎ  비 오는 날 커피 마시기에 더할 나위없이 좋았습니다.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5cf274b39b53ce4cc89d949e/review
# user_code = 5cf274b39b53ce4cc89d949e
# review_id = 1969497561_5cf274b39b53ce4cc89d949e
# rating = 5
# date = 2021.06.24
# 리뷰 내용 : 올레5코스 걷다가 힘들어서 들어갔는데 카페 분위기도 이쁘고 하귤에이드도 맛났어요. 귀여운 강아지도있고 사장님 부부도 친절하셨어요.
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210708_275%2F162572126248808OLg_JPEG%2Fupload_35cfe0db53f193d6c356b15b77bace81.jpg
# ----------------------------------------------
#
#
#
#
# ======================================================
# 443번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 역전할머니맥주제주표선점
# 식당 구분 : 맥주,호프
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5c7a77b64c1f1f021f1c9209/review
# user_code = 5c7a77b64c1f1f021f1c9209
# review_id = 1159429345_5c7a77b64c1f1f021f1c9209
# rating = 4.5
# date = 2021.09.12
# 리뷰 내용 : 맛나요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c190008cec648771bc49aff/review
# user_code = 5c190008cec648771bc49aff
# review_id = 1159429345_5c190008cec648771bc49aff
# rating = 2.5
# date = 2021.08.08
# 리뷰 내용 : 보통
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5cc91ef85bdf645721ee6b70/review
# user_code = 5cc91ef85bdf645721ee6b70
# review_id = 1159429345_5cc91ef85bdf645721ee6b70
# rating = 5
# date = 2021.06.19
# 리뷰 내용 :
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210624_46%2F1624493844580LIuKq_JPEG%2Fupload_6d84789c49017dea3099756b434a49a1.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5de349289ec8258e4a346caa/review
# user_code = 5de349289ec8258e4a346caa
# review_id = 1159429345_5de349289ec8258e4a346caa
# rating = 5
# date = 2021.06.18
# 리뷰 내용 : 알바생분 친절하고 이뻐용🤍
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f5da9a76c3d7f733489f72c/review
# user_code = 5f5da9a76c3d7f733489f72c
# review_id = 1159429345_5f5da9a76c3d7f733489f72c
# rating = 3.5
# date = 2021.04.26
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/605ec3f5eee54eaaac6992e0/review
# user_code = 605ec3f5eee54eaaac6992e0
# review_id = 1159429345_605ec3f5eee54eaaac6992e0
# rating = 4.5
# date = 2021.04.14
# 리뷰 내용 : 감튀맛있어용~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e97ac6c8f87a842bc09f86a/review
# user_code = 5e97ac6c8f87a842bc09f86a
# review_id = 1159429345_5e97ac6c8f87a842bc09f86a
# rating = 5
# date = 2021.02.27
# 리뷰 내용 : 가성비 너무 좋고,치즈라볶이랑 골뱅이비빔면 맛있게 먹었습니다~
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210227_92%2F1614436302906swzSJ_PNG%2Fupload_afaebd5bc40333b55ce95c4d3fc94da9.png
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c540e24301fc1b308989a0d/review
# user_code = 5c540e24301fc1b308989a0d
# review_id = 1159429345_5c540e24301fc1b308989a0d
# rating = 5
# date = 2020.11.25
# 리뷰 내용 : 여행중 한잔하기 좋음
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ba1b01e3878b47b2f90c837/review
# user_code = 5ba1b01e3878b47b2f90c837
# review_id = 1159429345_5ba1b01e3878b47b2f90c837
# rating = 5
# date = 2020.11.15
# 리뷰 내용 : 맛은 보통..
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20201116_162%2F1605527874136Ikrgc_JPEG%2Fupload_ae2f5f0894ac3039cd7e6e00e8b7759f.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f2819899ec8258e4a673327/review
# user_code = 5f2819899ec8258e4a673327
# review_id = 1159429345_5f2819899ec8258e4a673327
# rating = 4.5
# date = 2020.08.31
# 리뷰 내용 : 넓어요
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 444번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 마녀상회
# 식당 구분 : 돼지고기구이
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5d80d1718f87a842bced22b4/review
# user_code = 5d80d1718f87a842bced22b4
# review_id = 1561987598_5d80d1718f87a842bced22b4
# rating = 0.5
# date = 2021.10.10
# 리뷰 내용 : 굳이 기다려서 막을 맛이 아닙니다 주위에 아무것도 없어서 계속 먹긴 했는데 그렇게 친절하지도 않고 고기 질도 별로(삼겹살 맛있는 부위가 아니네요) 사장님 고기 굽는 실력도 별로 광고해 놓은 것 처럼 바다에서 가깝지도 않습니다 늦은시간까지 기다리시는 분들이 있어서 너무 안타까
# 워 후기를 남기게 되네요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c7b7639a22604435b01050d/review
# user_code = 5c7b7639a22604435b01050d
# review_id = 1561987598_5c7b7639a22604435b01050d
# rating = 5
# date = 2021.10.05
# 리뷰 내용 : 사장님. 마인드도최고 고기도최고 김치찌개도최고 꼬맹이 말도 최고 맛집인정 아들이또온다네요^^ 다음제주방문때 또방문합니다^^
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b9b9450c8fb33b2a2a74cf9/review
# user_code = 5b9b9450c8fb33b2a2a74cf9
# review_id = 1561987598_5b9b9450c8fb33b2a2a74cf9
# rating = 4
# date = 2021.09.23
# 리뷰 내용 : 맛있게 잘 구워주세요 잘 먹었습니다
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c07a1bf2d90ad7c3e77fa1b/review
# user_code = 5c07a1bf2d90ad7c3e77fa1b
# review_id = 1561987598_5c07a1bf2d90ad7c3e77fa1b
# rating = 5
# date = 2021.09.22
# 리뷰 내용 : 재방문한 사람들은 병신인가 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 올리비아님은 얼마나 좋은걸 쳐드시고 다니셧길래 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 전 항상 마녀상회 응원합니다!!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f0593ceb2804547b18887b3/review
# user_code = 5f0593ceb2804547b18887b3
# review_id = 1561987598_5f0593ceb2804547b18887b3
# rating = 5
# date = 2021.09.22
# 리뷰 내용 : 흑돼지 신선하고 맛있었어요 왜 유명한지 알겠음 ㅠㅠ 가게 분위기도 너무 좋구 여자친구랑 데이트코스로 최고! 재방문의사 200% 아 김치찌개도
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/61469ca01c8fc128c3769cb3/review
# user_code = 61469ca01c8fc128c3769cb3
# review_id = 1561987598_61469ca01c8fc128c3769cb3
# rating = 5
# date = 2021.09.22
# 리뷰 내용 : 고기맛있고 김치찌개 조합잘맞고
# 사장님이 고기도꾸어주시고
# 제주도 간다면..재방문 하고싶은?
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bc858f107536038beadef6f/review
# user_code = 5bc858f107536038beadef6f
# review_id = 1561987598_5bc858f107536038beadef6f
# rating = 1
# date = 2021.09.22
# 리뷰 내용 : <리뷰남기고 보니 리뷰업체에서 도와준답시고 까는글 올렸던데 ㅋㅋ너나 쳐드세요 > 제주의 마지막 밤이었는데 너무 실망했어요. 분위기로 장사하려고 하기전에 본업이 식당이라는걸 잊지마시길. 제주 흑돼지 처음 접했는데 가격이 비싼건 논외로 치더라도 잡내심하고 질기고 김치찌개
# 하…비계기름만 둥둥 떠다니고 김치는 몇조각 떠다니고 밥도 저렴이중에 저렴이 쌀로 지은밥 ㅜ 둘이서 돈 7만원가량에 밥 몇숟갈에 김치쪼가리 먹은느낌. 몇숟갈 먹지도 못했고요. 손님이 오던가던 응대없고요. 이 가격을 받고싶으심 심각히 반성하세요. 적어도 본인들이 맛은 보고 손
# 님상에 나가세요. 손님들 바보아닙니다. 뜨내기장사라 하더라도  리뷰 마케팅으로 장난질이전에 기본에 충실하시길
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e6381e28f87a842bc3f7d21/review
# user_code = 5e6381e28f87a842bc3f7d21
# review_id = 1561987598_5e6381e28f87a842bc3f7d21
# rating = 5
# date = 2021.09.22
# 리뷰 내용 : 존맛탱
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d71c3c28f87a842bc62edec/review
# user_code = 5d71c3c28f87a842bc62edec
# review_id = 1561987598_5d71c3c28f87a842bc62edec
# rating = 5
# date = 2021.09.22
# 리뷰 내용 : 사장님이 정말 친절하세요!!
# 음식도 맛있고
# 뷰가 너무 좋아서 매번 인생샷건져갑니다잇!!!!!!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/612b074d2d8e48ec4592bb9f/review
# user_code = 612b074d2d8e48ec4592bb9f
# review_id = 1561987598_612b074d2d8e48ec4592bb9f
# rating = 5
# date = 2021.09.21
# 리뷰 내용 : 제주도 자주 놀러가는데, 이런곳을이제알았다니ㅠㅠ매장도 깨끗하고 고기도 맛잇어서  지인들 자주 데리고 갑니다.  가게 번창하시길 바래요~
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 445번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 허브올레
# 식당 구분 : 카페,디저트
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5d46b3e72118c06581d22bec/review
# user_code = 5d46b3e72118c06581d22bec
# review_id = 1020309277_5d46b3e72118c06581d22bec
# rating = 5
# date = 2021.08.05
# 리뷰 내용 : 허브티 정말 좋아요.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d46b3e72118c06581d22bec/review
# user_code = 5d46b3e72118c06581d22bec
# review_id = 1020309277_5d46b3e72118c06581d22bec
# rating = 5
# date = 2021.08.05
# 리뷰 내용 : 좋았어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5eaef48b8f87a842bc90f5ce/review
# user_code = 5eaef48b8f87a842bc90f5ce
# review_id = 1020309277_5eaef48b8f87a842bc90f5ce
# rating = 5
# date = 2021.06.29
# 리뷰 내용 : 맛나요~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c79dcb8e5bd6902015f3da0/review
# user_code = 5c79dcb8e5bd6902015f3da0
# review_id = 1020309277_5c79dcb8e5bd6902015f3da0
# rating = 5
# date = 2021.06.22
# 리뷰 내용 : 상품이 좋아요~ 그리고 로즈마리~”감사합니다~~”
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c750f8b65d01e6ae132b82e/review
# user_code = 5c750f8b65d01e6ae132b82e
# review_id = 1020309277_5c750f8b65d01e6ae132b82e
# rating = 5
# date = 2021.03.17
# 리뷰 내용 : 친절하고 허브무료 시식치고너무 많이주세요~커피맛도 너무좋네요~^^낙타체험하고맞은편에목이말라커피마시러우연히드르곳치고좋은서비스친절한서비스경험하고잘하고가요감사합니다^^
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210317_65%2F1615957864716xMuhK_JPEG%2Fupload_997daa8d2bda3b2cfa49513a9ac200f6.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d8bf7008f87a842bc4423e9/review
# user_code = 5d8bf7008f87a842bc4423e9
# review_id = 1020309277_5d8bf7008f87a842bc4423e9
# rating = 5
# date = 2020.07.24
# 리뷰 내용 : 차도, 분위기도 서비스도 모두 최고였습니다.
# 덕분에 힐링하고 갑니다~
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20200724_236%2F1595569008821YjtAN_JPEG%2Fupload_e424cb4547c8c6f88d1e0b6fed6395fa.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d248a5ff30bfb5508779fcb/review
# user_code = 5d248a5ff30bfb5508779fcb
# review_id = 1020309277_5d248a5ff30bfb5508779fcb
# rating = 5
# date = 2020.07.16
# 리뷰 내용 : 허브향이 진함 방방이가 있어서 한참 놀다가 차마시고 샌드위치는 허브향때문에 애가 뱉 ㅋㅋ 어른을 위한장소
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20200717_198%2F1594945285502hGDdk_JPEG%2Fupload_c13863438a9ededdea46cbfb191efe80.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d591c77db68a2263b05edbc/review
# user_code = 5d591c77db68a2263b05edbc
# review_id = 1020309277_5d591c77db68a2263b05edbc
# rating = 4
# date = 2020.06.19
# 리뷰 내용 : 좋은 제품은 많아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5eb54cf48f87a842bcb8c965/review
# user_code = 5eb54cf48f87a842bcb8c965
# review_id = 1020309277_5eb54cf48f87a842bcb8c965
# rating = 5
# date = 2020.05.01
# 리뷰 내용 : 오래전부터 바디 미스트 애용해오던 사람입니다!
# 커피사러 우연히 들어간 카페가 허브올레 매장이더라구요 ㅎ
# 커피도 마시고 미스트도 사고 나왔어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d82c7eb8f87a842bcb52a43/review
# user_code = 5d82c7eb8f87a842bcb52a43
# review_id = 1020309277_5d82c7eb8f87a842bcb52a43
# rating = 5
# date = 2020.03.03
# 리뷰 내용 : 향 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 446번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 우리가족오늘반찬
# 식당 구분 : 반찬가게
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5b8679e92ed9362e1e5e6f35/review
# user_code = 5b8679e92ed9362e1e5e6f35
# review_id = 1828271046_5b8679e92ed9362e1e5e6f35
# rating = 5
# date = 2021.09.20
# 리뷰 내용 : 탐나는전 되고 맛도 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ff176e61644dde6589d163e/review
# user_code = 5ff176e61644dde6589d163e
# review_id = 1828271046_5ff176e61644dde6589d163e
# rating = 2.5
# date = 2021.09.15
# 리뷰 내용 : 색다른 메뉴도 종종 만들어 주셨음 해요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bf11eb3e60721e4abd1a6b1/review
# user_code = 5bf11eb3e60721e4abd1a6b1
# review_id = 1828271046_5bf11eb3e60721e4abd1a6b1
# rating = 5
# date = 2021.08.17
# 리뷰 내용 : 몇 달만에 갔는데 조리하는 분이 바뀌신건지
# 맛이 달라졌어요~돼지불고기 잡채 지금이 더 맛있네요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5efe732568401871104ea6cd/review
# user_code = 5efe732568401871104ea6cd
# review_id = 1828271046_5efe732568401871104ea6cd
# rating = 4
# date = 2021.07.27
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d7868528f87a842bc1ea842/review
# user_code = 5d7868528f87a842bc1ea842
# review_id = 1828271046_5d7868528f87a842bc1ea842
# rating = 4
# date = 2021.07.26
# 리뷰 내용 : 대체적으로 맛있음
# 전 종류는 비추합니다 허허
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5cf877de061fef50827fa07e/review
# user_code = 5cf877de061fef50827fa07e
# review_id = 1828271046_5cf877de061fef50827fa07e
# rating = 4
# date = 2021.07.15
# 리뷰 내용 : 대체로 맛있는거같아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c20217e10382f5a589cb36c/review
# user_code = 5c20217e10382f5a589cb36c
# review_id = 1828271046_5c20217e10382f5a589cb36c
# rating = 4
# date = 2021.04.25
# 리뷰 내용 : 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bf11eb3e60721e4abd1a6b1/review
# user_code = 5bf11eb3e60721e4abd1a6b1
# review_id = 1828271046_5bf11eb3e60721e4abd1a6b1
# rating = 4
# date = 2021.04.25
# 리뷰 내용 : 굿
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bf11eb3e60721e4abd1a6b1/review
# user_code = 5bf11eb3e60721e4abd1a6b1
# review_id = 1828271046_5bf11eb3e60721e4abd1a6b1
# rating = 3
# date = 2021.04.16
# 리뷰 내용 : 닭갈비 사와서 먹는데 거뭇한게 많은데 이게 뭘까요?탄 음식물 같기도 하구요..ㅠ
# 오늘 잡채는 양념이 고루 베어서 맛있네요.
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210416_112%2F1618567315896gN19n_JPEG%2Fupload_b1f5ad1741cd9546b43a47d983c61c1c.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5effaba0d012f64a7231e5e4/review
# user_code = 5effaba0d012f64a7231e5e4
# review_id = 1828271046_5effaba0d012f64a7231e5e4
# rating = 5
# date = 2021.04.08
# 리뷰 내용 : 맛있어요- 매일 반찬이 바뀌니까 더 자주 가는 것 같아요:-) 메뉴도 다양하고 친절합니다-
# 특히 장조림류가 맛있어요!!
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 447번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 누들보쌈배달만족신화월드점
# 식당 구분 : 야식
# ----------------------------------------------
# 리뷰 총 개수 : 1
# user_url = https://m.place.naver.com/my/5eb5d0b58f87a842bc1f387a/review
# user_code = 5eb5d0b58f87a842bc1f387a
# review_id = 1378184624_5eb5d0b58f87a842bc1f387a
# rating = 5
# date = 2021.09.01
# 리뷰 내용 : 너무 맛있게 잘먹었어요 ~~
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 448번째 식당
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-425d394daaeb> in <module>
#      15             time.sleep(2)
#      16             driver.find_element_by_tag_name('body').send_keys(Keys.END)
# ---> 17             time.sleep(5)
#      18             driver.find_element_by_css_selector('#app-root > div > div.place_detail_wrapper > div:nth-child(5) > div:nth-child(4) > div:nth-child(4) > div._2kAri > a').click()
#      19             time.sleep(5)
#
# KeyboardInterrupt:

# %%
#for i in range(len(df)): 1회차
for i in range(644,1200):    
    print('======================================================')
    print(str(i)+'번째 식당')
    
    # 식당 리뷰 개별 url 접속
    driver.get(df['naver_map_url'][i])
    thisurl = df['naver_map_url'][i]
    time.sleep(2)
    # 더보기 버튼 다 누르기
    # 더보기 버튼 누르기까지 10개
    # 더보기 버튼 누르면 10개 추가됨
    while True:
        try:
            time.sleep(2) # 1초로 바꾸고
            driver.find_element_by_tag_name('body').send_keys(Keys.END)
            time.sleep(5) # 4초로 바꾸고
            driver.find_element_by_xpath('//*[@id="app-root"]/div/div/div[2]/div[5]/div[4]/div[5]/div[2]/a').click()
            time.sleep(5) # 4초로 바꾸고
            driver.find_element_by_tag_name('body').send_keys(Keys.END)
            time.sleep(2)  # 1초로 바꾸고
            
        except NoSuchElementException:
            print('-더보기 버튼 모두 클릭 완료-')
            break

    
    # 파싱
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    time.sleep(1)
    
    # 식당 구분
    restaurant_name = df['사업장명'][i]
    print('식당 이름 : '+restaurant_name)
    
    user_review_id[restaurant_name] = {}
    review_json[restaurant_name] = {}
    image_json[restaurant_name] = {}
    
    try:
        restaurant_classificaton = soup.find_all('span',attrs = {'class':'_3ocDE'})[0].text
    except:
        restaurant_classificaton = 'none'
    print('식당 구분 : '+restaurant_classificaton)
    print('----------------------------------------------')
    
    try:
        one_review = soup.find_all('div', attrs = {'class':'_1Z_GL'})
        review_num = len(one_review) # 특정 식당의 리뷰 총 개수
        print('리뷰 총 개수 : '+str(review_num))
    
        # 리뷰 개수
        for i in range(len(one_review)):
        
            # user url
            user_url = one_review[i].find('div', attrs = {'class':'_23Rml'}).find('a').get('href')
            print('user_url = '+user_url)
            
            # user url로부터 user code 뽑아내기
            user_code = re.findall(r"my/(\w+)", user_url)[0]
            print('user_code = '+user_code)
            
            # review 1개에 대한 id 만들기 
            res_code = re.findall(r"restaurant/(\d+)", thisurl)[0]
            review_id = str(res_code)+"_"+user_code
            print('review_id = '+review_id)
            
            # rating, 별점
            rating = one_review[i].find('span', attrs = {'class':'_2tObC'}).text
            print('rating = '+rating)
            
            # 주의!!! 사진 리뷰 유무에 따라 날짜 파싱코드 다름
            # ('span', attrs = {'class':'_3WqoL'})
            # 사진 없는 경우 : 총 6개 중 4번째
            # 사진 있는 경우 : 총 5개 중 3번째
            
            # date
            # 사진 리뷰 없음
            if len(one_review[i].find_all('span', attrs = {'class':'_3WqoL'})) == 5:
                date = one_review[i].find_all('span', attrs = {'class':'_3WqoL'})[2].text
            elif len(one_review[i].find_all('span', attrs = {'class':'_3WqoL'})) == 6:
                date = one_review[i].find_all('span', attrs = {'class':'_3WqoL'})[3].text
            else:
                date = ""
            print('date = '+date)
            
            # review 내용
            try : 
                review_content = one_review[i].find('span', attrs = {'class':'WoYOw'}).text
            except: # 리뷰가 없다면
                review_content = ""
            print('리뷰 내용 : '+review_content)
            
            
            # image 내용
            sliced_soup = one_review[i].find('div', attrs = {'class':'_1aFEL _2GO1Q'})

            if (sliced_soup != None):
                sliced_soup = sliced_soup.find('div',attrs={'class':'dRZ2X'})
                
                try:
                    img_url = 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src='+re.findall(r'src=(.*jpeg)', str(sliced_soup))[0]
                except :
                    if (len(re.findall(r'src=(.*jpg)', str(sliced_soup)))!= 0):
                        img_url = 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src='+re.findall(r'src=(.*jpg)', str(sliced_soup))[0]
                    elif (len(re.findall(r'src=(.*png)', str(sliced_soup)))!= 0):
                        img_url = 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src='+re.findall(r'src=(.*png)', str(sliced_soup))[0]
                    else :
                        img_url = ""
            else:
                img_url = ""
                
            print('이미지 url : '+img_url)
            print('----------------------------------------------')
            print('\n')

            
            #리뷰정보
            # user_review_id
            user_review_id[restaurant_name][user_code] = review_id
            
            # review_json
            review_json[restaurant_name][review_id] = review_content
            
            # image_json
            image_json[restaurant_name][review_id] = img_url
            
            # rating_df_list
            naver_review = user_code, restaurant_name, rating, date
            rating_list.append(naver_review)
            
            
    
    
    except NoSuchElementException:
            none_review = "네이버 리뷰 없음"
            print(none_review)
            review_num = 0
            #리뷰정보 = restaurant_name, restaurant_classification, review_num, none_review
            
            # rating_df_list
            naver_review = user_code, restaurant_name, none_review, none_reivew
            rating_list.append(naver_review)
            
            
    print('\n')
# Out:
# ======================================================
# 644번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 덕성루
# 식당 구분 : 중식당
# ----------------------------------------------
# 리뷰 총 개수 : 0
#
#
# ======================================================
# 645번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 신백정
# 식당 구분 : 육류,고기요리
# ----------------------------------------------
# 리뷰 총 개수 : 11
# user_url = https://m.place.naver.com/my/5bb88baacd58cd6de724ef75/review
# user_code = 5bb88baacd58cd6de724ef75
# review_id = 1508768168_5bb88baacd58cd6de724ef75
# rating = 5
# date = 2021.09.12
# 리뷰 내용 : 고기가 정말 신선하고 맛있어요~^^
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b948bf424ae62d85648de2c/review
# user_code = 5b948bf424ae62d85648de2c
# review_id = 1508768168_5b948bf424ae62d85648de2c
# rating = 5
# date = 2021.08.22
# 리뷰 내용 : 맛있게 잘먹었네요 창밖으로 산방산을보며 먹는분위기도 좋았습니다 반찬이 특히 맛있었구요 새우살이 확실히 부드러웠고 좋았네요..
# .^^
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bcb4c178a5d0fc997ae9224/review
# user_code = 5bcb4c178a5d0fc997ae9224
# review_id = 1508768168_5bcb4c178a5d0fc997ae9224
# rating = 5
# date = 2021.07.28
# 리뷰 내용 : 고기가 아름답습니다. 맛도 아름답습니다. 인테리어도 아름답습니다. 사장님도 아름(?)답습니다. 쵝오에요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210729_189%2F1627542229526KmoPj_JPEG%2Fupload_836a84756fa3ec6f5a18dd43769e6cbb.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bfd4f25b8738c513a4d87cf/review
# user_code = 5bfd4f25b8738c513a4d87cf
# review_id = 1508768168_5bfd4f25b8738c513a4d87cf
# rating = 5
# date = 2021.07.21
# 리뷰 내용 : 네번째 방문이지만 단한번도 시ㄹ망한적이 없는곳입니다~~ 제주도엔 좀 괜찮다 싶은곳이 오랜만에 방문하면 폐점된곳들이 종종 있어
# 안타꾸운 마음이 들더라구요. 개인적으로 신백정은 오래~~~오래 문득 찾아가도 맛있는 한우 먹을 수 있는 집으로 거듭나길 바래봅니
# 다~ 갈때마다 실망시키지않고 내어주시는 곁들이반찬은 매번 다양하구요 항상 깔끔하고 맛깔스럽고. (부부가 한우를 넘 넘 좋아...
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d319f4b93b87698715e70df/review
# user_code = 5d319f4b93b87698715e70df
# review_id = 1508768168_5d319f4b93b87698715e70df
# rating = 5
# date = 2021.07.18
# 리뷰 내용 : 백정스페셜 맛있게 잘먹고갑니다. 제주에서 맨날 흑돼지만 먹었는데 함평한우 가성비좋네요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ce75ea752a51ea8196b592a/review
# user_code = 5ce75ea752a51ea8196b592a
# review_id = 1508768168_5ce75ea752a51ea8196b592a
# rating = 4
# date = 2021.06.14
# 리뷰 내용 : vip 1인 10만원인데 비싼값 하네요 ㅎㅎ육회 원래 안먹는데 진짜 맛있었고 고기 살살 녹았어요.
#  근데 끝에 나오는 밥이 읭..  살짝 오묘한 맛이었어요 라면수프맛도 나는 거 같고
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5efe176697c2663e9347c12a/review
# user_code = 5efe176697c2663e9347c12a
# review_id = 1508768168_5efe176697c2663e9347c12a
# rating = 5
# date = 2021.06.05
# 리뷰 내용 : 묵었던 숙소 근처에 있어서 방문 했는데 진짜 너무 좋았어요^^ 와인 콜키지도 되는곳이고 밑반찬 하나하나도 다 특색있고 맛있어요. 육회 육사시미도 여태 먹었던 곳중 제일 맛나요. 늦은 점심을 먹고가서 많이 남겼는데 포장도 해주시고 다음에 또 방문하고 싶은 곳이에요^^ 사장님 두분 너무 친절하세요.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5cc596e55f0cf4d7ef59604f/review
# user_code = 5cc596e55f0cf4d7ef59604f
# review_id = 1508768168_5cc596e55f0cf4d7ef59604f
# rating = 4
# date = 2021.01.07
# 리뷰 내용 : 조금 비싸서 그렇지, 소고기가 정말 맛있네요~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dc7bbc68f87a842bca60101/review
# user_code = 5dc7bbc68f87a842bca60101
# review_id = 1508768168_5dc7bbc68f87a842bca60101
# rating = 5
# date = 2020.12.03
# 리뷰 내용 : 제주도민과 함께 즐긴 소고기 특 ++에 너무 맛있었고 사장님 센스가 좋아요, 고기 얇기 취향 1호점은 이미 대박이래요  꼭드세요♥️
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d330050af8c6a31cfec9af9/review
# user_code = 5d330050af8c6a31cfec9af9
# review_id = 1508768168_5d330050af8c6a31cfec9af9
# rating = 5
# date = 2020.11.28
# 리뷰 내용 : 부드럽고 맛나네!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b7569563aa05c78c782b4c7/review
# user_code = 5b7569563aa05c78c782b4c7
# review_id = 1508768168_5b7569563aa05c78c782b4c7
# rating = 5
# date = 2020.11.26
# 리뷰 내용 : 소고기도 돼지고기도 정말 최고
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 646번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 글라스월평(Glass Wolpyeong)
# 식당 구분 : 카페
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5c5dea8be03dc7509dd35dc9/review
# user_code = 5c5dea8be03dc7509dd35dc9
# review_id = 37558848_5c5dea8be03dc7509dd35dc9
# rating = 5
# date = 2021.10.10
# 리뷰 내용 : 섬세함이 느껴지는 공간에 커피, 샤베트 모두 완벽한 맛이에요🍋 다음에 제주 방문하면 와인마시러 꼭 오고 싶은곳🌿
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211010_82%2F16338419441309kL3T_JPEG%2Fupload_07630a490b1330326783fd4f397ae88c.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e608f148f87a842bc000148/review
# user_code = 5e608f148f87a842bc000148
# review_id = 37558848_5e608f148f87a842bc000148
# rating = 5
# date = 2021.10.10
# 리뷰 내용 : 커피도 맛있고 친절하십니다!!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211010_183%2F1633841369839nARYf_JPEG%2Fupload_16c0e8efce5331ac0e0f7cae32890b6a.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e7b3fd48f87a842bcc0df8c/review
# user_code = 5e7b3fd48f87a842bcc0df8c
# review_id = 37558848_5e7b3fd48f87a842bcc0df8c
# rating = 5
# date = 2021.09.30
# 리뷰 내용 : 와인 시음도 해주시고, 서비스도 챙겨주시고 사장님 너무 친절하십니다. 디저트도 너무 예쁘고 맛있었어요!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210930_41%2F1632986386360uzyy7_JPEG%2Fupload_caf983fa5ec30b8b0bfe56a1524eb505.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c1eec16d786b28df1212041/review
# user_code = 5c1eec16d786b28df1212041
# review_id = 37558848_5c1eec16d786b28df1212041
# rating = 5
# date = 2021.09.25
# 리뷰 내용 : 느슨해진 제주 와인 시장에 긴장감을 주는 가게. 인테리어부터 와인, 와인에 대한 설명과 서비스, 마지막 정점으로 친절함까지. 석회미장이며 분위기 터지는 가구, 여기만큼 하루종일 와인 마시기 좋은 곳이 있을까싶다
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210925_70%2F1632543497120TXHpK_JPEG%2Fupload_ac5115618a7dbc5112e51abb43885d29.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dc954f08f87a842bc991004/review
# user_code = 5dc954f08f87a842bc991004
# review_id = 37558848_5dc954f08f87a842bc991004
# rating = 5
# date = 2021.09.17
# 리뷰 내용 : 복숭아레몬샤벳,,, 오래오래 팔아주세여,,, 시그니처메뉴 3가지 꼭 드세여,,,
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5be2d59307095f7661154c10/review
# user_code = 5be2d59307095f7661154c10
# review_id = 37558848_5be2d59307095f7661154c10
# rating = 5
# date = 2021.09.17
# 리뷰 내용 : 담엔 시그니처보단 글라스와인으로!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5daf083a8f87a842bc600fdf/review
# user_code = 5daf083a8f87a842bc600fdf
# review_id = 37558848_5daf083a8f87a842bc600fdf
# rating = 5
# date = 2021.09.11
# 리뷰 내용 : 너무너무 좋아요!!! 정말 ㅠㅠ 너무 예쁘고 라이스 비스켓 너무 쫀득 달달 꼬소 빠삭 맛있고 사장님 넘 친절하고 좋아요!! 카페 분위기도 좋고 옆에 소품가게도 있어서 오기 좋아요~
# 아 커피도 진짜 맛있었어요!!!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210919_80%2F16320243002396wqyd_JPEG%2Fupload_147f2958d6c9256f7a703ca82503fb80.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bca226f697c94664281c392/review
# user_code = 5bca226f697c94664281c392
# review_id = 37558848_5bca226f697c94664281c392
# rating = 4
# date = 2021.09.05
# 리뷰 내용 : 커피맛도 좋고 뷰도 좋아요. 라이스 비스킷은 시그니처라 먹어봤는데 맛있긴하지만 아주 특별하진 않고.. 가격이 사악한편이긴 합니다. 그래도 사장님 정말 친절하시고 기분좋은 방문이였어요!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f0d4169ca5cff09867a5793/review
# user_code = 5f0d4169ca5cff09867a5793
# review_id = 37558848_5f0d4169ca5cff09867a5793
# rating = 5
# date =
# 리뷰 내용 : 진짜 집같이 깨끗하고 디저트 맛있는 집 💗💗💗 향기가 너무 좋아요…. ☺️☺️
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e38c2d28f87a842bceb63a9/review
# user_code = 5e38c2d28f87a842bceb63a9
# review_id = 37558848_5e38c2d28f87a842bceb63a9
# rating = 5
# date = 2021.08.15
# 리뷰 내용 : 공간 예뻐요
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 647번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 돌모루
# 식당 구분 : 일식당
# ----------------------------------------------
# 리뷰 총 개수 : 4
# user_url = https://m.place.naver.com/my/5bfe13959be71ca6321ec13e/review
# user_code = 5bfe13959be71ca6321ec13e
# review_id = 1938776803_5bfe13959be71ca6321ec13e
# rating = 5
# date = 2021.07.17
# 리뷰 내용 : 정말 맛있어요! 반찬구성도 굿굿!! 진짜 나오는 반찬 다 맛있어요! 매운탕 잘 안먹는편인데 여긴 맛있어서 계속 먹었어요. 다음에 어내장탕도 먹으러  와봐야겠네요! 제주에서 회 드실거면 여기~ 추천합니다!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210723_296%2F1627016536377PmAVs_JPEG%2Fupload_ce28cfab1cf49e0b5ffda6f18e9cf9f5.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ce66f327dbd14195893fcef/review
# user_code = 5ce66f327dbd14195893fcef
# review_id = 1938776803_5ce66f327dbd14195893fcef
# rating = 5
# date = 2021.06.26
# 리뷰 내용 : 제철에 맞는 회를 맛있게 먹을수 있는곳 이었습니다 사장님 자부심을 갖고 장사하는 이유도 알겠네요  회도 맛있었지만 기본 반찬들도
# 정말 맛있었습니다 특히 이 돌모루 대표 메뉴라고 생각했던 어내장탕은 다른곳에서는 맛볼수 없었던 깔끔 그자체입니다 표선 방문하
# 시면 꼭 한번 들리실만한 곳이라고 추천합니다 경험해보세요 신선한 회와 맛있는 음식을 강추합니다
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e7dcb9e8f87a842bc425381/review
# user_code = 5e7dcb9e8f87a842bc425381
# review_id = 1938776803_5e7dcb9e8f87a842bc425381
# rating = 5
# date = 2021.06.22
# 리뷰 내용 : 먹느라사진도못찍고.. 초밥맛있구요. 반찬구성도좋아요. 사람들이 탕이맛있다고해서. 가봤는데.. 아..내장탕..작살납니다.표선에서는
# 갑이예요 내장탕 비려서못먹는데 여기내장탕먹고 물까지마셨는데..하나도안비립니다. 술도안마셨는데.해장했네요ㅋ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ba6fdd063a8336090be8eed/review
# user_code = 5ba6fdd063a8336090be8eed
# review_id = 1938776803_5ba6fdd063a8336090be8eed
# rating = 3.5
# date = 2021.01.04
# 리뷰 내용 : 초밥
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 648번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 뻘떡낙지모슬포점
# 식당 구분 : 낙지요리
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5cd51069c8552e7a5d15506a/review
# user_code = 5cd51069c8552e7a5d15506a
# review_id = 1864659561_5cd51069c8552e7a5d15506a
# rating = 5
# date = 2021.10.03
# 리뷰 내용 : 모슬포 찐맛집!!! 사장님도 너무 친절하시구 우리 식구 너무 좋아하는 식당이에요👍🏻👍🏻
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211003_59%2F1633260831121FlKOc_JPEG%2Fupload_b0281545cd3f5eaf7d3d588c73300968.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e9e4f488f87a842bc9a1372/review
# user_code = 5e9e4f488f87a842bc9a1372
# review_id = 1864659561_5e9e4f488f87a842bc9a1372
# rating = 5
# date = 2021.09.30
# 리뷰 내용 : 진짜 제주와서 최고의맛집
# 이집먹으러 산방산 또 올께요
# 반찬에서 이미 배차고 낙지 와 낙지파전 꼭 시키세요 꼭이요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ddc61529ec8258e4af6401a/review
# user_code = 5ddc61529ec8258e4af6401a
# review_id = 1864659561_5ddc61529ec8258e4af6401a
# rating = 4.5
# date = 2021.09.04
# 리뷰 내용 : 음식이 푸짐하고 맛있어요^^
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ce75ea752a51ea8196b592a/review
# user_code = 5ce75ea752a51ea8196b592a
# review_id = 1864659561_5ce75ea752a51ea8196b592a
# rating = 5
# date = 2021.08.18
# 리뷰 내용 : 매콤하고 맛있어요. 밥에 비벼먹어서 순삭
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210818_43%2F1629289041564HLIWG_JPEG%2Fupload_5f446b84859108d95194554587fe95b4.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b9b6234cb548ae6a1798c85/review
# user_code = 5b9b6234cb548ae6a1798c85
# review_id = 1864659561_5b9b6234cb548ae6a1798c85
# rating = 5
# date = 2021.08.08
# 리뷰 내용 : 3개월전에 방문했었는데 다시 가봤습니다. 예전에 비해서 메뉴 구성이 정말 좋아졌습니다. 재료는 예전과 같이 여전히 신선한 느낌이고 양도 많습니다. 메인인 낙지볶음 역시 맛있습니다. 아! 사장님께서도 참 친절하십니다. 여러모로 봤을때 가격대비 참 좋은 식당이라 생각합니다.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dcf4ea18f87a842bca677d9/review
# user_code = 5dcf4ea18f87a842bca677d9
# review_id = 1864659561_5dcf4ea18f87a842bca677d9
# rating = 5
# date = 2021.08.02
# 리뷰 내용 : 친절하시고 맛있어요 반찬 리필 셀프구요 계란후라이도 셀프로  구워드셔야해요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f0659b83f64550bfae7ed1d/review
# user_code = 5f0659b83f64550bfae7ed1d
# review_id = 1864659561_5f0659b83f64550bfae7ed1d
# rating = 5
# date = 2021.07.29
# 리뷰 내용 : 문어만두 최고입니다
# 지금까지 먹어본 만두중 최고~~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bab93933f4e4fe739d79ec1/review
# user_code = 5bab93933f4e4fe739d79ec1
# review_id = 1864659561_5bab93933f4e4fe739d79ec1
# rating = 5
# date = 2021.07.27
# 리뷰 내용 : 친절하고 맛있어요  아이들데리고가도 먹기좋고 가성비 너무 좋네요  간만에 맛있게 먹고 식당 잘 됬으면하는마음에  리뷰 처음써봐요
#  모슬포오시면 추천드려요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210727_271%2F1627379997718aHpJE_JPEG%2Fupload_d461c5289d6e4534e9292ce7dfeb65b2.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/60a0eb5c2d9ec80cdd2cd806/review
# user_code = 60a0eb5c2d9ec80cdd2cd806
# review_id = 1864659561_60a0eb5c2d9ec80cdd2cd806
# rating = 4
# date = 2021.06.26
# 리뷰 내용 : 동네에서 간단하게 식사하기 좋은 곳!! 사장님도 친절하시고 무엇보다 매워서 좋아용
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f0484f15a203ca38fa34f38/review
# user_code = 5f0484f15a203ca38fa34f38
# review_id = 1864659561_5f0484f15a203ca38fa34f38
# rating = 5
# date = 2021.06.20
# 리뷰 내용 : 사장님이 정말 친절하셨어요 잘먹었습니다!
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 649번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 인쌩맥주신서귀포점
# 식당 구분 : 맥주,호프
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5e26d4688f87a842bcf56273/review
# user_code = 5e26d4688f87a842bcf56273
# review_id = 1120201970_5e26d4688f87a842bcf56273
# rating = 2
# date = 2021.09.29
# 리뷰 내용 : 깔끔한 외관과 분위기 있는 인테리어에 방문했는데 서빙직원들이 별로예요. 음식이나 식기구도 건성으로 대충대충 놓아서 잘못하다간 바닥으로 바로 떨어질것 같고 방문시간때에는 여성 2분이 서빙하시던데 중단발 여성분은 주문도 잘못 받고 서빙도 잘못했는데 사과도 없이 그냥 가져가버리고 재방문 의사는 없을것 같습니다.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e67a8938f87a842bc4ac45e/review
# user_code = 5e67a8938f87a842bc4ac45e
# review_id = 1120201970_5e67a8938f87a842bc4ac45e
# rating = 5
# date = 2021.09.27
# 리뷰 내용 : 먹태랑 옛날김치우동 맛납니다..😇
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e3846c08f87a842bce226fb/review
# user_code = 5e3846c08f87a842bce226fb
# review_id = 1120201970_5e3846c08f87a842bce226fb
# rating = 4.5
# date = 2021.08.14
# 리뷰 내용 : 분위기 맛 오져
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bc7e8460d5b7f61fb66d95d/review
# user_code = 5bc7e8460d5b7f61fb66d95d
# review_id = 1120201970_5bc7e8460d5b7f61fb66d95d
# rating = 5
# date = 2021.06.14
# 리뷰 내용 : 생맥주 포장해서 시원하게 잘 마셨습니다!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c728f4874657006d8589062/review
# user_code = 5c728f4874657006d8589062
# review_id = 1120201970_5c728f4874657006d8589062
# rating = 0.5
# date = 2021.06.10
# 리뷰 내용 : 생맥주 가스도 없는데 장사하는 곳 생맥주집인데 생맥주가 없는.. 생맥주 조차 맛이 없는 집 다시는 갈일이 없는집  들어오는 손님도 말
# 리고 싶은곳
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c31e66fa7959d6f8878f7de/review
# user_code = 5c31e66fa7959d6f8878f7de
# review_id = 1120201970_5c31e66fa7959d6f8878f7de
# rating = 5
# date = 2021.05.24
# 리뷰 내용 : 저렴하고 맛있어용
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210524_147%2F16218635382502URYj_JPEG%2Fupload_a2db346e014214850c1d40b695a635a1.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5df5fe418f87a842bc2141b5/review
# user_code = 5df5fe418f87a842bc2141b5
# review_id = 1120201970_5df5fe418f87a842bc2141b5
# rating = 2.5
# date = 2021.05.20
# 리뷰 내용 : 쏘쏘
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5de5eb199ec8258e4a0d12c9/review
# user_code = 5de5eb199ec8258e4a0d12c9
# review_id = 1120201970_5de5eb199ec8258e4a0d12c9
# rating = 4.5
# date = 2021.05.01
# 리뷰 내용 : 저렴하고 가벼운 안주들이 많아서 2차로 자주 찾는 곳입니다.
# 특히 떡볶이 세트는 정말 가성비 갑이예요!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bef83714d6b6af76dcff4b2/review
# user_code = 5bef83714d6b6af76dcff4b2
# review_id = 1120201970_5bef83714d6b6af76dcff4b2
# rating = 2
# date = 2021.04.09
# 리뷰 내용 : 전 그냥 별루
# 안주를 맛없는걸 시킨건지 가격이 저렴해서 그런건지...
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d8b24778f87a842bce1a0eb/review
# user_code = 5d8b24778f87a842bce1a0eb
# review_id = 1120201970_5d8b24778f87a842bce1a0eb
# rating = 3.5
# date = 2021.04.07
# 리뷰 내용 : 생맥주집에서 멘보샤를 주문하여 다 먹지 못하고 탑을 쌓아버린 나 자신을 반성할 뿐.
# 맥주는 괜찮음.
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210410_57%2F1618033272184o2kPX_JPEG%2Fupload_86d30ad9064aa22a16dabc9874a4f479.jpg
# ----------------------------------------------
#
#
#
#
# ======================================================
# 650번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 이강통닭앤가츠
# 식당 구분 : 치킨,닭강정
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5d8b44678f87a842bc87eef5/review
# user_code = 5d8b44678f87a842bc87eef5
# review_id = 1644065620_5d8b44678f87a842bc87eef5
# rating = 4.5
# date = 2021.10.08
# 리뷰 내용 : 안심 등심 둘다 맛있었어요.애들도 맛있게 먹었고요~
# 치즈돈까스에 치즈가 듬뿍 들어 있었어요. 치즈돈까스를 더 많이 먹고 싶었는데 치즈가 다 떨어져서 많이 치즈가스를 2조각 밖에 못먹었어요ㅠ 순살바베큐 치킨도 맛있게 잘 먹었습니다~^^
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211008_128%2F1633698022380fug7R_JPEG%2Fupload_6a353ecef97f24cab89b62f85ed91537.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f05a868699d39675d9e0453/review
# user_code = 5f05a868699d39675d9e0453
# review_id = 1644065620_5f05a868699d39675d9e0453
# rating = 5
# date = 2021.10.02
# 리뷰 내용 : 친절하고 맛있어용 ㅎㅎ
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211002_283%2F16331478664603qRE2_JPEG%2Fupload_bce7cdcfba31d1f8305838be33bd3ab0.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b98c87a5a98d5993ed9f82c/review
# user_code = 5b98c87a5a98d5993ed9f82c
# review_id = 1644065620_5b98c87a5a98d5993ed9f82c
# rating = 5
# date = 2021.09.30
# 리뷰 내용 : 이집 찐 맛집 인정합니다. 어제 연돈보다 훨 나아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c0cd00feb84acc0f91a3c29/review
# user_code = 5c0cd00feb84acc0f91a3c29
# review_id = 1644065620_5c0cd00feb84acc0f91a3c29
# rating = 5
# date = 2021.09.28
# 리뷰 내용 :
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210928_128%2F1632794048161byRWI_JPEG%2Fupload_95b70003f021a9557a78e550dec9a50f.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ce1991a3b1f8a1c894f3ae9/review
# user_code = 5ce1991a3b1f8a1c894f3ae9
# review_id = 1644065620_5ce1991a3b1f8a1c894f3ae9
# rating = 5
# date = 2021.09.25
# 리뷰 내용 : 퍽퍽하지않고 육즙가득 촉촉한 숯불치킨은 여기가 처음이었요👍👍
# 오늘도 역시나 너무 맛있었어요!!  순살반반 포장해와서 밥 한공기 뚝딱했어요 ㅎㅎ
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210925_278%2F16325608346634otHv_JPEG%2Fupload_04f480388062d6ea37703a55a89ceb66.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d429b88c560744825e60876/review
# user_code = 5d429b88c560744825e60876
# review_id = 1644065620_5d429b88c560744825e60876
# rating = 5
# date = 2021.09.23
# 리뷰 내용 : 너~~~~무 너~~~~~무 맛있어요 후기 좋아서 여행와서 숙소근처라 갔는데 진작 가볼 걸 그랬어요  애들 둘도 너무 잘먹고... 여기 장점은
# 돈까스와 치킨을 한 곳에서 먹을 수 있다는것과 둘 다 우열을 가리기 힘들게 맛있었어요 사는 동네에 분점생기면 좋겠네요 같이 주는
# 카레도 맛나서 둘째가 밥에 잘먹네요 배 땅땅 두드리면서 진짜 잘먹었어요 원래는 바베큐 먹고싶었는데 아들이 후라이드 좋아해...
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d062e2ba6d4e2e2ba127ecf/review
# user_code = 5d062e2ba6d4e2e2ba127ecf
# review_id = 1644065620_5d062e2ba6d4e2e2ba127ecf
# rating = 5
# date = 2021.09.11
# 리뷰 내용 : 정말정말 맛있었어요~ 제주도 여행하면서 제일 맛있게 먹은거 같아요.  지금까지 살면서 먹은 돈가스 중에 제일 맛있었습니다^^ 돈가
# 스가 이렇게 부드러울수가 있다든게 너무 신기해요~  겉은 엄청 바삭 안은 완전 촉촉♡  여러분 두번가세요 세번가세요 제주도 가면 꼭
# 꼭 가세요~~~~
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210911_249%2F1631330940233yBfL8_JPEG%2Fupload_c246d1452fbbc3050ac0caac26af8cbb.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b9c7595d4d15ce2a5ccf5e7/review
# user_code = 5b9c7595d4d15ce2a5ccf5e7
# review_id = 1644065620_5b9c7595d4d15ce2a5ccf5e7
# rating = 5
# date = 2021.09.07
# 리뷰 내용 : 신랑과 아이와 갔는데 돈까스도 치킨도 먹고싶어 두개 다 시켰네요^^ 너무 맛있어서 순삭했네요
# 사장님도 친절하세요!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210912_103%2F1631408139846f3QLj_JPEG%2Fupload_e04c170bfd592643616be9d89da40074.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bf5760265200276323fd58a/review
# user_code = 5bf5760265200276323fd58a
# review_id = 1644065620_5bf5760265200276323fd58a
# rating = 5
# date = 2021.08.30
# 리뷰 내용 : 굿
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c1f0e6f3467ca597eb5dcf1/review
# user_code = 5c1f0e6f3467ca597eb5dcf1
# review_id = 1644065620_5c1f0e6f3467ca597eb5dcf1
# rating = 5
# date = 2021.08.28
# 리뷰 내용 : 숙소근처에 있어 미리보고나서 여행 마지막전날밤 먹어야지 생각하던차라  방문했어요~  마감시간이  얼마남지않아 포장으로 순살바
# 베큐 반반이랑  똥집팝콘 주문~매장 입장부터 나가는순간까지 사장님의 친절이 너무나 인상적이였고 , 나오면서 바로 똥집팝콘 한개를
# 먹어보니 빠삭함 최고~ㅎㅎ 숙소에 서둘러와서 나머지 메뉴도 먹어보니 치킨바베큐  너무 부드럽고 양념도 맛있어요~! 샐러드,...
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 651번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 바당한상
# 식당 구분 : 일식당
# ----------------------------------------------
# 리뷰 총 개수 : 1
# user_url = https://m.place.naver.com/my/5eaa8a148f87a842bcd91732/review
# user_code = 5eaa8a148f87a842bcd91732
# review_id = 1368419206_5eaa8a148f87a842bcd91732
# rating = 4
# date = 2021.05.19
# 리뷰 내용 : 음식 골고루 맛있어요.
# 매운탕이 없는게 아쉽네요.
# 진짜 배부르고 맛있게 먹었어요
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 652번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 유니스낵
# 식당 구분 : 종합분식
# ----------------------------------------------
# 리뷰 총 개수 : 0
#
#
# ======================================================
# 653번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 리틀보라카이
# 식당 구분 : 카페,디저트
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5eb548358f87a842bc722816/review
# user_code = 5eb548358f87a842bc722816
# review_id = 1947329475_5eb548358f87a842bc722816
# rating = 4.5
# date = 2021.10.12
# 리뷰 내용 : 맛있고 좋아요 보라카이 느낌나요 ㅋㅋㅋ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5cf69b9c05f76379b05c4b98/review
# user_code = 5cf69b9c05f76379b05c4b98
# review_id = 1947329475_5cf69b9c05f76379b05c4b98
# rating = 5
# date = 2021.10.12
# 리뷰 내용 : 너무맛있고 강아지가있었는데 너무 친절하게 배려해주셨어요 🧡🧡 음식 다 맛있어요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211012_297%2F16340337519065wMMt_JPEG%2Fupload_9c4f791a194ef1f6e344be6ee7db6fc0.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e9d75bc8f87a842bc3675e1/review
# user_code = 5e9d75bc8f87a842bc3675e1
# review_id = 1947329475_5e9d75bc8f87a842bc3675e1
# rating = 5
# date = 2021.10.12
# 리뷰 내용 : 매장 깔끔 음식 청결 맛 좋아요
# 재방문의향있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f2edcba9ec8258e4adc938a/review
# user_code = 5f2edcba9ec8258e4adc938a
# review_id = 1947329475_5f2edcba9ec8258e4adc938a
# rating = 5
# date = 2021.10.12
# 리뷰 내용 : 너무너무 맛있어요 뭣보다 직원분들 인성이 좋으심
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211012_290%2F1634031398143gnskG_JPEG%2Fupload_3786c8f2ddc9f7e8e5bead24c66bfe66.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bffc7cc5ebad211c6c052a6/review
# user_code = 5bffc7cc5ebad211c6c052a6
# review_id = 1947329475_5bffc7cc5ebad211c6c052a6
# rating = 5
# date = 2021.10.12
# 리뷰 내용 : 전복 게우 파스타 완전 맛잇어요👍🏻👍🏻👍🏻
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/6165233785c21e14eb31f845/review
# user_code = 6165233785c21e14eb31f845
# review_id = 1947329475_6165233785c21e14eb31f845
# rating = 5
# date = 2021.10.12
# 리뷰 내용 : 졸맛탱!!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211012_101%2F1634018156607xd2Qc_JPEG%2Fupload_54009ece93d85a213359c2edd6e23bbd.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e6dd6818f87a842bcf86567/review
# user_code = 5e6dd6818f87a842bcf86567
# review_id = 1947329475_5e6dd6818f87a842bcf86567
# rating = 5
# date = 2021.10.12
# 리뷰 내용 : 셀러드 사진만 있네요 ~~
# 제주도에서 먹었던 파스타 중에 당연 최고 였네요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211012_294%2F1634014349533AtgcX_JPEG%2Fupload_71bef3266620484459e1447d4eea7a55.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5fbe00b89dd241e6080c136b/review
# user_code = 5fbe00b89dd241e6080c136b
# review_id = 1947329475_5fbe00b89dd241e6080c136b
# rating = 5
# date = 2021.10.12
# 리뷰 내용 :
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211012_187%2F1634014339202Q6z9X_JPEG%2Fupload_9d52dd6a2d39c2a56662134212f616b8.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e9970568f87a842bcccfd1e/review
# user_code = 5e9970568f87a842bcccfd1e
# review_id = 1947329475_5e9970568f87a842bcccfd1e
# rating = 5
# date = 2021.10.11
# 리뷰 내용 : 사장님이랑 가게 직원분들 너무 친절하시고 분위기 너무 좋아요!! ㅎㅎ
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211011_70%2F1633957167102Wy617_JPEG%2Fupload_fcd4421dfe0ba9f70695ebd4bd2f40ad.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d5fbf878f87a842bcb1ec5d/review
# user_code = 5d5fbf878f87a842bcb1ec5d
# review_id = 1947329475_5d5fbf878f87a842bcb1ec5d
# rating = 5
# date = 2021.10.11
# 리뷰 내용 :
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20211011_223%2F1633957147815bGXgH_JPEG%2Fupload_f1a780f17e88d529dde3b28262bf99bd.jpg
# ----------------------------------------------
#
#
#
#
# ======================================================
# 654번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 미스터김
# 식당 구분 : 양식
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5d57c16bfacb83457ddbfab9/review
# user_code = 5d57c16bfacb83457ddbfab9
# review_id = 1342818931_5d57c16bfacb83457ddbfab9
# rating = 3
# date = 2021.09.23
# 리뷰 내용 : 넙죽이순한돈까스와 뭉텅이 순한치킨밥
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210923_218%2F1632396800762RcolO_JPEG%2Fupload_1d3c4a93fc086ccd1817e8299f43ba06.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e817c078f87a842bc544d46/review
# user_code = 5e817c078f87a842bc544d46
# review_id = 1342818931_5e817c078f87a842bc544d46
# rating = 4
# date = 2021.09.23
# 리뷰 내용 : 맛있어요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210923_291%2F1632396721548OBmeD_JPEG%2Fupload_5f2b44661f6e4c980bcc517741ab83b3.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e2fef468f87a842bc23d757/review
# user_code = 5e2fef468f87a842bc23d757
# review_id = 1342818931_5e2fef468f87a842bc23d757
# rating = 5
# date = 2021.08.28
# 리뷰 내용 : 수제돈까스 정말 맛있어요
# 그리고 치킨이 정말 부드럽고 맛나요!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210828_120%2F1630131442973Ppt3S_JPEG%2Fupload_35a8ace80d1867195b4c86b5e10f4491.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c652a262c51a04918dd0fd0/review
# user_code = 5c652a262c51a04918dd0fd0
# review_id = 1342818931_5c652a262c51a04918dd0fd0
# rating = 5
# date = 2021.07.05
# 리뷰 내용 : 맵돈 순돈 둘다 맛있었구 너무 친절하셨습니닼!!
# 치킨밥도 먹고싶었음!!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210705_185%2F1625461949329RQN4b_JPEG%2Fupload_127203414b75a5f314baf674eee35159.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c57839dcbb000137959e754/review
# user_code = 5c57839dcbb000137959e754
# review_id = 1342818931_5c57839dcbb000137959e754
# rating = 5
# date = 2021.06.12
# 리뷰 내용 : 와...연돈이랑 맞먹는 돈가스....꼭 드세요.. 2번 드세요 진짜!!!! 찍먹하시는 분들은 소스 따로 달라고 하기!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f05100195fe4a9e8ba9d897/review
# user_code = 5f05100195fe4a9e8ba9d897
# review_id = 1342818931_5f05100195fe4a9e8ba9d897
# rating = 5
# date = 2021.06.10
# 리뷰 내용 : 와 .. 우연히 들어간 곳에서 맛집 발견! 가족들이랑 같이 갔다가 다들 감동하고 나왔어요 강력 추천입니다!! 가성비 최고에요ㅠㅠ 사장님
# 돈 더 받으셔야할듯.. ⭐️⭐️⭐️넙죽이 돈까스⭐️⭐️⭐️*100000: 진짜 바삭 바삭하고 고기가 두툼해요.. 인생돈까스.. 소스 맛이 진짜 특
# 이합니다 하나도 안느끼하고 완전 맛있어요!! 왕 강추입니다  ⭐️⭐️⭐️뭉텅이 순한 치킨밥⭐️⭐️⭐️: 치킨에 밀가루가 엄청 얇아...
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5cc2d3efda24ebe59fe1aaae/review
# user_code = 5cc2d3efda24ebe59fe1aaae
# review_id = 1342818931_5cc2d3efda24ebe59fe1aaae
# rating = 5
# date = 2021.05.04
# 리뷰 내용 : 관광객 타겟은 아닌 곳인데 돈까스집 검색해서 찾아갔습니다 해물라면은 그동안 제주에서 먹은 것 중에 최고였고 돈가스 치킨도 맛있습니다 사장님도 친절하시고요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c74f2b06aff2bc2c55b8cb0/review
# user_code = 5c74f2b06aff2bc2c55b8cb0
# review_id = 1342818931_5c74f2b06aff2bc2c55b8cb0
# rating = 5
# date = 2021.04.29
# 리뷰 내용 : 돈까스맛이 너무 기가 막힌 맛입니다 소스도 맛있고 튀김도 바삭하고 이렇게 외진곳에 맛있는 집이 있다는게 놀랍습니다 다음에 또 올
# 께요 리뷰는 처음 남겨봅니다 넘 맛있어서..
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b833084b73b2a355ed9cd2e/review
# user_code = 5b833084b73b2a355ed9cd2e
# review_id = 1342818931_5b833084b73b2a355ed9cd2e
# rating = 5
# date = 2021.04.29
# 리뷰 내용 : 리뷰를  남기고   남기고  남기고  싶은맛 우리애가 여기만 찾으니 어쩌나요 사장님 대박나세요~~ 오늘도 잘 먹었습니다 ^^
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ef4d3248f87a842bc69e4f9/review
# user_code = 5ef4d3248f87a842bc69e4f9
# review_id = 1342818931_5ef4d3248f87a842bc69e4f9
# rating = 5
# date = 2021.04.14
# 리뷰 내용 : 너무 맛있어요! 순한맛은 애들이 먹기에도 맛있게 잘 먹을것같아요~
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210414_155%2F1618381601898KXKLa_JPEG%2Fupload_61fa9db72a84e45887e97dcf58892883.jpeg
# ----------------------------------------------
#
#
#
#
# ======================================================
# 655번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 희나리와돌맹이
# 식당 구분 : 카페,디저트
# ----------------------------------------------
# 리뷰 총 개수 : 0
#
#
# ======================================================
# 656번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 안뜨르
# 식당 구분 : 한식
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/609f5db57f27b83166e92519/review
# user_code = 609f5db57f27b83166e92519
# review_id = 1170172085_609f5db57f27b83166e92519
# rating = 5
# date = 2021.10.12
# 리뷰 내용 : ㅇㅇ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f1ce33b6120d0a4d538967b/review
# user_code = 5f1ce33b6120d0a4d538967b
# review_id = 1170172085_5f1ce33b6120d0a4d538967b
# rating = 5
# date = 2021.09.22
# 리뷰 내용 : 정-말 잘먹고 돌아가요 :) 동쪽 유명한 전복구이집을 좋아해서 제주오면 들리곤했는데 이제 안뜨르가 저의 제주 최애 전복집 입니다~
# 특히 야채랑 내장까지 구워서 나오고 상큼한 샐러드가 있어서 느끼할때 먹음 좋더라구요 일행은 구이를 안좋아해서 솥밥먹고 혼자 8개
# 다 먹고가요 ㅎㅎ 기본솥밥만 시켜도 반찬 잘나오고 부족한건 없는지 챙겨주시는 직원분들도 감사했어용 장소 저장하기 꾹 누르...
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210922_73%2F1632291002622MELkU_JPEG%2Fupload_2d9759600872d0847d46d748c749c7cd.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f46ddb4a602e98f56c29703/review
# user_code = 5f46ddb4a602e98f56c29703
# review_id = 1170172085_5f46ddb4a602e98f56c29703
# rating = 5
# date = 2021.09.19
# 리뷰 내용 : 우연히 찾아낸 맛집! 훈남직원들 넘 친절하시고 맛도 가성비 가심비 모두 백점!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ca4ca74528ecc8cac2f3f15/review
# user_code = 5ca4ca74528ecc8cac2f3f15
# review_id = 1170172085_5ca4ca74528ecc8cac2f3f15
# rating = 5
# date = 2021.09.18
# 리뷰 내용 : 올레7코스 중간쯤에 우연히 들른 소담한 식당에서 진심어린 음식을 먹고 생애 첫 리뷰를 써봅니다. 전복솥밥을 시켰는데 거의 정식처
# 럼 계속나온 음식들~감동이였어요. 토토리전이나오구 양배추삶은거에 강된장을 싸서 먹게 나오구~다먹고나니 더드시라면서 한번도
# 새롭게 끓여서 주셨어요 잡채도 주시고 배불렀는데 전복밥이 나와서 맛나게 된장국과함께 먹었어요. 반찬도 정갈하게 4가지를~...
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c1313e8eaf0146b2b96aa6e/review
# user_code = 5c1313e8eaf0146b2b96aa6e
# review_id = 1170172085_5c1313e8eaf0146b2b96aa6e
# rating = 4.5
# date = 2021.08.29
# 리뷰 내용 : 반찬 가지수도 넉넉하고 양도 많아 배부르고 기분좋게 먹었어요. 이가격에 이정도면 매우 훌륭하다고 생각이 들어요.  반찬 양이나 맛도 체크하시고 친절하게 응대해주셔서 기분이 좋았네요. 옥돔구이가 특히 맛이 좋았어요 .
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bbe188447e7210e59e5639c/review
# user_code = 5bbe188447e7210e59e5639c
# review_id = 1170172085_5bbe188447e7210e59e5639c
# rating = 4.5
# date = 2021.08.28
# 리뷰 내용 : ⭐️⭐️⭐️⭐️(4.5점)
# 반찬구성이나 전체적으로 좋았습니다-
# 음식이 제 입맛에는 조금 짠편이라 아쉬웠어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e8f67d28f87a842bc0ad482/review
# user_code = 5e8f67d28f87a842bc0ad482
# review_id = 1170172085_5e8f67d28f87a842bc0ad482
# rating = 5
# date = 2021.08.24
# 리뷰 내용 : 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5efe0b1967c6d4320f571642/review
# user_code = 5efe0b1967c6d4320f571642
# review_id = 1170172085_5efe0b1967c6d4320f571642
# rating = 5
# date = 2021.08.23
# 리뷰 내용 : 숙소 근처를 찾다가 오게 되었는데 너무 맛있게 잘 먹고 가요! 먹으면서 계속 맛있다고 몇 번을 말했나 몰라요, 직원분들 모두 너무 친절
# 하시구 재료들도 신선하고 나오는 음식과 반찬 하나하나 다 맛있었습니다!  코스 구성도 엄청 푸짐하고 다양해요  든든한 제주 밥 드시
# 고 싶으신 분들께 추천드려용
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c674c083c6384a8570e6891/review
# user_code = 5c674c083c6384a8570e6891
# review_id = 1170172085_5c674c083c6384a8570e6891
# rating = 5
# date = 2021.08.08
# 리뷰 내용 : 아하하 찐 싹 먹어서..빈 그릇 사진입니다.^^;
# 우선 맛있어요..전복밥 부드럽고 비리지않고 반찬들 정성 스럽고요. 아이와 함께 갔는데 친절하시고 배려해 주시고 주차 안쪽에 완전 편합니다. 그리고 옥돔구이가 나와요 ㅋㅋ 그냥 전복솥밥인데요!^^♡
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210809_131%2F1628467761493QOjrT_JPEG%2Fupload_e33e392f47696585a967353d7ca15627.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d2f88230d3fcc7a0d0cbb0f/review
# user_code = 5d2f88230d3fcc7a0d0cbb0f
# review_id = 1170172085_5d2f88230d3fcc7a0d0cbb0f
# rating = 5
# date = 2021.07.31
# 리뷰 내용 : 3박 4일 여행중 가장 맛있고 가장 기분좋게 식사한 곳입니다. 코로나 시국에 식구끼리 밥먹어도 눈치봐야하는데 편하게 맛있게 즐겁게
# 먹었어요. 음식 하나하나 반찬하나하나 정갈하게 나오고 밥값 지불하는데도 하나도 아깝지않게 잘먹었습니다. 다음여행에도 꼭 가고
# 싶을만큼 맛있는집입니다.분위기도 좋고 참 맘에 드는곳이네요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210731_258%2F1627742043566lU3II_JPEG%2Fupload_f41926ef3c94368f2fd93c9b0399f5b1.jpg
# ----------------------------------------------
#
#
#
#
# ======================================================
# 657번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 구억마을옹기카페
# 식당 구분 : 카페,디저트
# ----------------------------------------------
# 리뷰 총 개수 : 0
#
#
# ======================================================
# 658번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 해촌바지락
# 식당 구분 : 비빔밥
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5b9102c9ba138a114f94c809/review
# user_code = 5b9102c9ba138a114f94c809
# review_id = 1553045543_5b9102c9ba138a114f94c809
# rating = 5
# date = 2021.09.19
# 리뷰 내용 : 깨끗하고, 친절하고 ,맛있어요.
# 바지락탕은 시원하고, 바지락 비빔밥은
# 바지락 바로 무쳐나와서 감칠맛 나고 맛있어요.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dd754d39ec8258e4a6ac55d/review
# user_code = 5dd754d39ec8258e4a6ac55d
# review_id = 1553045543_5dd754d39ec8258e4a6ac55d
# rating = 4
# date = 2021.09.10
# 리뷰 내용 : 칼국수 딱 바지락칼숙수 맛이고 ㅎㅎ 바지락비빔밥 맛있었고, 부침개도 바삭하니 맛나게 잘먹었어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f366cbf9ec8258e4a05dcaf/review
# user_code = 5f366cbf9ec8258e4a05dcaf
# review_id = 1553045543_5f366cbf9ec8258e4a05dcaf
# rating = 5
# date = 2021.08.02
# 리뷰 내용 : 흔한 비빔밥처럼 간이쌔거나 고추장맛이 강하거나 그런거 하나없이 맛잇어요! 제주도 여행하면서 제일 맛잇는거같아요 비빔밥을 좋아
# 하는 편이 아닌대 여기는 양도 많고 비빔밥에 신선한채소도 잇고 배도 들어가있나바요 식감도 너무 좋아요 20대 연인끼리 점심에 먹기
# 편할거같아요!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210802_233%2F1627898674039esUDN_JPEG%2Fupload_a27839b0bff675a13c62cf67c58cc31b.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c8b9c0064b6dc727ccd665e/review
# user_code = 5c8b9c0064b6dc727ccd665e
# review_id = 1553045543_5c8b9c0064b6dc727ccd665e
# rating = 5
# date = 2021.07.16
# 리뷰 내용 : 바지락비빔밥  너무 맛있어요. 야채도 싱싱하고 양념의 비법이 궁금합니다^^  이폭우에도 먹겠다는 일념으로 찾아가서 역시나 맛있게 먹었습니다.^^
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210716_201%2F1626404664363KOzPV_JPEG%2Fupload_4812f2dbfa1fe663da4f25b0afc4c3b0.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d319417ce46875ac0ab0391/review
# user_code = 5d319417ce46875ac0ab0391
# review_id = 1553045543_5d319417ce46875ac0ab0391
# rating = 5
# date = 2021.07.14
# 리뷰 내용 : 양도많고 비릿내 1도없음. 재방문의사 100%
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210714_50%2F1626240813090RoxCd_JPEG%2Fupload_4d9da4aaa0d7c14f143e6843238c4b33.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b794cc32f94c2308cb81e68/review
# user_code = 5b794cc32f94c2308cb81e68
# review_id = 1553045543_5b794cc32f94c2308cb81e68
# rating = 4.5
# date = 2021.07.12
# 리뷰 내용 : 신선하고 맛있어요
# 다만 오이당근채가 너무 길어서 입가에 자주 묻어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b794cc32f94c2308cb81e68/review
# user_code = 5b794cc32f94c2308cb81e68
# review_id = 1553045543_5b794cc32f94c2308cb81e68
# rating = 5
# date = 2021.07.01
# 리뷰 내용 : 깔끔한맛입니다
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e69959e8f87a842bc860c71/review
# user_code = 5e69959e8f87a842bc860c71
# review_id = 1553045543_5e69959e8f87a842bc860c71
# rating = 5
# date = 2021.06.26
# 리뷰 내용 : 바지락 신선하고 통통하고 좋았습니다
# 비빔밥과 칼국수 그리고 바지락전을 먹었는데 간도 잘 맞고 짜지 않고 깊은 맛을 느낄 수 있어서 좋았습니다 다음에 또 가고 싶은 곳입니다
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210626_261%2F1624707702314Na4Uo_JPEG%2Fupload_af5361742d77631e40cf216ac4be6ef1.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e85ea4b8f87a842bc1d2591/review
# user_code = 5e85ea4b8f87a842bc1d2591
# review_id = 1553045543_5e85ea4b8f87a842bc1d2591
# rating = 5
# date = 2021.06.08
# 리뷰 내용 : 굿
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e04d8a98f87a842bc2286bc/review
# user_code = 5e04d8a98f87a842bc2286bc
# review_id = 1553045543_5e04d8a98f87a842bc2286bc
# rating = 5
# date = 2021.06.02
# 리뷰 내용 : 굿
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 659번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 연남물갈비서귀포점
# 식당 구분 : 육류,고기요리
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5d934cd58f87a842bc8e7077/review
# user_code = 5d934cd58f87a842bc8e7077
# review_id = 1056052810_5d934cd58f87a842bc8e7077
# rating = 4.5
# date = 2021.10.07
# 리뷰 내용 : 물갈비라는걸 처음 먹어봤는데 야채가 많고 국물이 달콤매콤하게 맛있구여 육전물막국수는 최고! 또 먹고싶네요~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c9c9fde287137d47b9def89/review
# user_code = 5c9c9fde287137d47b9def89
# review_id = 1056052810_5c9c9fde287137d47b9def89
# rating = 4.5
# date = 2021.09.20
# 리뷰 내용 : 연휴 첫날 문 연 가게도 많지 않은데 급하게 찾아간 곳인데도 불구하고 아이랑 부모님 모시고 한끼 하기 좋았어요 버섯이랑 파채 추가했는데 양 많이 주시구 ㅋ ㅋ ㅋ직원분도 혼자 바쁘셨는데 시크한듯 친절하셨어요👍🏻👍🏻👍🏻👍🏻👍🏻
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210920_292%2F1632115124403Rka42_JPEG%2Fupload_ccd3c9658fee14f630c530db1ed0f2f0.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c634ca507383898e0e48291/review
# user_code = 5c634ca507383898e0e48291
# review_id = 1056052810_5c634ca507383898e0e48291
# rating = 5
# date = 2021.09.19
# 리뷰 내용 : 맛있게 잘 먹었어요!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c73da6a9443547e8f6b58cd/review
# user_code = 5c73da6a9443547e8f6b58cd
# review_id = 1056052810_5c73da6a9443547e8f6b58cd
# rating = 5
# date = 2021.09.11
# 리뷰 내용 : 연남물갈비 서귀포점 강추합니다 사장님도 친절하시고 새로 오픈하여 매장이 아주 깨끗합니다 무엇보다 너무 맛있어요 많이 먹어도
# 부담스럽지 않은 깔끔한 맛입니다 서귀포가신다면 추천드립니다
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b794cc32f94c2308cb81e68/review
# user_code = 5b794cc32f94c2308cb81e68
# review_id = 1056052810_5b794cc32f94c2308cb81e68
# rating = 5
# date = 2021.09.06
# 리뷰 내용 : 점심특선으로 볶음밥까지 먹었는데 양많고 맛있었네요ㅎㅎ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e120a888f87a842bc301008/review
# user_code = 5e120a888f87a842bc301008
# review_id = 1056052810_5e120a888f87a842bc301008
# rating = 5
# date = 2021.09.04
# 리뷰 내용 : 음식도 깔끔하고. 마지막볶음밥하나만주문했는데.
# 양은둘이먹어도남았어요.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c108700d6a2ba3087f49f25/review
# user_code = 5c108700d6a2ba3087f49f25
# review_id = 1056052810_5c108700d6a2ba3087f49f25
# rating = 4.5
# date = 2021.08.31
# 리뷰 내용 : 맛있어요
# 육전이 더 맛있었어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d7271ec8f87a842bc2b0382/review
# user_code = 5d7271ec8f87a842bc2b0382
# review_id = 1056052810_5d7271ec8f87a842bc2b0382
# rating = 3
# date = 2021.08.10
# 리뷰 내용 : 평범했어요! 국물맛이 약간 떡볶이 맛??
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210810_75%2F1628595297977HuJI8_JPEG%2Fupload_835846bed5c9b4971c6b8442a2fbf3be.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c0e10b67a6c315300b9bc61/review
# user_code = 5c0e10b67a6c315300b9bc61
# review_id = 1056052810_5c0e10b67a6c315300b9bc61
# rating = 5
# date = 2021.08.08
# 리뷰 내용 : 야들야들한 등갈비에 신선한 채소 듬뿍! 얇게 썰어진 샤브고기가 수북하게 쌓아올려진 물갈비 맛집이에요!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210808_172%2F1628400606389u0wJ3_JPEG%2Fupload_c4311466e9a58f760f818eefb3bd4a46.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ddb98f39ec8258e4aacea4f/review
# user_code = 5ddb98f39ec8258e4aacea4f
# review_id = 1056052810_5ddb98f39ec8258e4aacea4f
# rating = 5
# date = 2021.08.04
# 리뷰 내용 : 처음먹어본 물갈비!! 너무 맛있게 먹었어요!
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 660번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 마시오름
# 식당 구분 : 요리주점
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5de5b0f69ec8258e4aef8b72/review
# user_code = 5de5b0f69ec8258e4aef8b72
# review_id = 1654757633_5de5b0f69ec8258e4aef8b72
# rating = 5
# date = 2021.09.22
# 리뷰 내용 : 오랜만에 먹은 버섯전골 홍탕 !!  신라면 맵기의 2배라고 설명해주시는ㄷㅔ 그 말씀이 딱 맞아용  넘마시써.......
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210924_165%2F1632457696355hsjKv_JPEG%2Fupload_999e7b852ec03a89fbe1a2379d990bbc.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5de5b0f69ec8258e4aef8b72/review
# user_code = 5de5b0f69ec8258e4aef8b72
# review_id = 1654757633_5de5b0f69ec8258e4aef8b72
# rating = 5
# date = 2021.08.24
# 리뷰 내용 : 제주시 사는 친구한테 소개시켜줬어용
# 밥먹구 가서 상큼하게 청어알쌈 ! 크 ~~~
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210824_287%2F1629784952865W8Oet_JPEG%2Fupload_e495766d0a5081376adffcc93ebb4391.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5de5b0f69ec8258e4aef8b72/review
# user_code = 5de5b0f69ec8258e4aef8b72
# review_id = 1654757633_5de5b0f69ec8258e4aef8b72
# rating = 5
# date = 2021.08.24
# 리뷰 내용 : 동생들이랑 동ㄴㅔ술집 !
# 친절함은 물론이고 존맛 .. 💚
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210824_2%2F1629784857561fQmho_JPEG%2Fupload_abe21f7356272e38484ca11c2b544f2f.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c210790cff02b306eb9f5e4/review
# user_code = 5c210790cff02b306eb9f5e4
# review_id = 1654757633_5c210790cff02b306eb9f5e4
# rating = 5
# date = 2021.08.12
# 리뷰 내용 : 서귀포 맛집 한시간 찾아 들어갓는데 너무 맛잇네요!!!!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5cfc865e715edd1964249f9d/review
# user_code = 5cfc865e715edd1964249f9d
# review_id = 1654757633_5cfc865e715edd1964249f9d
# rating = 5
# date = 2021.08.12
# 리뷰 내용 : 사장님도 친절하시구 음식도 맛있어요~
# 가정집 개조해서 만든거라 인테리어도 멋져요^^
# 번창하세요!!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ee5db238f87a842bc82820c/review
# user_code = 5ee5db238f87a842bc82820c
# review_id = 1654757633_5ee5db238f87a842bc82820c
# rating = 5
# date = 2021.08.10
# 리뷰 내용 : 기본 반찬도 너무 맛있고 제주놀라와서 먹은 음식중 제일 괜찮은것 같아요 좋은 추억 만들다 갑니다 너무 잘먹었어요 여기 생각나서 제주도 또 와야겠네요 최고에요!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5efe4f96670bd5c7e120a24f/review
# user_code = 5efe4f96670bd5c7e120a24f
# review_id = 1654757633_5efe4f96670bd5c7e120a24f
# rating = 5
# date = 2021.08.04
# 리뷰 내용 : 너무 맛있게 잘 먹었습니다^~^* 덕분에 좋은 여행되었네요 인테리어도 이쁘고 얼큰버섯전골 진짜 중독적이구요,미나리새우전 튀기신
# ...
# review_id = 1189743089_5ba0636354fc623d6649eed4
# rating = 5
# date = 2021.05.17
# 리뷰 내용 : 기대안하고 수제버거 땡겨서 찾다가 가까운곳에 있어서 갔는데 왠지 원하는 진짜 수제버거 맛 아닐까바 걱정했는데  생각보다 맛있었
# 어요 :)
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e776f0f8f87a842bc5aae2f/review
# user_code = 5e776f0f8f87a842bc5aae2f
# review_id = 1189743089_5e776f0f8f87a842bc5aae2f
# rating = 0.5
# date = 2021.05.12
# 리뷰 내용 : 리뷰 안남기는데 처음 남김 업장에서 흑돼지새우버거에 새우를 넣지않는 실수를 하고 오히려 손님을 이상한 사람 취급. 무언가 실수하
# 거나 잘못하셨으면 인정하는 법, 그리고 죄송합니다라는 말을 배우셔야할듯.  서비스 0점. 친절도 0점. 맛 1점도 아깝. 제주여행의 마지
# 막날 기분 더럽게 마무리.
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210514_240%2F1620963093409pc1vM_JPEG%2Fupload_12285205e78a372d6979a1d7609bc422.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f0a887e9ec8258e4a34be91/review
# user_code = 5f0a887e9ec8258e4a34be91
# review_id = 1189743089_5f0a887e9ec8258e4a34be91
# rating = 4.5
# date = 2021.05.08
# 리뷰 내용 : 맛있네요 ~~
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210508_78%2F1620441050256BFU5q_JPEG%2Fupload_d313cffa507504d4d6270b9269bca738.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5ed5958f8f87a842bc85ba16/review
# user_code = 5ed5958f8f87a842bc85ba16
# review_id = 1189743089_5ed5958f8f87a842bc85ba16
# rating = 4
# date = 2021.05.08
# 리뷰 내용 : 맛있어요 ~~~
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210508_40%2F1620440544768h1adu_JPEG%2Fupload_4d4ac7a384c390a555aef353ff404bb8.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5decc3b38f87a842bc461b5c/review
# user_code = 5decc3b38f87a842bc461b5c
# review_id = 1189743089_5decc3b38f87a842bc461b5c
# rating = 5
# date = 2021.05.07
# 리뷰 내용 : 꽃담버거 드세요 제일 맛남
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c25c0659372242f2d9ef8d1/review
# user_code = 5c25c0659372242f2d9ef8d1
# review_id = 1189743089_5c25c0659372242f2d9ef8d1
# rating = 4
# date = 2021.05.02
# 리뷰 내용 : 맛있네요~
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d8717188f87a842bcadf0da/review
# user_code = 5d8717188f87a842bcadf0da
# review_id = 1189743089_5d8717188f87a842bcadf0da
# rating = 4.5
# date = 2021.05.01
# 리뷰 내용 :
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210501_290%2F16198582424563jK8X_JPEG%2Fupload_2ce4c2b633f253880cfe1812ba2bac5e.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f82793d6c3d7f73347c4eea/review
# user_code = 5f82793d6c3d7f73347c4eea
# review_id = 1189743089_5f82793d6c3d7f73347c4eea
# rating = 3.5
# date = 2021.04.30
# 리뷰 내용 : ㅠㅠ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c24715d66560cfe62c63e12/review
# user_code = 5c24715d66560cfe62c63e12
# review_id = 1189743089_5c24715d66560cfe62c63e12
# rating = 5
# date = 2021.04.30
# 리뷰 내용 : 가게도 예쁘고 음식도 맛나용 :) 오메기과일떡 진짜 너무 맛있어용 :)
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210503_100%2F1620028917517Pqyla_JPEG%2Fupload_1ad4f2a08477631097db00192c333002.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bc99f06b489e47f94b49dc7/review
# user_code = 5bc99f06b489e47f94b49dc7
# review_id = 1189743089_5bc99f06b489e47f94b49dc7
# rating = 5
# date = 2021.04.29
# 리뷰 내용 : 흑돼지버거세트 너무 맛있어요.
# 쉑쉑버거보다 훨씬 커요. 고기도 푸짐하고 부드러워요.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e30c08a8f87a842bcf01849/review
# user_code = 5e30c08a8f87a842bcf01849
# review_id = 1189743089_5e30c08a8f87a842bcf01849
# rating = 5
# date = 2021.04.28
# 리뷰 내용 : 아침에 길가다가 들렸는데 와...여러분 여기 진짜 개존맛탱 수제버거집입니다...흑돼지버거,흑돼지 새우버거 ㄹㅇ 맛있어서 울면서 먹었습니다 와 여기 꼭 오세요!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d9bdc028f87a842bc67b44d/review
# user_code = 5d9bdc028f87a842bc67b44d
# review_id = 1189743089_5d9bdc028f87a842bc67b44d
# rating = 2.5
# date = 2021.04.27
# 리뷰 내용 : 쏘쏘에요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f5da9a76c3d7f733489f72c/review
# user_code = 5f5da9a76c3d7f733489f72c
# review_id = 1189743089_5f5da9a76c3d7f733489f72c
# rating = 4
# date = 2021.04.25
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5de288d39ec8258e4ac46cc4/review
# user_code = 5de288d39ec8258e4ac46cc4
# review_id = 1189743089_5de288d39ec8258e4ac46cc4
# rating = 4
# date = 2021.04.24
# 리뷰 내용 : 좀비싼편인데 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5eaac3888f87a842bc865e7a/review
# user_code = 5eaac3888f87a842bc865e7a
# review_id = 1189743089_5eaac3888f87a842bc865e7a
# rating = 1.5
# date = 2021.04.23
# 리뷰 내용 : 주문받는 남자분 말투가 퉁명스럽네요
# 그래도 맛있게 먹고있는데 뭔가 질긴 내용물이 있어서 봤더니 토마토 윗둥이더구요 토마토 위아래는 껍질부위가 많아 질길수 있는데...버거가격이 싼것도 아닌데 아쉽네요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210423_153%2F1619164560646WKJPt_JPEG%2Fupload_f40c6cd79eee6cab64a234b04c145ca8.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bd7159211001a66e260c535/review
# user_code = 5bd7159211001a66e260c535
# review_id = 1189743089_5bd7159211001a66e260c535
# rating = 5
# date = 2021.04.19
# 리뷰 내용 : 팥죽맛집 ㅎㅎ 작년에도 왔었는데 또 생각나서 왓어요 ~!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bacdaa65cfe0fe754ea82cc/review
# user_code = 5bacdaa65cfe0fe754ea82cc
# review_id = 1189743089_5bacdaa65cfe0fe754ea82cc
# rating = 4
# date = 2021.04.19
# 리뷰 내용 : 직접 만든 팥이라 그런지 건강한 맛이에요 근데 나오는 양이나 토픽을 보니 가격은 조금 비싸다 생각이 들었어요 빙수 먹다보니 옆에서
#  버거만드는 냄새가 좋아서 버거 먹으러 한 번 더 가볼 것 같아요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210419_63%2F1618823012506w6r2I_JPEG%2Fupload_1e4814ecb322a6c546e4b5afa8d85133.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c2a2c669c05b76438756725/review
# user_code = 5c2a2c669c05b76438756725
# review_id = 1189743089_5c2a2c669c05b76438756725
# rating = 5
# date = 2021.04.18
# 리뷰 내용 : 맛있어요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210419_154%2F1618791376731vW37i_JPEG%2Fupload_5d96c85250ea7b4d8ead496f0e502baa.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b8c997fac7af4fac13b92f1/review
# user_code = 5b8c997fac7af4fac13b92f1
# review_id = 1189743089_5b8c997fac7af4fac13b92f1
# rating = 4.5
# date = 2021.04.17
# 리뷰 내용 :
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210417_102%2F1618622024530Yep5V_JPEG%2Fupload_45f59233d32b9c014c371eadd36b29f9.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e51430b8f87a842bc93900e/review
# user_code = 5e51430b8f87a842bc93900e
# review_id = 1189743089_5e51430b8f87a842bc93900e
# rating = 1
# date = 2021.04.16
# 리뷰 내용 : 애견있어서 "가게 밖"에서 기다리는데 쫒아나와서 강아지 데리고왔으면 자기네한테 말하라고;;
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f05d0cd67168be0227679bc/review
# user_code = 5f05d0cd67168be0227679bc
# review_id = 1189743089_5f05d0cd67168be0227679bc
# rating = 5
# date = 2021.04.13
# 리뷰 내용 : 정말 맛있어요 ~~ㅎㅎ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5efe139f15c4bcd43058b818/review
# user_code = 5efe139f15c4bcd43058b818
# review_id = 1189743089_5efe139f15c4bcd43058b818
# rating = 5
# date = 2021.04.13
# 리뷰 내용 : 맛잇어용
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bd54f5499dc1016a040b794/review
# user_code = 5bd54f5499dc1016a040b794
# review_id = 1189743089_5bd54f5499dc1016a040b794
# rating = 4.5
# date = 2021.04.12
# 리뷰 내용 : 맛있어요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210412_78%2F16182228337372Se5p_JPEG%2Fupload_c83e9a376273e7691d8c6b2314f9f9c1.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c336d8983c3aa8e3c5665d9/review
# user_code = 5c336d8983c3aa8e3c5665d9
# review_id = 1189743089_5c336d8983c3aa8e3c5665d9
# rating = 3.5
# date = 2021.04.10
# 리뷰 내용 : 맛있어요
# 근데 좀 정리하면서 하셯음
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bbb58b0b371b69bbe88158e/review
# user_code = 5bbb58b0b371b69bbe88158e
# review_id = 1189743089_5bbb58b0b371b69bbe88158e
# rating = 5
# date = 2021.04.09
# 리뷰 내용 : 햄버거도 맛있었지만 생과일 오메기떡도 일품!! 또 먹고 싶은 맛이네요.. 가게 안에서 바라보는 성산 일출봉도 짱!! (안구 정화 ㅋ) 너무
# 좋아 힐링 잘 하고 왔어요.. 대박 나시길...^^
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/606fe5c2a349a590953f88b1/review
# user_code = 606fe5c2a349a590953f88b1
# review_id = 1189743089_606fe5c2a349a590953f88b1
# rating = 5
# date = 2021.04.09
# 리뷰 내용 : 토착형 수제버거 아이덴티티 확실합니다. 카페 아름다운 정경은 덤!!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/6040907d9da70eae49ba87ad/review
# user_code = 6040907d9da70eae49ba87ad
# review_id = 1189743089_6040907d9da70eae49ba87ad
# rating = 5
# date = 2021.04.08
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c258965fa2cce79ad708a01/review
# user_code = 5c258965fa2cce79ad708a01
# review_id = 1189743089_5c258965fa2cce79ad708a01
# rating = 3
# date = 2021.04.07
# 리뷰 내용 : 패티가 아니구 고기 구워올려서 그런지 기름이 줄줄흐르고 느끼했습니다..
# 고기는 간장에절여서 올리셨는지 일반 간장돼지불고기맛이였습니다. 가게 분위기는 좋았습니다
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210407_35%2F1617766851393ckruW_JPEG%2Fupload_e08c9317e84321b8c393969d93d874c1.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e9e31488f87a842bcb9cc9e/review
# user_code = 5e9e31488f87a842bcb9cc9e
# review_id = 1189743089_5e9e31488f87a842bcb9cc9e
# rating = 4
# date = 2021.04.04
# 리뷰 내용 : 햄버거 존마탱
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dc4aa838f87a842bc098aca/review
# user_code = 5dc4aa838f87a842bc098aca
# review_id = 1189743089_5dc4aa838f87a842bc098aca
# rating = 5
# date = 2021.04.04
# 리뷰 내용 : 여기 왜 제주도 맛집랭킹에 왜 없을까요?
# 제가 제주도에서 먹은 버거. 토스트 다합쳐서 제일 맛있는 집인데요? 진짜 너무 맛집인데 제발 많이들 오세요 제발
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210404_99%2F1617503898555K1FBn_JPEG%2Fupload_e90415bc5de7f1b6b80251771ceb5368.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e37b3ec8f87a842bce774db/review
# user_code = 5e37b3ec8f87a842bce774db
# review_id = 1189743089_5e37b3ec8f87a842bce774db
# rating = 5
# date = 2021.04.04
# 리뷰 내용 : 오메기떡중에 젤맛있는거같아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5eb8c21e8f87a842bc2e7625/review
# user_code = 5eb8c21e8f87a842bc2e7625
# review_id = 1189743089_5eb8c21e8f87a842bc2e7625
# rating = 5
# date = 2021.03.26
# 리뷰 내용 : 분위기좋고 맛도좋구
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5eb15f318f87a842bc196206/review
# user_code = 5eb15f318f87a842bc196206
# review_id = 1189743089_5eb15f318f87a842bc196206
# rating = 5
# date = 2021.03.24
# 리뷰 내용 : 제주도 원톱 가성비 맛집입니다. 진짜루!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5eaa8d598f87a842bc125189/review
# user_code = 5eaa8d598f87a842bc125189
# review_id = 1189743089_5eaa8d598f87a842bc125189
# rating = 4
# date = 2021.03.23
# 리뷰 내용 : 포장에서 숙소에서 먹었는데 식어도 맛이있어요 빵이 진짜 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c23893a17dd427a35728126/review
# user_code = 5c23893a17dd427a35728126
# review_id = 1189743089_5c23893a17dd427a35728126
# rating = 5
# date = 2021.03.20
# 리뷰 내용 : 맛있어요 ㅋㅋ 버거가 엄청커요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e3f523d8f87a842bc9a7fba/review
# user_code = 5e3f523d8f87a842bc9a7fba
# review_id = 1189743089_5e3f523d8f87a842bc9a7fba
# rating = 5
# date = 2021.03.17
# 리뷰 내용 : 성산일출봉 바로 앞 돌담집. 흑돼지버거 맛있어요~
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210407_57%2F1617751678361xy3x2_JPEG%2Fupload_871cd7afee57e6e3cbad2bb0b2aa5030.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dfe9c2f8f87a842bc1c9475/review
# user_code = 5dfe9c2f8f87a842bc1c9475
# review_id = 1189743089_5dfe9c2f8f87a842bc1c9475
# rating = 5
# date = 2021.03.14
# 리뷰 내용 : 흑돼지버거 푸짐하니 맛있어요. 고기도 냄새  안 나고 푸짐하게 들어있어서 든든하게 먹었답니다. 성산일출을 바라보며 먹으면 굿
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210317_111%2F1615984031234o5mvA_JPEG%2Fupload_3d37017eb3e1f8858a0cf1a3a2b9e05e.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5cdf6fea40954d6f37ccd536/review
# user_code = 5cdf6fea40954d6f37ccd536
# review_id = 1189743089_5cdf6fea40954d6f37ccd536
# rating = 4.5
# date = 2021.03.09
# 리뷰 내용 : 친절 깔끔 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5d9df5758f87a842bcd20f9e/review
# user_code = 5d9df5758f87a842bcd20f9e
# review_id = 1189743089_5d9df5758f87a842bcd20f9e
# rating = 5
# date = 2021.02.28
# 리뷰 내용 : 육즙가득 맛있어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5efd4ab28f87a842bc6f6918/review
# user_code = 5efd4ab28f87a842bc6f6918
# review_id = 1189743089_5efd4ab28f87a842bc6f6918
# rating = 4
# date = 2021.02.26
# 리뷰 내용 : 버거는 시그니처버거가  역시!
# 꽃담버거  맛있었어요
# 콜라는 ㅠ.ㅠ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b9ba156491c01b743acef23/review
# user_code = 5b9ba156491c01b743acef23
# review_id = 1189743089_5b9ba156491c01b743acef23
# rating = 5
# date = 2021.02.22
# 리뷰 내용 : 성산일출봉 뷰맛집이네요. 제주 분위기가 물씬 나는 곳입니다.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e7243988f87a842bc5876ce/review
# user_code = 5e7243988f87a842bc5876ce
# review_id = 1189743089_5e7243988f87a842bc5876ce
# rating = 5
# date = 2021.02.18
# 리뷰 내용 : 제가 먹어본 수제버거 중에 젤루 맛있었어요!!😋 칼바람을 맞으며 성산일출봉에서 내려와 고단한 몸을 녹이기에 너무 좋은 따뜻한 가
# 게였어요!! 떡갈비버거도 딸기오메기 떡도 귀여운 포크도 친환경 종이 빨대도 아기자기한 인테리어까지 정말 하나같이 맘에 들었어요!!
# ★ 성산일출봉이 바로 내다뵈는 뷰도 짱이에요!!  담에 성산 오면 또 올거예요!!!!!!!❤
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f9b8429a92a9844db8ea88d/review
# user_code = 5f9b8429a92a9844db8ea88d
# review_id = 1189743089_5f9b8429a92a9844db8ea88d
# rating = 5
# date = 2021.02.07
# 리뷰 내용 : 아담하니 이뻐요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fnaverbooking-phinf.pstatic.net%2F20210207_241%2F16126646482478ve4b_JPEG%2Fimage.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5da97d648f87a842bca35ce9/review
# user_code = 5da97d648f87a842bca35ce9
# review_id = 1189743089_5da97d648f87a842bca35ce9
# rating = 5
# date = 2020.01.05
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
#
#
# ======================================================
# 665번째 식당

# %%
rating_df = pd.DataFrame(rating_list)
rating_df.columns = ['UserID','ItemID','Rating','Timestamp']
rating_df.to_csv('rating9.csv', encoding='utf-8-sig')

import json

file_path = "./user_review_id.json"
with open(file_path,'w', encoding="UTF-8") as outfile:
    json.dump(user_review_id, outfile, ensure_ascii=False)
    
file_path = "./review.json"
with open(file_path,'w', encoding="UTF-8") as outfile:
    json.dump(review_json, outfile, ensure_ascii=False)

file_path = "./image.json"
with open(file_path,'w', encoding="UTF-8") as outfile:
    json.dump(image_json, outfile, ensure_ascii=False)

# %% [markdown]
# ## 최종 크롤링된 데이터프레임에
# ## 공통 값을 기준으로(열 기준) concat하여 주소 붙이기 !!!

# %%
# 수정사항
# 1. 1번파일에 상호명+도로명전체주소 처리한 새로운 열만들어서
# 2. 이 새로운 열로 검색 url키워드 만들기
# 3. 만들어진 키워드로 검색
