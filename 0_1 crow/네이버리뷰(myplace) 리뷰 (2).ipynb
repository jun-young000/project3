# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import time
import re
from bs4 import BeautifulSoup 
import random 
import multiprocessing
from tqdm import tqdm


df = pd.read_csv('./제주특별자치도음식점목록(통합).csv', sep=',', encoding='CP949')
df['naver_map_url'] = '' # 미리 url을 담을 column을 만들어줌

chromedriver = './chromedriver' 
driver = webdriver.Chrome(chromedriver) 

# driver = webdriver.Chrome(executable_path=r'C:\\Users\\ui\\Desktop\chromedriver.exe') # 웹드라이버가 설치된 경로를 지정해주시면 됩니다.

# %%
df = df[df.영업상태명 != '폐업']

# %%
df = df.reset_index()

# %%
del df['index']

# %%
# df = df.iloc[9576:12768]
df = df.iloc[12768:15961]

# %%
df = df.reset_index()
del df['index']

# %%
df
# Out:
#                 사업장명 업종구분대분류   업종구분소분류     인허가일자  인허가취소일자  영업상태명 상세영업상태명  \
# 0                파파야   일반음식점        기타  20160412      NaN  영업/정상      영업
# 1               청우식당   일반음식점        분식  20160414      NaN  영업/정상      영업
# 2              이승악식당   일반음식점        한식  20160415      NaN  영업/정상      영업
# 3              당포회센타   일반음식점        회집  20160908      NaN  영업/정상      영업
# 4               할매곱창   일반음식점        한식  20170317      NaN  영업/정상      영업
# ...              ...     ...       ...       ...      ...    ...     ...
# 3188        쥬씨제주한라대점   휴게음식점       커피숍  20160215      NaN  영업/정상      영업
# 3189  써브웨이신제주연동신시가지점   휴게음식점     패스트푸드  20160215      NaN  영업/정상      영업
# 3190          서제니의시간   휴게음식점       커피숍  20160216      NaN  영업/정상      영업
# 3191           보리빵마을   휴게음식점  기타 휴게음식점  20040413      NaN  영업/정상      영업
# 3192      씨유제주일중사거리점   휴게음식점  기타 휴게음식점  20171215      NaN  영업/정상      영업
#
#       폐업일자  휴업시작일자  휴업종료일자  재개업일자   소재지면적                         소재지전체주소  \
# 0      NaN     NaN     NaN    NaN      32  제주특별자치도 서귀포시 성산읍 성산리 230-22번지
# 1      NaN     NaN     NaN    NaN    93.5       제주특별자치도 서귀포시 강정동 165-7번지
# 2      NaN     NaN     NaN    NaN      33  제주특별자치도 서귀포시 남원읍 신례리 2162-8번지
# 3      NaN     NaN     NaN    NaN  162.08    제주특별자치도 서귀포시 표선면 표선리 45-6번지
# 4      NaN     NaN     NaN    NaN     115       제주특별자치도 서귀포시 동홍동 472-1번지
# ...    ...     ...     ...    ...     ...                             ...
# 3188   NaN     NaN     NaN    NaN    32.3        제주특별자치도 제주시 노형동 755-2번지
# 3189   NaN     NaN     NaN    NaN   47.96          제주특별자치도 제주시 연동 1482번지
# 3190   NaN     NaN     NaN    NaN      22   제주특별자치도 제주시 애월읍 하귀1리 166-1번지
# 3191   NaN     NaN     NaN    NaN   47.17        제주특별자치도 제주시 연동 2514-3번지
# 3192   NaN     NaN     NaN    NaN     8.8     제주특별자치도 제주시 이도이동 1970-11번지
#
#                                   도로명전체주소  도로명우편번호           데이터갱신일자  \
# 0                제주특별자치도 서귀포시 성산읍 성산등용로 7  63643.0  2018-08-31 23:59
# 1     제주특별자치도 서귀포시 신서로48번길 20-9, 1층 (강정동)  63566.0   2020-05-14 2:40
# 2                제주특별자치도 서귀포시 남원읍 서성로 308  63608.0   2019-04-24 2:40
# 3               제주특별자치도 서귀포시 표선면 표선당포로 29  63629.0   2019-10-04 2:40
# 4      제주특별자치도 서귀포시 동홍중앙로66번길 22-10 (동홍동)  63587.0  2018-08-31 23:59
# ...                                   ...      ...               ...
# 3188         제주특별자치도 제주시 정원로 51, 1층 (노형동)  63089.0  2018-08-31 23:59
# 3189     제주특별자치도 제주시 국기로1길 2, 지하1~1층 (연동)  63139.0  2018-08-31 23:59
# 3190     제주특별자치도 제주시 애월읍 하귀9길 71, 1층 101호  63052.0  2018-08-31 23:59
# 3191             제주특별자치도 제주시 도령로 170 (연동)  63117.0  2018-08-31 23:59
# 3192  제주특별자치도 제주시 신설로2길 5-9, 지하 1층 (이도이동)  63227.0   2020-03-01 2:40
#
#      naver_map_url
# 0
# 1
# 2
# 3
# 4
# ...            ...
# 3188
# 3189
# 3190
# 3191
# 3192
#
# [3193 rows x 17 columns]

# %%
df = df[['사업장명', '업종구분대분류', '업종구분소분류', '소재지전체주소', 'naver_map_url']]
df
# Out:
#                 사업장명 업종구분대분류   업종구분소분류                         소재지전체주소  \
# 0                파파야   일반음식점        기타  제주특별자치도 서귀포시 성산읍 성산리 230-22번지
# 1               청우식당   일반음식점        분식       제주특별자치도 서귀포시 강정동 165-7번지
# 2              이승악식당   일반음식점        한식  제주특별자치도 서귀포시 남원읍 신례리 2162-8번지
# 3              당포회센타   일반음식점        회집    제주특별자치도 서귀포시 표선면 표선리 45-6번지
# 4               할매곱창   일반음식점        한식       제주특별자치도 서귀포시 동홍동 472-1번지
# ...              ...     ...       ...                             ...
# 3188        쥬씨제주한라대점   휴게음식점       커피숍        제주특별자치도 제주시 노형동 755-2번지
# 3189  써브웨이신제주연동신시가지점   휴게음식점     패스트푸드          제주특별자치도 제주시 연동 1482번지
# 3190          서제니의시간   휴게음식점       커피숍   제주특별자치도 제주시 애월읍 하귀1리 166-1번지
# 3191           보리빵마을   휴게음식점  기타 휴게음식점        제주특별자치도 제주시 연동 2514-3번지
# 3192      씨유제주일중사거리점   휴게음식점  기타 휴게음식점     제주특별자치도 제주시 이도이동 1970-11번지
#
#      naver_map_url
# 0
# 1
# 2
# 3
# 4
# ...            ...
# 3188
# 3189
# 3190
# 3191
# 3192
#
# [3193 rows x 5 columns]

# %%
for i, keyword in enumerate(df['사업장명'].tolist()):
    print("이번에 찾을 키워드 :", i, f"/ {df.shape[0]} 행", "제주", keyword)
    
    try:
        naver_map_search_url = f"https://map.naver.com/v5/search/제주&{keyword}/place" # 검색 url 만들기
        driver.get(naver_map_search_url) # 검색 url 접속, 즉 검색하기
        
        time.sleep(2) # 중요함
        cu = driver.current_url # 검색이 성공된 플레이스에 대한 개별 페이지
        
        res_code = re.findall(r"place/(\d+)", cu)
        final_url = 'https://pcmap.place.naver.com/restaurant/'+res_code[0]+'/review/visitor#'
        
        print(final_url)
        df['naver_map_url'][i]=final_url
        
    except IndexError:
        df['naver_map_url'][i]= ''
        print('none')
# Out:
# 이번에 찾을 키워드 : 0 / 3193 행 제주 파파야
# https://pcmap.place.naver.com/restaurant/37890576/review/visitor#
# 이번에 찾을 키워드 : 1 / 3193 행 제주 청우식당
# C:\Users\ui\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# none
# 이번에 찾을 키워드 : 2 / 3193 행 제주 이승악식당
# none
# 이번에 찾을 키워드 : 3 / 3193 행 제주 당포회센타
# https://pcmap.place.naver.com/restaurant/1465642893/review/visitor#
# 이번에 찾을 키워드 : 4 / 3193 행 제주 할매곱창
# none
# 이번에 찾을 키워드 : 5 / 3193 행 제주 해민이네양곱창
# https://pcmap.place.naver.com/restaurant/93708698/review/visitor#
# 이번에 찾을 키워드 : 6 / 3193 행 제주 농부의밥상
# https://pcmap.place.naver.com/restaurant/1122024164/review/visitor#
# 이번에 찾을 키워드 : 7 / 3193 행 제주 리시온레스토랑
# none
# 이번에 찾을 키워드 : 8 / 3193 행 제주 팔미돈가2호점
# https://pcmap.place.naver.com/restaurant/1136661174/review/visitor#
# 이번에 찾을 키워드 : 9 / 3193 행 제주 키다리네
# https://pcmap.place.naver.com/restaurant/1636682834/review/visitor#
# 이번에 찾을 키워드 : 10 / 3193 행 제주 대동강초계탕
# none
# 이번에 찾을 키워드 : 11 / 3193 행 제주 맘스터치남원점
# none
# 이번에 찾을 키워드 : 12 / 3193 행 제주 소랑밥상
# https://pcmap.place.naver.com/restaurant/38591445/review/visitor#
# 이번에 찾을 키워드 : 13 / 3193 행 제주 상효올레집
# https://pcmap.place.naver.com/restaurant/582599548/review/visitor#
# 이번에 찾을 키워드 : 14 / 3193 행 제주 한마음정육식당중문점
# none
# 이번에 찾을 키워드 : 15 / 3193 행 제주 비비큐영어교육도시점
# none
# 이번에 찾을 키워드 : 16 / 3193 행 제주 뽀르또
# https://pcmap.place.naver.com/restaurant/34942163/review/visitor#
# 이번에 찾을 키워드 : 17 / 3193 행 제주 중문레지나김밥
# https://pcmap.place.naver.com/restaurant/38310744/review/visitor#
# 이번에 찾을 키워드 : 18 / 3193 행 제주 하눌타리정식
# none
# 이번에 찾을 키워드 : 19 / 3193 행 제주 더포그레이스호텔앤리조트
# none
# 이번에 찾을 키워드 : 20 / 3193 행 제주 욜로
# none
# 이번에 찾을 키워드 : 21 / 3193 행 제주 예원회수산
# https://pcmap.place.naver.com/restaurant/16928002/review/visitor#
# 이번에 찾을 키워드 : 22 / 3193 행 제주 불닭공장서귀포신시가지점
# https://pcmap.place.naver.com/restaurant/1123084536/review/visitor#
# 이번에 찾을 키워드 : 23 / 3193 행 제주 통돌이돈통가
# https://pcmap.place.naver.com/restaurant/1130282337/review/visitor#
# 이번에 찾을 키워드 : 24 / 3193 행 제주 더썸
# none
# 이번에 찾을 키워드 : 25 / 3193 행 제주 서귀포돈사촌
# none
# 이번에 찾을 키워드 : 26 / 3193 행 제주 투다리남원점
# none
# 이번에 찾을 키워드 : 27 / 3193 행 제주 소백산맥더블핸스테이크
# none
# 이번에 찾을 키워드 : 28 / 3193 행 제주 어울림
# none
# 이번에 찾을 키워드 : 29 / 3193 행 제주 키아오라카페
# none
# 이번에 찾을 키워드 : 30 / 3193 행 제주 홍교
# https://pcmap.place.naver.com/restaurant/1281515072/review/visitor#
# 이번에 찾을 키워드 : 31 / 3193 행 제주 신산상회
# https://pcmap.place.naver.com/restaurant/1058593038/review/visitor#
# 이번에 찾을 키워드 : 32 / 3193 행 제주 팔도실비집신서귀포점
# https://pcmap.place.naver.com/restaurant/12948836/review/visitor#
# 이번에 찾을 키워드 : 33 / 3193 행 제주 전원일기동광점
# https://pcmap.place.naver.com/restaurant/1600390812/review/visitor#
# 이번에 찾을 키워드 : 34 / 3193 행 제주 국수1번가
# https://pcmap.place.naver.com/restaurant/1626510153/review/visitor#
# 이번에 찾을 키워드 : 35 / 3193 행 제주 공가네구이촌
# https://pcmap.place.naver.com/restaurant/1700703512/review/visitor#
# 이번에 찾을 키워드 : 36 / 3193 행 제주 사계의시간
# https://pcmap.place.naver.com/restaurant/1297456747/review/visitor#
# 이번에 찾을 키워드 : 37 / 3193 행 제주 중문국수마을
# https://pcmap.place.naver.com/restaurant/1176535831/review/visitor#
# 이번에 찾을 키워드 : 38 / 3193 행 제주 촌놈숯불구이
# https://pcmap.place.naver.com/restaurant/1053060237/review/visitor#
# 이번에 찾을 키워드 : 39 / 3193 행 제주 더조은치킨서귀포1호점
# none
# 이번에 찾을 키워드 : 40 / 3193 행 제주 로트105
# https://pcmap.place.naver.com/restaurant/1804941282/review/visitor#
# 이번에 찾을 키워드 : 41 / 3193 행 제주 순대이야기
# https://pcmap.place.naver.com/restaurant/31734969/review/visitor#
# 이번에 찾을 키워드 : 42 / 3193 행 제주 까투리올레점
# none
# 이번에 찾을 키워드 : 43 / 3193 행 제주 미소녀
# https://pcmap.place.naver.com/restaurant/37653557/review/visitor#
# 이번에 찾을 키워드 : 44 / 3193 행 제주 돈삼겹
# none
# 이번에 찾을 키워드 : 45 / 3193 행 제주 슬기로운와인생활
# https://pcmap.place.naver.com/restaurant/1569757450/review/visitor#
# 이번에 찾을 키워드 : 46 / 3193 행 제주 강정장원식당
# https://pcmap.place.naver.com/restaurant/37666767/review/visitor#
# 이번에 찾을 키워드 : 47 / 3193 행 제주 회양과국수군송악산점
# none
# 이번에 찾을 키워드 : 48 / 3193 행 제주 봄향기
# https://pcmap.place.naver.com/restaurant/1955773694/review/visitor#
# 이번에 찾을 키워드 : 49 / 3193 행 제주 별맛해장국
# https://pcmap.place.naver.com/restaurant/16943197/review/visitor#
# 이번에 찾을 키워드 : 50 / 3193 행 제주 새늘봄
# https://pcmap.place.naver.com/restaurant/16970495/review/visitor#
# 이번에 찾을 키워드 : 51 / 3193 행 제주 코업시티호텔성산
# https://pcmap.place.naver.com/restaurant/1236944819/review/visitor#
# 이번에 찾을 키워드 : 52 / 3193 행 제주 이차돌제주서귀포점
# none
# 이번에 찾을 키워드 : 53 / 3193 행 제주 정직한통닭중문점
# https://pcmap.place.naver.com/restaurant/603484231/review/visitor#
# 이번에 찾을 키워드 : 54 / 3193 행 제주 구이랑돔베보쌈
# none
# 이번에 찾을 키워드 : 55 / 3193 행 제주 동광마트식당
# none
# 이번에 찾을 키워드 : 56 / 3193 행 제주 미향해장국성산점
# https://pcmap.place.naver.com/restaurant/37898247/review/visitor#
# 이번에 찾을 키워드 : 57 / 3193 행 제주 블라제
# https://pcmap.place.naver.com/restaurant/12917695/review/visitor#
# 이번에 찾을 키워드 : 58 / 3193 행 제주 섭지코지로
# none
# 이번에 찾을 키워드 : 59 / 3193 행 제주 성산돈까스집
# none
# 이번에 찾을 키워드 : 60 / 3193 행 제주 하이디펍
# none
# 이번에 찾을 키워드 : 61 / 3193 행 제주 묵전
# https://pcmap.place.naver.com/restaurant/483967513/review/visitor#
# 이번에 찾을 키워드 : 62 / 3193 행 제주 세옥식당
# none
# 이번에 찾을 키워드 : 63 / 3193 행 제주 고사리식당
# none
# 이번에 찾을 키워드 : 64 / 3193 행 제주 미풍해장국성산포점
# none
# 이번에 찾을 키워드 : 65 / 3193 행 제주 네거티브바이브
# none
# 이번에 찾을 키워드 : 66 / 3193 행 제주 자담치킨보목점
# none
# 이번에 찾을 키워드 : 67 / 3193 행 제주 7번길
# none
# 이번에 찾을 키워드 : 68 / 3193 행 제주 노랑통닭강정점
# none
# 이번에 찾을 키워드 : 69 / 3193 행 제주 88버거
# https://pcmap.place.naver.com/restaurant/37698735/review/visitor#
# 이번에 찾을 키워드 : 70 / 3193 행 제주 모다드렁
# none
# 이번에 찾을 키워드 : 71 / 3193 행 제주 올레차이나타운
# none
# 이번에 찾을 키워드 : 72 / 3193 행 제주 동홍옛날통닭
# https://pcmap.place.naver.com/restaurant/37920408/review/visitor#
# 이번에 찾을 키워드 : 73 / 3193 행 제주 대윤흑돼지
# https://pcmap.place.naver.com/restaurant/97127451/review/visitor#
# 이번에 찾을 키워드 : 74 / 3193 행 제주 전주한마음조림식당
# none
# 이번에 찾을 키워드 : 75 / 3193 행 제주 피엠푸드서귀포동홍점
# none
# 이번에 찾을 키워드 : 76 / 3193 행 제주 언니네
# none
# 이번에 찾을 키워드 : 77 / 3193 행 제주 우석촌
# https://pcmap.place.naver.com/restaurant/37747010/review/visitor#
# 이번에 찾을 키워드 : 78 / 3193 행 제주 호텔휴식서귀포
# https://pcmap.place.naver.com/restaurant/1058525972/review/visitor#
# 이번에 찾을 키워드 : 79 / 3193 행 제주 오규동
# none
# 이번에 찾을 키워드 : 80 / 3193 행 제주 사삼구번길
# https://pcmap.place.naver.com/restaurant/270578238/review/visitor#
# 이번에 찾을 키워드 : 81 / 3193 행 제주 그라스가든
# none
# 이번에 찾을 키워드 : 82 / 3193 행 제주 우사미
# https://pcmap.place.naver.com/restaurant/38446427/review/visitor#
# 이번에 찾을 키워드 : 83 / 3193 행 제주 명품동막골식당
# https://pcmap.place.naver.com/restaurant/37004956/review/visitor#
# 이번에 찾을 키워드 : 84 / 3193 행 제주 아땀분식
# none
# 이번에 찾을 키워드 : 85 / 3193 행 제주 어랭이나라
# https://pcmap.place.naver.com/restaurant/1659349111/review/visitor#
# 이번에 찾을 키워드 : 86 / 3193 행 제주 탐관오리
# https://pcmap.place.naver.com/restaurant/16943698/review/visitor#
# 이번에 찾을 키워드 : 87 / 3193 행 제주 신양귀비
# none
# 이번에 찾을 키워드 : 88 / 3193 행 제주 일산바지락손칼국수
# https://pcmap.place.naver.com/restaurant/1892887534/review/visitor#
# 이번에 찾을 키워드 : 89 / 3193 행 제주 오동도아구찜
# https://pcmap.place.naver.com/restaurant/1374334089/review/visitor#
# 이번에 찾을 키워드 : 90 / 3193 행 제주 면맛에입맛이좋아
# https://pcmap.place.naver.com/restaurant/1349786099/review/visitor#
# 이번에 찾을 키워드 : 91 / 3193 행 제주 클래식
# none
# 이번에 찾을 키워드 : 92 / 3193 행 제주 유박사참숯갈비
# https://pcmap.place.naver.com/restaurant/1937983380/review/visitor#
# 이번에 찾을 키워드 : 93 / 3193 행 제주 사려니
# none
# 이번에 찾을 키워드 : 94 / 3193 행 제주 팔로우
# none
# 이번에 찾을 키워드 : 95 / 3193 행 제주 휘게카페
# none
# 이번에 찾을 키워드 : 96 / 3193 행 제주 흑도세기숯불친구
# https://pcmap.place.naver.com/restaurant/16915693/review/visitor#
# 이번에 찾을 키워드 : 97 / 3193 행 제주 제주민주공화국
# https://pcmap.place.naver.com/restaurant/1121813285/review/visitor#
# 이번에 찾을 키워드 : 98 / 3193 행 제주 싸양맛집
# none
# 이번에 찾을 키워드 : 99 / 3193 행 제주 봉기네깡통구이
# https://pcmap.place.naver.com/restaurant/1180683480/review/visitor#
# 이번에 찾을 키워드 : 100 / 3193 행 제주 제주칼국수제주해물탕
# none
# 이번에 찾을 키워드 : 101 / 3193 행 제주 올레칠돈
# https://pcmap.place.naver.com/restaurant/37687253/review/visitor#
# 이번에 찾을 키워드 : 102 / 3193 행 제주 성산갈치맛집
# none
# 이번에 찾을 키워드 : 103 / 3193 행 제주 옛날통닭
# none
# 이번에 찾을 키워드 : 104 / 3193 행 제주 이가곰탕
# https://pcmap.place.naver.com/restaurant/36660377/review/visitor#
# 이번에 찾을 키워드 : 105 / 3193 행 제주 정체불명
# https://pcmap.place.naver.com/restaurant/1282162525/review/visitor#
# 이번에 찾을 키워드 : 106 / 3193 행 제주 미로객잔
# https://pcmap.place.naver.com/restaurant/35575795/review/visitor#
# 이번에 찾을 키워드 : 107 / 3193 행 제주 다미야 서귀포점
# https://pcmap.place.naver.com/restaurant/38458924/review/visitor#
# 이번에 찾을 키워드 : 108 / 3193 행 제주 코데인커피로스터스
# https://pcmap.place.naver.com/restaurant/1225129827/review/visitor#
# 이번에 찾을 키워드 : 109 / 3193 행 제주 육지것들
# https://pcmap.place.naver.com/restaurant/1018645495/review/visitor#
# 이번에 찾을 키워드 : 110 / 3193 행 제주 통족중문점
# https://pcmap.place.naver.com/restaurant/1757476526/review/visitor#
# 이번에 찾을 키워드 : 111 / 3193 행 제주 맛깔참죽서귀포1호점
# none
# 이번에 찾을 키워드 : 112 / 3193 행 제주 구이구이돌담집
# none
# 이번에 찾을 키워드 : 113 / 3193 행 제주 우리집흑돼지
# none
# 이번에 찾을 키워드 : 114 / 3193 행 제주 소희네뚝배기식당
# https://pcmap.place.naver.com/restaurant/16949508/review/visitor#
# 이번에 찾을 키워드 : 115 / 3193 행 제주 장어먹엉갑소
# https://pcmap.place.naver.com/restaurant/1279219529/review/visitor#
# 이번에 찾을 키워드 : 116 / 3193 행 제주 중문조림식당
# https://pcmap.place.naver.com/restaurant/16927205/review/visitor#
# 이번에 찾을 키워드 : 117 / 3193 행 제주 난타5000모슬포점
# none
# 이번에 찾을 키워드 : 118 / 3193 행 제주 하여사국수
# https://pcmap.place.naver.com/restaurant/1012228579/review/visitor#
# 이번에 찾을 키워드 : 119 / 3193 행 제주 일송회수산
# https://pcmap.place.naver.com/restaurant/13286289/review/visitor#
# 이번에 찾을 키워드 : 120 / 3193 행 제주 솔동산스토리
# https://pcmap.place.naver.com/restaurant/19945266/review/visitor#
# 이번에 찾을 키워드 : 121 / 3193 행 제주 쿡1015동홍점
# https://pcmap.place.naver.com/restaurant/1760756861/review/visitor#
# 이번에 찾을 키워드 : 122 / 3193 행 제주 팔복식당
# none
# 이번에 찾을 키워드 : 123 / 3193 행 제주 고망난돌민박가든
# https://pcmap.place.naver.com/restaurant/21627312/review/visitor#
# 이번에 찾을 키워드 : 124 / 3193 행 제주 제주막창
# none
# 이번에 찾을 키워드 : 125 / 3193 행 제주 오돈가
# https://pcmap.place.naver.com/restaurant/1243094217/review/visitor#
# 이번에 찾을 키워드 : 126 / 3193 행 제주 원조한라산갈비
# https://pcmap.place.naver.com/restaurant/1088852141/review/visitor#
# 이번에 찾을 키워드 : 127 / 3193 행 제주 태흥횟집
# none
# 이번에 찾을 키워드 : 128 / 3193 행 제주 옛날통닭중문점
# https://pcmap.place.naver.com/restaurant/37885146/review/visitor#
# 이번에 찾을 키워드 : 129 / 3193 행 제주 요망진흑돼지
# none
# 이번에 찾을 키워드 : 130 / 3193 행 제주 샤브차이나
# none
# 이번에 찾을 키워드 : 131 / 3193 행 제주 꺼멍목장
# https://pcmap.place.naver.com/restaurant/466851716/review/visitor#
# 이번에 찾을 키워드 : 132 / 3193 행 제주 바리골식당
# https://pcmap.place.naver.com/restaurant/1689615980/review/visitor#
# 이번에 찾을 키워드 : 133 / 3193 행 제주 솔가
# none
# 이번에 찾을 키워드 : 134 / 3193 행 제주 굽네치킨봄그리고가을리조트점
# none
# 이번에 찾을 키워드 : 135 / 3193 행 제주 런던1972
# https://pcmap.place.naver.com/restaurant/273888967/review/visitor#
# 이번에 찾을 키워드 : 136 / 3193 행 제주 용순이네
# https://pcmap.place.naver.com/restaurant/937596281/review/visitor#
# 이번에 찾을 키워드 : 137 / 3193 행 제주 리촐리
# https://pcmap.place.naver.com/restaurant/1777854789/review/visitor#
# 이번에 찾을 키워드 : 138 / 3193 행 제주 디아트
# none
# 이번에 찾을 키워드 : 139 / 3193 행 제주 제주용산유스호스텔식당
# none
# 이번에 찾을 키워드 : 140 / 3193 행 제주 남동영농조합법인남원점
# none
# 이번에 찾을 키워드 : 141 / 3193 행 제주 로드푸줏간
# none
# 이번에 찾을 키워드 : 142 / 3193 행 제주 상구통닭제주영어교육도시점
# https://pcmap.place.naver.com/restaurant/1232725695/review/visitor#
# 이번에 찾을 키워드 : 143 / 3193 행 제주 제주팩토리
# none
# 이번에 찾을 키워드 : 144 / 3193 행 제주 아리
# none
# 이번에 찾을 키워드 : 145 / 3193 행 제주 천지연전복해물뚝배기갈치요리전문
# https://pcmap.place.naver.com/restaurant/16918507/review/visitor#
# 이번에 찾을 키워드 : 146 / 3193 행 제주 월향이네
# none
# 이번에 찾을 키워드 : 147 / 3193 행 제주 제주기념사휴게소
# none
# 이번에 찾을 키워드 : 148 / 3193 행 제주 네거리식당
# https://pcmap.place.naver.com/restaurant/19873758/review/visitor#
# 이번에 찾을 키워드 : 149 / 3193 행 제주 씨제이프레시웨이안트레
# none
# 이번에 찾을 키워드 : 150 / 3193 행 제주 부부동원식당
# https://pcmap.place.naver.com/restaurant/1963437984/review/visitor#
# 이번에 찾을 키워드 : 151 / 3193 행 제주 솔누리
# none
# 이번에 찾을 키워드 : 152 / 3193 행 제주 오븐에빠진닭서홍점
# none
# 이번에 찾을 키워드 : 153 / 3193 행 제주 제주진미마돈가
# none
# 이번에 찾을 키워드 : 154 / 3193 행 제주 더웨이팅
# https://pcmap.place.naver.com/restaurant/1029848471/review/visitor#
# 이번에 찾을 키워드 : 155 / 3193 행 제주 도새기1982
# none
# 이번에 찾을 키워드 : 156 / 3193 행 제주 초이스
# none
# 이번에 찾을 키워드 : 157 / 3193 행 제주 한옥집돈삼겹
# https://pcmap.place.naver.com/restaurant/1250134759/review/visitor#
# 이번에 찾을 키워드 : 158 / 3193 행 제주 박초밥안덕점
# https://pcmap.place.naver.com/restaurant/1409270802/review/visitor#
# 이번에 찾을 키워드 : 159 / 3193 행 제주 위미항활어회센터
# https://pcmap.place.naver.com/restaurant/37873378/review/visitor#
# 이번에 찾을 키워드 : 160 / 3193 행 제주 표선꽃돼지촌본점
# none
# 이번에 찾을 키워드 : 161 / 3193 행 제주 성산은하식당본점
# none
# 이번에 찾을 키워드 : 162 / 3193 행 제주 별궁
# none
# 이번에 찾을 키워드 : 163 / 3193 행 제주 신촌수제비
# https://pcmap.place.naver.com/restaurant/16966762/review/visitor#
# 이번에 찾을 키워드 : 164 / 3193 행 제주 중문시민갈비
# https://pcmap.place.naver.com/restaurant/37632235/review/visitor#
# 이번에 찾을 키워드 : 165 / 3193 행 제주 흑염소가든
# none
# 이번에 찾을 키워드 : 166 / 3193 행 제주 흑돈퍼주는집
# https://pcmap.place.naver.com/restaurant/16930412/review/visitor#
# 이번에 찾을 키워드 : 167 / 3193 행 제주 우리마식당
# https://pcmap.place.naver.com/restaurant/16963502/review/visitor#
# 이번에 찾을 키워드 : 168 / 3193 행 제주 해오름식당
# none
# 이번에 찾을 키워드 : 169 / 3193 행 제주 혼밥대왕
# none
# 이번에 찾을 키워드 : 170 / 3193 행 제주 물허벅집
# https://pcmap.place.naver.com/restaurant/19886231/review/visitor#
# 이번에 찾을 키워드 : 171 / 3193 행 제주 핀크스골프클럽회원제티하우스2
# none
# 이번에 찾을 키워드 : 172 / 3193 행 제주 땡겨불닭
# https://pcmap.place.naver.com/restaurant/1285349686/review/visitor#
# 이번에 찾을 키워드 : 173 / 3193 행 제주 오버더윈도우
# https://pcmap.place.naver.com/restaurant/38310210/review/visitor#
# 이번에 찾을 키워드 : 174 / 3193 행 제주 주점부리
# none
# 이번에 찾을 키워드 : 175 / 3193 행 제주 꼬동꼬동
# https://pcmap.place.naver.com/restaurant/1581736406/review/visitor#
# 이번에 찾을 키워드 : 176 / 3193 행 제주 정낭식당
# none
# 이번에 찾을 키워드 : 177 / 3193 행 제주 나그네분식
# https://pcmap.place.naver.com/restaurant/16952435/review/visitor#
# 이번에 찾을 키워드 : 178 / 3193 행 제주 고은물식당
# https://pcmap.place.naver.com/restaurant/13069371/review/visitor#
# 이번에 찾을 키워드 : 179 / 3193 행 제주 막걸리한잔
# https://pcmap.place.naver.com/restaurant/1091713364/review/visitor#
# 이번에 찾을 키워드 : 180 / 3193 행 제주 돌섬
# none
# 이번에 찾을 키워드 : 181 / 3193 행 제주 꽃돼지
# none
# 이번에 찾을 키워드 : 182 / 3193 행 제주 멋진녀석들
# https://pcmap.place.naver.com/restaurant/38325571/review/visitor#
# 이번에 찾을 키워드 : 183 / 3193 행 제주 돔뱅이
# none
# 이번에 찾을 키워드 : 184 / 3193 행 제주 모이세해장국모슬포점
# none
# 이번에 찾을 키워드 : 185 / 3193 행 제주 돈방석모슬포8호점
# none
# 이번에 찾을 키워드 : 186 / 3193 행 제주 장수해장국
# none
# 이번에 찾을 키워드 : 187 / 3193 행 제주 속풀이해장국
# https://pcmap.place.naver.com/restaurant/38710958/review/visitor#
# 이번에 찾을 키워드 : 188 / 3193 행 제주 집나간왕새우바람난조개
# none
# 이번에 찾을 키워드 : 189 / 3193 행 제주 시골촌
# https://pcmap.place.naver.com/restaurant/16952091/review/visitor#
# 이번에 찾을 키워드 : 190 / 3193 행 제주 닐모리동동
# none
# 이번에 찾을 키워드 : 191 / 3193 행 제주 미성원
# https://pcmap.place.naver.com/restaurant/38275426/review/visitor#
# 이번에 찾을 키워드 : 192 / 3193 행 제주 시나브로
# none
# 이번에 찾을 키워드 : 193 / 3193 행 제주 남원흑돼지연탄골목
# https://pcmap.place.naver.com/restaurant/1805575346/review/visitor#
# 이번에 찾을 키워드 : 194 / 3193 행 제주 강치비국밥
# none
# 이번에 찾을 키워드 : 195 / 3193 행 제주 나니아카페
# none
# 이번에 찾을 키워드 : 196 / 3193 행 제주 가문잔치
# none
# 이번에 찾을 키워드 : 197 / 3193 행 제주 도순고기국수
# none
# 이번에 찾을 키워드 : 198 / 3193 행 제주 물메
# none
# 이번에 찾을 키워드 : 199 / 3193 행 제주 모이
# none
# 이번에 찾을 키워드 : 200 / 3193 행 제주 운정이네본점
# https://pcmap.place.naver.com/restaurant/36876360/review/visitor#
# 이번에 찾을 키워드 : 201 / 3193 행 제주 성도식당
# none
# 이번에 찾을 키워드 : 202 / 3193 행 제주 경민이네주공분식
# none
# 이번에 찾을 키워드 : 203 / 3193 행 제주 어랑어랑
# https://pcmap.place.naver.com/restaurant/1806845838/review/visitor#
# 이번에 찾을 키워드 : 204 / 3193 행 제주 온평바다한그릇
# https://pcmap.place.naver.com/restaurant/1397321112/review/visitor#
# 이번에 찾을 키워드 : 205 / 3193 행 제주 로컬크랩
# https://pcmap.place.naver.com/restaurant/307299913/review/visitor#
# 이번에 찾을 키워드 : 206 / 3193 행 제주 길카페
# none
# 이번에 찾을 키워드 : 207 / 3193 행 제주 1958빈티지
# https://pcmap.place.naver.com/restaurant/1886055164/review/visitor#
# 이번에 찾을 키워드 : 208 / 3193 행 제주 파주닭국수
# none
# 이번에 찾을 키워드 : 209 / 3193 행 제주 올레수제초밥
# none
# 이번에 찾을 키워드 : 210 / 3193 행 제주 부자식당
# none
# 이번에 찾을 키워드 : 211 / 3193 행 제주 참치코지
# https://pcmap.place.naver.com/restaurant/1867563356/review/visitor#
# 이번에 찾을 키워드 : 212 / 3193 행 제주 본죽엔비빔밥까페제주강정점
# https://pcmap.place.naver.com/restaurant/1492822022/review/visitor#
# 이번에 찾을 키워드 : 213 / 3193 행 제주 보라네식당
# none
# 이번에 찾을 키워드 : 214 / 3193 행 제주 기억나는집
# https://pcmap.place.naver.com/restaurant/16966744/review/visitor#
# 이번에 찾을 키워드 : 215 / 3193 행 제주 동네포차앤치킨
# https://pcmap.place.naver.com/restaurant/1021870508/review/visitor#
# 이번에 찾을 키워드 : 216 / 3193 행 제주 쇠소깍대박밥상
# https://pcmap.place.naver.com/restaurant/191137085/review/visitor#
# 이번에 찾을 키워드 : 217 / 3193 행 제주 오케이식당
# none
# 이번에 찾을 키워드 : 218 / 3193 행 제주 제주정제
# none
# 이번에 찾을 키워드 : 219 / 3193 행 제주 군족강정점
# none
# 이번에 찾을 키워드 : 220 / 3193 행 제주 메밀애본점
# none
# 이번에 찾을 키워드 : 221 / 3193 행 제주 수일통닭강정점
# none
# 이번에 찾을 키워드 : 222 / 3193 행 제주 올댓비어
# https://pcmap.place.naver.com/restaurant/21578094/review/visitor#
# 이번에 찾을 키워드 : 223 / 3193 행 제주 서귀포월드컵리조트
# https://pcmap.place.naver.com/restaurant/36339515/review/visitor#
# 이번에 찾을 키워드 : 224 / 3193 행 제주 흑한우명품관별관
# none
# 이번에 찾을 키워드 : 225 / 3193 행 제주 정원꼬리곰탕
# https://pcmap.place.naver.com/restaurant/37941877/review/visitor#
# 이번에 찾을 키워드 : 226 / 3193 행 제주 집밥풍년
# https://pcmap.place.naver.com/restaurant/1164213564/review/visitor#
# 이번에 찾을 키워드 : 227 / 3193 행 제주 스타트하우스
# https://pcmap.place.naver.com/restaurant/34240640/review/visitor#
# 이번에 찾을 키워드 : 228 / 3193 행 제주 모영
# none
# 이번에 찾을 키워드 : 229 / 3193 행 제주 돈둥지
# https://pcmap.place.naver.com/restaurant/38711079/review/visitor#
# 이번에 찾을 키워드 : 230 / 3193 행 제주 미향해장국표선점
# https://pcmap.place.naver.com/restaurant/37220592/review/visitor#
# 이번에 찾을 키워드 : 231 / 3193 행 제주 새연교횟집
# https://pcmap.place.naver.com/restaurant/1513732864/review/visitor#
# 이번에 찾을 키워드 : 232 / 3193 행 제주 상미선지해장국
# none
# 이번에 찾을 키워드 : 233 / 3193 행 제주 동현식당
# none
# 이번에 찾을 키워드 : 234 / 3193 행 제주 색달돈가
# https://pcmap.place.naver.com/restaurant/1929789003/review/visitor#
# 이번에 찾을 키워드 : 235 / 3193 행 제주 신동홍돈
# none
# 이번에 찾을 키워드 : 236 / 3193 행 제주 사계바다
# none
# 이번에 찾을 키워드 : 237 / 3193 행 제주 산동성
# https://pcmap.place.naver.com/restaurant/1789890841/review/visitor#
# 이번에 찾을 키워드 : 238 / 3193 행 제주 흑사돈
# https://pcmap.place.naver.com/restaurant/866050965/review/visitor#
# 이번에 찾을 키워드 : 239 / 3193 행 제주 최네집성산점
# https://pcmap.place.naver.com/restaurant/1346498747/review/visitor#
# 이번에 찾을 키워드 : 240 / 3193 행 제주 왕호랑이막창
# none
# 이번에 찾을 키워드 : 241 / 3193 행 제주 영풍해장국
# https://pcmap.place.naver.com/restaurant/37159321/review/visitor#
# 이번에 찾을 키워드 : 242 / 3193 행 제주 유어스호텔레스토랑
# none
# 이번에 찾을 키워드 : 243 / 3193 행 제주 야자나라
# https://pcmap.place.naver.com/restaurant/1014453611/review/visitor#
# 이번에 찾을 키워드 : 244 / 3193 행 제주 글라가게
# none
# 이번에 찾을 키워드 : 245 / 3193 행 제주 시봉카페
# none
# 이번에 찾을 키워드 : 246 / 3193 행 제주 우발탄
# none
# 이번에 찾을 키워드 : 247 / 3193 행 제주 돌돌이
# none
# 이번에 찾을 키워드 : 248 / 3193 행 제주 김삿갓보쌈족발
# https://pcmap.place.naver.com/restaurant/32048252/review/visitor#
# 이번에 찾을 키워드 : 249 / 3193 행 제주 미림
# none
# 이번에 찾을 키워드 : 250 / 3193 행 제주 충청도식당
# none
# 이번에 찾을 키워드 : 251 / 3193 행 제주 우주식당
# none
# 이번에 찾을 키워드 : 252 / 3193 행 제주 모루쿠다본점
# none
# 이번에 찾을 키워드 : 253 / 3193 행 제주 모모
# none
# 이번에 찾을 키워드 : 254 / 3193 행 제주 오름
# none
# 이번에 찾을 키워드 : 255 / 3193 행 제주 줄서서먹는짜장신시가지점
# none
# 이번에 찾을 키워드 : 256 / 3193 행 제주 나원회포차
# https://pcmap.place.naver.com/restaurant/33210988/review/visitor#
# 이번에 찾을 키워드 : 257 / 3193 행 제주 권가네올레김밥
# https://pcmap.place.naver.com/restaurant/1308745944/review/visitor#
# 이번에 찾을 키워드 : 258 / 3193 행 제주 (주)산티아고가는길남원점
# none
# 이번에 찾을 키워드 : 259 / 3193 행 제주 돌체
# none
# 이번에 찾을 키워드 : 260 / 3193 행 제주 토크쇼천지점
# https://pcmap.place.naver.com/restaurant/44641390/review/visitor#
# 이번에 찾을 키워드 : 261 / 3193 행 제주 송가네참숯가든
# https://pcmap.place.naver.com/restaurant/13067987/review/visitor#
# 이번에 찾을 키워드 : 262 / 3193 행 제주 3050식당
# none
# 이번에 찾을 키워드 : 263 / 3193 행 제주 풍향가든
# https://pcmap.place.naver.com/restaurant/13392235/review/visitor#
# 이번에 찾을 키워드 : 264 / 3193 행 제주 금복주
# https://pcmap.place.naver.com/restaurant/20777064/review/visitor#
# 이번에 찾을 키워드 : 265 / 3193 행 제주 만추
# https://pcmap.place.naver.com/restaurant/1022315944/review/visitor#
# 이번에 찾을 키워드 : 266 / 3193 행 제주 동광가든
# https://pcmap.place.naver.com/restaurant/16959372/review/visitor#
# 이번에 찾을 키워드 : 267 / 3193 행 제주 춘부네식당
# none
# 이번에 찾을 키워드 : 268 / 3193 행 제주 제주수산
# none
# 이번에 찾을 키워드 : 269 / 3193 행 제주 바떼온
# https://pcmap.place.naver.com/restaurant/753671165/review/visitor#
# 이번에 찾을 키워드 : 270 / 3193 행 제주 송가네순대국밥
# https://pcmap.place.naver.com/restaurant/1069167800/review/visitor#
# 이번에 찾을 키워드 : 271 / 3193 행 제주 믿음정육식당
# https://pcmap.place.naver.com/restaurant/1624618954/review/visitor#
# 이번에 찾을 키워드 : 272 / 3193 행 제주 중문칠돈가
# none
# 이번에 찾을 키워드 : 273 / 3193 행 제주 고가네
# none
# 이번에 찾을 키워드 : 274 / 3193 행 제주 바다다
# none
# 이번에 찾을 키워드 : 275 / 3193 행 제주 서귀포해뜨는집
# none
# 이번에 찾을 키워드 : 276 / 3193 행 제주 커피맛이멜로
# none
# 이번에 찾을 키워드 : 277 / 3193 행 제주 소소담
# https://pcmap.place.naver.com/restaurant/1366051940/review/visitor#
# 이번에 찾을 키워드 : 278 / 3193 행 제주 본도시락
# none
# 이번에 찾을 키워드 : 279 / 3193 행 제주 징검다리
# none
# 이번에 찾을 키워드 : 280 / 3193 행 제주 나니아(NANIA)
# none
# 이번에 찾을 키워드 : 281 / 3193 행 제주 모해
# none
# 이번에 찾을 키워드 : 282 / 3193 행 제주 청개구리식당
# https://pcmap.place.naver.com/restaurant/1275241663/review/visitor#
# 이번에 찾을 키워드 : 283 / 3193 행 제주 조선드립480
# https://pcmap.place.naver.com/restaurant/1860699313/review/visitor#
# 이번에 찾을 키워드 : 284 / 3193 행 제주 글라몬딱
# https://pcmap.place.naver.com/restaurant/882119676/review/visitor#
# 이번에 찾을 키워드 : 285 / 3193 행 제주 신례토종닭식당
# https://pcmap.place.naver.com/restaurant/20539567/review/visitor#
# 이번에 찾을 키워드 : 286 / 3193 행 제주 초계명가
# https://pcmap.place.naver.com/restaurant/927182656/review/visitor#
# 이번에 찾을 키워드 : 287 / 3193 행 제주 올레길카페
# none
# 이번에 찾을 키워드 : 288 / 3193 행 제주 산방흑돼지순대영어교육도시점
# https://pcmap.place.naver.com/restaurant/1776286598/review/visitor#
# 이번에 찾을 키워드 : 289 / 3193 행 제주 동호갈비
# https://pcmap.place.naver.com/restaurant/1593219127/review/visitor#
# 이번에 찾을 키워드 : 290 / 3193 행 제주 우리집정식
# https://pcmap.place.naver.com/restaurant/16918421/review/visitor#
# 이번에 찾을 키워드 : 291 / 3193 행 제주 제피로스
# none
# 이번에 찾을 키워드 : 292 / 3193 행 제주 사계해녀의집
# https://pcmap.place.naver.com/restaurant/1387655195/review/visitor#
# 이번에 찾을 키워드 : 293 / 3193 행 제주 도가촌
# https://pcmap.place.naver.com/restaurant/37804051/review/visitor#
# 이번에 찾을 키워드 : 294 / 3193 행 제주 처가집연탄구이
# https://pcmap.place.naver.com/restaurant/32169090/review/visitor#
# 이번에 찾을 키워드 : 295 / 3193 행 제주 라울
# https://pcmap.place.naver.com/restaurant/1264263152/review/visitor#
# 이번에 찾을 키워드 : 296 / 3193 행 제주 누구나홀딱반한닭대정점
# none
# 이번에 찾을 키워드 : 297 / 3193 행 제주 돈블랙올레시장점
# https://pcmap.place.naver.com/restaurant/1880758258/review/visitor#
# 이번에 찾을 키워드 : 298 / 3193 행 제주 서귀포부두식당
# none
# 이번에 찾을 키워드 : 299 / 3193 행 제주 사일팔(418)
# https://pcmap.place.naver.com/restaurant/38278802/review/visitor#
# 이번에 찾을 키워드 : 300 / 3193 행 제주 백기식당
# none
# 이번에 찾을 키워드 : 301 / 3193 행 제주 창천삼거리식당
# none
# 이번에 찾을 키워드 : 302 / 3193 행 제주 해당화
# https://pcmap.place.naver.com/restaurant/37623578/review/visitor#
# 이번에 찾을 키워드 : 303 / 3193 행 제주 PPONG(뽕)
# none
# 이번에 찾을 키워드 : 304 / 3193 행 제주 에르미타주
# https://pcmap.place.naver.com/restaurant/1791615972/review/visitor#
# 이번에 찾을 키워드 : 305 / 3193 행 제주 바당꽃
# none
# 이번에 찾을 키워드 : 306 / 3193 행 제주 BHC치킨신서귀포점
# none
# 이번에 찾을 키워드 : 307 / 3193 행 제주 마농비어
# https://pcmap.place.naver.com/restaurant/1542513504/review/visitor#
# 이번에 찾을 키워드 : 308 / 3193 행 제주 특수부위전문점한울
# none
# 이번에 찾을 키워드 : 309 / 3193 행 제주 교촌치킨대정점
# none
# 이번에 찾을 키워드 : 310 / 3193 행 제주 마므레
# none
# 이번에 찾을 키워드 : 311 / 3193 행 제주 찰스앤바비
# https://pcmap.place.naver.com/restaurant/1920856558/review/visitor#
# 이번에 찾을 키워드 : 312 / 3193 행 제주 동백화로
# https://pcmap.place.naver.com/restaurant/1504748261/review/visitor#
# 이번에 찾을 키워드 : 313 / 3193 행 제주 임숙현돼지주물럭
# https://pcmap.place.naver.com/restaurant/307012521/review/visitor#
# 이번에 찾을 키워드 : 314 / 3193 행 제주 서귀피안세컨룸
# none
# 이번에 찾을 키워드 : 315 / 3193 행 제주 만복민물장어
# https://pcmap.place.naver.com/restaurant/1538693442/review/visitor#
# 이번에 찾을 키워드 : 316 / 3193 행 제주 올래국수서귀포점
# https://pcmap.place.naver.com/restaurant/38703215/review/visitor#
# 이번에 찾을 키워드 : 317 / 3193 행 제주 나트랑
# none
# 이번에 찾을 키워드 : 318 / 3193 행 제주 코소롱
# none
# 이번에 찾을 키워드 : 319 / 3193 행 제주 탐라만찬
# https://pcmap.place.naver.com/restaurant/1480232748/review/visitor#
# 이번에 찾을 키워드 : 320 / 3193 행 제주 부산어묵앤카페
# none
# 이번에 찾을 키워드 : 321 / 3193 행 제주 철이라멘
# none
# 이번에 찾을 키워드 : 322 / 3193 행 제주 장수마을밥상
# https://pcmap.place.naver.com/restaurant/19495519/review/visitor#
# 이번에 찾을 키워드 : 323 / 3193 행 제주 일광회센터
# https://pcmap.place.naver.com/restaurant/16927994/review/visitor#
# 이번에 찾을 키워드 : 324 / 3193 행 제주 제주마루
# none
# 이번에 찾을 키워드 : 325 / 3193 행 제주 명원정
# https://pcmap.place.naver.com/restaurant/16935213/review/visitor#
# 이번에 찾을 키워드 : 326 / 3193 행 제주 마라도해녀촌자장
# none
# 이번에 찾을 키워드 : 327 / 3193 행 제주 마라도에서
# https://pcmap.place.naver.com/restaurant/1354847150/review/visitor#
# 이번에 찾을 키워드 : 328 / 3193 행 제주 팔도민박횟집
# none
# 이번에 찾을 키워드 : 329 / 3193 행 제주 서민갈비
# none
# 이번에 찾을 키워드 : 330 / 3193 행 제주 미가족발
# https://pcmap.place.naver.com/restaurant/1301855871/review/visitor#
# 이번에 찾을 키워드 : 331 / 3193 행 제주 빨간대게
# https://pcmap.place.naver.com/restaurant/1420715890/review/visitor#
# 이번에 찾을 키워드 : 332 / 3193 행 제주 서정
# none
# 이번에 찾을 키워드 : 333 / 3193 행 제주 해녀의숨비소리
# https://pcmap.place.naver.com/restaurant/1196220222/review/visitor#
# 이번에 찾을 키워드 : 334 / 3193 행 제주 30년할매닭발
# none
# 이번에 찾을 키워드 : 335 / 3193 행 제주 이가네일품해장국
# none
# 이번에 찾을 키워드 : 336 / 3193 행 제주 꽃담플라워카페
# none
# 이번에 찾을 키워드 : 337 / 3193 행 제주 바당포구
# https://pcmap.place.naver.com/restaurant/1099997968/review/visitor#
# 이번에 찾을 키워드 : 338 / 3193 행 제주 대정족발영어교육도시점
# none
# 이번에 찾을 키워드 : 339 / 3193 행 제주 술집
# none
# 이번에 찾을 키워드 : 340 / 3193 행 제주 꽃가람
# https://pcmap.place.naver.com/restaurant/514292398/review/visitor#
# 이번에 찾을 키워드 : 341 / 3193 행 제주 통통
# none
# 이번에 찾을 키워드 : 342 / 3193 행 제주 제주푸드트립
# https://pcmap.place.naver.com/restaurant/1197261886/review/visitor#
# 이번에 찾을 키워드 : 343 / 3193 행 제주 화전민촌
# https://pcmap.place.naver.com/restaurant/1022676049/review/visitor#
# 이번에 찾을 키워드 : 344 / 3193 행 제주 다이닝펍휴
# https://pcmap.place.naver.com/restaurant/1039606582/review/visitor#
# 이번에 찾을 키워드 : 345 / 3193 행 제주 효돈수제돈까스
# none
# 이번에 찾을 키워드 : 346 / 3193 행 제주 마루샤브제주서귀포2호점
# none
# 이번에 찾을 키워드 : 347 / 3193 행 제주 샤브차이나별관
# none
# 이번에 찾을 키워드 : 348 / 3193 행 제주 해선락와사비남원태흥점
# https://pcmap.place.naver.com/restaurant/1737596146/review/visitor#
# 이번에 찾을 키워드 : 349 / 3193 행 제주 신촌흑돼지강정
# https://pcmap.place.naver.com/restaurant/1304452977/review/visitor#
# 이번에 찾을 키워드 : 350 / 3193 행 제주 돌샘호프
# https://pcmap.place.naver.com/restaurant/1264539120/review/visitor#
# 이번에 찾을 키워드 : 351 / 3193 행 제주 서귀포호텔스카이라운지
# none
# 이번에 찾을 키워드 : 352 / 3193 행 제주 제리스펍
# https://pcmap.place.naver.com/restaurant/205326161/review/visitor#
# 이번에 찾을 키워드 : 353 / 3193 행 제주 땡큐소주방
# https://pcmap.place.naver.com/restaurant/1472617822/review/visitor#
# 이번에 찾을 키워드 : 354 / 3193 행 제주 글라글라하와이
# https://pcmap.place.naver.com/restaurant/38712171/review/visitor#
# 이번에 찾을 키워드 : 355 / 3193 행 제주 율.13
# https://pcmap.place.naver.com/restaurant/1896217221/review/visitor#
# 이번에 찾을 키워드 : 356 / 3193 행 제주 나무아래쉼팡
# https://pcmap.place.naver.com/restaurant/38692517/review/visitor#
# 이번에 찾을 키워드 : 357 / 3193 행 제주 하례정원
# none
# 이번에 찾을 키워드 : 358 / 3193 행 제주 카페만감교차
# https://pcmap.place.naver.com/restaurant/1173716144/review/visitor#
# 이번에 찾을 키워드 : 359 / 3193 행 제주 제주한판
# none
# 이번에 찾을 키워드 : 360 / 3193 행 제주 봉자매
# https://pcmap.place.naver.com/restaurant/37003434/review/visitor#
# 이번에 찾을 키워드 : 361 / 3193 행 제주 달펍
# https://pcmap.place.naver.com/restaurant/1924002333/review/visitor#
# 이번에 찾을 키워드 : 362 / 3193 행 제주 돈솔
# none
# 이번에 찾을 키워드 : 363 / 3193 행 제주 성산어촌계해녀의집
# none
# 이번에 찾을 키워드 : 364 / 3193 행 제주 굼부리식당
# https://pcmap.place.naver.com/restaurant/11710934/review/visitor#
# 이번에 찾을 키워드 : 365 / 3193 행 제주 친구수산
# none
# 이번에 찾을 키워드 : 366 / 3193 행 제주 스카이온파이브다이닝(Sky on 5 Dining)
# none
# 이번에 찾을 키워드 : 367 / 3193 행 제주 랜딩라운지(Landing Lounge)
# https://pcmap.place.naver.com/restaurant/1551251329/review/visitor#
# 이번에 찾을 키워드 : 368 / 3193 행 제주 디 아일렛 라운지(The Islet Lounge)
# https://pcmap.place.naver.com/restaurant/1757021361/review/visitor#
# 이번에 찾을 키워드 : 369 / 3193 행 제주 풀사이드 카페(Poolside Cafe)
# https://pcmap.place.naver.com/restaurant/1118777999/review/visitor#
# 이번에 찾을 키워드 : 370 / 3193 행 제주 랜딩 다이닝(Landing Dining)
# https://pcmap.place.naver.com/restaurant/1510480425/review/visitor#
# 이번에 찾을 키워드 : 371 / 3193 행 제주 민경이네식당
# none
# 이번에 찾을 키워드 : 372 / 3193 행 제주 남문숯불바베큐중문점
# https://pcmap.place.naver.com/restaurant/1185639781/review/visitor#
# 이번에 찾을 키워드 : 373 / 3193 행 제주 중문정든해장국집
# https://pcmap.place.naver.com/restaurant/36518240/review/visitor#
# 이번에 찾을 키워드 : 374 / 3193 행 제주 26번가
# https://pcmap.place.naver.com/restaurant/1973388070/review/visitor#
# 이번에 찾을 키워드 : 375 / 3193 행 제주 아일랜드스토리
# https://pcmap.place.naver.com/restaurant/1045985473/review/visitor#
# 이번에 찾을 키워드 : 376 / 3193 행 제주 한라산저팔계
# https://pcmap.place.naver.com/restaurant/34510569/review/visitor#
# 이번에 찾을 키워드 : 377 / 3193 행 제주 먹깨비촌
# https://pcmap.place.naver.com/restaurant/1796221751/review/visitor#
# 이번에 찾을 키워드 : 378 / 3193 행 제주 벨에포크
# https://pcmap.place.naver.com/restaurant/387243080/review/visitor#
# 이번에 찾을 키워드 : 379 / 3193 행 제주 한솥도시락제주대정점
# none
# 이번에 찾을 키워드 : 380 / 3193 행 제주 카페예스아이엠서귀포점
# none
# 이번에 찾을 키워드 : 381 / 3193 행 제주 중문국수나라
# https://pcmap.place.naver.com/restaurant/61225374/review/visitor#
# 이번에 찾을 키워드 : 382 / 3193 행 제주 춘천손가닭갈비
# https://pcmap.place.naver.com/restaurant/11630348/review/visitor#
# 이번에 찾을 키워드 : 383 / 3193 행 제주 채플린
# none
# 이번에 찾을 키워드 : 384 / 3193 행 제주 24시뼈다귀탕동홍점
# https://pcmap.place.naver.com/restaurant/1274041067/review/visitor#
# 이번에 찾을 키워드 : 385 / 3193 행 제주 순덕이네해산물장터
# https://pcmap.place.naver.com/restaurant/11876693/review/visitor#
# 이번에 찾을 키워드 : 386 / 3193 행 제주 교래흑돼지표선점
# https://pcmap.place.naver.com/restaurant/1166323794/review/visitor#
# 이번에 찾을 키워드 : 387 / 3193 행 제주 하논미가식당
# none
# 이번에 찾을 키워드 : 388 / 3193 행 제주 성산카베츠
# none
# 이번에 찾을 키워드 : 389 / 3193 행 제주 해비치바람의집
# none
# 이번에 찾을 키워드 : 390 / 3193 행 제주 딸기와삼룡이
# none
# 이번에 찾을 키워드 : 391 / 3193 행 제주 국수몽
# https://pcmap.place.naver.com/restaurant/37454098/review/visitor#
# 이번에 찾을 키워드 : 392 / 3193 행 제주 매직스푼
# https://pcmap.place.naver.com/restaurant/37419552/review/visitor#
# 이번에 찾을 키워드 : 393 / 3193 행 제주 사계올레밥집
# none
# 이번에 찾을 키워드 : 394 / 3193 행 제주 천지연무태장어신서귀포점
# none
# 이번에 찾을 키워드 : 395 / 3193 행 제주 비어드코지98
# none
# 이번에 찾을 키워드 : 396 / 3193 행 제주 서귀포닭해장국
# none
# 이번에 찾을 키워드 : 397 / 3193 행 제주 바다양푼이동태탕중문점
# none
# 이번에 찾을 키워드 : 398 / 3193 행 제주 중문수원음식점
# https://pcmap.place.naver.com/restaurant/13444878/review/visitor#
# 이번에 찾을 키워드 : 399 / 3193 행 제주 표선반점
# none
# 이번에 찾을 키워드 : 400 / 3193 행 제주 서작가초밥집
# https://pcmap.place.naver.com/restaurant/299964938/review/visitor#
# 이번에 찾을 키워드 : 401 / 3193 행 제주 용왕식당
# none
# 이번에 찾을 키워드 : 402 / 3193 행 제주 규영이네
# https://pcmap.place.naver.com/restaurant/19803547/review/visitor#
# 이번에 찾을 키워드 : 403 / 3193 행 제주 꺼멍도새기
# https://pcmap.place.naver.com/restaurant/13487619/review/visitor#
# 이번에 찾을 키워드 : 404 / 3193 행 제주 더클리프
# none
# 이번에 찾을 키워드 : 405 / 3193 행 제주 오조마을돌담쉼팡
# none
# 이번에 찾을 키워드 : 406 / 3193 행 제주 서귀포차이나타운
# none
# 이번에 찾을 키워드 : 407 / 3193 행 제주 엉클통김밥법환점
# https://pcmap.place.naver.com/restaurant/38499611/review/visitor#
# 이번에 찾을 키워드 : 408 / 3193 행 제주 오늘은왠지
# https://pcmap.place.naver.com/restaurant/1229394065/review/visitor#
# 이번에 찾을 키워드 : 409 / 3193 행 제주 만사성
# https://pcmap.place.naver.com/restaurant/1731643039/review/visitor#
# 이번에 찾을 키워드 : 410 / 3193 행 제주 통큰갈비중문점
# https://pcmap.place.naver.com/restaurant/1800146156/review/visitor#
# 이번에 찾을 키워드 : 411 / 3193 행 제주 전원일기
# none
# 이번에 찾을 키워드 : 412 / 3193 행 제주 잔디포차
# https://pcmap.place.naver.com/restaurant/16937426/review/visitor#
# 이번에 찾을 키워드 : 413 / 3193 행 제주 제남가든
# https://pcmap.place.naver.com/restaurant/16942415/review/visitor#
# 이번에 찾을 키워드 : 414 / 3193 행 제주 마라도짜장면
# none
# 이번에 찾을 키워드 : 415 / 3193 행 제주 대독장신서귀포점
# https://pcmap.place.naver.com/restaurant/1644522459/review/visitor#
# 이번에 찾을 키워드 : 416 / 3193 행 제주 먹깨비
# none
# 이번에 찾을 키워드 : 417 / 3193 행 제주 까투리모슬포점
# none
# 이번에 찾을 키워드 : 418 / 3193 행 제주 파파엔도터
# https://pcmap.place.naver.com/restaurant/1634465616/review/visitor#
# 이번에 찾을 키워드 : 419 / 3193 행 제주 장가네해장국
# https://pcmap.place.naver.com/restaurant/38258469/review/visitor#
# 이번에 찾을 키워드 : 420 / 3193 행 제주 센트로
# https://pcmap.place.naver.com/restaurant/1371181339/review/visitor#
# 이번에 찾을 키워드 : 421 / 3193 행 제주 바당동네
# none
# 이번에 찾을 키워드 : 422 / 3193 행 제주 만덕할망맛집
# https://pcmap.place.naver.com/restaurant/1430466418/review/visitor#
# 이번에 찾을 키워드 : 423 / 3193 행 제주 홍다원밥앤차
# none
# 이번에 찾을 키워드 : 424 / 3193 행 제주 푸라닭강정점
# none
# 이번에 찾을 키워드 : 425 / 3193 행 제주 바당국수
# none
# 이번에 찾을 키워드 : 426 / 3193 행 제주 코바코서귀포점
# none
# 이번에 찾을 키워드 : 427 / 3193 행 제주 도우미식당
# https://pcmap.place.naver.com/restaurant/12024289/review/visitor#
# 이번에 찾을 키워드 : 428 / 3193 행 제주 불타는숯불갈비
# https://pcmap.place.naver.com/restaurant/31992459/review/visitor#
# 이번에 찾을 키워드 : 429 / 3193 행 제주 제주다온가
# none
# 이번에 찾을 키워드 : 430 / 3193 행 제주 따라비가든
# https://pcmap.place.naver.com/restaurant/38314943/review/visitor#
# 이번에 찾을 키워드 : 431 / 3193 행 제주 그랜드메르호텔 제주
# https://pcmap.place.naver.com/restaurant/37890415/review/visitor#
# 이번에 찾을 키워드 : 432 / 3193 행 제주 동성수산횟집
# none
# 이번에 찾을 키워드 : 433 / 3193 행 제주 우리웰빙식당
# none
# 이번에 찾을 키워드 : 434 / 3193 행 제주 차이나마씸
# https://pcmap.place.naver.com/restaurant/36605093/review/visitor#
# 이번에 찾을 키워드 : 435 / 3193 행 제주 푸줏간쌀롱
# https://pcmap.place.naver.com/restaurant/1818639509/review/visitor#
# 이번에 찾을 키워드 : 436 / 3193 행 제주 에뜨랑제
# https://pcmap.place.naver.com/restaurant/16938409/review/visitor#
# 이번에 찾을 키워드 : 437 / 3193 행 제주 하영횟집
# https://pcmap.place.naver.com/restaurant/13444926/review/visitor#
# 이번에 찾을 키워드 : 438 / 3193 행 제주 색달해녀의집
# https://pcmap.place.naver.com/restaurant/20557367/review/visitor#
# 이번에 찾을 키워드 : 439 / 3193 행 제주 마왕치킨
# https://pcmap.place.naver.com/restaurant/1544285432/review/visitor#
# 이번에 찾을 키워드 : 440 / 3193 행 제주 은하수식당
# none
# 이번에 찾을 키워드 : 441 / 3193 행 제주 자야음식점
# none
# 이번에 찾을 키워드 : 442 / 3193 행 제주 번개불
# https://pcmap.place.naver.com/restaurant/1974909900/review/visitor#
# 이번에 찾을 키워드 : 443 / 3193 행 제주 이루후제
# https://pcmap.place.naver.com/restaurant/37909515/review/visitor#
# 이번에 찾을 키워드 : 444 / 3193 행 제주 명동춘천닭갈비2호점
# none
# 이번에 찾을 키워드 : 445 / 3193 행 제주 쏘쏘비어
# none
# 이번에 찾을 키워드 : 446 / 3193 행 제주 시골길
# none
# 이번에 찾을 키워드 : 447 / 3193 행 제주 한우리식당
# none
# 이번에 찾을 키워드 : 448 / 3193 행 제주 횟집바다목장
# https://pcmap.place.naver.com/restaurant/1446178162/review/visitor#
# 이번에 찾을 키워드 : 449 / 3193 행 제주 술과동창회
# https://pcmap.place.naver.com/restaurant/1105149520/review/visitor#
# 이번에 찾을 키워드 : 450 / 3193 행 제주 요네주방
# none
# 이번에 찾을 키워드 : 451 / 3193 행 제주 아트빌라스클럽라운지
# none
# 이번에 찾을 키워드 : 452 / 3193 행 제주 열열이얼큰이&크리스피치킨
# https://pcmap.place.naver.com/restaurant/1526394820/review/visitor#
# 이번에 찾을 키워드 : 453 / 3193 행 제주 인우식당
# https://pcmap.place.naver.com/restaurant/19874912/review/visitor#
# 이번에 찾을 키워드 : 454 / 3193 행 제주 필
# none
# 이번에 찾을 키워드 : 455 / 3193 행 제주 아트빌라스커뮤니티센터
# https://pcmap.place.naver.com/restaurant/30820729/review/visitor#
# 이번에 찾을 키워드 : 456 / 3193 행 제주 제주해조네보말성게전문점
# https://pcmap.place.naver.com/restaurant/265144987/review/visitor#
# 이번에 찾을 키워드 : 457 / 3193 행 제주 하루(HARU)
# none
# 이번에 찾을 키워드 : 458 / 3193 행 제주 동원정식당
# https://pcmap.place.naver.com/restaurant/16975106/review/visitor#
# 이번에 찾을 키워드 : 459 / 3193 행 제주 돈돼지흑돼지가든
# none
# 이번에 찾을 키워드 : 460 / 3193 행 제주 바당어죽
# https://pcmap.place.naver.com/restaurant/17045703/review/visitor#
# 이번에 찾을 키워드 : 461 / 3193 행 제주 더캔버스하나
# none
# 이번에 찾을 키워드 : 462 / 3193 행 제주 더캔버스
# none
# 이번에 찾을 키워드 : 463 / 3193 행 제주 예담
# none
# 이번에 찾을 키워드 : 464 / 3193 행 제주 카페힐
# none
# 이번에 찾을 키워드 : 465 / 3193 행 제주 가랑가랑
# none
# 이번에 찾을 키워드 : 466 / 3193 행 제주 토끼트멍
# https://pcmap.place.naver.com/restaurant/547239954/review/visitor#
# 이번에 찾을 키워드 : 467 / 3193 행 제주 제주약수터올레시장점
# https://pcmap.place.naver.com/restaurant/1777244767/review/visitor#
# 이번에 찾을 키워드 : 468 / 3193 행 제주 정가네
# none
# 이번에 찾을 키워드 : 469 / 3193 행 제주 두레반점
# https://pcmap.place.naver.com/restaurant/1883069991/review/visitor#
# 이번에 찾을 키워드 : 470 / 3193 행 제주 쌍둥이네치킨
# none
# 이번에 찾을 키워드 : 471 / 3193 행 제주 카페가드니아
# https://pcmap.place.naver.com/restaurant/381625468/review/visitor#
# 이번에 찾을 키워드 : 472 / 3193 행 제주 홍다원
# https://pcmap.place.naver.com/restaurant/681650742/review/visitor#
# 이번에 찾을 키워드 : 473 / 3193 행 제주 뿔발
# none
# 이번에 찾을 키워드 : 474 / 3193 행 제주 떡군이네떡볶이신서귀포점
# none
# 이번에 찾을 키워드 : 475 / 3193 행 제주 한일식당
# none
# 이번에 찾을 키워드 : 476 / 3193 행 제주 제주기장횟집
# none
# 이번에 찾을 키워드 : 477 / 3193 행 제주 친구야식
# https://pcmap.place.naver.com/restaurant/1568248352/review/visitor#
# 이번에 찾을 키워드 : 478 / 3193 행 제주 달빛소주방국수
# none
# 이번에 찾을 키워드 : 479 / 3193 행 제주 국수의전설
# https://pcmap.place.naver.com/restaurant/1765587608/review/visitor#
# 이번에 찾을 키워드 : 480 / 3193 행 제주 토크쇼동문점
# https://pcmap.place.naver.com/restaurant/553486548/review/visitor#
# 이번에 찾을 키워드 : 481 / 3193 행 제주 삼다숯불갈비
# https://pcmap.place.naver.com/restaurant/16966634/review/visitor#
# 이번에 찾을 키워드 : 482 / 3193 행 제주 오구삼구민물장어아구찜
# none
# 이번에 찾을 키워드 : 483 / 3193 행 제주 삼겹살데이
# none
# 이번에 찾을 키워드 : 484 / 3193 행 제주 솔동산고기국수
# https://pcmap.place.naver.com/restaurant/34714074/review/visitor#
# 이번에 찾을 키워드 : 485 / 3193 행 제주 꾸러기
# none
# 이번에 찾을 키워드 : 486 / 3193 행 제주 컬투치킨&피자효돈점
# none
# 이번에 찾을 키워드 : 487 / 3193 행 제주 온평꽃돈숯불구이
# https://pcmap.place.naver.com/restaurant/1070040446/review/visitor#
# 이번에 찾을 키워드 : 488 / 3193 행 제주 막숙해담식당
# none
# 이번에 찾을 키워드 : 489 / 3193 행 제주 우리한뚝배기
# none
# 이번에 찾을 키워드 : 490 / 3193 행 제주 쇠소깍복순이네식당
# https://pcmap.place.naver.com/restaurant/520160543/review/visitor#
# 이번에 찾을 키워드 : 491 / 3193 행 제주 랍씨네
# https://pcmap.place.naver.com/restaurant/38422758/review/visitor#
# 이번에 찾을 키워드 : 492 / 3193 행 제주 바다여행횟집
# https://pcmap.place.naver.com/restaurant/35103320/review/visitor#
# 이번에 찾을 키워드 : 493 / 3193 행 제주 컬투치킨성산점
# none
# 이번에 찾을 키워드 : 494 / 3193 행 제주 해송초밥
# https://pcmap.place.naver.com/restaurant/750190900/review/visitor#
# 이번에 찾을 키워드 : 495 / 3193 행 제주 성산미소복집
# https://pcmap.place.naver.com/restaurant/1128371429/review/visitor#
# 이번에 찾을 키워드 : 496 / 3193 행 제주 순실이네
# none
# 이번에 찾을 키워드 : 497 / 3193 행 제주 홍당무떡볶이
# https://pcmap.place.naver.com/restaurant/648503521/review/visitor#
# 이번에 찾을 키워드 : 498 / 3193 행 제주 성읍치킨튀
# https://pcmap.place.naver.com/restaurant/1891863288/review/visitor#
# 이번에 찾을 키워드 : 499 / 3193 행 제주 자구리국수
# none
# 이번에 찾을 키워드 : 500 / 3193 행 제주 오라방횟집
# https://pcmap.place.naver.com/restaurant/19789243/review/visitor#
# 이번에 찾을 키워드 : 501 / 3193 행 제주 위미다온국밥
# https://pcmap.place.naver.com/restaurant/1185316651/review/visitor#
# 이번에 찾을 키워드 : 502 / 3193 행 제주 중섭이네식당
# https://pcmap.place.naver.com/restaurant/1099511109/review/visitor#
# 이번에 찾을 키워드 : 503 / 3193 행 제주 제주삼다국수&도담찜닭
# https://pcmap.place.naver.com/restaurant/20706483/review/visitor#
# 이번에 찾을 키워드 : 504 / 3193 행 제주 베트남향기
# https://pcmap.place.naver.com/restaurant/1112819225/review/visitor#
# 이번에 찾을 키워드 : 505 / 3193 행 제주 하버39
# none
# 이번에 찾을 키워드 : 506 / 3193 행 제주 표선골목집본점
# none
# 이번에 찾을 키워드 : 507 / 3193 행 제주 피자명인제주남원점
# none
# 이번에 찾을 키워드 : 508 / 3193 행 제주 비케이
# none
# 이번에 찾을 키워드 : 509 / 3193 행 제주 라이브카페레옹
# https://pcmap.place.naver.com/restaurant/1980447904/review/visitor#
# 이번에 찾을 키워드 : 510 / 3193 행 제주 다올
# none
# 이번에 찾을 키워드 : 511 / 3193 행 제주 아지
# none
# 이번에 찾을 키워드 : 512 / 3193 행 제주 서울불고기
# https://pcmap.place.naver.com/restaurant/1372323235/review/visitor#
# 이번에 찾을 키워드 : 513 / 3193 행 제주 사락
# https://pcmap.place.naver.com/restaurant/1176823351/review/visitor#
# 이번에 찾을 키워드 : 514 / 3193 행 제주 상원가든
# https://pcmap.place.naver.com/restaurant/16935043/review/visitor#
# 이번에 찾을 키워드 : 515 / 3193 행 제주 한잔해
# none
# 이번에 찾을 키워드 : 516 / 3193 행 제주 집나간 왕새우 바람난 조개구이 표선점
# https://pcmap.place.naver.com/restaurant/38681553/review/visitor#
# 이번에 찾을 키워드 : 517 / 3193 행 제주 식도향
# https://pcmap.place.naver.com/restaurant/11603035/review/visitor#
# 이번에 찾을 키워드 : 518 / 3193 행 제주 만물식당
# none
# 이번에 찾을 키워드 : 519 / 3193 행 제주 바다사냥
# https://pcmap.place.naver.com/restaurant/13121749/review/visitor#
# 이번에 찾을 키워드 : 520 / 3193 행 제주 주점부리성산일출봉점
# none
# 이번에 찾을 키워드 : 521 / 3193 행 제주 은빌레식당
# none
# 이번에 찾을 키워드 : 522 / 3193 행 제주 미풍해장국서귀포직영점
# none
# 이번에 찾을 키워드 : 523 / 3193 행 제주 썬시티
# none
# 이번에 찾을 키워드 : 524 / 3193 행 제주 성아네갈비
# https://pcmap.place.naver.com/restaurant/62645840/review/visitor#
# 이번에 찾을 키워드 : 525 / 3193 행 제주 성산마씸
# none
# 이번에 찾을 키워드 : 526 / 3193 행 제주 명동춘천닭갈비4호점
# https://pcmap.place.naver.com/restaurant/1030286875/review/visitor#
# 이번에 찾을 키워드 : 527 / 3193 행 제주 대게나라
# none
# 이번에 찾을 키워드 : 528 / 3193 행 제주 제주수제도시락
# none
# 이번에 찾을 키워드 : 529 / 3193 행 제주 카페바라크라
# https://pcmap.place.naver.com/restaurant/48871363/review/visitor#
# 이번에 찾을 키워드 : 530 / 3193 행 제주 육떡식당
# https://pcmap.place.naver.com/restaurant/57449378/review/visitor#
# 이번에 찾을 키워드 : 531 / 3193 행 제주 정담가찌개랑
# https://pcmap.place.naver.com/restaurant/1373998957/review/visitor#
# 이번에 찾을 키워드 : 532 / 3193 행 제주 바람이풀에그림그린날
# https://pcmap.place.naver.com/restaurant/83931252/review/visitor#
# 이번에 찾을 키워드 : 533 / 3193 행 제주 동홍정육식당
# none
# 이번에 찾을 키워드 : 534 / 3193 행 제주 황금치킨
# none
# 이번에 찾을 키워드 : 535 / 3193 행 제주 굽네치킨중문점
# none
# 이번에 찾을 키워드 : 536 / 3193 행 제주 페닌슐라
# https://pcmap.place.naver.com/restaurant/32839784/review/visitor#
# 이번에 찾을 키워드 : 537 / 3193 행 제주 하마
# none
# 이번에 찾을 키워드 : 538 / 3193 행 제주 짱아저씨구이구이
# https://pcmap.place.naver.com/restaurant/13484740/review/visitor#
# 이번에 찾을 키워드 : 539 / 3193 행 제주 엑스오라운지
# none
# 이번에 찾을 키워드 : 540 / 3193 행 제주 더끌림카페
# https://pcmap.place.naver.com/restaurant/1078517241/review/visitor#
# 이번에 찾을 키워드 : 541 / 3193 행 제주 은미네식당
# https://pcmap.place.naver.com/restaurant/16954085/review/visitor#
# 이번에 찾을 키워드 : 542 / 3193 행 제주 담앤루
# none
# 이번에 찾을 키워드 : 543 / 3193 행 제주 성광식당
# https://pcmap.place.naver.com/restaurant/16922278/review/visitor#
# 이번에 찾을 키워드 : 544 / 3193 행 제주 뚱뚱이네보쌈족발
# https://pcmap.place.naver.com/restaurant/16912087/review/visitor#
# 이번에 찾을 키워드 : 545 / 3193 행 제주 관촌밀면
# https://pcmap.place.naver.com/restaurant/13444879/review/visitor#
# 이번에 찾을 키워드 : 546 / 3193 행 제주 국수야
# https://pcmap.place.naver.com/restaurant/1757505131/review/visitor#
# 이번에 찾을 키워드 : 547 / 3193 행 제주 못동산가든
# https://pcmap.place.naver.com/restaurant/16927121/review/visitor#
# 이번에 찾을 키워드 : 548 / 3193 행 제주 오리나라닭마을
# https://pcmap.place.naver.com/restaurant/1261162359/review/visitor#
# 이번에 찾을 키워드 : 549 / 3193 행 제주 고미횟집
# https://pcmap.place.naver.com/restaurant/13415230/review/visitor#
# 이번에 찾을 키워드 : 550 / 3193 행 제주 나몰라
# https://pcmap.place.naver.com/restaurant/1579513385/review/visitor#
# 이번에 찾을 키워드 : 551 / 3193 행 제주 티라한식당
# https://pcmap.place.naver.com/restaurant/1029082408/review/visitor#
# 이번에 찾을 키워드 : 552 / 3193 행 제주 야구펍
# none
# 이번에 찾을 키워드 : 553 / 3193 행 제주 부산숯불갈비
# none
# 이번에 찾을 키워드 : 554 / 3193 행 제주 춘천명동닭갈비
# none
# 이번에 찾을 키워드 : 555 / 3193 행 제주 새로나식당
# none
# 이번에 찾을 키워드 : 556 / 3193 행 제주 민트
# none
# 이번에 찾을 키워드 : 557 / 3193 행 제주 동수식당
# none
# 이번에 찾을 키워드 : 558 / 3193 행 제주 중문양꼬치
# https://pcmap.place.naver.com/restaurant/1616259398/review/visitor#
# 이번에 찾을 키워드 : 559 / 3193 행 제주 칠돈가서귀포점
# none
# 이번에 찾을 키워드 : 560 / 3193 행 제주 블랑드오조
# none
# 이번에 찾을 키워드 : 561 / 3193 행 제주 소미네
# none
# 이번에 찾을 키워드 : 562 / 3193 행 제주 올레은하수마카롱
# https://pcmap.place.naver.com/restaurant/1220353689/review/visitor#
# 이번에 찾을 키워드 : 563 / 3193 행 제주 쉬림포크
# https://pcmap.place.naver.com/restaurant/556649295/review/visitor#
# 이번에 찾을 키워드 : 564 / 3193 행 제주 별빛한잔
# none
# 이번에 찾을 키워드 : 565 / 3193 행 제주 본앤베이커리
# none
# 이번에 찾을 키워드 : 566 / 3193 행 제주 흑미진
# https://pcmap.place.naver.com/restaurant/16881298/review/visitor#
# 이번에 찾을 키워드 : 567 / 3193 행 제주 아지트호프
# none
# 이번에 찾을 키워드 : 568 / 3193 행 제주 보롬왓
# none
# 이번에 찾을 키워드 : 569 / 3193 행 제주 다금바리횟집
# none
# 이번에 찾을 키워드 : 570 / 3193 행 제주 미쎄스올리브
# https://pcmap.place.naver.com/restaurant/32430173/review/visitor#
# 이번에 찾을 키워드 : 571 / 3193 행 제주 한우설렁탕
# none
# 이번에 찾을 키워드 : 572 / 3193 행 제주 서귀포대정식당
# none
# 이번에 찾을 키워드 : 573 / 3193 행 제주 노리 매
# none
# 이번에 찾을 키워드 : 574 / 3193 행 제주 한남닭농원식당
# https://pcmap.place.naver.com/restaurant/34163946/review/visitor#
# 이번에 찾을 키워드 : 575 / 3193 행 제주 네네치킨성산점
# none
# 이번에 찾을 키워드 : 576 / 3193 행 제주 꾸브라꼬숯불두마리치킨서귀점
# none
# 이번에 찾을 키워드 : 577 / 3193 행 제주 굽네치킨표선점
# none
# 이번에 찾을 키워드 : 578 / 3193 행 제주 베니스
# none
# 이번에 찾을 키워드 : 579 / 3193 행 제주 사계180카페
# none
# 이번에 찾을 키워드 : 580 / 3193 행 제주 황금돼지
# none
# 이번에 찾을 키워드 : 581 / 3193 행 제주 삼다도흑돼지갈비
# none
# 이번에 찾을 키워드 : 582 / 3193 행 제주 오렌지가든1호점
# none
# 이번에 찾을 키워드 : 583 / 3193 행 제주 오렌지가든2호점
# none
# 이번에 찾을 키워드 : 584 / 3193 행 제주 차르망
# none
# 이번에 찾을 키워드 : 585 / 3193 행 제주 고메밀면제주본점
# https://pcmap.place.naver.com/restaurant/1797447350/review/visitor#
# 이번에 찾을 키워드 : 586 / 3193 행 제주 제주찰칵스튜디오카페
# none
# 이번에 찾을 키워드 : 587 / 3193 행 제주 구찌커피앤비어
# https://pcmap.place.naver.com/restaurant/1362997299/review/visitor#
# 이번에 찾을 키워드 : 588 / 3193 행 제주 열열이얼큰이서귀포점
# https://pcmap.place.naver.com/restaurant/1986535461/review/visitor#
# 이번에 찾을 키워드 : 589 / 3193 행 제주 일품순두부남원점
# https://pcmap.place.naver.com/restaurant/1344391960/review/visitor#
# 이번에 찾을 키워드 : 590 / 3193 행 제주 동류암
# https://pcmap.place.naver.com/restaurant/1074076734/review/visitor#
# 이번에 찾을 키워드 : 591 / 3193 행 제주 빼어날수정식
# https://pcmap.place.naver.com/restaurant/1168417080/review/visitor#
# 이번에 찾을 키워드 : 592 / 3193 행 제주 물고기자리
# none
# 이번에 찾을 키워드 : 593 / 3193 행 제주 황금돈사랑
# https://pcmap.place.naver.com/restaurant/1036879286/review/visitor#
# 이번에 찾을 키워드 : 594 / 3193 행 제주 공새미솥뚜껑
# https://pcmap.place.naver.com/restaurant/1762042953/review/visitor#
# 이번에 찾을 키워드 : 595 / 3193 행 제주 깜장돈돈돈
# https://pcmap.place.naver.com/restaurant/1071053085/review/visitor#
# 이번에 찾을 키워드 : 596 / 3193 행 제주 제주전복치킨
# https://pcmap.place.naver.com/restaurant/1530942162/review/visitor#
# 이번에 찾을 키워드 : 597 / 3193 행 제주 헤밍웨이
# none
# 이번에 찾을 키워드 : 598 / 3193 행 제주 역전할머니맥주제주동홍점
# https://pcmap.place.naver.com/restaurant/1526611289/review/visitor#
# 이번에 찾을 키워드 : 599 / 3193 행 제주 우리마을가마솥정식
# https://pcmap.place.naver.com/restaurant/39330782/review/visitor#
# 이번에 찾을 키워드 : 600 / 3193 행 제주 라그라스
# none
# 이번에 찾을 키워드 : 601 / 3193 행 제주 중문보말칼국수
# none
# 이번에 찾을 키워드 : 602 / 3193 행 제주 마농오메기통닭마농문어통닭
# https://pcmap.place.naver.com/restaurant/1615280999/review/visitor#
# 이번에 찾을 키워드 : 603 / 3193 행 제주 더쉐프
# https://pcmap.place.naver.com/restaurant/1566536639/review/visitor#
# 이번에 찾을 키워드 : 604 / 3193 행 제주 닭찬들마켓서귀포점
# https://pcmap.place.naver.com/restaurant/1471171605/review/visitor#
# 이번에 찾을 키워드 : 605 / 3193 행 제주 나인브로스커피
# https://pcmap.place.naver.com/restaurant/1299976067/review/visitor#
# 이번에 찾을 키워드 : 606 / 3193 행 제주 덕수선물카페
# none
# 이번에 찾을 키워드 : 607 / 3193 행 제주 60계치킨제주서귀포동홍점
# none
# 이번에 찾을 키워드 : 608 / 3193 행 제주 그럼피베이비
# https://pcmap.place.naver.com/restaurant/1090954658/review/visitor#
# 이번에 찾을 키워드 : 609 / 3193 행 제주 어물전
# none
# 이번에 찾을 키워드 : 610 / 3193 행 제주 누구나홀딱반한닭동홍점
# none
# 이번에 찾을 키워드 : 611 / 3193 행 제주 청춘괴기동홍점
# none
# 이번에 찾을 키워드 : 612 / 3193 행 제주 대포면옥
# https://pcmap.place.naver.com/restaurant/1005412540/review/visitor#
# 이번에 찾을 키워드 : 613 / 3193 행 제주 가보정원
# https://pcmap.place.naver.com/restaurant/1290396612/review/visitor#
# 이번에 찾을 키워드 : 614 / 3193 행 제주 모심
# none
# 이번에 찾을 키워드 : 615 / 3193 행 제주 노랑통닭동홍점
# none
# 이번에 찾을 키워드 : 616 / 3193 행 제주 제주뽀로로파크
# none
# 이번에 찾을 키워드 : 617 / 3193 행 제주 구포집
# none
# 이번에 찾을 키워드 : 618 / 3193 행 제주 로컬라운지
# https://pcmap.place.naver.com/restaurant/1652384249/review/visitor#
# 이번에 찾을 키워드 : 619 / 3193 행 제주 청보리밥상
# https://pcmap.place.naver.com/restaurant/1067854676/review/visitor#
# 이번에 찾을 키워드 : 620 / 3193 행 제주 카페오라
# none
# 이번에 찾을 키워드 : 621 / 3193 행 제주 일출명가
# https://pcmap.place.naver.com/restaurant/37590575/review/visitor#
# 이번에 찾을 키워드 : 622 / 3193 행 제주 성산썬라이즈호텔
# none
# 이번에 찾을 키워드 : 623 / 3193 행 제주 마당별
# none
# 이번에 찾을 키워드 : 624 / 3193 행 제주 레트로보이즈
# https://pcmap.place.naver.com/restaurant/1689067900/review/visitor#
# 이번에 찾을 키워드 : 625 / 3193 행 제주 위미방자연농장
# none
# 이번에 찾을 키워드 : 626 / 3193 행 제주 참방참방
# https://pcmap.place.naver.com/restaurant/1241448783/review/visitor#
# 이번에 찾을 키워드 : 627 / 3193 행 제주 행복한뷔페
# none
# 이번에 찾을 키워드 : 628 / 3193 행 제주 풀룸
# https://pcmap.place.naver.com/restaurant/1618257022/review/visitor#
# 이번에 찾을 키워드 : 629 / 3193 행 제주 한라생얼큰이서귀포점
# https://pcmap.place.naver.com/restaurant/1832697295/review/visitor#
# 이번에 찾을 키워드 : 630 / 3193 행 제주 올디벗구디
# https://pcmap.place.naver.com/restaurant/1600898921/review/visitor#
# 이번에 찾을 키워드 : 631 / 3193 행 제주 플루메리아
# none
# 이번에 찾을 키워드 : 632 / 3193 행 제주 카페펌킨제주점
# https://pcmap.place.naver.com/restaurant/1240871544/review/visitor#
# 이번에 찾을 키워드 : 633 / 3193 행 제주 한와담제주점
# none
# 이번에 찾을 키워드 : 634 / 3193 행 제주 춘흥뷔페
# none
# 이번에 찾을 키워드 : 635 / 3193 행 제주 몬파보히
# https://pcmap.place.naver.com/restaurant/1560056381/review/visitor#
# 이번에 찾을 키워드 : 636 / 3193 행 제주 진풍해장국
# none
# 이번에 찾을 키워드 : 637 / 3193 행 제주 월정리갈비밥서귀포점
# https://pcmap.place.naver.com/restaurant/1158867039/review/visitor#
# 이번에 찾을 키워드 : 638 / 3193 행 제주 제주냉동삼겹살제주산
# none
# 이번에 찾을 키워드 : 639 / 3193 행 제주 화단못
# https://pcmap.place.naver.com/restaurant/1086019737/review/visitor#
# 이번에 찾을 키워드 : 640 / 3193 행 제주 바온탑(Bar on Top)
# none
# 이번에 찾을 키워드 : 641 / 3193 행 제주 신화다이닝앤라운지(Shinhwa Dining & Lounge)
# none
# 이번에 찾을 키워드 : 642 / 3193 행 제주 봄바쉑(Bombashack)
# none
# 이번에 찾을 키워드 : 643 / 3193 행 제주 돔베집
# none
# 이번에 찾을 키워드 : 644 / 3193 행 제주 카페제주더블유
# none
# 이번에 찾을 키워드 : 645 / 3193 행 제주 수작
# none
# 이번에 찾을 키워드 : 646 / 3193 행 제주 글로벌제주문화협동조합
# https://pcmap.place.naver.com/restaurant/1052480355/review/visitor#
# 이번에 찾을 키워드 : 647 / 3193 행 제주 노마스
# https://pcmap.place.naver.com/restaurant/1181602520/review/visitor#
# 이번에 찾을 키워드 : 648 / 3193 행 제주 이공일구아지트
# https://pcmap.place.naver.com/restaurant/1615881733/review/visitor#
# 이번에 찾을 키워드 : 649 / 3193 행 제주 카페바나나중문점
# https://pcmap.place.naver.com/restaurant/1897276148/review/visitor#
# 이번에 찾을 키워드 : 650 / 3193 행 제주 제주선채향
# https://pcmap.place.naver.com/restaurant/1333639081/review/visitor#
# 이번에 찾을 키워드 : 651 / 3193 행 제주 야키토리타키비
# https://pcmap.place.naver.com/restaurant/1819192536/review/visitor#
# 이번에 찾을 키워드 : 652 / 3193 행 제주 제주화덕족발대정점
# https://pcmap.place.naver.com/restaurant/1654991153/review/visitor#
# 이번에 찾을 키워드 : 653 / 3193 행 제주 오태식해바라기치킨신시가지점
# none
# 이번에 찾을 키워드 : 654 / 3193 행 제주 핫마마
# https://pcmap.place.naver.com/restaurant/1602103587/review/visitor#
# 이번에 찾을 키워드 : 655 / 3193 행 제주 구두미바당
# https://pcmap.place.naver.com/restaurant/1413874797/review/visitor#
# 이번에 찾을 키워드 : 656 / 3193 행 제주 제주어향원
# https://pcmap.place.naver.com/restaurant/1605149893/review/visitor#
# 이번에 찾을 키워드 : 657 / 3193 행 제주 이글아지트식당
# none
# 이번에 찾을 키워드 : 658 / 3193 행 제주 소담소담
# none
# 이번에 찾을 키워드 : 659 / 3193 행 제주 태공밥집
# ...
# 이번에 찾을 키워드 : 1403 / 3193 행 제주 스크류비어
# https://pcmap.place.naver.com/restaurant/38707985/review/visitor#
# 이번에 찾을 키워드 : 1404 / 3193 행 제주 우리동네
# none
# 이번에 찾을 키워드 : 1405 / 3193 행 제주 쇠소깍빵명장
# https://pcmap.place.naver.com/restaurant/1238493751/review/visitor#
# 이번에 찾을 키워드 : 1406 / 3193 행 제주 햇살국수
# https://pcmap.place.naver.com/restaurant/1180494587/review/visitor#
# 이번에 찾을 키워드 : 1407 / 3193 행 제주 멕시코니안덕점
# none
# 이번에 찾을 키워드 : 1408 / 3193 행 제주 사부작
# none
# 이번에 찾을 키워드 : 1409 / 3193 행 제주 돼지삼형제
# none
# 이번에 찾을 키워드 : 1410 / 3193 행 제주 노리터펍
# none
# 이번에 찾을 키워드 : 1411 / 3193 행 제주 쏠티브리즈
# https://pcmap.place.naver.com/restaurant/1435663151/review/visitor#
# 이번에 찾을 키워드 : 1412 / 3193 행 제주 고기에오르다
# https://pcmap.place.naver.com/restaurant/1383219785/review/visitor#
# 이번에 찾을 키워드 : 1413 / 3193 행 제주 가건물
# https://pcmap.place.naver.com/restaurant/1170006246/review/visitor#
# 이번에 찾을 키워드 : 1414 / 3193 행 제주 만두삼촌
# https://pcmap.place.naver.com/restaurant/1128426071/review/visitor#
# 이번에 찾을 키워드 : 1415 / 3193 행 제주 제주초계한우
# https://pcmap.place.naver.com/restaurant/1144786194/review/visitor#
# 이번에 찾을 키워드 : 1416 / 3193 행 제주 산방산해물라면오빠네
# https://pcmap.place.naver.com/restaurant/1133619256/review/visitor#
# 이번에 찾을 키워드 : 1417 / 3193 행 제주 영육일삼
# https://pcmap.place.naver.com/restaurant/1045653426/review/visitor#
# 이번에 찾을 키워드 : 1418 / 3193 행 제주 사계전복
# https://pcmap.place.naver.com/restaurant/1244382800/review/visitor#
# 이번에 찾을 키워드 : 1419 / 3193 행 제주 세영수산회조림전문
# none
# 이번에 찾을 키워드 : 1420 / 3193 행 제주 해월정서귀포점
# https://pcmap.place.naver.com/restaurant/1291320257/review/visitor#
# 이번에 찾을 키워드 : 1421 / 3193 행 제주 서림향
# https://pcmap.place.naver.com/restaurant/1077110666/review/visitor#
# 이번에 찾을 키워드 : 1422 / 3193 행 제주 우디94
# https://pcmap.place.naver.com/restaurant/1073711572/review/visitor#
# 이번에 찾을 키워드 : 1423 / 3193 행 제주 코지게하식당
# none
# 이번에 찾을 키워드 : 1424 / 3193 행 제주 혜연플라워카페
# https://pcmap.place.naver.com/restaurant/1543135965/review/visitor#
# 이번에 찾을 키워드 : 1425 / 3193 행 제주 뜨랑국수
# https://pcmap.place.naver.com/restaurant/1978772663/review/visitor#
# 이번에 찾을 키워드 : 1426 / 3193 행 제주 21앤비어
# none
# 이번에 찾을 키워드 : 1427 / 3193 행 제주 제주흑돼지황칠족발
# https://pcmap.place.naver.com/restaurant/1283193340/review/visitor#
# 이번에 찾을 키워드 : 1428 / 3193 행 제주 소요0617
# https://pcmap.place.naver.com/restaurant/1279731375/review/visitor#
# 이번에 찾을 키워드 : 1429 / 3193 행 제주 백년손님
# none
# 이번에 찾을 키워드 : 1430 / 3193 행 제주 성산봄죽칼국수본점
# none
# 이번에 찾을 키워드 : 1431 / 3193 행 제주 배달삼겹돼지되지
# none
# 이번에 찾을 키워드 : 1432 / 3193 행 제주 팔도식당갈치조림섭지코지점
# https://pcmap.place.naver.com/restaurant/1950026137/review/visitor#
# 이번에 찾을 키워드 : 1433 / 3193 행 제주 중문클럽하우스주식회사
# none
# 이번에 찾을 키워드 : 1434 / 3193 행 제주 하누초롬
# https://pcmap.place.naver.com/restaurant/1626920848/review/visitor#
# 이번에 찾을 키워드 : 1435 / 3193 행 제주 소쿠리
# https://pcmap.place.naver.com/restaurant/1874514725/review/visitor#
# 이번에 찾을 키워드 : 1436 / 3193 행 제주 쇼어(SHORE)
# none
# 이번에 찾을 키워드 : 1437 / 3193 행 제주 콩이네두부
# https://pcmap.place.naver.com/restaurant/19654358/review/visitor#
# 이번에 찾을 키워드 : 1438 / 3193 행 제주 김밥천국
# none
# 이번에 찾을 키워드 : 1439 / 3193 행 제주 그때그자리
# https://pcmap.place.naver.com/restaurant/702290686/review/visitor#
# 이번에 찾을 키워드 : 1440 / 3193 행 제주 용림식당
# https://pcmap.place.naver.com/restaurant/16958395/review/visitor#
# 이번에 찾을 키워드 : 1441 / 3193 행 제주 장군식당
# none
# 이번에 찾을 키워드 : 1442 / 3193 행 제주 고향마을
# https://pcmap.place.naver.com/restaurant/16963486/review/visitor#
# 이번에 찾을 키워드 : 1443 / 3193 행 제주 마스로
# https://pcmap.place.naver.com/restaurant/1897341351/review/visitor#
# 이번에 찾을 키워드 : 1444 / 3193 행 제주 고선장네
# https://pcmap.place.naver.com/restaurant/1089738201/review/visitor#
# 이번에 찾을 키워드 : 1445 / 3193 행 제주 수희식당
# https://pcmap.place.naver.com/restaurant/19877808/review/visitor#
# 이번에 찾을 키워드 : 1446 / 3193 행 제주 보물섬횟집
# https://pcmap.place.naver.com/restaurant/38457203/review/visitor#
# 이번에 찾을 키워드 : 1447 / 3193 행 제주 수악관식당
# https://pcmap.place.naver.com/restaurant/16945997/review/visitor#
# 이번에 찾을 키워드 : 1448 / 3193 행 제주 독고집
# https://pcmap.place.naver.com/restaurant/1325949781/review/visitor#
# 이번에 찾을 키워드 : 1449 / 3193 행 제주 페리카나양념통닭동문분점
# none
# 이번에 찾을 키워드 : 1450 / 3193 행 제주 효진이네
# none
# 이번에 찾을 키워드 : 1451 / 3193 행 제주 대포칼제비
# https://pcmap.place.naver.com/restaurant/1594545800/review/visitor#
# 이번에 찾을 키워드 : 1452 / 3193 행 제주 론푸드차이나
# https://pcmap.place.naver.com/restaurant/37775577/review/visitor#
# 이번에 찾을 키워드 : 1453 / 3193 행 제주 성영식당
# none
# 이번에 찾을 키워드 : 1454 / 3193 행 제주 국수데이(day)
# none
# 이번에 찾을 키워드 : 1455 / 3193 행 제주 짜짜루
# https://pcmap.place.naver.com/restaurant/32166494/review/visitor#
# 이번에 찾을 키워드 : 1456 / 3193 행 제주 서귀포장수해장국
# none
# 이번에 찾을 키워드 : 1457 / 3193 행 제주 경인식당
# https://pcmap.place.naver.com/restaurant/16942476/review/visitor#
# 이번에 찾을 키워드 : 1458 / 3193 행 제주 늘푸른리조트식당
# none
# 이번에 찾을 키워드 : 1459 / 3193 행 제주 성읍고을식당
# none
# 이번에 찾을 키워드 : 1460 / 3193 행 제주 카푸치노
# none
# 이번에 찾을 키워드 : 1461 / 3193 행 제주 이것저것짬뽕
# none
# 이번에 찾을 키워드 : 1462 / 3193 행 제주 남도밥상
# https://pcmap.place.naver.com/restaurant/1512189920/review/visitor#
# 이번에 찾을 키워드 : 1463 / 3193 행 제주 대원관
# none
# 이번에 찾을 키워드 : 1464 / 3193 행 제주 성산녘
# https://pcmap.place.naver.com/restaurant/1280230317/review/visitor#
# 이번에 찾을 키워드 : 1465 / 3193 행 제주 늘봄해물찜앤낙지
# none
# 이번에 찾을 키워드 : 1466 / 3193 행 제주 카페담아
# https://pcmap.place.naver.com/restaurant/1307294634/review/visitor#
# 이번에 찾을 키워드 : 1467 / 3193 행 제주 육장갈비
# none
# 이번에 찾을 키워드 : 1468 / 3193 행 제주 카페그네
# https://pcmap.place.naver.com/restaurant/1494892291/review/visitor#
# 이번에 찾을 키워드 : 1469 / 3193 행 제주 포차분식
# https://pcmap.place.naver.com/restaurant/1172454749/review/visitor#
# 이번에 찾을 키워드 : 1470 / 3193 행 제주 디피일오구(dp159)
# https://pcmap.place.naver.com/restaurant/1003949692/review/visitor#
# 이번에 찾을 키워드 : 1471 / 3193 행 제주 마당식당
# none
# 이번에 찾을 키워드 : 1472 / 3193 행 제주 구닮
# https://pcmap.place.naver.com/restaurant/1531770573/review/visitor#
# 이번에 찾을 키워드 : 1473 / 3193 행 제주 신세기식당
# https://pcmap.place.naver.com/restaurant/16901022/review/visitor#
# 이번에 찾을 키워드 : 1474 / 3193 행 제주 루트84
# https://pcmap.place.naver.com/restaurant/36310674/review/visitor#
# 이번에 찾을 키워드 : 1475 / 3193 행 제주 갈비마당
# none
# 이번에 찾을 키워드 : 1476 / 3193 행 제주 고수목마
# none
# 이번에 찾을 키워드 : 1477 / 3193 행 제주 엠소주카페
# none
# 이번에 찾을 키워드 : 1478 / 3193 행 제주 범일분식
# https://pcmap.place.naver.com/restaurant/17069378/review/visitor#
# 이번에 찾을 키워드 : 1479 / 3193 행 제주 올레일품
# https://pcmap.place.naver.com/restaurant/20995852/review/visitor#
# 이번에 찾을 키워드 : 1480 / 3193 행 제주 명동분식
# https://pcmap.place.naver.com/restaurant/16884321/review/visitor#
# 이번에 찾을 키워드 : 1481 / 3193 행 제주 가마솥국밥
# none
# 이번에 찾을 키워드 : 1482 / 3193 행 제주 카페카노푸스2
# none
# 이번에 찾을 키워드 : 1483 / 3193 행 제주 동호식당
# none
# 이번에 찾을 키워드 : 1484 / 3193 행 제주 유경분식
# https://pcmap.place.naver.com/restaurant/16937957/review/visitor#
# 이번에 찾을 키워드 : 1485 / 3193 행 제주 한라식당
# none
# 이번에 찾을 키워드 : 1486 / 3193 행 제주 사또야
# https://pcmap.place.naver.com/restaurant/16963423/review/visitor#
# 이번에 찾을 키워드 : 1487 / 3193 행 제주 남문식당
# none
# 이번에 찾을 키워드 : 1488 / 3193 행 제주 자연원
# https://pcmap.place.naver.com/restaurant/30813215/review/visitor#
# 이번에 찾을 키워드 : 1489 / 3193 행 제주 만미식당
# https://pcmap.place.naver.com/restaurant/20256085/review/visitor#
# 이번에 찾을 키워드 : 1490 / 3193 행 제주 가시리명문식당
# https://pcmap.place.naver.com/restaurant/13481036/review/visitor#
# 이번에 찾을 키워드 : 1491 / 3193 행 제주 페리카나양념통닭효돈분점
# none
# 이번에 찾을 키워드 : 1492 / 3193 행 제주 대유랜드휴게실
# none
# 이번에 찾을 키워드 : 1493 / 3193 행 제주 제일반점
# https://pcmap.place.naver.com/restaurant/16969218/review/visitor#
# 이번에 찾을 키워드 : 1494 / 3193 행 제주 한성식당
# none
# 이번에 찾을 키워드 : 1495 / 3193 행 제주 한라성
# https://pcmap.place.naver.com/restaurant/1056737453/review/visitor#
# 이번에 찾을 키워드 : 1496 / 3193 행 제주 부촌식당
# none
# 이번에 찾을 키워드 : 1497 / 3193 행 제주 카페더모닝중문점
# none
# 이번에 찾을 키워드 : 1498 / 3193 행 제주 등경돌
# https://pcmap.place.naver.com/restaurant/17076083/review/visitor#
# 이번에 찾을 키워드 : 1499 / 3193 행 제주 바나나에반하다
# none
# 이번에 찾을 키워드 : 1500 / 3193 행 제주 성문식당
# none
# 이번에 찾을 키워드 : 1501 / 3193 행 제주 옛날옛적에
# none
# 이번에 찾을 키워드 : 1502 / 3193 행 제주 성산포흑돈애
# https://pcmap.place.naver.com/restaurant/37604438/review/visitor#
# 이번에 찾을 키워드 : 1503 / 3193 행 제주 서귀포칼호텔살레
# https://pcmap.place.naver.com/restaurant/32840017/review/visitor#
# 이번에 찾을 키워드 : 1504 / 3193 행 제주 세숫대야냉면
# https://pcmap.place.naver.com/restaurant/16789092/review/visitor#
# 이번에 찾을 키워드 : 1505 / 3193 행 제주 이화삼계탕
# https://pcmap.place.naver.com/restaurant/16974038/review/visitor#
# 이번에 찾을 키워드 : 1506 / 3193 행 제주 가정식당
# none
# 이번에 찾을 키워드 : 1507 / 3193 행 제주 나목도식당
# https://pcmap.place.naver.com/restaurant/19877579/review/visitor#
# 이번에 찾을 키워드 : 1508 / 3193 행 제주 삼이사
# https://pcmap.place.naver.com/restaurant/603157561/review/visitor#
# 이번에 찾을 키워드 : 1509 / 3193 행 제주 마시로
# none
# 이번에 찾을 키워드 : 1510 / 3193 행 제주 메추리식당
# none
# 이번에 찾을 키워드 : 1511 / 3193 행 제주 서귀포화정식당
# none
# 이번에 찾을 키워드 : 1512 / 3193 행 제주 호텔신라제주호텔천지
# https://pcmap.place.naver.com/restaurant/33875256/review/visitor#
# 이번에 찾을 키워드 : 1513 / 3193 행 제주 호텔신라제주호텔일출
# none
# 이번에 찾을 키워드 : 1514 / 3193 행 제주 더파크뷰
# none
# 이번에 찾을 키워드 : 1515 / 3193 행 제주 항구식당
# none
# 이번에 찾을 키워드 : 1516 / 3193 행 제주 돌하루방잔치국수
# none
# 이번에 찾을 키워드 : 1517 / 3193 행 제주 수정식당
# none
# 이번에 찾을 키워드 : 1518 / 3193 행 제주 옛장터가든
# none
# 이번에 찾을 키워드 : 1519 / 3193 행 제주 주식회사부두식당
# none
# 이번에 찾을 키워드 : 1520 / 3193 행 제주 사계우리음식점
# https://pcmap.place.naver.com/restaurant/17082872/review/visitor#
# 이번에 찾을 키워드 : 1521 / 3193 행 제주 현대식당
# none
# 이번에 찾을 키워드 : 1522 / 3193 행 제주 나루터
# none
# 이번에 찾을 키워드 : 1523 / 3193 행 제주 오일장반점
# none
# 이번에 찾을 키워드 : 1524 / 3193 행 제주 동유암식당
# https://pcmap.place.naver.com/restaurant/16951993/review/visitor#
# 이번에 찾을 키워드 : 1525 / 3193 행 제주 해송수산물회센타서귀포중문점
# https://pcmap.place.naver.com/restaurant/1464237361/review/visitor#
# 이번에 찾을 키워드 : 1526 / 3193 행 제주 장원닭갈비
# https://pcmap.place.naver.com/restaurant/16966904/review/visitor#
# 이번에 찾을 키워드 : 1527 / 3193 행 제주 원담
# none
# 이번에 찾을 키워드 : 1528 / 3193 행 제주 용이식당
# none
# 이번에 찾을 키워드 : 1529 / 3193 행 제주 올랭이와물꾸럭
# none
# 이번에 찾을 키워드 : 1530 / 3193 행 제주 그때그집식당
# none
# 이번에 찾을 키워드 : 1531 / 3193 행 제주 영해식당
# none
# 이번에 찾을 키워드 : 1532 / 3193 행 제주 산포식당(수산)
# none
# 이번에 찾을 키워드 : 1533 / 3193 행 제주 서귀포소방서구내식당
# none
# 이번에 찾을 키워드 : 1534 / 3193 행 제주 피로회복
# none
# 이번에 찾을 키워드 : 1535 / 3193 행 제주 미풍해장국서귀포점
# none
# 이번에 찾을 키워드 : 1536 / 3193 행 제주 고성신양어촌계(백기해녀의집)
# none
# 이번에 찾을 키워드 : 1537 / 3193 행 제주 식개집
# none
# 이번에 찾을 키워드 : 1538 / 3193 행 제주 동해미락
# https://pcmap.place.naver.com/restaurant/12843612/review/visitor#
# 이번에 찾을 키워드 : 1539 / 3193 행 제주 한라가든
# none
# 이번에 찾을 키워드 : 1540 / 3193 행 제주 해심갈비
# https://pcmap.place.naver.com/restaurant/13444932/review/visitor#
# 이번에 찾을 키워드 : 1541 / 3193 행 제주 와랑와랑본점
# none
# 이번에 찾을 키워드 : 1542 / 3193 행 제주 충남식당
# none
# 이번에 찾을 키워드 : 1543 / 3193 행 제주 익산식당
# https://pcmap.place.naver.com/restaurant/38711108/review/visitor#
# 이번에 찾을 키워드 : 1544 / 3193 행 제주 유성반점
# https://pcmap.place.naver.com/restaurant/16950592/review/visitor#
# 이번에 찾을 키워드 : 1545 / 3193 행 제주 신태백관
# https://pcmap.place.naver.com/restaurant/16936477/review/visitor#
# 이번에 찾을 키워드 : 1546 / 3193 행 제주 금란이네
# https://pcmap.place.naver.com/restaurant/256908957/review/visitor#
# 이번에 찾을 키워드 : 1547 / 3193 행 제주 흑돼지BBQ
# none
# 이번에 찾을 키워드 : 1548 / 3193 행 제주 맛있는집
# none
# 이번에 찾을 키워드 : 1549 / 3193 행 제주 통큰맛집
# none
# 이번에 찾을 키워드 : 1550 / 3193 행 제주 안트레
# none
# 이번에 찾을 키워드 : 1551 / 3193 행 제주 한라반점
# https://pcmap.place.naver.com/restaurant/13119477/review/visitor#
# 이번에 찾을 키워드 : 1552 / 3193 행 제주 정성식당
# none
# 이번에 찾을 키워드 : 1553 / 3193 행 제주 장수해장국&해물구이
# https://pcmap.place.naver.com/restaurant/16926644/review/visitor#
# 이번에 찾을 키워드 : 1554 / 3193 행 제주 한남식육식당
# none
# 이번에 찾을 키워드 : 1555 / 3193 행 제주 한남동그집
# none
# 이번에 찾을 키워드 : 1556 / 3193 행 제주 호박식당
# https://pcmap.place.naver.com/restaurant/16963939/review/visitor#
# 이번에 찾을 키워드 : 1557 / 3193 행 제주 남도성찬
# https://pcmap.place.naver.com/restaurant/1954916563/review/visitor#
# 이번에 찾을 키워드 : 1558 / 3193 행 제주 승리분식
# https://pcmap.place.naver.com/restaurant/1487510457/review/visitor#
# 이번에 찾을 키워드 : 1559 / 3193 행 제주 멕시칸동남체인점
# none
# 이번에 찾을 키워드 : 1560 / 3193 행 제주 하르방식당
# none
# 이번에 찾을 키워드 : 1561 / 3193 행 제주 돈우촌숯불갈비
# none
# 이번에 찾을 키워드 : 1562 / 3193 행 제주 중앙식당
# none
# 이번에 찾을 키워드 : 1563 / 3193 행 제주 김대감
# none
# 이번에 찾을 키워드 : 1564 / 3193 행 제주 삼행식당
# none
# 이번에 찾을 키워드 : 1565 / 3193 행 제주 해녀식당
# none
# 이번에 찾을 키워드 : 1566 / 3193 행 제주 명동갈비
# https://pcmap.place.naver.com/restaurant/16972508/review/visitor#
# 이번에 찾을 키워드 : 1567 / 3193 행 제주 담다디분식
# https://pcmap.place.naver.com/restaurant/13106013/review/visitor#
# 이번에 찾을 키워드 : 1568 / 3193 행 제주 행복밥상
# none
# 이번에 찾을 키워드 : 1569 / 3193 행 제주 대포횟집
# none
# 이번에 찾을 키워드 : 1570 / 3193 행 제주 촌고기
# https://pcmap.place.naver.com/restaurant/1331533889/review/visitor#
# 이번에 찾을 키워드 : 1571 / 3193 행 제주 대우반점
# https://pcmap.place.naver.com/restaurant/16960606/review/visitor#
# 이번에 찾을 키워드 : 1572 / 3193 행 제주 멕시코니치킨
# none
# 이번에 찾을 키워드 : 1573 / 3193 행 제주 제주뚝배기
# none
# 이번에 찾을 키워드 : 1574 / 3193 행 제주 삼거리해장국,찜
# https://pcmap.place.naver.com/restaurant/38275632/review/visitor#
# 이번에 찾을 키워드 : 1575 / 3193 행 제주 육거리포차
# none
# 이번에 찾을 키워드 : 1576 / 3193 행 제주 한아름식당
# none
# 이번에 찾을 키워드 : 1577 / 3193 행 제주 효성식당
# none
# 이번에 찾을 키워드 : 1578 / 3193 행 제주 항구횟집
# https://pcmap.place.naver.com/restaurant/20336354/review/visitor#
# 이번에 찾을 키워드 : 1579 / 3193 행 제주 보일식당
# none
# 이번에 찾을 키워드 : 1580 / 3193 행 제주 늘장터식당
# https://pcmap.place.naver.com/restaurant/33063512/review/visitor#
# 이번에 찾을 키워드 : 1581 / 3193 행 제주 웅담식당
# https://pcmap.place.naver.com/restaurant/11877729/review/visitor#
# 이번에 찾을 키워드 : 1582 / 3193 행 제주 고래
# none
# 이번에 찾을 키워드 : 1583 / 3193 행 제주 형과아우
# https://pcmap.place.naver.com/restaurant/1042807827/review/visitor#
# 이번에 찾을 키워드 : 1584 / 3193 행 제주 올레삼다정
# https://pcmap.place.naver.com/restaurant/36784947/review/visitor#
# 이번에 찾을 키워드 : 1585 / 3193 행 제주 옵데강식당
# none
# 이번에 찾을 키워드 : 1586 / 3193 행 제주 고려반점
# https://pcmap.place.naver.com/restaurant/16969249/review/visitor#
# 이번에 찾을 키워드 : 1587 / 3193 행 제주 수진돌솥밥
# https://pcmap.place.naver.com/restaurant/16970478/review/visitor#
# 이번에 찾을 키워드 : 1588 / 3193 행 제주 자갈치아구찜
# https://pcmap.place.naver.com/restaurant/32036007/review/visitor#
# 이번에 찾을 키워드 : 1589 / 3193 행 제주 그리운바다성산포
# none
# 이번에 찾을 키워드 : 1590 / 3193 행 제주 제주해풍횟집
# https://pcmap.place.naver.com/restaurant/37402584/review/visitor#
# 이번에 찾을 키워드 : 1591 / 3193 행 제주 신산나들목
# https://pcmap.place.naver.com/restaurant/21357868/review/visitor#
# 이번에 찾을 키워드 : 1592 / 3193 행 제주 천제연토속
# https://pcmap.place.naver.com/restaurant/11860683/review/visitor#
# 이번에 찾을 키워드 : 1593 / 3193 행 제주 더리트리브
# https://pcmap.place.naver.com/restaurant/741621665/review/visitor#
# 이번에 찾을 키워드 : 1594 / 3193 행 제주 가시식당
# none
# 이번에 찾을 키워드 : 1595 / 3193 행 제주 새향원분식
# https://pcmap.place.naver.com/restaurant/16967528/review/visitor#
# 이번에 찾을 키워드 : 1596 / 3193 행 제주 진미명가식당
# https://pcmap.place.naver.com/restaurant/11608775/review/visitor#
# 이번에 찾을 키워드 : 1597 / 3193 행 제주 광동식당
# none
# 이번에 찾을 키워드 : 1598 / 3193 행 제주 한국콘도한식당
# none
# 이번에 찾을 키워드 : 1599 / 3193 행 제주 진성식당
# none
# 이번에 찾을 키워드 : 1600 / 3193 행 제주 제주소
# none
# 이번에 찾을 키워드 : 1601 / 3193 행 제주 보성식당
# none
# 이번에 찾을 키워드 : 1602 / 3193 행 제주 절구통
# https://pcmap.place.naver.com/restaurant/1656327314/review/visitor#
# 이번에 찾을 키워드 : 1603 / 3193 행 제주 낭쿰낭쿰
# https://pcmap.place.naver.com/restaurant/1495301401/review/visitor#
# 이번에 찾을 키워드 : 1604 / 3193 행 제주 고가명가
# https://pcmap.place.naver.com/restaurant/37048357/review/visitor#
# 이번에 찾을 키워드 : 1605 / 3193 행 제주 어른이보호구역
# https://pcmap.place.naver.com/restaurant/1381477499/review/visitor#
# 이번에 찾을 키워드 : 1606 / 3193 행 제주 새벽기차
# https://pcmap.place.naver.com/restaurant/34578468/review/visitor#
# 이번에 찾을 키워드 : 1607 / 3193 행 제주 큰갯물횟집
# https://pcmap.place.naver.com/restaurant/37101721/review/visitor#
# 이번에 찾을 키워드 : 1608 / 3193 행 제주 라라소주앤비어
# https://pcmap.place.naver.com/restaurant/1476135290/review/visitor#
# 이번에 찾을 키워드 : 1609 / 3193 행 제주 표선풍천장어
# https://pcmap.place.naver.com/restaurant/1398988740/review/visitor#
# 이번에 찾을 키워드 : 1610 / 3193 행 제주 큰산식당
# https://pcmap.place.naver.com/restaurant/16963432/review/visitor#
# 이번에 찾을 키워드 : 1611 / 3193 행 제주 신라가든
# none
# 이번에 찾을 키워드 : 1612 / 3193 행 제주 스페샬표선점
# none
# 이번에 찾을 키워드 : 1613 / 3193 행 제주 태백관
# https://pcmap.place.naver.com/restaurant/16950584/review/visitor#
# 이번에 찾을 키워드 : 1614 / 3193 행 제주 평화식당
# none
# 이번에 찾을 키워드 : 1615 / 3193 행 제주 삼강식당
# none
# 이번에 찾을 키워드 : 1616 / 3193 행 제주 혼차롱식개집
# https://pcmap.place.naver.com/restaurant/1370697290/review/visitor#
# 이번에 찾을 키워드 : 1617 / 3193 행 제주 동원참치
# https://pcmap.place.naver.com/restaurant/33758643/review/visitor#
# 이번에 찾을 키워드 : 1618 / 3193 행 제주 페리카나성산점
# none
# 이번에 찾을 키워드 : 1619 / 3193 행 제주 해변정식당
# https://pcmap.place.naver.com/restaurant/34850108/review/visitor#
# 이번에 찾을 키워드 : 1620 / 3193 행 제주 서문식당
# none
# 이번에 찾을 키워드 : 1621 / 3193 행 제주 신제가든
# https://pcmap.place.naver.com/restaurant/13444907/review/visitor#
# 이번에 찾을 키워드 : 1622 / 3193 행 제주 고씨네천지국수
# https://pcmap.place.naver.com/restaurant/1794435212/review/visitor#
# 이번에 찾을 키워드 : 1623 / 3193 행 제주 버들집

# %%
# df
df['naver_map_url'].replace('', np.nan, inplace=True)

# %%
df = df.dropna(subset=['naver_map_url'])

# %%
df.to_csv('url_completed.csv', encoding = 'utf-8-sig')

# %%
df

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import time
import re

from bs4 import BeautifulSoup
from tqdm import tqdm

# 웹드라이버 접속
driver = webdriver.Chrome(executable_path='./chromedriver.exe')

df = pd.read_csv('url_completed.csv') #null값 처리 완료 데이터

# 수집할 정보들
rating_list = [] # 평점
user_review_id = {} # 유저의 id - 추천시스템에서는 필수
review_json = {} # 리뷰
image_json = {} # 이미지

# %%
for i in range(len(df)):
    
    print('======================================================')
    print(str(i)+'번째 식당')
    
    # 식당 리뷰 개별 url 접속
    driver.get(df['naver_map_url'][i])
    thisurl = df['naver_map_url'][i]
    time.sleep(2)
    # 더보기 버튼 다 누르기
    # 더보기 버튼 누르기까지 10개
    # 더보기 버튼 누르면 10개 추가됨
    while True:
        try:
            time.sleep(1)
            driver.find_element_by_tag_name('body').send_keys(Keys.END)
            time.sleep(3)
            driver.find_element_by_css_selector('#app-root > div > div.place_detail_wrapper > div:nth-child(5) > div:nth-child(4) > div:nth-child(4) > div._2kAri > a').click()
            time.sleep(3)
            driver.find_element_by_tag_name('body').send_keys(Keys.END)
            time.sleep(1)
            
        except NoSuchElementException:
            print('-더보기 버튼 모두 클릭 완료-')
            break

    
    # 파싱
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    time.sleep(1)
    
    # 식당 구분
    restaurant_name = df['사업장명'][i]
    print('식당 이름 : '+restaurant_name)
    
    user_review_id[restaurant_name] = {}
    review_json[restaurant_name] = {}
    image_json[restaurant_name] = {}
    
    try:
        restaurant_classificaton = soup.find_all('span',attrs = {'class':'_3ocDE'})[0].text
    except:
        restaurant_classificaton = 'none'
    print('식당 구분 : '+restaurant_classificaton)
    print('----------------------------------------------')
    
    try:
        one_review = soup.find_all('div', attrs = {'class':'_1Z_GL'})
        review_num = len(one_review) # 특정 식당의 리뷰 총 개수
        print('리뷰 총 개수 : '+str(review_num))
    
        # 리뷰 개수
        for i in range(len(one_review)):
        
            # user url
            user_url = one_review[i].find('div', attrs = {'class':'_23Rml'}).find('a').get('href')
            print('user_url = '+user_url)
            
            # user url로부터 user code 뽑아내기
            user_code = re.findall(r"my/(\w+)", user_url)[0]
            print('user_code = '+user_code)
            
            # review 1개에 대한 id 만들기 
            res_code = re.findall(r"restaurant/(\d+)", thisurl)[0]
            review_id = str(res_code)+"_"+user_code
            print('review_id = '+review_id)
            
            # rating, 별점
            rating = one_review[i].find('span', attrs = {'class':'_2tObC'}).text
            print('rating = '+rating)
            
            # 주의!!! 사진 리뷰 유무에 따라 날짜 파싱코드 다름
            # ('span', attrs = {'class':'_3WqoL'})
            # 사진 없는 경우 : 총 6개 중 4번째
            # 사진 있는 경우 : 총 5개 중 3번째
            
            # date
            # 사진 리뷰 없음
            if len(one_review[i].find_all('span', attrs = {'class':'_3WqoL'})) == 5:
                date = one_review[i].find_all('span', attrs = {'class':'_3WqoL'})[2].text
            elif len(one_review[i].find_all('span', attrs = {'class':'_3WqoL'})) == 6:
                date = one_review[i].find_all('span', attrs = {'class':'_3WqoL'})[3].text
            else:
                date = ""
            print('date = '+date)
            
            # review 내용
            try : 
                review_content = one_review[i].find('span', attrs = {'class':'WoYOw'}).text
            except: # 리뷰가 없다면
                review_content = ""
            print('리뷰 내용 : '+review_content)
            
            
            # image 내용
            sliced_soup = one_review[i].find('div', attrs = {'class':'_1aFEL _2GO1Q'})

            if (sliced_soup != None):
                sliced_soup = sliced_soup.find('div',attrs={'class':'dRZ2X'})
                
                try:
                    img_url = 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src='+re.findall(r'src=(.*jpeg)', str(sliced_soup))[0]
                except :
                    if (len(re.findall(r'src=(.*jpg)', str(sliced_soup)))!= 0):
                        img_url = 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src='+re.findall(r'src=(.*jpg)', str(sliced_soup))[0]
                    elif (len(re.findall(r'src=(.*png)', str(sliced_soup)))!= 0):
                        img_url = 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src='+re.findall(r'src=(.*png)', str(sliced_soup))[0]
                    else :
                        img_url = ""
            else:
                img_url = ""
                
            print('이미지 url : '+img_url)
            print('----------------------------------------------')
            print('\n')

            
            #리뷰정보
            # user_review_id
            user_review_id[restaurant_name][user_code] = review_id
            
            # review_json
            review_json[restaurant_name][review_id] = review_content
            
            # image_json
            image_json[restaurant_name][review_id] = img_url
            
            # rating_df_list
            naver_review = user_code, restaurant_name, rating, date
            rating_list.append(naver_review)
            
            
    
    
    except NoSuchElementException:
            none_review = "네이버 리뷰 없음"
            print(none_review)
            review_num = 0
            #리뷰정보 = restaurant_name, restaurant_classification, review_num, none_review
            
            # rating_df_list
            naver_review = user_code, restaurant_name, none_review, none_reivew
            rating_list.append(naver_review)
            
            
    print('\n')
# Out:
# ======================================================
# 0번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 카페송키
# 식당 구분 : 브런치
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5cc6e32a328ab3726e6ccf99/review
# user_code = 5cc6e32a328ab3726e6ccf99
# review_id = 1333668157_5cc6e32a328ab3726e6ccf99
# rating = 5
# date = 2021.10.08
# 리뷰 내용 : 친절하시고 내부도 아기자기 너무 이뻐용
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5efe294967c6d4320f574088/review
# user_code = 5efe294967c6d4320f574088
# review_id = 1333668157_5efe294967c6d4320f574088
# rating = 5
# date = 2021.09.21
# 리뷰 내용 : 커피, 디저트도 맛있고 분위기도 너무 좋아요! 귀여운 마스코트 반디가 반겨줘용~ 에그타르트가 너무 맛있어서 서울올때 포장해서 가
# 지고 왔어요.  제주도 갈 때마다 무조건 들리는 카페에요👍🏻
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c820edb479bdeab699408fe/review
# user_code = 5c820edb479bdeab699408fe
# review_id = 1333668157_5c820edb479bdeab699408fe
# rating = 4
# date = 2021.09.18
# 리뷰 내용 : 내부 인테리어가 독특하고 예뻐요.
# 공간이 분리되어 있어서 조용히 얘기하고 싶을 때 좋은 거 같아요.
# 친절하시고 라떼도 맛있었어요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5bec21244df9b74b39095e61/review
# user_code = 5bec21244df9b74b39095e61
# review_id = 1333668157_5bec21244df9b74b39095e61
# rating = 4.5
# date = 2021.08.19
# 리뷰 내용 : 쵝오 입니다^^
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c2e5d36964b7df0b5dace89/review
# user_code = 5c2e5d36964b7df0b5dace89
# review_id = 1333668157_5c2e5d36964b7df0b5dace89
# rating = 5
# date = 2021.07.12
# 리뷰 내용 : 제주올때마다 들리는곳예요.😊 항상 친절한 카페송키  이번에도 힐링하고갑니다 메뉴다 신선하고 맛있어요😍
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5f066b48ace692ef62446a17/review
# user_code = 5f066b48ace692ef62446a17
# review_id = 1333668157_5f066b48ace692ef62446a17
# rating = 5
# date = 2021.07.12
# 리뷰 내용 : 여행 왔다가 우연하게 찾은 카페!!
# 분위기 좋아요!
# 친절하시고…!!!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dd25cdb8f87a842bceee93f/review
# user_code = 5dd25cdb8f87a842bceee93f
# review_id = 1333668157_5dd25cdb8f87a842bceee93f
# rating = 4
# date = 2021.07.05
# 리뷰 내용 :
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210705_277%2F16254610882939BxVE_JPEG%2Fupload_1e7b6d74d70eb35998ddeda8b05d5405.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5cd0fac9f2e2f539839e1c4e/review
# user_code = 5cd0fac9f2e2f539839e1c4e
# review_id = 1333668157_5cd0fac9f2e2f539839e1c4e
# rating = 3.5
# date = 2021.05.16
# 리뷰 내용 : 음료비추, 대형견 귀여움, 비오는날 가기 좋음
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5da97d648f87a842bca35ce9/review
# user_code = 5da97d648f87a842bca35ce9
# review_id = 1333668157_5da97d648f87a842bca35ce9
# rating = 5
# date = 2021.04.23
# 리뷰 내용 : 숨어있는 멋진 공간
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b9b3657be15b70f57bdbdfb/review
# user_code = 5b9b3657be15b70f57bdbdfb
# review_id = 1333668157_5b9b3657be15b70f57bdbdfb
# rating = 5
# date = 2021.03.14
# 리뷰 내용 :
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210314_114%2F1615687794760pyTWa_JPEG%2Fupload_2310fd51e4a3422a2d41508514af901f.jpeg
# ----------------------------------------------
#
#
#
#
# ======================================================
# 1번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 에릭스에스프레소
# 식당 구분 : 카페,디저트
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5bdb53fb730c4f374a52166e/review
# user_code = 5bdb53fb730c4f374a52166e
# review_id = 1728932164_5bdb53fb730c4f374a52166e
# rating = 5
# date = 2021.07.08
# 리뷰 내용 : 제주에서 맛있는 커피를 찾기가 힘들었는데 여기는 정말 만족했어요.
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5be0d5a1ffcd768cda8e5fe3/review
# user_code = 5be0d5a1ffcd768cda8e5fe3
# review_id = 1728932164_5be0d5a1ffcd768cda8e5fe3
# rating = 4
# date = 2021.06.08
# 리뷰 내용 : 좋았어요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210608_47%2F1623151202911I3tO3_JPEG%2Fupload_b2c7f348d5d2b0b52dfae58ef30df199.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b7bfebb96617a8cf4e60465/review
# user_code = 5b7bfebb96617a8cf4e60465
# review_id = 1728932164_5b7bfebb96617a8cf4e60465
# rating = 3
# date = 2021.05.25
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c28dfaaa27981ca61f1a168/review
# user_code = 5c28dfaaa27981ca61f1a168
# review_id = 1728932164_5c28dfaaa27981ca61f1a168
# rating = 3
# date = 2021.05.25
# 리뷰 내용 : 굿굿
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e3902d58f87a842bc80e248/review
# user_code = 5e3902d58f87a842bc80e248
# review_id = 1728932164_5e3902d58f87a842bc80e248
# rating = 5
# date = 2021.05.15
# 리뷰 내용 : 잘 마셨어요ㅎㅎ
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5efddf0b854ca9293112be5e/review
# user_code = 5efddf0b854ca9293112be5e
# review_id = 1728932164_5efddf0b854ca9293112be5e
# rating = 4
# date = 2021.04.17
# 리뷰 내용 : 창가자리좋아용
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c4b02e49d3f282ad1d2c5b8/review
# user_code = 5c4b02e49d3f282ad1d2c5b8
# review_id = 1728932164_5c4b02e49d3f282ad1d2c5b8
# rating = 5
# date = 2021.03.03
# 리뷰 내용 : 시그니처라는 크리미루나라떼 마셨는데 크림이 진짜 고소하고 맛있었어요 친구는 아메리카노 다크로스팅 마셨는데 원래 다크로스팅 안좋아하는데도 많이 안쓰고 좋았대요☺️
# 내부도 아기자기하게 예뻐요! 음료 나올때 색칠놀이 종이를 하나 주시는데 앉아서 슥슥 칠하다 보니 너무 힐링됐어요 잘 쉬다 갑니다
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210303_104%2F1614744930119a7AHC_JPEG%2Fupload_7ce08beb9789f6dd78cdc2d419a2f08f.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5cddb44ccfda590634265365/review
# user_code = 5cddb44ccfda590634265365
# review_id = 1728932164_5cddb44ccfda590634265365
# rating = 5
# date = 2021.02.25
# 리뷰 내용 : 커피 너무 맛있어요^^
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210303_241%2F1614739171247FPhrx_JPEG%2Fupload_d80e4c554b3b0194e58175762661a779.jpg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b65af776089406ce2547a82/review
# user_code = 5b65af776089406ce2547a82
# review_id = 1728932164_5b65af776089406ce2547a82
# rating = 4
# date = 2021.02.20
# 리뷰 내용 : 사장님 친절하세요.
# 커피도 산미있는것도 좋아하는데 맛있었어요
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210220_247%2F1613803904882b0B5S_JPEG%2Fupload_fe1af48bd8a4fdfd48c8e999ab05d2c1.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5e7c560c8f87a842bcd6e127/review
# user_code = 5e7c560c8f87a842bcd6e127
# review_id = 1728932164_5e7c560c8f87a842bcd6e127
# rating = 5
# date = 2021.02.09
# 리뷰 내용 : 대박 커피 맛있어요. 타르트도! 주차는 건너편에!
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210209_138%2F1612846781874g4Or3_JPEG%2Fupload_ce3d5541223fe2344de5ecc53612b765.jpg
# ----------------------------------------------
#
#
#
#
# ======================================================
# 2번째 식당
# -더보기 버튼 모두 클릭 완료-
# 식당 이름 : 일품순두부한림점
# 식당 구분 : 두부요리
# ----------------------------------------------
# 리뷰 총 개수 : 10
# user_url = https://m.place.naver.com/my/5b9a8f278b86b48144c1cc98/review
# user_code = 5b9a8f278b86b48144c1cc98
# review_id = 1284120911_5b9a8f278b86b48144c1cc98
# rating = 5
# date = 2021.09.30
# 리뷰 내용 : 맛있
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/60362d56ebed9b83d5a74172/review
# user_code = 60362d56ebed9b83d5a74172
# review_id = 1284120911_60362d56ebed9b83d5a74172
# rating = 4.5
# date = 2021.09.16
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b8bc9d6b598cef11fbb90cd/review
# user_code = 5b8bc9d6b598cef11fbb90cd
# review_id = 1284120911_5b8bc9d6b598cef11fbb90cd
# rating = 4.5
# date = 2021.08.23
# 리뷰 내용 : 다양한 순두부 요리
# 아침 먹음 달걀 후라이서비스
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5fa0ec57e5e26858e82ac991/review
# user_code = 5fa0ec57e5e26858e82ac991
# review_id = 1284120911_5fa0ec57e5e26858e82ac991
# rating = 3
# date = 2021.08.21
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/60d282d9d04bb53d9531d6e5/review
# user_code = 60d282d9d04bb53d9531d6e5
# review_id = 1284120911_60d282d9d04bb53d9531d6e5
# rating = 5
# date = 2021.07.13
# 리뷰 내용 : 늦은 시간까지 영업하는 곳이라 너무  편해요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5fa0ec57e5e26858e82ac991/review
# user_code = 5fa0ec57e5e26858e82ac991
# review_id = 1284120911_5fa0ec57e5e26858e82ac991
# rating = 5
# date = 2021.06.24
# 리뷰 내용 : 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5c05b4e26b3b70f50787c5fd/review
# user_code = 5c05b4e26b3b70f50787c5fd
# review_id = 1284120911_5c05b4e26b3b70f50787c5fd
# rating = 5
# date = 2021.06.01
# 리뷰 내용 : 일품순두부 가는곳 마다 조금 다른데요 한림에 일품 순두부는 반찬이 집밥 느낌이예요 갈때마다 잘나오는구나 했어요 추천합니다. 아
# 일하시는분 들도 친절 하셨어요!
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b6bcfccbd9bd08764c37e27/review
# user_code = 5b6bcfccbd9bd08764c37e27
# review_id = 1284120911_5b6bcfccbd9bd08764c37e27
# rating = 2.5
# date = 2021.06.01
# 리뷰 내용 : 보통입니다
# 이미지 url : https://search.pstatic.net/common/?autoRotate=true&quality=95&type=l&size=800x800&src=https%3A%2F%2Fmyplace-phinf.pstatic.net%2F20210603_137%2F1622690583719Qo2et_JPEG%2Fupload_3345218e6634bd13fe59275684eee4a8.jpeg
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5dcf066e8f87a842bc138cd6/review
# user_code = 5dcf066e8f87a842bc138cd6
# review_id = 1284120911_5dcf066e8f87a842bc138cd6
# rating = 5
# date = 2021.05.30
# 리뷰 내용 : 친절하시고 맛도 좋아요
# 이미지 url :
# ----------------------------------------------
#
#
# user_url = https://m.place.naver.com/my/5b67d57a90122a28437a6d1c/review
# user_code = 5b67d57a90122a28437a6d1c
# review_id = 1284120911_5b67d57a90122a28437a6d1c
# rating = 5
# date = 2021.05.23
# 리뷰 내용 : 친절 5, 맛 5, 위생 5
# 가성비 너무 좋고, 매장 직원분도 정말 친절하세요!
# 이미지 url :
# ----------------------------------------------

# %%
rating_df = pd.DataFrame(rating_list)
rating_df.columns = ['UserID','ItemID','Rating','Timestamp']
rating_df.to_csv('rating9.csv', encoding='utf-8-sig')

import json

file_path = "./user_review_id.json"
with open(file_path,'w', encoding="UTF-8") as outfile:
    json.dump(user_review_id, outfile, ensure_ascii=False)
    
file_path = "./review.json"
with open(file_path,'w', encoding="UTF-8") as outfile:
    json.dump(review_json, outfile, ensure_ascii=False)

file_path = "./image.json"
with open(file_path,'w', encoding="UTF-8") as outfile:
    json.dump(image_json, outfile, ensure_ascii=False)

# %% [markdown]
# ## 최종 크롤링된 데이터프레임에
# ## 공통 값을 기준으로(열 기준) concat하여 주소 붙이기 !!!
