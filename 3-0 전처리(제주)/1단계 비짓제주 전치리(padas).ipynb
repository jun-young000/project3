# %%
import json
import pandas as pd
import numpy as np
import os

# %%
df1 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Culture.csv',encoding='cp949', index_col=0)
df1
# Out:
#                                    name keyword  \
# Column1
# 0        더럭초등학교(구, 더럭분교)....    문화
# 1        더럭초등학교(구, 더럭분교)....    문화
# 2        더럭초등학교(구, 더럭분교)....    문화
# 3        더럭초등학교(구, 더럭분교)....    문화
# 4        더럭초등학교(구, 더럭분교)....    문화
# ...                                 ...     ...
# 0                   제주향교               문화
# 0          평화통일 불사리탑               문화
# 0        포도갤러리 in 포도호텔......      문화
# 0               프랑스샤르망               문화
# 0               화북비석거리               문화
#
#                                    content                         tags  \
# Column1
# 0        초등학교 동창들과 함께한 가을...   ['#제주컬러어택', '#더럭...
# 1        무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 2        무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 3        알록달록 너무 예쁜 초등학교에...   ['##5월엔제주', '##더...
# 4        #제주도 #더럭분교 #연화못 ...      ['#제주도', '#더럭분교'...
# ...                                   ...                        ...
# 0        #고풍스러운 느낌! #옛느낌이...     ['#고풍스러운', '#옛느낌...
# ...

# %%
df1['keyword'] = '문화'

# %%
df1_col=["name","keyword","content","tags","address"]

# %%
df1=df1[df1_col]

# %%
df1
# Out:
#                                    name keyword  \
# Column1
# 0        더럭초등학교(구, 더럭분교)....    문화
# 1        더럭초등학교(구, 더럭분교)....    문화
# 2        더럭초등학교(구, 더럭분교)....    문화
# 3        더럭초등학교(구, 더럭분교)....    문화
# 4        더럭초등학교(구, 더럭분교)....    문화
# ...                                 ...     ...
# 0                   제주향교               문화
# 0          평화통일 불사리탑               문화
# 0        포도갤러리 in 포도호텔......      문화
# 0               프랑스샤르망               문화
# 0               화북비석거리               문화
#
#                                    content                         tags  \
# Column1
# 0        초등학교 동창들과 함께한 가을...   ['#제주컬러어택', '#더럭...
# 1        무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 2        무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 3        알록달록 너무 예쁜 초등학교에...   ['##5월엔제주', '##더...
# 4        #제주도 #더럭분교 #연화못 ...      ['#제주도', '#더럭분교'...
# ...                                   ...                        ...
# 0        #고풍스러운 느낌! #옛느낌이...     ['#고풍스러운', '#옛느낌...
# ...

# %%
df1.to_csv('Culture.csv')

# %%
df2 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Leisure experience.csv',index_col=0)
df2
# Out:
#               name    keyword                          content  \
# 0     아침미소목장  레저/체험  #여름 #아침미소목장
# 1     아침미소목장  레저/체험  4박 제주 일정 중 가장 기억...
# 2     아침미소목장  레저/체험  #6감만족 #제주여행 #아침미...
# 3     아침미소목장  레저/체험  #아침미소목장 #체험짱 #6감...
# 4     아침미소목장  레저/체험  #6감만족#제주체험#어린이체험...
# ..             ...        ...                              ...
# 2   조랑말체험공원  레저/체험  #신나는 말타기 #성산 조랑말...
# 3   조랑말체험공원  레저/체험  #제주 에서 아이들과 #승마 ...
# 4   조랑말체험공원  레저/체험  결혼 10주년 4번째 시간!\...
# 5   조랑말체험공원  레저/체험  제주도에 가면 말을 타봐야죠\...
# 6   조랑말체험공원  레저/체험  2016 나의 가슴속에 있었던...
#
#                            tags                            address
# 0   ['#여름', '#아침미소목장...  제주특별자치도 제주시 월평동 ...
# 1   ['#여름', '#체험', '...      제주특별자치도 제주시 월평동 ...
# 2   ['#6감만족', '#제주여행...   제주특별자치도 제주시 월평동 ...
# 3   ['#아침미소목장', '#체험...  제주특별자치도 제주시 월평동 ...
# 4   ['#6감만족', '#제주체험...   제주특별자치도 제주시 월평동 ...
# ..                         ...                                ...
# 2   ['#신나는', '#성산']....     제주특별자치도 서귀포시 표선면...
# ...

# %%
df2['keyword'] = '레저/체험'

# %%
df2_col=["name","keyword","content","tags","address"]

# %%
df2=df2[df2_col]

# %%
df2
# Out:
#               name    keyword                          content  \
# 0     아침미소목장  레저/체험  #여름 #아침미소목장
# 1     아침미소목장  레저/체험  4박 제주 일정 중 가장 기억...
# 2     아침미소목장  레저/체험  #6감만족 #제주여행 #아침미...
# 3     아침미소목장  레저/체험  #아침미소목장 #체험짱 #6감...
# 4     아침미소목장  레저/체험  #6감만족#제주체험#어린이체험...
# ..             ...        ...                              ...
# 2   조랑말체험공원  레저/체험  #신나는 말타기 #성산 조랑말...
# 3   조랑말체험공원  레저/체험  #제주 에서 아이들과 #승마 ...
# 4   조랑말체험공원  레저/체험  결혼 10주년 4번째 시간!\...
# 5   조랑말체험공원  레저/체험  제주도에 가면 말을 타봐야죠\...
# 6   조랑말체험공원  레저/체험  2016 나의 가슴속에 있었던...
#
#                            tags                            address
# 0   ['#여름', '#아침미소목장...  제주특별자치도 제주시 월평동 ...
# 1   ['#여름', '#체험', '...      제주특별자치도 제주시 월평동 ...
# 2   ['#6감만족', '#제주여행...   제주특별자치도 제주시 월평동 ...
# 3   ['#아침미소목장', '#체험...  제주특별자치도 제주시 월평동 ...
# 4   ['#6감만족', '#제주체험...   제주특별자치도 제주시 월평동 ...
# ..                         ...                                ...
# 2   ['#신나는', '#성산']....     제주특별자치도 서귀포시 표선면...
# ...

# %%
df2.to_csv('Leisure experience.csv')

# %%
df3 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Nature.csv', encoding='cp949',index_col=0)
df3
# Out:
#                                    name keyword  \
# Column1
# 0        성산일출봉(UNESCO 세계자...       자연
# 1        성산일출봉(UNESCO 세계자...       자연
# 2        성산일출봉(UNESCO 세계자...       자연
# 3        성산일출봉(UNESCO 세계자...       자연
# 4        성산일출봉(UNESCO 세계자...       자연
# ...                              ...        ...
# 0        천아오름(틍낭오름,天娥岳).....    자연
# 0               큰바리메오름               자연
# 0                     통오름               자연
# 0        판포오름 (널개오름, 板浦岳)...    자연
# 0           행원육상양식단지               자연
#
#                                    content                            tags  \
# Column1
# 0        방문전에는 전화 등을 통해 이...    ['#불친절', '#직원교육'...
# 1        유네스코 성산일출봉입니다 세계...  ['#제주도', '#유네스코'...
# 2        경치도 아름답고 자연도 좋고,...    ['##여름', '##걷기',...
# 3        성산일출봉 자체는 좋았는데.....    ['#봄', '#힐링', '#...
# 4        매표소 여직원 너무 불친절 기...    ['##성산 #직원 #교육이든...
# ...                                  ...                       ...
# ...

# %%
df3.rename(columns = {"adress": "address"}, inplace = True)  # 열이름 변경

# %%
df3['keyword'] = '자연'

# %%
df3_col=["name","keyword","content","tags","address"]

# %%
df3=df3[df3_col]

# %%
df3
# Out:
#                                    name keyword  \
# Column1
# 0        성산일출봉(UNESCO 세계자...       자연
# 1        성산일출봉(UNESCO 세계자...       자연
# 2        성산일출봉(UNESCO 세계자...       자연
# 3        성산일출봉(UNESCO 세계자...       자연
# 4        성산일출봉(UNESCO 세계자...       자연
# ...                              ...        ...
# 0        천아오름(틍낭오름,天娥岳).....    자연
# 0               큰바리메오름               자연
# 0                     통오름               자연
# 0        판포오름 (널개오름, 板浦岳)...    자연
# 0           행원육상양식단지               자연
#
#                                    content                            tags  \
# Column1
# 0        방문전에는 전화 등을 통해 이...    ['#불친절', '#직원교육'...
# 1        유네스코 성산일출봉입니다 세계...  ['#제주도', '#유네스코'...
# 2        경치도 아름답고 자연도 좋고,...    ['##여름', '##걷기',...
# 3        성산일출봉 자체는 좋았는데.....    ['#봄', '#힐링', '#...
# 4        매표소 여직원 너무 불친절 기...    ['##성산 #직원 #교육이든...
# ...                                  ...                       ...
# ...

# %%
df3.to_csv('Nature.csv')

# %%
df4 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Theme.csv',encoding='cp949',index_col=0)
df4
# Out:
#                                      name   keyword  \
# Column1
# 0                 카멜리아힐               테마관광
# 1                 카멜리아힐               테마관광
# 2                 카멜리아힐               테마관광
# 3                 카멜리아힐               테마관광
# 4                 카멜리아힐               테마관광
# ...                      ...                    ...
# 0                 지포뮤지엄               테마관광
# 0          피규어뮤지엄 제주               테마관광
# 0        한국야구명예전당(야구박물관)....  테마관광
# 0                   한울랜드               테마관광
# 0               해거름전망대               테마관광
#
#                                   content                         tags  \
# Column1
# 0              기대가 됩니다               ['#여름', '#미식', '...
# 1          친구들과 우정여행               ['#제주컬러어택', '#카멜...
# 2        친구들과 함께한 겨울 데주.....    ['#겨울', '#제주', '...
# 3        태교여행으로 갔던 가을의 제주...  ['#제주가을', '#카멜리아...
# 4        태풍으로 항공편도 변경하고 일...  ['#제주여행', '#카멜리아...
# ...                                   ...                          ...
# ...

# %%
df4['keyword'] = '테마관광'

# %%
df4_col=["name","keyword","content","tags","address"]

# %%
df4=df4[df4_col]

# %%
df4
# Out:
#                                      name   keyword  \
# Column1
# 0                 카멜리아힐               테마관광
# 1                 카멜리아힐               테마관광
# 2                 카멜리아힐               테마관광
# 3                 카멜리아힐               테마관광
# 4                 카멜리아힐               테마관광
# ...                      ...                    ...
# 0                 지포뮤지엄               테마관광
# 0          피규어뮤지엄 제주               테마관광
# 0        한국야구명예전당(야구박물관)....  테마관광
# 0                   한울랜드               테마관광
# 0               해거름전망대               테마관광
#
#                                   content                         tags  \
# Column1
# 0              기대가 됩니다               ['#여름', '#미식', '...
# 1          친구들과 우정여행               ['#제주컬러어택', '#카멜...
# 2        친구들과 함께한 겨울 데주.....    ['#겨울', '#제주', '...
# 3        태교여행으로 갔던 가을의 제주...  ['#제주가을', '#카멜리아...
# 4        태풍으로 항공편도 변경하고 일...  ['#제주여행', '#카멜리아...
# ...                                   ...                          ...
# ...

# %%
df4.to_csv('Theme.csv')

# %%
df5 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Walking.csv',encoding='cp949',index_col=0)
df5
# Out:
#                                   name keyword  \
# Column1
# 0                 사려니숲길              도보
# 1                 사려니숲길              도보
# 2                 사려니숲길              도보
# 3                 사려니숲길              도보
# 4                 사려니숲길              도보
# ...                      ...               ...
# 0        서광리 곶자왈생태탐방로......    도보
# 0            제주올레 12코스              도보
# 0            제주올레 13코스              도보
# 0          제주올레 15-B코스              도보
# 0          제주올레 18-1코스              도보
#
#                                    content                         tags  \
# Column1
# 0        #사려니숲. #붉은오름 4/2...        ['#걷기', '#친구', '...
# 1        작년11월 예술치유 영상 작업...     ['##예술치유', '##칼림...
# 2        여름의 시작과 끝을 함께하는 ...    ['#여름', '#산수국', ...
# 3        몇년만에 함께한 가족여행, 제...    ['#가족여행', '#사랑해요...
# 4        처음만나 제주의 가을 사려니숲...   ['##여행', '##제주행'...
# ...                                  ...                            ...
# ...

# %%
df5['keyword'] = '도보'

# %%
df5_col=["name","keyword","content","tags","address"]

# %%
df5=df5[df5_col]

# %%
df5
# Out:
#                                   name keyword  \
# Column1
# 0                 사려니숲길              도보
# 1                 사려니숲길              도보
# 2                 사려니숲길              도보
# 3                 사려니숲길              도보
# 4                 사려니숲길              도보
# ...                      ...               ...
# 0        서광리 곶자왈생태탐방로......    도보
# 0            제주올레 12코스              도보
# 0            제주올레 13코스              도보
# 0          제주올레 15-B코스              도보
# 0          제주올레 18-1코스              도보
#
#                                    content                         tags  \
# Column1
# 0        #사려니숲. #붉은오름 4/2...        ['#걷기', '#친구', '...
# 1        작년11월 예술치유 영상 작업...     ['##예술치유', '##칼림...
# 2        여름의 시작과 끝을 함께하는 ...    ['#여름', '#산수국', ...
# 3        몇년만에 함께한 가족여행, 제...    ['#가족여행', '#사랑해요...
# 4        처음만나 제주의 가을 사려니숲...   ['##여행', '##제주행'...
# ...                                  ...                            ...
# ...

# %%
df5.to_csv('Walking.csv')

# %%
pd.set_option('display.max_columns', 100)                       # 출력할 열의 최대개수
pd.set_option('display.max_colwidth', 20)                      # 출력할 열의 너비
pd.set_option('display.unicode.east_asian_width', True)

# %%
df6 = pd.concat([df1,df2,df3,df4,df5],ignore_index=True)
print(df6)
# Out:
#                                  name keyword  \
# 0      더럭초등학교(구, 더럭분교)....    문화
# 1      더럭초등학교(구, 더럭분교)....    문화
# 2      더럭초등학교(구, 더럭분교)....    문화
# 3      더럭초등학교(구, 더럭분교)....    문화
# 4      더럭초등학교(구, 더럭분교)....    문화
# ...                               ...     ...
# 14929  서광리 곶자왈생태탐방로......     도보
# 14930      제주올레 12코스               도보
# 14931      제주올레 13코스               도보
# 14932    제주올레 15-B코스               도보
# 14933    제주올레 18-1코스               도보
#
#                                  content                         tags  \
# 0      초등학교 동창들과 함께한 가을...   ['#제주컬러어택', '#더럭...
# 1      무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 2      무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 3      알록달록 너무 예쁜 초등학교에...   ['##5월엔제주', '##더...
# 4      #제주도 #더럭분교 #연화못 ...      ['#제주도', '#더럭분교'...
# ...                              ...                             ...
# 14929  서광리 곶자왈 생태탐방로......                      []
# 14930  제주 올레길 12코스 수월봉 ...                       []
# ...

# %%
df6
# Out:
#                                  name keyword  \
# 0      더럭초등학교(구, 더럭분교)....    문화
# 1      더럭초등학교(구, 더럭분교)....    문화
# 2      더럭초등학교(구, 더럭분교)....    문화
# 3      더럭초등학교(구, 더럭분교)....    문화
# 4      더럭초등학교(구, 더럭분교)....    문화
# ...                               ...     ...
# 14929  서광리 곶자왈생태탐방로......     도보
# 14930      제주올레 12코스               도보
# 14931      제주올레 13코스               도보
# 14932    제주올레 15-B코스               도보
# 14933    제주올레 18-1코스               도보
#
#                                  content                         tags  \
# 0      초등학교 동창들과 함께한 가을...   ['#제주컬러어택', '#더럭...
# 1      무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 2      무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 3      알록달록 너무 예쁜 초등학교에...   ['##5월엔제주', '##더...
# 4      #제주도 #더럭분교 #연화못 ...      ['#제주도', '#더럭분교'...
# ...                              ...                             ...
# 14929  서광리 곶자왈 생태탐방로......                      []
# 14930  제주 올레길 12코스 수월봉 ...                       []
# ...

# %%
pd.DataFrame(df6).to_csv('jeju_Tourism.csv', header = True, index = False, encoding='utf-8-sig')

# %%
jeju = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\3-0 전처리(제주)\\jeju_Tourism.csv',encoding='UTF-8', index_col=0)
jeju
# Out:
#                               keyword                            content  \
# name
# 더럭초등학교(구, 더럭분교)...    문화  초등학교 동창들과 함께한 가을...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  알록달록 너무 예쁜 초등학교에...
# 더럭초등학교(구, 더럭분교)...    문화  #제주도 #더럭분교 #연화못 ...
# ...                               ...                               ...
# 서광리 곶자왈생태탐방로...       도보  서광리 곶자왈 생태탐방로......
# 제주올레 12코스                  도보  제주 올레길 12코스 수월봉 ...
# 제주올레 13코스                  도보  올레길 13코스를 꼬닥꼬닥 걸...
# 제주올레 15-B코스                도보  #올레길 #15-b #담장을 ...
# 제주올레 18-1코스                도보  용듬벙에서 바로보는 나발론절벽...
#
#                                                       tags  \
# name
# 더럭초등학교(구, 더럭분교)...  ['#제주컬러어택', '#더럭...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##5월엔제주', '##더...
# 더럭초등학교(구, 더럭분교)...  ['#제주도', '#더럭분교'...
# ...                                                 ...
# ...

# %%
# jeju['address1'] = jeju.address.str.split(' ').str[2]

#jeju['address'].str.split(" ", expand=True).tail(100)

# %%
#jeju['address'].str.extract('( \w*도 )|( \w*시 )|( \w*동 )|( \w*읍 )')

# %%
#jeju['address1']=jeju['address'].str.extract('( \w*읍 | \w*면| \w*동 )')

jeju['address1']=jeju['address'].str.extract('( \w*읍 | \w*면 )')
#읍련테그

# %%
jeju
# Out:
#                               keyword                            content  \
# name
# 더럭초등학교(구, 더럭분교)...    문화  초등학교 동창들과 함께한 가을...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  알록달록 너무 예쁜 초등학교에...
# 더럭초등학교(구, 더럭분교)...    문화  #제주도 #더럭분교 #연화못 ...
# ...                               ...                               ...
# 서광리 곶자왈생태탐방로...       도보  서광리 곶자왈 생태탐방로......
# 제주올레 12코스                  도보  제주 올레길 12코스 수월봉 ...
# 제주올레 13코스                  도보  올레길 13코스를 꼬닥꼬닥 걸...
# 제주올레 15-B코스                도보  #올레길 #15-b #담장을 ...
# 제주올레 18-1코스                도보  용듬벙에서 바로보는 나발론절벽...
#
#                                                       tags  \
# name
# 더럭초등학교(구, 더럭분교)...  ['#제주컬러어택', '#더럭...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##5월엔제주', '##더...
# 더럭초등학교(구, 더럭분교)...  ['#제주도', '#더럭분교'...
# ...                                                 ...
# ...

# %%
jeju_dop_row = jeju.dropna(subset=["address1"])  # 읍면테그 안달린 행 삭제

# %%
jeju_dop_row
# Out:
#                               keyword                            content  \
# name
# 더럭초등학교(구, 더럭분교)...    문화  초등학교 동창들과 함께한 가을...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  알록달록 너무 예쁜 초등학교에...
# 더럭초등학교(구, 더럭분교)...    문화  #제주도 #더럭분교 #연화못 ...
# ...                               ...                               ...
# 서광리 곶자왈생태탐방로...       도보  서광리 곶자왈 생태탐방로......
# 제주올레 12코스                  도보  제주 올레길 12코스 수월봉 ...
# 제주올레 13코스                  도보  올레길 13코스를 꼬닥꼬닥 걸...
# 제주올레 15-B코스                도보  #올레길 #15-b #담장을 ...
# 제주올레 18-1코스                도보  용듬벙에서 바로보는 나발론절벽...
#
#                                                       tags  \
# name
# 더럭초등학교(구, 더럭분교)...  ['#제주컬러어택', '#더럭...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##5월엔제주', '##더...
# 더럭초등학교(구, 더럭분교)...  ['#제주도', '#더럭분교'...
# ...                                                 ...
# ...

# %%
jejunull=jeju[jeju['address1'].isnull()] # null값 있는 행만 가져오기

# %%
jejunull
# Out:
#                    keyword                             content  \
# name
# 관덕정                문화  별은 다섯개 주고 싶지만 누워...
# 관덕정                문화  제주의 척박한 삶.. 거친음식...
# 관덕정                문화  #제주43 #제주43사건 #관...
# 관덕정                문화  1448년이래로 지금까지 제주...
# 관덕정                문화  #관덕정 제주목관아 수문장교대...
# ...                    ...                            ...
# 숫모르편백나무숲길    도보  제주생태공원에서 절물자연휴양림...
# 숫모르편백나무숲길    도보         #숫모르숲길,
# 올레여행자센터        도보                  NaN
# 올레여행자센터        도보                  NaN
# 삼의악트레킹코스      도보  #산과오름 #삼의악오름......
#
#                                             tags  \
# name
# 관덕정              ['#관덕정', '#관리자',...
# 관덕정              ['#제주4', '#하멜표류기...
# 관덕정              ['#제주43', '#제주43...
# 관덕정                               []
# 관덕정                      ['#관덕정']
# ...                                 ...
# 숫모르편백나무숲길  ['#숫모르편백나무숲길', '...
# 숫모르편백나무숲길      ['#숫모르숲길']
# 올레여행자센터                       []
# 올레여행자센터                       []
# ...

# %%
jejunull['address1'].isnull().sum()
# Out:
# 3649

# %%
jejunull['address1'] = jejunull.address.str.split(' ').str[1]
# Out:
# C:\Users\ui\AppData\Local\Temp/ipykernel_1968/568662585.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jejunull['address1'] = jejunull.address.str.split(' ').str[1]

# %%
jejunull
# Out:
#                    keyword                             content  \
# name
# 관덕정                문화  별은 다섯개 주고 싶지만 누워...
# 관덕정                문화  제주의 척박한 삶.. 거친음식...
# 관덕정                문화  #제주43 #제주43사건 #관...
# 관덕정                문화  1448년이래로 지금까지 제주...
# 관덕정                문화  #관덕정 제주목관아 수문장교대...
# ...                    ...                            ...
# 숫모르편백나무숲길    도보  제주생태공원에서 절물자연휴양림...
# 숫모르편백나무숲길    도보         #숫모르숲길,
# 올레여행자센터        도보                  NaN
# 올레여행자센터        도보                  NaN
# 삼의악트레킹코스      도보  #산과오름 #삼의악오름......
#
#                                             tags  \
# name
# 관덕정              ['#관덕정', '#관리자',...
# 관덕정              ['#제주4', '#하멜표류기...
# 관덕정              ['#제주43', '#제주43...
# 관덕정                               []
# 관덕정                      ['#관덕정']
# ...                                 ...
# 숫모르편백나무숲길  ['#숫모르편백나무숲길', '...
# 숫모르편백나무숲길      ['#숫모르숲길']
# 올레여행자센터                       []
# 올레여행자센터                       []
# ...

# %%
# jeju와 jejunull을 합치기

# %%
jeju_teg=pd.concat([jeju_dop_row,jejunull])

# %%
jeju_teg
# Out:
#                               keyword                             content  \
# name
# 더럭초등학교(구, 더럭분교)...    문화  초등학교 동창들과 함께한 가을...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  알록달록 너무 예쁜 초등학교에...
# 더럭초등학교(구, 더럭분교)...    문화  #제주도 #더럭분교 #연화못 ...
# ...                               ...                               ...
# 숫모르편백나무숲길               도보  제주생태공원에서 절물자연휴양림...
# 숫모르편백나무숲길               도보         #숫모르숲길,
# 올레여행자센터                   도보                  NaN
# 올레여행자센터                   도보                  NaN
# 삼의악트레킹코스                 도보  #산과오름 #삼의악오름......
#
#                                                        tags  \
# name
# 더럭초등학교(구, 더럭분교)...  ['#제주컬러어택', '#더럭...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##5월엔제주', '##더...
# 더럭초등학교(구, 더럭분교)...  ['#제주도', '#더럭분교'...
# ...                                                 ...
# ...

# %%
jeju_teg=jeju_teg.reset_index()

# %%
jeju_teg
# Out:
#                                  name keyword  \
# 0      더럭초등학교(구, 더럭분교)....    문화
# 1      더럭초등학교(구, 더럭분교)....    문화
# 2      더럭초등학교(구, 더럭분교)....    문화
# 3      더럭초등학교(구, 더럭분교)....    문화
# 4      더럭초등학교(구, 더럭분교)....    문화
# ...                               ...     ...
# 14929   숫모르편백나무숲길               도보
# 14930   숫모르편백나무숲길               도보
# 14931       올레여행자센터               도보
# 14932       올레여행자센터               도보
# 14933     삼의악트레킹코스               도보
#
#                                   content                          tags  \
# 0      초등학교 동창들과 함께한 가을...    ['#제주컬러어택', '#더럭...
# 1      무지개빛 아름다운 더럭초등학교...   ['##더럭초등학교', '##...
# 2      무지개빛 아름다운 더럭초등학교...   ['##더럭초등학교', '##...
# 3      알록달록 너무 예쁜 초등학교에...    ['##5월엔제주', '##더...
# 4      #제주도 #더럭분교 #연화못 ...       ['#제주도', '#더럭분교'...
# ...                              ...                              ...
# 14929  제주생태공원에서 절물자연휴양림...  ['#숫모르편백나무숲길', '...
# 14930         #숫모르숲길,                     ['#숫모르숲길']
# ...

# %%
pd.DataFrame(jeju_teg).to_csv('jeju_Tourism1.csv', header = True, encoding='utf-8-sig')

# %%
data = pd.read_csv('./jeju_Tourism1.csv')

# %%
data.dropna(inplace=True) # 리뷰 없는값 제거

# %%
data
# Out:
#                                  name keyword  \
# 0      더럭초등학교(구, 더럭분교)....    문화
# 1      더럭초등학교(구, 더럭분교)....    문화
# 2      더럭초등학교(구, 더럭분교)....    문화
# 3      더럭초등학교(구, 더럭분교)....    문화
# 4      더럭초등학교(구, 더럭분교)....    문화
# ...                               ...     ...
# 14926  누웨마루거리(구 바오젠)......     도보
# 14928  누웨마루거리(구 바오젠)......     도보
# 14929   숫모르편백나무숲길               도보
# 14930   숫모르편백나무숲길               도보
# 14933     삼의악트레킹코스               도보
#
#                                   content                          tags  \
# 0      초등학교 동창들과 함께한 가을...    ['#제주컬러어택', '#더럭...
# 1      무지개빛 아름다운 더럭초등학교...   ['##더럭초등학교', '##...
# 2      무지개빛 아름다운 더럭초등학교...   ['##더럭초등학교', '##...
# 3      알록달록 너무 예쁜 초등학교에...    ['##5월엔제주', '##더...
# 4      #제주도 #더럭분교 #연화못 ...       ['#제주도', '#더럭분교'...
# ...                              ...                              ...
# 14926  #바오젠거리 #신라스테이제주 ...     ['#바오젠거리', '#신라스...
# 14928  중국인들이 많이 찾는다는 제주...                     []
# ...

# %%
# 리뷰 합쳐보기

# %%
data.rename(columns = {'﻿name' : 'name'}, inplace = True)

# %%
data
# Out:
#                                  name keyword  \
# 0      더럭초등학교(구, 더럭분교)....    문화
# 1      더럭초등학교(구, 더럭분교)....    문화
# 2      더럭초등학교(구, 더럭분교)....    문화
# 3      더럭초등학교(구, 더럭분교)....    문화
# 4      더럭초등학교(구, 더럭분교)....    문화
# ...                               ...     ...
# 14926  누웨마루거리(구 바오젠)......     도보
# 14928  누웨마루거리(구 바오젠)......     도보
# 14929   숫모르편백나무숲길               도보
# 14930   숫모르편백나무숲길               도보
# 14933     삼의악트레킹코스               도보
#
#                                   content                          tags  \
# 0      초등학교 동창들과 함께한 가을...    ['#제주컬러어택', '#더럭...
# 1      무지개빛 아름다운 더럭초등학교...   ['##더럭초등학교', '##...
# 2      무지개빛 아름다운 더럭초등학교...   ['##더럭초등학교', '##...
# 3      알록달록 너무 예쁜 초등학교에...    ['##5월엔제주', '##더...
# 4      #제주도 #더럭분교 #연화못 ...       ['#제주도', '#더럭분교'...
# ...                              ...                              ...
# 14926  #바오젠거리 #신라스테이제주 ...     ['#바오젠거리', '#신라스...
# 14928  중국인들이 많이 찾는다는 제주...                     []
# ...

# %%
sum_data=pd.DataFrame(data.groupby(['name','keyword','address1'])['content'].sum())

# %%
sum_data
# Out:
#                                                                   content
# name                keyword   address1
# 1100고지(휴게소)    자연      서귀포시  겨울에 가장 아름다운 곳#제주...
# 1100고지습지        자연      서귀포시  친구와함께방금전지나왔습니다. ...
# 5.16도로숲터널      자연       남원읍   #가을가을한제주#5.16도로숲...
# 9.81 파크           테마관광   애월읍   강추!! 981어플설치하니까 ...
# 가뫼물              레저/체험  남원읍   #6월 #감귤대신블루베리 #감...
# ...                                                              ...
# 환상숲 곶자왈공원   도보       한경면   식물들이 직접 자생하며 만든 ...
#                     자연       한경면   식물들이 직접 자생하며 만든 ...
# 황우지해안          자연      서귀포시  엄마와 올해 초에 여행 갔을 ...
# 황우지해안 열두굴   자연      서귀포시  #황우지해안#바다수영#자연수영...
# 휴애리 자연생활공원 테마관광   남원읍   응 동물학대휴애리 핑크뮬리 넘...
#
# [499 rows x 1 columns]

# %%
data['content']=[x.replace('\r',' ') for x in data['content']]

# %%
#data["content"]= data["content"].replace(r'\\n',' ', regex=True)
#data["name"]= data["name"].replace(r'\\n',' ', regex=True)
#data["tags"]= data["tags"].replace(r'\\n',' ', regex=True)
#data["address"]= data["address"].replace(r'\\n',' ', regex=True)
#효과없음.안됨

# %%
data=data.reset_index(drop=True)

# %%
data
# Out:
#                                  name keyword  \
# 0      더럭초등학교(구, 더럭분교)....    문화
# 1      더럭초등학교(구, 더럭분교)....    문화
# 2      더럭초등학교(구, 더럭분교)....    문화
# 3      더럭초등학교(구, 더럭분교)....    문화
# 4      더럭초등학교(구, 더럭분교)....    문화
# ...                               ...     ...
# 13064  누웨마루거리(구 바오젠)......     도보
# 13065  누웨마루거리(구 바오젠)......     도보
# 13066   숫모르편백나무숲길               도보
# 13067   숫모르편백나무숲길               도보
# 13068     삼의악트레킹코스               도보
#
#                                   content                          tags  \
# 0      초등학교 동창들과 함께한 가을...    ['#제주컬러어택', '#더럭...
# 1      무지개빛 아름다운 더럭초등학교...   ['##더럭초등학교', '##...
# 2      무지개빛 아름다운 더럭초등학교...   ['##더럭초등학교', '##...
# 3      알록달록 너무 예쁜 초등학교에...    ['##5월엔제주', '##더...
# 4      #제주도 #더럭분교 #연화못 ...       ['#제주도', '#더럭분교'...
# ...                              ...                              ...
# 13064  #바오젠거리 #신라스테이제주 ...     ['#바오젠거리', '#신라스...
# 13065  중국인들이 많이 찾는다는 제주...                     []
# ...

# %%
data.to_csv('d.csv')

# %%
# 자연어 분석을 위한 전처리
# 주소를 가지고 위경도를 구한후>하나의 df로 만든다.
