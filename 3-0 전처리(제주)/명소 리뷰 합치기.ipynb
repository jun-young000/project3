# %%
import pandas as pd

# %%
data = pd.read_csv('./jeju_Tourism1.csv')
data.dropna(inplace=True) # 리뷰 없는값 제거
#data.dropna(inplace=False)

# %%
data
# Out:
#        Unnamed: 0             name keyword  \
# 0               0  더럭초등학교(구, 더럭분교)      문화
# 1               1  더럭초등학교(구, 더럭분교)      문화
# 2               2  더럭초등학교(구, 더럭분교)      문화
# 3               3  더럭초등학교(구, 더럭분교)      문화
# 4               4  더럭초등학교(구, 더럭분교)      문화
# ...           ...              ...     ...
# 14926       14926    누웨마루거리(구 바오젠)      도보
# 14928       14928    누웨마루거리(구 바오젠)      도보
# 14929       14929        숫모르편백나무숲길      도보
# 14930       14930        숫모르편백나무숲길      도보
# 14933       14933         삼의악트레킹코스      도보
#
#                                                  content  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                       무지개빛 아름다운 더럭초등학교
# 2                                       무지개빛 아름다운 더럭초등학교
# 3              알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4      #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                                                  ...
# ...

# %%
data=data.drop(['Unnamed: 0'],axis=1)

# %%
data
# Out:
#                   name keyword  \
# 0      더럭초등학교(구, 더럭분교)      문화
# 1      더럭초등학교(구, 더럭분교)      문화
# 2      더럭초등학교(구, 더럭분교)      문화
# 3      더럭초등학교(구, 더럭분교)      문화
# 4      더럭초등학교(구, 더럭분교)      문화
# ...                ...     ...
# 14926    누웨마루거리(구 바오젠)      도보
# 14928    누웨마루거리(구 바오젠)      도보
# 14929        숫모르편백나무숲길      도보
# 14930        숫모르편백나무숲길      도보
# 14933         삼의악트레킹코스      도보
#
#                                                  content  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                       무지개빛 아름다운 더럭초등학교
# 2                                       무지개빛 아름다운 더럭초등학교
# 3              알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4      #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                                                  ...
# 14926                              #바오젠거리 #신라스테이제주 #돌하루방
# 14928                        중국인들이 많이 찾는다는 제주시 연동 바오젠거리.
# 14929  제주생태공원에서 절물자연휴양림으로 이어지는 걷기 좋은 길이다.\r\n#숫모르편백나무...
# ...

# %%
# 리뷰 합쳐보기

# %%
data.rename(columns = {'﻿name' : 'name'}, inplace = True)

# %%
sum_data=pd.DataFrame(data.groupby(['name','keyword','address1'])['content'].sum())

# %%
sum_data
# Out:
#                                                                         content
# name        keyword address1
# 1100고지(휴게소) 자연      서귀포시      겨울에 가장 아름다운 곳#제주여행공유#제주가을#1100고지#비짓제주#한라산#눈이오면...
# 1100고지습지    자연      서귀포시      친구와함께방금전지나왔습니다. 눈꽃과절경이 눈부셨습니다. 하지만택시업을하시는분때문에 ...
# 5.16도로숲터널   자연       남원읍      #가을가을한제주#5.16도로숲터널개인적으로 봄 계절, 제주시->서귀포로 넘어가는 방...
# 9.81 파크     테마관광     애월읍      강추!! 981어플설치하니까 누가 잘탔는지 내기도 하고 레이싱한 영상도 다운받을 수...
# 가뫼물         레저/체험    남원읍      #6월 #감귤대신블루베리 #감귤밭 #모노레일 #감귤비누만들기 #동물먹이주기 #알찬체...
# ...                                                                         ...
# 환상숲 곶자왈공원   도보       한경면      식물들이 직접 자생하며 만든 곳. 선생님의 설명을 통해 곶자왈의 깊이가 더욱 깊어졌...
#             자연       한경면      식물들이 직접 자생하며 만든 곳. 선생님의 설명을 통해 곶자왈의 깊이가 더욱 깊어졌...
# 황우지해안       자연      서귀포시      엄마와 올해 초에 여행 갔을 때 찍었는데요 제주도에 방문 하면서 처음 가보았는데 제...
# 황우지해안 열두굴   자연      서귀포시      #황우지해안#바다수영#자연수영장#제주 가을, #황우지해안 열두굴제주도 스노쿨링 명소...
# ...

# %%
# 리뷰 엔터 삭제>>>조심해서 하자

# %%
data['content']=[x.replace('\n',' ') for x in data['content']]

# %%
data['content']=[x.replace('\r',' ') for x in data['content']]

# %%
data=data.reset_index(drop=True)

# %%
data
# Out:
#                   name keyword  \
# 0      더럭초등학교(구, 더럭분교)      문화
# 1      더럭초등학교(구, 더럭분교)      문화
# 2      더럭초등학교(구, 더럭분교)      문화
# 3      더럭초등학교(구, 더럭분교)      문화
# 4      더럭초등학교(구, 더럭분교)      문화
# ...                ...     ...
# 13063    누웨마루거리(구 바오젠)      도보
# 13064    누웨마루거리(구 바오젠)      도보
# 13065        숫모르편백나무숲길      도보
# 13066        숫모르편백나무숲길      도보
# 13067         삼의악트레킹코스      도보
#
#                                                  content  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                       무지개빛 아름다운 더럭초등학교
# 2                                       무지개빛 아름다운 더럭초등학교
# 3              알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4      #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                                                  ...
# 13063                              #바오젠거리 #신라스테이제주 #돌하루방
# 13064                        중국인들이 많이 찾는다는 제주시 연동 바오젠거리.
# 13065  제주생태공원에서 절물자연휴양림으로 이어지는 걷기 좋은 길이다.  #숫모르편백나무숲길...
# ...

# %%
data.to_csv('d.csv')

# %%
#data["content"]= data["content"].replace(r'\\n',' ', regex=True)
#data["name"]= data["name"].replace(r'\\n',' ', regex=True)
#data["tags"]= data["tags"].replace(r'\\n',' ', regex=True)
#data["address"]= data["address"].replace(r'\\n',' ', regex=True)
#효과없음.안됨

# %%
#data

# %%
#data.to_csv('d1.csv')
