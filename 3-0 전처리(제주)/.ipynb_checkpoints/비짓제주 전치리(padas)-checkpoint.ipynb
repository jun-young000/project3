# %%
import json
import pandas as pd
import numpy as np
import os

# %%
df1 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Culture.csv',encoding='cp949', index_col=0)
df1
# Out:
#                               name                            content  \
# 0   더럭초등학교(구, 더럭분교)....  초등학교 동창들과 함께한 가을...
# 1   더럭초등학교(구, 더럭분교)....  무지개빛 아름다운 더럭초등학교...
# 2   더럭초등학교(구, 더럭분교)....  무지개빛 아름다운 더럭초등학교...
# 3   더럭초등학교(구, 더럭분교)....  알록달록 너무 예쁜 초등학교에...
# 4   더럭초등학교(구, 더럭분교)....  #제주도 #더럭분교 #연화못 ...
# ..                             ...                            ...
# 0              제주향교             #고풍스러운 느낌! #옛느낌이...
# 0     평화통일 불사리탑             용두암에서 월정리까지 자전거 ...
# 0   포도갤러리 in 포도호텔......    우동으로 유명한 포도호텔에서 ...
# 0          프랑스샤르망             프랑스샤르망/ 제주프랑스문화원...
# 0          화북비석거리               화북쪽 벚꽃거리!!
#
#                            tags                            address
# 0   ['#제주컬러어택', '#더럭...  제주특별자치도 제주시 애월읍 ...
# 1   ['##더럭초등학교', '##...    제주특별자치도 제주시 애월읍 ...
# 2   ['##더럭초등학교', '##...    제주특별자치도 제주시 애월읍 ...
# 3   ['##5월엔제주', '##더...     제주특별자치도 제주시 애월읍 ...
# 4   ['#제주도', '#더럭분교'...   제주특별자치도 제주시 애월읍 ...
# ..                         ...                                ...
# 0   ['#고풍스러운', '#옛느낌...  제주특별자치도 제주시 서문로 ...
# 0   ['#봄', '#레포츠', '...      제주특별자치도 제주시 조천읍 ...
# 0                    []          제주특별자치도 서귀포시 안덕면...
# 0                    []          제주시 한림읍 명상로 37.....
# 0                    []          제주특별자치도 제주시 일주동로...
#
# [964 rows x 4 columns]

# %%
df1['keyword'] = '문화'

# %%
df1_col=["name","keyword","content","tags","address"]

# %%
df1=df1[df1_col]

# %%
df1
# Out:
#                               name keyword                            content  \
# 0   더럭초등학교(구, 더럭분교)....    문화  초등학교 동창들과 함께한 가을...
# 1   더럭초등학교(구, 더럭분교)....    문화  무지개빛 아름다운 더럭초등학교...
# 2   더럭초등학교(구, 더럭분교)....    문화  무지개빛 아름다운 더럭초등학교...
# 3   더럭초등학교(구, 더럭분교)....    문화  알록달록 너무 예쁜 초등학교에...
# 4   더럭초등학교(구, 더럭분교)....    문화  #제주도 #더럭분교 #연화못 ...
# ..                             ...     ...                            ...
# 0              제주향교               문화  #고풍스러운 느낌! #옛느낌이...
# 0     평화통일 불사리탑               문화  용두암에서 월정리까지 자전거 ...
# 0   포도갤러리 in 포도호텔......      문화  우동으로 유명한 포도호텔에서 ...
# 0          프랑스샤르망               문화  프랑스샤르망/ 제주프랑스문화원...
# 0          화북비석거리               문화    화북쪽 벚꽃거리!!
#
#                            tags                            address
# 0   ['#제주컬러어택', '#더럭...  제주특별자치도 제주시 애월읍 ...
# 1   ['##더럭초등학교', '##...    제주특별자치도 제주시 애월읍 ...
# 2   ['##더럭초등학교', '##...    제주특별자치도 제주시 애월읍 ...
# 3   ['##5월엔제주', '##더...     제주특별자치도 제주시 애월읍 ...
# 4   ['#제주도', '#더럭분교'...   제주특별자치도 제주시 애월읍 ...
# ..                         ...                                ...
# 0   ['#고풍스러운', '#옛느낌...  제주특별자치도 제주시 서문로 ...
# 0   ['#봄', '#레포츠', '...      제주특별자치도 제주시 조천읍 ...
# 0                    []          제주특별자치도 서귀포시 안덕면...
# 0                    []          제주시 한림읍 명상로 37.....
# 0                    []          제주특별자치도 제주시 일주동로...
#
# [964 rows x 5 columns]

# %%
df1.to_csv('Culture.csv')

# %%
df2 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Leisure experience.csv',index_col=0)
df2
# Out:
#               name                          content  \
# 0     아침미소목장  #여름 #아침미소목장
# 1     아침미소목장  4박 제주 일정 중 가장 기억...
# 2     아침미소목장  #6감만족 #제주여행 #아침미...
# 3     아침미소목장  #아침미소목장 #체험짱 #6감...
# 4     아침미소목장  #6감만족#제주체험#어린이체험...
# ..             ...                              ...
# 2   조랑말체험공원  #신나는 말타기 #성산 조랑말...
# 3   조랑말체험공원  #제주 에서 아이들과 #승마 ...
# 4   조랑말체험공원  결혼 10주년 4번째 시간!\...
# 5   조랑말체험공원  제주도에 가면 말을 타봐야죠\...
# 6   조랑말체험공원  2016 나의 가슴속에 있었던...
#
#                            tags                            address
# 0   ['#여름', '#아침미소목장...  제주특별자치도 제주시 월평동 ...
# 1   ['#여름', '#체험', '...      제주특별자치도 제주시 월평동 ...
# 2   ['#6감만족', '#제주여행...   제주특별자치도 제주시 월평동 ...
# 3   ['#아침미소목장', '#체험...  제주특별자치도 제주시 월평동 ...
# 4   ['#6감만족', '#제주체험...   제주특별자치도 제주시 월평동 ...
# ..                         ...                                ...
# 2   ['#신나는', '#성산']....     제주특별자치도 서귀포시 표선면...
# 3    ['#제주', '#승마']          제주특별자치도 서귀포시 표선면...
# 4                    []          제주특별자치도 서귀포시 표선면...
# 5                    []          제주특별자치도 서귀포시 표선면...
# 6                    []          제주특별자치도 서귀포시 표선면...
#
# [273 rows x 4 columns]

# %%
df2['keyword'] = '레저/체험'

# %%
df2_col=["name","keyword","content","tags","address"]

# %%
df2=df2[df2_col]

# %%
df2
# Out:
#               name    keyword                          content  \
# 0     아침미소목장  레저/체험  #여름 #아침미소목장
# 1     아침미소목장  레저/체험  4박 제주 일정 중 가장 기억...
# 2     아침미소목장  레저/체험  #6감만족 #제주여행 #아침미...
# 3     아침미소목장  레저/체험  #아침미소목장 #체험짱 #6감...
# 4     아침미소목장  레저/체험  #6감만족#제주체험#어린이체험...
# ..             ...        ...                              ...
# 2   조랑말체험공원  레저/체험  #신나는 말타기 #성산 조랑말...
# 3   조랑말체험공원  레저/체험  #제주 에서 아이들과 #승마 ...
# 4   조랑말체험공원  레저/체험  결혼 10주년 4번째 시간!\...
# 5   조랑말체험공원  레저/체험  제주도에 가면 말을 타봐야죠\...
# 6   조랑말체험공원  레저/체험  2016 나의 가슴속에 있었던...
#
#                            tags                            address
# 0   ['#여름', '#아침미소목장...  제주특별자치도 제주시 월평동 ...
# 1   ['#여름', '#체험', '...      제주특별자치도 제주시 월평동 ...
# 2   ['#6감만족', '#제주여행...   제주특별자치도 제주시 월평동 ...
# 3   ['#아침미소목장', '#체험...  제주특별자치도 제주시 월평동 ...
# 4   ['#6감만족', '#제주체험...   제주특별자치도 제주시 월평동 ...
# ..                         ...                                ...
# 2   ['#신나는', '#성산']....     제주특별자치도 서귀포시 표선면...
# 3    ['#제주', '#승마']          제주특별자치도 서귀포시 표선면...
# 4                    []          제주특별자치도 서귀포시 표선면...
# 5                    []          제주특별자치도 서귀포시 표선면...
# 6                    []          제주특별자치도 서귀포시 표선면...
#
# [273 rows x 5 columns]

# %%
df2.to_csv('Leisure experience.csv')

# %%
df3 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Nature.csv', encoding='cp949',index_col=0)
df3
# Out:
#                               name                            content  \
# 0   성산일출봉(UNESCO 세계자...     방문전에는 전화 등을 통해 이...
# 1   성산일출봉(UNESCO 세계자...     유네스코 성산일출봉입니다 세계...
# 2   성산일출봉(UNESCO 세계자...     경치도 아름답고 자연도 좋고,...
# 3   성산일출봉(UNESCO 세계자...     성산일출봉 자체는 좋았는데.....
# 4   성산일출봉(UNESCO 세계자...     매표소 여직원 너무 불친절 기...
# ..                          ...                                 ...
# 0   천아오름(틍낭오름,天娥岳).....                  NaN
# 0          큰바리메오름             #산과오름#바리메오름......
# 0                통오름             #제주풍경 #통오름 #짧은오름...
# 0   판포오름 (널개오름, 板浦岳)...     판포에서 본 노을
# 0      행원육상양식단지             35년 공직생활 무사히 정년퇴...
#
#                               tags                             adress
# 0   ['#불친절', '#직원교육'...      제주특별자치도 서귀포시 성산읍...
# 1   ['#제주도', '#유네스코'...      제주특별자치도 서귀포시 성산읍...
# 2   ['##여름', '##걷기',...         제주특별자치도 서귀포시 성산읍...
# 3   ['#봄', '#힐링', '#...          제주특별자치도 서귀포시 성산읍...
# 4   ['##성산 #직원 #교육이든...     제주특별자치도 서귀포시 성산읍...
# ..                          ...                                   ...
# 0                    []             제주특별자치도 제주시 애월읍 ...
# 0   ['#산과오름', '#바리메오...     제주특별자치도 제주시 애월읍 ...
# 0   ['#제주풍경', '#통오름'...      제주특별자치도 서귀포시 성산읍...
# 0                    []             제주특별자치도 제주시 한경면 ...
# 0   ['#행원풍력발전단지바닷가',...  제주특별자치도 제주시 구좌읍 ...
#
# [9784 rows x 4 columns]

# %%
df3.rename(columns = {"adress": "address"}, inplace = True)  # 열이름 변경

# %%
df3['keyword'] = '자연'

# %%
df3_col=["name","keyword","content","tags","address"]

# %%
df3=df3[df3_col]

# %%
df3
# Out:
#                               name keyword                            content  \
# 0   성산일출봉(UNESCO 세계자...       자연  방문전에는 전화 등을 통해 이...
# 1   성산일출봉(UNESCO 세계자...       자연  유네스코 성산일출봉입니다 세계...
# 2   성산일출봉(UNESCO 세계자...       자연  경치도 아름답고 자연도 좋고,...
# 3   성산일출봉(UNESCO 세계자...       자연  성산일출봉 자체는 좋았는데.....
# 4   성산일출봉(UNESCO 세계자...       자연  매표소 여직원 너무 불친절 기...
# ..                          ...        ...                              ...
# 0   천아오름(틍낭오름,天娥岳).....    자연                  NaN
# 0          큰바리메오름               자연  #산과오름#바리메오름......
# 0                통오름               자연  #제주풍경 #통오름 #짧은오름...
# 0   판포오름 (널개오름, 板浦岳)...    자연     판포에서 본 노을
# 0      행원육상양식단지               자연  35년 공직생활 무사히 정년퇴...
#
#                               tags                            address
# 0   ['#불친절', '#직원교육'...      제주특별자치도 서귀포시 성산읍...
# 1   ['#제주도', '#유네스코'...      제주특별자치도 서귀포시 성산읍...
# 2   ['##여름', '##걷기',...         제주특별자치도 서귀포시 성산읍...
# 3   ['#봄', '#힐링', '#...          제주특별자치도 서귀포시 성산읍...
# 4   ['##성산 #직원 #교육이든...     제주특별자치도 서귀포시 성산읍...
# ..                          ...                                   ...
# 0                    []             제주특별자치도 제주시 애월읍 ...
# 0   ['#산과오름', '#바리메오...     제주특별자치도 제주시 애월읍 ...
# 0   ['#제주풍경', '#통오름'...      제주특별자치도 서귀포시 성산읍...
# 0                    []             제주특별자치도 제주시 한경면 ...
# 0   ['#행원풍력발전단지바닷가',...  제주특별자치도 제주시 구좌읍 ...
#
# [9784 rows x 5 columns]

# %%
df3.to_csv('Nature.csv')

# %%
df4 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Theme.csv',index_col=0)
df4
# Out:
#                                 name                           content  \
# 0            카멜리아힐                     기대가 됩니다
# 1            카멜리아힐                 친구들과 우정여행
# 2            카멜리아힐               친구들과 함께한 겨울 데주.....
# 3            카멜리아힐               태교여행으로 갔던 가을의 제주...
# 4            카멜리아힐               태풍으로 항공편도 변경하고 일...
# ..                  ...                                            ...
# 0            지포뮤지엄               태양의 정기를 정면으로 받을 ...
# 0     피규어뮤지엄 제주               제주마지막날 안개와 해무가 자...
# 0   한국야구명예전당(야구박물관)....  야구가 같은 팀이 매어준 커플...
# 0              한울랜드               아이와의 체험은 항상 좋은 기...
# 0          해거름전망대                 나홀로 자전거여행
#
#                            tags                            address
# 0   ['#여름', '#미식', '...      제주 서귀포시 안덕면 병악로 ...
# 1   ['#제주컬러어택', '#카멜...  제주 서귀포시 안덕면 병악로 ...
# 2   ['#겨울', '#제주', '...      제주 서귀포시 안덕면 병악로 ...
# 3   ['#제주가을', '#카멜리아...  제주 서귀포시 안덕면 병악로 ...
# 4   ['#제주여행', '#카멜리아...  제주 서귀포시 안덕면 병악로 ...
# ..                          ...                              ...
# 0                    []          제주특별자치도 서귀포시 성산읍...
# 0   ['#피규어뮤지엄을', '#베...  제주특별자치도 서귀포시 안덕면...
# 0                    []          제주특별자치도 서귀포시 중산간...
# 0                    []          제주특별자치도 제주시 구좌읍 ...
# 0                    []          제주특별자치도 제주시 한경면 ...
#
# [2888 rows x 4 columns]

# %%
df4['keyword'] = '테마관광'

# %%
df4_col=["name","keyword","content","tags","address"]

# %%
df4=df4[df4_col]

# %%
df4
# Out:
#                                 name   keyword  \
# 0            카멜리아힐               테마관광
# 1            카멜리아힐               테마관광
# 2            카멜리아힐               테마관광
# 3            카멜리아힐               테마관광
# 4            카멜리아힐               테마관광
# ..                  ...                    ...
# 0            지포뮤지엄               테마관광
# 0     피규어뮤지엄 제주               테마관광
# 0   한국야구명예전당(야구박물관)....  테마관광
# 0              한울랜드               테마관광
# 0          해거름전망대               테마관광
#
#                              content                         tags  \
# 0         기대가 됩니다               ['#여름', '#미식', '...
# 1     친구들과 우정여행               ['#제주컬러어택', '#카멜...
# 2   친구들과 함께한 겨울 데주.....    ['#겨울', '#제주', '...
# 3   태교여행으로 갔던 가을의 제주...  ['#제주가을', '#카멜리아...
# 4   태풍으로 항공편도 변경하고 일...  ['#제주여행', '#카멜리아...
# ..                               ...                          ...
# 0   태양의 정기를 정면으로 받을 ...                    []
# 0   제주마지막날 안개와 해무가 자...  ['#피규어뮤지엄을', '#베...
# 0   야구가 같은 팀이 매어준 커플...                    []
# 0   아이와의 체험은 항상 좋은 기...                    []
# 0     나홀로 자전거여행                                []
#
#                               address
# 0   제주 서귀포시 안덕면 병악로 ...
# 1   제주 서귀포시 안덕면 병악로 ...
# 2   제주 서귀포시 안덕면 병악로 ...
# 3   제주 서귀포시 안덕면 병악로 ...
# 4   제주 서귀포시 안덕면 병악로 ...
# ..                              ...
# 0   제주특별자치도 서귀포시 성산읍...
# 0   제주특별자치도 서귀포시 안덕면...
# 0   제주특별자치도 서귀포시 중산간...
# 0   제주특별자치도 제주시 구좌읍 ...
# 0   제주특별자치도 제주시 한경면 ...
#
# [2888 rows x 5 columns]

# %%
df4.to_csv('Theme.csv')

# %%
df5 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Walking.csv',index_col=0)
df5
# Out:
#                              name                            content  \
# 0            사려니숲길            #사려니숲. #붉은오름 4/2...
# 1            사려니숲길            작년11월 예술치유 영상 작업...
# 2            사려니숲길            여름의 시작과 끝을 함께하는 ...
# 3            사려니숲길            몇년만에 함께한 가족여행, 제...
# 4            사려니숲길            처음만나 제주의 가을 사려니숲...
# ..                  ...                                         ...
# 0   서광리 곶자왈생태탐방로......  서광리 곶자왈 생태탐방로......
# 0       제주올레 12코스            제주 올레길 12코스 수월봉 ...
# 0       제주올레 13코스            올레길 13코스를 꼬닥꼬닥 걸...
# 0     제주올레 15-B코스            #올레길 #15-b #담장을 ...
# 0     제주올레 18-1코스            용듬벙에서 바로보는 나발론절벽...
#
#                            tags                            address
# 0   ['#걷기', '#친구', '...      제주특별자치도 제주시 조천읍 ...
# 1   ['##예술치유', '##칼림...    제주특별자치도 제주시 조천읍 ...
# 2   ['#여름', '#산수국', ...     제주특별자치도 제주시 조천읍 ...
# 3   ['#가족여행', '#사랑해요...  제주특별자치도 제주시 조천읍 ...
# 4   ['##여행', '##제주행'...     제주특별자치도 제주시 조천읍 ...
# ..                       ...                                  ...
# 0                    []          제주특별자치도 서귀포시 안덕면...
# 0                    []          제주특별자치도 서귀포시 대정읍...
# 0                    []          제주특별자치도 제주시 한경면 ...
# 0   ['#올레길', '#15', ...       제주특별자치도 제주시 한림읍 ...
# 0   ['#알파캠프', '#올레캠프...  제주특별자치도 제주시 추자면 ...
#
# [1025 rows x 4 columns]

# %%
df5['keyword'] = '도보'

# %%
df5_col=["name","keyword","content","tags","address"]

# %%
df5=df5[df5_col]

# %%
df5
# Out:
#                              name keyword                            content  \
# 0            사려니숲길              도보  #사려니숲. #붉은오름 4/2...
# 1            사려니숲길              도보  작년11월 예술치유 영상 작업...
# 2            사려니숲길              도보  여름의 시작과 끝을 함께하는 ...
# 3            사려니숲길              도보  몇년만에 함께한 가족여행, 제...
# 4            사려니숲길              도보  처음만나 제주의 가을 사려니숲...
# ..                  ...               ...                               ...
# 0   서광리 곶자왈생태탐방로......    도보  서광리 곶자왈 생태탐방로......
# 0       제주올레 12코스              도보  제주 올레길 12코스 수월봉 ...
# 0       제주올레 13코스              도보  올레길 13코스를 꼬닥꼬닥 걸...
# 0     제주올레 15-B코스              도보  #올레길 #15-b #담장을 ...
# 0     제주올레 18-1코스              도보  용듬벙에서 바로보는 나발론절벽...
#
#                            tags                            address
# 0   ['#걷기', '#친구', '...      제주특별자치도 제주시 조천읍 ...
# 1   ['##예술치유', '##칼림...    제주특별자치도 제주시 조천읍 ...
# 2   ['#여름', '#산수국', ...     제주특별자치도 제주시 조천읍 ...
# 3   ['#가족여행', '#사랑해요...  제주특별자치도 제주시 조천읍 ...
# 4   ['##여행', '##제주행'...     제주특별자치도 제주시 조천읍 ...
# ..                       ...                                  ...
# 0                    []          제주특별자치도 서귀포시 안덕면...
# 0                    []          제주특별자치도 서귀포시 대정읍...
# 0                    []          제주특별자치도 제주시 한경면 ...
# 0   ['#올레길', '#15', ...       제주특별자치도 제주시 한림읍 ...
# 0   ['#알파캠프', '#올레캠프...  제주특별자치도 제주시 추자면 ...
#
# [1025 rows x 5 columns]

# %%
df5.to_csv('Walking.csv')

# %%
pd.set_option('display.max_columns', 100)                       # 출력할 열의 최대개수
pd.set_option('display.max_colwidth', 20)                      # 출력할 열의 너비
pd.set_option('display.unicode.east_asian_width', True)

# %%
df6 = pd.concat([df1,df2,df3,df4,df5],ignore_index=True)
print(df6)
# Out:
#                                  name keyword  \
# 0      더럭초등학교(구, 더럭분교)....    문화
# 1      더럭초등학교(구, 더럭분교)....    문화
# 2      더럭초등학교(구, 더럭분교)....    문화
# 3      더럭초등학교(구, 더럭분교)....    문화
# 4      더럭초등학교(구, 더럭분교)....    문화
# ...                               ...     ...
# 14929  서광리 곶자왈생태탐방로......     도보
# 14930      제주올레 12코스               도보
# 14931      제주올레 13코스               도보
# 14932    제주올레 15-B코스               도보
# 14933    제주올레 18-1코스               도보
#
#                                  content                         tags  \
# 0      초등학교 동창들과 함께한 가을...   ['#제주컬러어택', '#더럭...
# 1      무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 2      무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 3      알록달록 너무 예쁜 초등학교에...   ['##5월엔제주', '##더...
# 4      #제주도 #더럭분교 #연화못 ...      ['#제주도', '#더럭분교'...
# ...                              ...                             ...
# 14929  서광리 곶자왈 생태탐방로......                      []
# 14930  제주 올레길 12코스 수월봉 ...                       []
# 14931  올레길 13코스를 꼬닥꼬닥 걸...                      []
# 14932  #올레길 #15-b #담장을 ...          ['#올레길', '#15', ...
# 14933  용듬벙에서 바로보는 나발론절벽...  ['#알파캠프', '#올레캠프...
#
#                                  address
# 0      제주특별자치도 제주시 애월읍 ...
# 1      제주특별자치도 제주시 애월읍 ...
# 2      제주특별자치도 제주시 애월읍 ...
# 3      제주특별자치도 제주시 애월읍 ...
# 4      제주특별자치도 제주시 애월읍 ...
# ...                                 ...
# 14929  제주특별자치도 서귀포시 안덕면...
# 14930  제주특별자치도 서귀포시 대정읍...
# 14931  제주특별자치도 제주시 한경면 ...
# 14932  제주특별자치도 제주시 한림읍 ...
# 14933  제주특별자치도 제주시 추자면 ...
#
# [14934 rows x 5 columns]

# %%
df6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9e24c92edfd1> in <module>
# ----> 1 df6
#
# NameError: name 'df6' is not defined

# %%
pd.DataFrame(df6).to_csv('jeju_Tourism1.csv', header = True, index = False, encoding='utf-8-sig')

# %%
jeju = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\3-0 전처리(제주)\\jeju_Tourism.csv',encoding='UTF-8', index_col=0)
jeju
# Out:
#                 keyword                                            content  \
# ﻿name
# 더럭초등학교(구, 더럭분교)      문화                  초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 더럭초등학교(구, 더럭분교)      문화                                   무지개빛 아름다운 더럭초등학교
# 더럭초등학교(구, 더럭분교)      문화                                   무지개빛 아름다운 더럭초등학교
# 더럭초등학교(구, 더럭분교)      문화          알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 더럭초등학교(구, 더럭분교)      문화  #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                 ...                                                ...
# 서광리 곶자왈생태탐방로         도보                                      서광리 곶자왈 생태탐방로
# 제주올레 12코스            도보  제주 올레길 12코스 수월봉 화산쇄설층\n정상의 지형은 완만한 편이지만 해안 절벽을...
# 제주올레 13코스            도보  올레길 13코스를 꼬닥꼬닥 걸으며... 이날은 클린올레로 올레길을 청소해서 마음도 ...
# 제주올레 15-B코스          도보              #올레길 #15-b #담장을 #벗삼아 #태양을 #바라보는 #난제주개
# 제주올레 18-1코스          도보                              용듬벙에서 바로보는 나발론절벽과 하늘길
#
#                                                               tags  \
# ﻿name
# 더럭초등학교(구, 더럭분교)       ['#제주컬러어택', '#더럭분교', '#초등동창가을여행', '#무지개빛우정']
# 더럭초등학교(구, 더럭분교)                    ['##더럭초등학교', '##더럭분교', '##애월읍']
# 더럭초등학교(구, 더럭분교)         ['##더럭초등학교', '##더럭분교', '##무지개학교', '##애월읍']
# 더럭초등학교(구, 더럭분교)                  ['##5월엔제주', '##더럭분교', '##더럭초등학교']
# 더럭초등학교(구, 더럭분교)                 ['#제주도', '#더럭분교', '#연화못', '#연꽃마을']
# ...                                                            ...
# 서광리 곶자왈생태탐방로                                                    []
# 제주올레 12코스                                                       []
# 제주올레 13코스                                                       []
# 제주올레 15-B코스      ['#올레길', '#15', '#담장을', '#벗삼아', '#태양을', '#바라보는...
# 제주올레 18-1코스      ['#알파캠프', '#올레캠프본점알파캠프', '#제주', '#제주도', '#제주올레...
#
#                                      address
# ﻿name
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195
# ...                                      ...
# 서광리 곶자왈생태탐방로            제주특별자치도 서귀포시 안덕면 서광리
# 제주올레 12코스        제주특별자치도 서귀포시 대정읍 신도리 2883-2
# 제주올레 13코스         제주특별자치도 제주시 한경면 조수리 2137-2
# 제주올레 15-B코스        제주특별자치도 제주시 한림읍 한림해안로 192
# 제주올레 18-1코스         제주특별자치도 제주시 추자면 묵리 산 133
#
# [14934 rows x 4 columns]

# %%
# jeju['address1'] = jeju.address.str.split(' ').str[2]

#jeju['address'].str.split(" ", expand=True).tail(100)

# %%
#jeju['address'].str.extract('( \w*도 )|( \w*시 )|( \w*동 )|( \w*읍 )')

# %%
#jeju['address1']=jeju['address'].str.extract('( \w*읍 | \w*면| \w*동 )')

jeju['address1']=jeju['address'].str.extract('( \w*읍 | \w*면 )')
#읍련테그

# %%
jeju
# Out:
#                 keyword                                            content  \
# ﻿name
# 더럭초등학교(구, 더럭분교)      문화                  초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 더럭초등학교(구, 더럭분교)      문화                                   무지개빛 아름다운 더럭초등학교
# 더럭초등학교(구, 더럭분교)      문화                                   무지개빛 아름다운 더럭초등학교
# 더럭초등학교(구, 더럭분교)      문화          알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 더럭초등학교(구, 더럭분교)      문화  #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                 ...                                                ...
# 서광리 곶자왈생태탐방로         도보                                      서광리 곶자왈 생태탐방로
# 제주올레 12코스            도보  제주 올레길 12코스 수월봉 화산쇄설층\n정상의 지형은 완만한 편이지만 해안 절벽을...
# 제주올레 13코스            도보  올레길 13코스를 꼬닥꼬닥 걸으며... 이날은 클린올레로 올레길을 청소해서 마음도 ...
# 제주올레 15-B코스          도보              #올레길 #15-b #담장을 #벗삼아 #태양을 #바라보는 #난제주개
# 제주올레 18-1코스          도보                              용듬벙에서 바로보는 나발론절벽과 하늘길
#
#                                                               tags  \
# ﻿name
# 더럭초등학교(구, 더럭분교)       ['#제주컬러어택', '#더럭분교', '#초등동창가을여행', '#무지개빛우정']
# 더럭초등학교(구, 더럭분교)                    ['##더럭초등학교', '##더럭분교', '##애월읍']
# 더럭초등학교(구, 더럭분교)         ['##더럭초등학교', '##더럭분교', '##무지개학교', '##애월읍']
# 더럭초등학교(구, 더럭분교)                  ['##5월엔제주', '##더럭분교', '##더럭초등학교']
# 더럭초등학교(구, 더럭분교)                 ['#제주도', '#더럭분교', '#연화못', '#연꽃마을']
# ...                                                            ...
# 서광리 곶자왈생태탐방로                                                    []
# 제주올레 12코스                                                       []
# 제주올레 13코스                                                       []
# 제주올레 15-B코스      ['#올레길', '#15', '#담장을', '#벗삼아', '#태양을', '#바라보는...
# 제주올레 18-1코스      ['#알파캠프', '#올레캠프본점알파캠프', '#제주', '#제주도', '#제주올레...
#
#                                      address address1
# ﻿name
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195     애월읍
# ...                                      ...      ...
# 서광리 곶자왈생태탐방로            제주특별자치도 서귀포시 안덕면 서광리     안덕면
# 제주올레 12코스        제주특별자치도 서귀포시 대정읍 신도리 2883-2     대정읍
# 제주올레 13코스         제주특별자치도 제주시 한경면 조수리 2137-2     한경면
# 제주올레 15-B코스        제주특별자치도 제주시 한림읍 한림해안로 192     한림읍
# 제주올레 18-1코스         제주특별자치도 제주시 추자면 묵리 산 133     추자면
#
# [14934 rows x 5 columns]

# %%
jeju_dop_row = jeju.dropna(axis=0)  # 읍면테그 안달린 행 삭제

# %%
jeju_dop_row
# Out:
#                 keyword                                            content  \
# ﻿name
# 더럭초등학교(구, 더럭분교)      문화                  초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 더럭초등학교(구, 더럭분교)      문화                                   무지개빛 아름다운 더럭초등학교
# 더럭초등학교(구, 더럭분교)      문화                                   무지개빛 아름다운 더럭초등학교
# 더럭초등학교(구, 더럭분교)      문화          알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 더럭초등학교(구, 더럭분교)      문화  #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                 ...                                                ...
# 서광리 곶자왈생태탐방로         도보                                      서광리 곶자왈 생태탐방로
# 제주올레 12코스            도보  제주 올레길 12코스 수월봉 화산쇄설층\n정상의 지형은 완만한 편이지만 해안 절벽을...
# 제주올레 13코스            도보  올레길 13코스를 꼬닥꼬닥 걸으며... 이날은 클린올레로 올레길을 청소해서 마음도 ...
# 제주올레 15-B코스          도보              #올레길 #15-b #담장을 #벗삼아 #태양을 #바라보는 #난제주개
# 제주올레 18-1코스          도보                              용듬벙에서 바로보는 나발론절벽과 하늘길
#
#                                                               tags  \
# ﻿name
# 더럭초등학교(구, 더럭분교)       ['#제주컬러어택', '#더럭분교', '#초등동창가을여행', '#무지개빛우정']
# 더럭초등학교(구, 더럭분교)                    ['##더럭초등학교', '##더럭분교', '##애월읍']
# 더럭초등학교(구, 더럭분교)         ['##더럭초등학교', '##더럭분교', '##무지개학교', '##애월읍']
# 더럭초등학교(구, 더럭분교)                  ['##5월엔제주', '##더럭분교', '##더럭초등학교']
# 더럭초등학교(구, 더럭분교)                 ['#제주도', '#더럭분교', '#연화못', '#연꽃마을']
# ...                                                            ...
# 서광리 곶자왈생태탐방로                                                    []
# 제주올레 12코스                                                       []
# 제주올레 13코스                                                       []
# 제주올레 15-B코스      ['#올레길', '#15', '#담장을', '#벗삼아', '#태양을', '#바라보는...
# 제주올레 18-1코스      ['#알파캠프', '#올레캠프본점알파캠프', '#제주', '#제주도', '#제주올레...
#
#                                      address address1
# ﻿name
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)      제주특별자치도 제주시 애월읍 하가로 195     애월읍
# ...                                      ...      ...
# 서광리 곶자왈생태탐방로            제주특별자치도 서귀포시 안덕면 서광리     안덕면
# 제주올레 12코스        제주특별자치도 서귀포시 대정읍 신도리 2883-2     대정읍
# 제주올레 13코스         제주특별자치도 제주시 한경면 조수리 2137-2     한경면
# 제주올레 15-B코스        제주특별자치도 제주시 한림읍 한림해안로 192     한림읍
# 제주올레 18-1코스         제주특별자치도 제주시 추자면 묵리 산 133     추자면
#
# [11287 rows x 5 columns]

# %%
jejunull=jeju[jeju['address1'].isnull()] # null값 있는 행만 가져오기

# %%
jejunull
# Out:
#           keyword                                            content  \
# ﻿name
# 관덕정            문화  별은 다섯개 주고 싶지만 누워서 처마밑 하늘을 보는데 누군가 다가와 제지한다. 누우...
# 관덕정            문화  제주의 척박한 삶.. 거친음식과 삶속에서 고뇌하셨던 부친의 기억..\n\n4.3사태...
# 관덕정            문화                        #제주43 #제주43사건 #관덕정 #제주43유적지
# 관덕정            문화  1448년이래로 지금까지 제주도민과 역사를 함께한 관덕정. 늘 여행차 지나며 보아오...
# 관덕정            문화                     #관덕정 제주목관아 수문장교대의식 과 김수문목사와결사대
# ...           ...                                                ...
# 숫모르편백나무숲길      도보  제주생태공원에서 절물자연휴양림으로 이어지는 걷기 좋은 길이다.\n#숫모르편백나무숲길...
# 숫모르편백나무숲길      도보                                            #숫모르숲길,
# 올레여행자센터        도보                                                 []
# 올레여행자센터        도보                                                 []
# 삼의악트레킹코스       도보                                       #산과오름 #삼의악오름
#
#                                                 tags                 address  \
# ﻿name
# 관덕정        ['#관덕정', '#관리자', '#교육좀', '#친절교육도', '#함께']      제주특별자치도 제주시 관덕로 19
# 관덕정                       ['#제주4', '#하멜표류기', '#관덕정']      제주특별자치도 제주시 관덕로 19
# 관덕정         ['#제주43', '#제주43사건', '#관덕정', '#제주43유적지']      제주특별자치도 제주시 관덕로 19
# 관덕정                                               []      제주특별자치도 제주시 관덕로 19
# 관덕정                                         ['#관덕정']      제주특별자치도 제주시 관덕로 19
# ...                                              ...                     ...
# 숫모르편백나무숲길   ['#숫모르편백나무숲길', '#숫모르숲길', '#편백나무', '#숲길']   제주특별자치도 제주시 516로 2596
# 숫모르편백나무숲길                                 ['#숫모르숲길']   제주특별자치도 제주시 516로 2596
# 올레여행자센터                                           []     제주특별자치도 서귀포시 중정로 22
# 올레여행자센터                                           []     제주특별자치도 서귀포시 중정로 22
# 삼의악트레킹코스                         ['#산과오름', '#삼의악오름']  제주특별자치도 제주시 아라동 산 24-2
#
#           address1
# ﻿name
# 관덕정            NaN
# 관덕정            NaN
# 관덕정            NaN
# 관덕정            NaN
# 관덕정            NaN
# ...            ...
# 숫모르편백나무숲길      NaN
# 숫모르편백나무숲길      NaN
# 올레여행자센터        NaN
# 올레여행자센터        NaN
# 삼의악트레킹코스       NaN
#
# [3647 rows x 5 columns]

# %%
jejunull['address1'].isnull().sum()
# Out:
# 3647

# %%
jejunull['address1'] = jejunull.address.str.split(' ').str[1]
# Out:
# <ipython-input-30-08c1237e6118>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jejunull['address1'] = jejunull.address.str.split(' ').str[1]

# %%
jejunull
# Out:
#           keyword                                            content  \
# ﻿name
# 관덕정            문화  별은 다섯개 주고 싶지만 누워서 처마밑 하늘을 보는데 누군가 다가와 제지한다. 누우...
# 관덕정            문화  제주의 척박한 삶.. 거친음식과 삶속에서 고뇌하셨던 부친의 기억..\n\n4.3사태...
# 관덕정            문화                        #제주43 #제주43사건 #관덕정 #제주43유적지
# 관덕정            문화  1448년이래로 지금까지 제주도민과 역사를 함께한 관덕정. 늘 여행차 지나며 보아오...
# 관덕정            문화                     #관덕정 제주목관아 수문장교대의식 과 김수문목사와결사대
# ...           ...                                                ...
# 숫모르편백나무숲길      도보  제주생태공원에서 절물자연휴양림으로 이어지는 걷기 좋은 길이다.\n#숫모르편백나무숲길...
# 숫모르편백나무숲길      도보                                            #숫모르숲길,
# 올레여행자센터        도보                                                 []
# 올레여행자센터        도보                                                 []
# 삼의악트레킹코스       도보                                       #산과오름 #삼의악오름
#
#                                                 tags                 address  \
# ﻿name
# 관덕정        ['#관덕정', '#관리자', '#교육좀', '#친절교육도', '#함께']      제주특별자치도 제주시 관덕로 19
# 관덕정                       ['#제주4', '#하멜표류기', '#관덕정']      제주특별자치도 제주시 관덕로 19
# 관덕정         ['#제주43', '#제주43사건', '#관덕정', '#제주43유적지']      제주특별자치도 제주시 관덕로 19
# 관덕정                                               []      제주특별자치도 제주시 관덕로 19
# 관덕정                                         ['#관덕정']      제주특별자치도 제주시 관덕로 19
# ...                                              ...                     ...
# 숫모르편백나무숲길   ['#숫모르편백나무숲길', '#숫모르숲길', '#편백나무', '#숲길']   제주특별자치도 제주시 516로 2596
# 숫모르편백나무숲길                                 ['#숫모르숲길']   제주특별자치도 제주시 516로 2596
# 올레여행자센터                                           []     제주특별자치도 서귀포시 중정로 22
# 올레여행자센터                                           []     제주특별자치도 서귀포시 중정로 22
# 삼의악트레킹코스                         ['#산과오름', '#삼의악오름']  제주특별자치도 제주시 아라동 산 24-2
#
#           address1
# ﻿name
# 관덕정            제주시
# 관덕정            제주시
# 관덕정            제주시
# 관덕정            제주시
# 관덕정            제주시
# ...            ...
# 숫모르편백나무숲길      제주시
# 숫모르편백나무숲길      제주시
# 올레여행자센터       서귀포시
# 올레여행자센터       서귀포시
# 삼의악트레킹코스       제주시
#
# [3647 rows x 5 columns]

# %%
# jeju와 jejunull을 합치기

# %%
jeju_teg=pd.concat([jeju_dop_row,jejunull])

# %%
jeju_teg
# Out:
#                 keyword                                            content  \
# ﻿name
# 더럭초등학교(구, 더럭분교)      문화                  초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 더럭초등학교(구, 더럭분교)      문화                                   무지개빛 아름다운 더럭초등학교
# 더럭초등학교(구, 더럭분교)      문화                                   무지개빛 아름다운 더럭초등학교
# 더럭초등학교(구, 더럭분교)      문화          알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 더럭초등학교(구, 더럭분교)      문화  #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                 ...                                                ...
# 숫모르편백나무숲길            도보  제주생태공원에서 절물자연휴양림으로 이어지는 걷기 좋은 길이다.\n#숫모르편백나무숲길...
# 숫모르편백나무숲길            도보                                            #숫모르숲길,
# 올레여행자센터              도보                                                 []
# 올레여행자센터              도보                                                 []
# 삼의악트레킹코스             도보                                       #산과오름 #삼의악오름
#
#                                                          tags  \
# ﻿name
# 더럭초등학교(구, 더럭분교)  ['#제주컬러어택', '#더럭분교', '#초등동창가을여행', '#무지개빛우정']
# 더럭초등학교(구, 더럭분교)               ['##더럭초등학교', '##더럭분교', '##애월읍']
# 더럭초등학교(구, 더럭분교)    ['##더럭초등학교', '##더럭분교', '##무지개학교', '##애월읍']
# 더럭초등학교(구, 더럭분교)             ['##5월엔제주', '##더럭분교', '##더럭초등학교']
# 더럭초등학교(구, 더럭분교)            ['#제주도', '#더럭분교', '#연화못', '#연꽃마을']
# ...                                                       ...
# 숫모르편백나무숲길            ['#숫모르편백나무숲길', '#숫모르숲길', '#편백나무', '#숲길']
# 숫모르편백나무숲길                                          ['#숫모르숲길']
# 올레여행자센터                                                    []
# 올레여행자센터                                                    []
# 삼의악트레킹코스                                  ['#산과오름', '#삼의악오름']
#
#                                  address address1
# ﻿name
# 더럭초등학교(구, 더럭분교)  제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)  제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)  제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)  제주특별자치도 제주시 애월읍 하가로 195     애월읍
# 더럭초등학교(구, 더럭분교)  제주특별자치도 제주시 애월읍 하가로 195     애월읍
# ...                                  ...      ...
# 숫모르편백나무숲길          제주특별자치도 제주시 516로 2596      제주시
# 숫모르편백나무숲길          제주특별자치도 제주시 516로 2596      제주시
# 올레여행자센터              제주특별자치도 서귀포시 중정로 22     서귀포시
# 올레여행자센터              제주특별자치도 서귀포시 중정로 22     서귀포시
# 삼의악트레킹코스          제주특별자치도 제주시 아라동 산 24-2      제주시
#
# [14934 rows x 5 columns]

# %%
jeju_teg.reset_index()
# Out:
#                  ﻿name keyword  \
# 0      더럭초등학교(구, 더럭분교)      문화
# 1      더럭초등학교(구, 더럭분교)      문화
# 2      더럭초등학교(구, 더럭분교)      문화
# 3      더럭초등학교(구, 더럭분교)      문화
# 4      더럭초등학교(구, 더럭분교)      문화
# ...                ...     ...
# 14929        숫모르편백나무숲길      도보
# 14930        숫모르편백나무숲길      도보
# 14931          올레여행자센터      도보
# 14932          올레여행자센터      도보
# 14933         삼의악트레킹코스      도보
#
#                                                  content  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                       무지개빛 아름다운 더럭초등학교
# 2                                       무지개빛 아름다운 더럭초등학교
# 3              알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4      #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                                                  ...
# 14929  제주생태공원에서 절물자연휴양림으로 이어지는 걷기 좋은 길이다.\n#숫모르편백나무숲길...
# 14930                                            #숫모르숲길,
# 14931                                                 []
# 14932                                                 []
# 14933                                       #산과오름 #삼의악오름
#
#                                                tags                  address  \
# 0      ['#제주컬러어택', '#더럭분교', '#초등동창가을여행', '#무지개빛우정']  제주특별자치도 제주시 애월읍 하가로 195
# 1                   ['##더럭초등학교', '##더럭분교', '##애월읍']  제주특별자치도 제주시 애월읍 하가로 195
# 2        ['##더럭초등학교', '##더럭분교', '##무지개학교', '##애월읍']  제주특별자치도 제주시 애월읍 하가로 195
# 3                 ['##5월엔제주', '##더럭분교', '##더럭초등학교']  제주특별자치도 제주시 애월읍 하가로 195
# 4                ['#제주도', '#더럭분교', '#연화못', '#연꽃마을']  제주특별자치도 제주시 애월읍 하가로 195
# ...                                             ...                      ...
# 14929      ['#숫모르편백나무숲길', '#숫모르숲길', '#편백나무', '#숲길']    제주특별자치도 제주시 516로 2596
# 14930                                    ['#숫모르숲길']    제주특별자치도 제주시 516로 2596
# 14931                                            []      제주특별자치도 서귀포시 중정로 22
# 14932                                            []      제주특별자치도 서귀포시 중정로 22
# 14933                           ['#산과오름', '#삼의악오름']   제주특별자치도 제주시 아라동 산 24-2
#
#       address1
# 0         애월읍
# 1         애월읍
# 2         애월읍
# 3         애월읍
# 4         애월읍
# ...        ...
# 14929      제주시
# 14930      제주시
# 14931     서귀포시
# 14932     서귀포시
# 14933      제주시
#
# [14934 rows x 6 columns]

# %%
pd.DataFrame(jeju).to_csv('jeju_Tourism1.csv', header = True, index = False, encoding='utf-8-sig')
