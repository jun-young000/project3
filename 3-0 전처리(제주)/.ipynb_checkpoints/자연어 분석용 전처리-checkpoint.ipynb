# %%
import json
import pandas as pd
import re

# %%
df = pd.read_csv('d.csv',index_col=0)

# %%
df
# Out:
#                   name keyword  \
# 0      더럭초등학교(구, 더럭분교)      문화
# 1      더럭초등학교(구, 더럭분교)      문화
# 2      더럭초등학교(구, 더럭분교)      문화
# 3      더럭초등학교(구, 더럭분교)      문화
# 4      더럭초등학교(구, 더럭분교)      문화
# ...                ...     ...
# 13064    누웨마루거리(구 바오젠)      도보
# 13065    누웨마루거리(구 바오젠)      도보
# 13066        숫모르편백나무숲길      도보
# 13067        숫모르편백나무숲길      도보
# 13068         삼의악트레킹코스      도보
#
#                                                  content  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                       무지개빛 아름다운 더럭초등학교
# 2                                       무지개빛 아름다운 더럭초등학교
# 3              알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4      #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                                                  ...
# 13064                              #바오젠거리 #신라스테이제주 #돌하루방
# 13065                        중국인들이 많이 찾는다는 제주시 연동 바오젠거리.
# 13066  제주생태공원에서 절물자연휴양림으로 이어지는 걷기 좋은 길이다.\n#숫모르편백나무숲길...
# ...

# %%
df1 = df.groupby(['name','address']).agg({'keyword':'first', 
                             'content': ''.join, 
                             'tags': ''.join,                             
                             'address1':'first'
                              }).reset_index()
# contect와 tags를 하나로 묶기
# ['name','address']로 묶은 이유 동명의 장소이름을 가졌으나 주소가 다른 경우가 존재

# %%
df1
# Out:
#             name                               address keyword  \
# 0    1100고지(휴게소)                제주특별자치도 서귀포시 색달동 산 1-3      자연
# 1       1100고지습지                제주특별자치도 서귀포시 색달동 산 1-2      자연
# 2      5.16도로숲터널            제주특별자치도 서귀포시 남원읍 신례리 산 2-1      자연
# 3        9.81 파크            제주특별자치도 제주시 애월읍 천덕로 880-24    테마관광
# 4            가뫼물           제주특별자치도 서귀포시 남원읍 남원리 2140-6   레저/체험
# ..           ...                                   ...     ...
# 486          화조원               제주특별자치도 제주시 애월읍 애원로 804    테마관광
# 487    환상숲 곶자왈공원           제주특별자치도 제주시 한경면 녹차분재로 594-1      자연
# 488        황우지해안                제주특별자치도 서귀포시 서홍동 766-1      자연
# 489    황우지해안 열두굴                제주특별자치도 서귀포시 서홍동 764-1      자연
# 490   휴애리 자연생활공원  제주특별자치도 서귀포시 남원읍 신례동로 256 (신례리, 휴애리)    테마관광
#
#                                                content  \
# 0    겨울에 가장 아름다운 곳#제주여행공유#제주가을#1100고지#비짓제주#한라산#눈이오면...
# 1    친구와함께방금전지나왔습니다. 눈꽃과절경이 눈부셨습니다. 하지만택시업을하시는분때문에 ...
# ...

# %%
# 주소를 바탕으로 위경도 받아오기

# %%
df1.to_csv('e.csv')

# %%
import googlemaps
import pandas as pd

my_key = "AIzaSyDa9AwBq_wIY4lraiCjJVf7CWgbHYyYyy0"
maps = googlemaps.Client(key=my_key)  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.
places = df1["address"]

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df2 = pd.DataFrame({'위도':lat, '경도':lng}, index=places)
print(df2)
# Out:
# 1번 인덱스에서 제주특별자치도 서귀포시 색달동 산 1-3의 위치를 찾고있습니다
# 2번 인덱스에서 제주특별자치도 서귀포시 색달동 산 1-2의 위치를 찾고있습니다
# 3번 인덱스에서 제주특별자치도 서귀포시 남원읍 신례리 산 2-1의 위치를 찾고있습니다
# 4번 인덱스에서 제주특별자치도 제주시 애월읍 천덕로 880-24의 위치를 찾고있습니다
# 5번 인덱스에서 제주특별자치도 서귀포시 남원읍 남원리 2140-6의 위치를 찾고있습니다
# 6번 인덱스에서 제주특별자치도 서귀포시 효돈순환로 441의 위치를 찾고있습니다
# 7번 인덱스에서 제주특별자치도 서귀포시 강정통물로 (강정동)의 위치를 찾고있습니다
# 8번 인덱스에서 제주특별자치도 서귀포시 표선면 성읍리 2974의 위치를 찾고있습니다
# 9번 인덱스에서 제주특별자치도 제주시 조천읍 선흘리 478의 위치를 찾고있습니다
# 10번 인덱스에서 제주특별자치도 제주시 구좌읍 송당리 산 145의 위치를 찾고있습니다
# 11번 인덱스에서 제주특별자치도 서귀포시 안덕면 일주서로 1611의 위치를 찾고있습니다
# 12번 인덱스에서 제주특별자치도 서귀포시 남성로 (서홍동)의 위치를 찾고있습니다
# 13번 인덱스에서 제주특별자치도 제주시 우도면의 위치를 찾고있습니다
# 14번 인덱스에서 제주특별자치도 제주시 우도면 우도해안길의 위치를 찾고있습니다
# 15번 인덱스에서 제주특별자치도 제주시 애월읍 고내리의 위치를 찾고있습니다
# 16번 인덱스에서 제주특별자치도 제주시 애월읍 고내리 산 3-1의 위치를 찾고있습니다
# 17번 인덱스에서 제주특별자치도 서귀포시 대정읍 영락리 2169의 위치를 찾고있습니다
# 18번 인덱스에서 제주특별자치도 서귀포시 남원읍 신례리의 위치를 찾고있습니다
# 19번 인덱스에서 제주특별자치도 서귀포시 남원읍 신례리의 위치를 찾고있습니다
# 20번 인덱스에서 제주특별자치도 서귀포시 대정읍 신평리의 위치를 찾고있습니다
# 21번 인덱스에서 제주특별자치도 제주시 애월읍 애월원당길 (곽지리)의 위치를 찾고있습니다
# ...

# %%
df2
# Out:
#                                              위도          경도
# address
# 제주특별자치도 서귀포시 색달동 산 1-3                33.357774  126.462518
# 제주특별자치도 서귀포시 색달동 산 1-2                33.357774  126.462518
# 제주특별자치도 서귀포시 남원읍 신례리 산 2-1            33.370906  126.570475
# 제주특별자치도 제주시 애월읍 천덕로 880-24            33.391182  126.366529
# 제주특별자치도 서귀포시 남원읍 남원리 2140-6           33.289973  126.693528
# ...                                         ...         ...
# 제주특별자치도 제주시 애월읍 애원로 804               33.443130  126.338599
# 제주특별자치도 제주시 한경면 녹차분재로 594-1           33.322576  126.263305
# 제주특별자치도 서귀포시 서홍동 766-1                33.241566  126.549811
# 제주특별자치도 서귀포시 서홍동 764-1                33.241973  126.550789
# 제주특별자치도 서귀포시 남원읍 신례동로 256 (신례리, 휴애리)  33.308757  126.633794
#
# [491 rows x 2 columns]

# %%
df3=df2.reset_index()

# %%
df3
# Out:
#                                   address         위도          경도
# 0                  제주특별자치도 서귀포시 색달동 산 1-3  33.357774  126.462518
# 1                  제주특별자치도 서귀포시 색달동 산 1-2  33.357774  126.462518
# 2              제주특별자치도 서귀포시 남원읍 신례리 산 2-1  33.370906  126.570475
# 3              제주특별자치도 제주시 애월읍 천덕로 880-24  33.391182  126.366529
# 4             제주특별자치도 서귀포시 남원읍 남원리 2140-6  33.289973  126.693528
# ..                                    ...        ...         ...
# 486               제주특별자치도 제주시 애월읍 애원로 804  33.443130  126.338599
# 487           제주특별자치도 제주시 한경면 녹차분재로 594-1  33.322576  126.263305
# 488                제주특별자치도 서귀포시 서홍동 766-1  33.241566  126.549811
# 489                제주특별자치도 서귀포시 서홍동 764-1  33.241973  126.550789
# 490  제주특별자치도 서귀포시 남원읍 신례동로 256 (신례리, 휴애리)  33.308757  126.633794
#
# [491 rows x 3 columns]

# %%
df3.rename(columns={"address":"address2"},inplace=True)

# %%
df3
# Out:
#                                  address2         위도          경도
# 0                  제주특별자치도 서귀포시 색달동 산 1-3  33.357774  126.462518
# 1                  제주특별자치도 서귀포시 색달동 산 1-2  33.357774  126.462518
# 2              제주특별자치도 서귀포시 남원읍 신례리 산 2-1  33.370906  126.570475
# 3              제주특별자치도 제주시 애월읍 천덕로 880-24  33.391182  126.366529
# 4             제주특별자치도 서귀포시 남원읍 남원리 2140-6  33.289973  126.693528
# ..                                    ...        ...         ...
# 486               제주특별자치도 제주시 애월읍 애원로 804  33.443130  126.338599
# 487           제주특별자치도 제주시 한경면 녹차분재로 594-1  33.322576  126.263305
# 488                제주특별자치도 서귀포시 서홍동 766-1  33.241566  126.549811
# 489                제주특별자치도 서귀포시 서홍동 764-1  33.241973  126.550789
# 490  제주특별자치도 서귀포시 남원읍 신례동로 256 (신례리, 휴애리)  33.308757  126.633794
#
# [491 rows x 3 columns]

# %%
df4=pd.concat([df1,df3],axis=1)

# %%
df4
# Out:
#             name                               address keyword  \
# 0    1100고지(휴게소)                제주특별자치도 서귀포시 색달동 산 1-3      자연
# 1       1100고지습지                제주특별자치도 서귀포시 색달동 산 1-2      자연
# 2      5.16도로숲터널            제주특별자치도 서귀포시 남원읍 신례리 산 2-1      자연
# 3        9.81 파크            제주특별자치도 제주시 애월읍 천덕로 880-24    테마관광
# 4            가뫼물           제주특별자치도 서귀포시 남원읍 남원리 2140-6   레저/체험
# ..           ...                                   ...     ...
# 486          화조원               제주특별자치도 제주시 애월읍 애원로 804    테마관광
# 487    환상숲 곶자왈공원           제주특별자치도 제주시 한경면 녹차분재로 594-1      자연
# 488        황우지해안                제주특별자치도 서귀포시 서홍동 766-1      자연
# 489    황우지해안 열두굴                제주특별자치도 서귀포시 서홍동 764-1      자연
# 490   휴애리 자연생활공원  제주특별자치도 서귀포시 남원읍 신례동로 256 (신례리, 휴애리)    테마관광
#
#                                                content  \
# 0    겨울에 가장 아름다운 곳#제주여행공유#제주가을#1100고지#비짓제주#한라산#눈이오면...
# 1    친구와함께방금전지나왔습니다. 눈꽃과절경이 눈부셨습니다. 하지만택시업을하시는분때문에 ...
# ...

# %%
df4.drop(["tags"],axis=1, inplace=True)

# %%
df4['noname'] = df4['name'].apply(lambda x: x )
df4['noaddress'] = df4['address'].apply(lambda x: x )
df4['nocontent'] = df4['content'].apply(lambda x: x )

# %%
df4
# Out:
#             name                               address keyword  \
# 0    1100고지(휴게소)                제주특별자치도 서귀포시 색달동 산 1-3      자연
# 1       1100고지습지                제주특별자치도 서귀포시 색달동 산 1-2      자연
# 2      5.16도로숲터널            제주특별자치도 서귀포시 남원읍 신례리 산 2-1      자연
# 3        9.81 파크            제주특별자치도 제주시 애월읍 천덕로 880-24    테마관광
# 4            가뫼물           제주특별자치도 서귀포시 남원읍 남원리 2140-6   레저/체험
# ..           ...                                   ...     ...
# 486          화조원               제주특별자치도 제주시 애월읍 애원로 804    테마관광
# 487    환상숲 곶자왈공원           제주특별자치도 제주시 한경면 녹차분재로 594-1      자연
# 488        황우지해안                제주특별자치도 서귀포시 서홍동 766-1      자연
# 489    황우지해안 열두굴                제주특별자치도 서귀포시 서홍동 764-1      자연
# 490   휴애리 자연생활공원  제주특별자치도 서귀포시 남원읍 신례동로 256 (신례리, 휴애리)    테마관광
#
#                                                content address1  \
# 0    겨울에 가장 아름다운 곳#제주여행공유#제주가을#1100고지#비짓제주#한라산#눈이오면...     서귀포시
# 1    친구와함께방금전지나왔습니다. 눈꽃과절경이 눈부셨습니다. 하지만택시업을하시는분때문에 ...     서귀포시
# ...

# %%
df4.drop(["address2"],axis=1, inplace=True)

# %%
df4
# Out:
#             name                               address keyword  \
# 0    1100고지(휴게소)                제주특별자치도 서귀포시 색달동 산 1-3      자연
# 1       1100고지습지                제주특별자치도 서귀포시 색달동 산 1-2      자연
# 2      5.16도로숲터널            제주특별자치도 서귀포시 남원읍 신례리 산 2-1      자연
# 3        9.81 파크            제주특별자치도 제주시 애월읍 천덕로 880-24    테마관광
# 4            가뫼물           제주특별자치도 서귀포시 남원읍 남원리 2140-6   레저/체험
# ..           ...                                   ...     ...
# 486          화조원               제주특별자치도 제주시 애월읍 애원로 804    테마관광
# 487    환상숲 곶자왈공원           제주특별자치도 제주시 한경면 녹차분재로 594-1      자연
# 488        황우지해안                제주특별자치도 서귀포시 서홍동 766-1      자연
# 489    황우지해안 열두굴                제주특별자치도 서귀포시 서홍동 764-1      자연
# 490   휴애리 자연생활공원  제주특별자치도 서귀포시 남원읍 신례동로 256 (신례리, 휴애리)    테마관광
#
#                                                content address1         위도  \
# 0    겨울에 가장 아름다운 곳#제주여행공유#제주가을#1100고지#비짓제주#한라산#눈이오면...     서귀포시  33.357774
# ...

# %%
df4["noname"] = df4["noname"].str.replace(pat=r'[^\w]', repl=r' ', regex=True)#특수기호삭제
df4["noaddress"] = df4["noaddress"].str.replace(pat=r'[^\w]', repl=r' ', regex=True) 
df4["nocontent"] = df4["nocontent"].str.replace(pat=r'[^\w]', repl=r' ', regex=True)

# %%
df4["content"]  = [re.sub('[^A-Za-z0-9가-힣]', ' ', s) for s in df4["content"]] #특수기호삭제 
df4["noaddress"]  = [re.sub('[^A-Za-z0-9가-힣]', ' ', s) for s in df4["noaddress"]]
df4["nocontent"]  = [re.sub('[^A-Za-z0-9가-힣]', ' ', s) for s in df4["nocontent"]]

# %%
df4
# Out:
#             name                               address keyword  \
# 0    1100고지(휴게소)                제주특별자치도 서귀포시 색달동 산 1-3      자연
# 1       1100고지습지                제주특별자치도 서귀포시 색달동 산 1-2      자연
# 2      5.16도로숲터널            제주특별자치도 서귀포시 남원읍 신례리 산 2-1      자연
# 3        9.81 파크            제주특별자치도 제주시 애월읍 천덕로 880-24    테마관광
# 4            가뫼물           제주특별자치도 서귀포시 남원읍 남원리 2140-6   레저/체험
# ..           ...                                   ...     ...
# 486          화조원               제주특별자치도 제주시 애월읍 애원로 804    테마관광
# 487    환상숲 곶자왈공원           제주특별자치도 제주시 한경면 녹차분재로 594-1      자연
# 488        황우지해안                제주특별자치도 서귀포시 서홍동 766-1      자연
# 489    황우지해안 열두굴                제주특별자치도 서귀포시 서홍동 764-1      자연
# 490   휴애리 자연생활공원  제주특별자치도 서귀포시 남원읍 신례동로 256 (신례리, 휴애리)    테마관광
#
#                                                content address1         위도  \
# 0    겨울에 가장 아름다운 곳 제주여행공유 제주가을 1100고지 비짓제주 한라산 눈이오면...     서귀포시  33.357774
# ...

# %%
df4["noname"]  = [re.sub('[^A-Za-z가-힣]', ' ', s) for s in df4["noname"]]#숫자 삭제
df4["noaddress"]  = [re.sub('[^A-Za-z가-힣]', ' ', s) for s in df4["noaddress"]]
df4["nocontent"]  = [re.sub('[^A-Za-z가-힣]', ' ', s) for s in df4["nocontent"]]

# %%
df4['content']=[x.replace('\r',' ') for x in df4['content']]
df4['nocontent']=[x.replace('\r',' ') for x in df4['nocontent']]

# %%
df5.to_csv('f.csv') # 우측 3개열은 자연어분석용 나머지는  장소에 관한 원데이터입니다.
