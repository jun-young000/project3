# %%
import json
import pandas as pd
import numpy as np
import os

# %%
df1 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Culture.csv',encoding='cp949', index_col=0)
df1
# Out:
#                name                                            content  \
# 0   더럭초등학교(구, 더럭분교)                  초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1   더럭초등학교(구, 더럭분교)                                   무지개빛 아름다운 더럭초등학교
# 2   더럭초등학교(구, 더럭분교)                                   무지개빛 아름다운 더럭초등학교
# 3   더럭초등학교(구, 더럭분교)          알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4   더럭초등학교(구, 더럭분교)  #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ..              ...                                                ...
# 0              제주향교                               #고풍스러운 느낌! #옛느낌이 가득!
# 0         평화통일 불사리탑  용두암에서 월정리까지 자전거 여행 중에 잠시 들렀습니다. 경내를 다 둘러보진 못했지...
# 0     포도갤러리 in 포도호텔  우동으로 유명한 포도호텔에서 포도갤러리가 오픈되서 가보니,\r\n포도호텔 자체만으로...
# 0            프랑스샤르망  프랑스샤르망/ 제주프랑스문화원에서 프랑스박물관의 명칭이며, 미술품, 예술품, 공통품...
# 0            화북비석거리                                         화북쪽 벚꽃거리!!
#
#                                             tags  \
# 0   ['#제주컬러어택', '#더럭분교', '#초등동창가을여행', '#무지개빛우정']
# 1                ['##더럭초등학교', '##더럭분교', '##애월읍']
# 2     ['##더럭초등학교', '##더럭분교', '##무지개학교', '##애월읍']
# 3              ['##5월엔제주', '##더럭분교', '##더럭초등학교']
# 4             ['#제주도', '#더럭분교', '#연화못', '#연꽃마을']
# ..                                           ...
# 0                            ['#고풍스러운', '#옛느낌이']
# 0                ['#봄', '#레포츠', '#혼자', '#자전거여행']
# 0                                             []
# 0                                             []
# 0                                             []
#
#                                 address
# 0               제주특별자치도 제주시 애월읍 하가로 195
# 1               제주특별자치도 제주시 애월읍 하가로 196
# 2               제주특별자치도 제주시 애월읍 하가로 197
# 3               제주특별자치도 제주시 애월읍 하가로 198
# 4               제주특별자치도 제주시 애월읍 하가로 199
# ..                                  ...
# 0                    제주특별자치도 제주시 서문로 43
# 0              제주특별자치도 제주시 조천읍 일주동로 884
# 0   제주특별자치도 서귀포시 안덕면 산록남로 863 포도호텔 지하1층
# 0                        제주시 한림읍 명상로 37
# 0                      제주특별자치도 제주시 일주동로
#
# [964 rows x 4 columns]

# %%
df1['keyword'] = '문화'

# %%
df1_col=["name","keyword","content","tags","address"]

# %%
df1=df1[df1_col]

# %%
df1
# Out:
#                name keyword  \
# 0   더럭초등학교(구, 더럭분교)      문화
# 1   더럭초등학교(구, 더럭분교)      문화
# 2   더럭초등학교(구, 더럭분교)      문화
# 3   더럭초등학교(구, 더럭분교)      문화
# 4   더럭초등학교(구, 더럭분교)      문화
# ..              ...     ...
# 0              제주향교      문화
# 0         평화통일 불사리탑      문화
# 0     포도갤러리 in 포도호텔      문화
# 0            프랑스샤르망      문화
# 0            화북비석거리      문화
#
#                                               content  \
# 0                   초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                    무지개빛 아름다운 더럭초등학교
# 2                                    무지개빛 아름다운 더럭초등학교
# 3           알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4   #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ..                                                ...
# 0                                #고풍스러운 느낌! #옛느낌이 가득!
# 0   용두암에서 월정리까지 자전거 여행 중에 잠시 들렀습니다. 경내를 다 둘러보진 못했지...
# 0   우동으로 유명한 포도호텔에서 포도갤러리가 오픈되서 가보니,\r\n포도호텔 자체만으로...
# 0   프랑스샤르망/ 제주프랑스문화원에서 프랑스박물관의 명칭이며, 미술품, 예술품, 공통품...
# 0                                          화북쪽 벚꽃거리!!
#
#                                             tags  \
# 0   ['#제주컬러어택', '#더럭분교', '#초등동창가을여행', '#무지개빛우정']
# 1                ['##더럭초등학교', '##더럭분교', '##애월읍']
# 2     ['##더럭초등학교', '##더럭분교', '##무지개학교', '##애월읍']
# 3              ['##5월엔제주', '##더럭분교', '##더럭초등학교']
# 4             ['#제주도', '#더럭분교', '#연화못', '#연꽃마을']
# ..                                           ...
# 0                            ['#고풍스러운', '#옛느낌이']
# 0                ['#봄', '#레포츠', '#혼자', '#자전거여행']
# 0                                             []
# 0                                             []
# 0                                             []
#
#                                 address
# 0               제주특별자치도 제주시 애월읍 하가로 195
# 1               제주특별자치도 제주시 애월읍 하가로 196
# 2               제주특별자치도 제주시 애월읍 하가로 197
# 3               제주특별자치도 제주시 애월읍 하가로 198
# 4               제주특별자치도 제주시 애월읍 하가로 199
# ..                                  ...
# 0                    제주특별자치도 제주시 서문로 43
# 0              제주특별자치도 제주시 조천읍 일주동로 884
# 0   제주특별자치도 서귀포시 안덕면 산록남로 863 포도호텔 지하1층
# 0                        제주시 한림읍 명상로 37
# 0                      제주특별자치도 제주시 일주동로
#
# [964 rows x 5 columns]

# %%
df1.to_csv('Culture.csv')

# %%
df2 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Leisure experience.csv',index_col=0)
df2
# Out:
#        name                                            content  \
# 0    아침미소목장                                        #여름 #아침미소목장
# 1    아침미소목장  4박 제주 일정 중 가장 기억에 남는 TOP 3 중 하나 ㅋㅋ엄마가 송아지 먹이 주...
# 2    아침미소목장                                #6감만족 #제주여행 #아침미소목장
# 3    아침미소목장                                 #아침미소목장 #체험짱 #6감만족
# 4    아침미소목장                          #6감만족#제주체험#어린이체험#아기소우유먹이기
# ..      ...                                                ...
# 2   조랑말체험공원  #신나는 말타기 #성산 조랑말타운\r\n선선한 10윌 선선한 제주 날씨와 더불어\r...
# 3   조랑말체험공원  #제주 에서 아이들과 #승마 를 했습니다. 너무 즐거워하는 아이들을 보니 제가 더 ...
# 4   조랑말체험공원  결혼 10주년 4번째 시간!\r\n와이프는 무서워해서 아들하고\r\n둘이서 조랑말 ...
# 5   조랑말체험공원  제주도에 가면 말을 타봐야죠\r\n아기가 무서워 할 줄 알았는데\r\n재밌다며 다리...
# 6   조랑말체험공원  2016 나의 가슴속에 있었던 버킷리스트를 이룬날-! 제주도 트레일러닝 18K. 제...
#
#                                          tags                       address
# 0                          ['#여름', '#아침미소목장']           제주특별자치도 제주시 월평동 155
# 1                ['#여름', '#체험', '#힐링', '#가족']           제주특별자치도 제주시 월평동 155
# 2               ['#6감만족', '#제주여행', '#아침미소목장']           제주특별자치도 제주시 월평동 155
# 3                ['#아침미소목장', '#체험짱', '#6감만족']           제주특별자치도 제주시 월평동 155
# 4   ['#6감만족', '#제주체험', '#어린이체험', '#아기소우유먹이기']           제주특별자치도 제주시 월평동 155
# ..                                        ...                           ...
# 2                             ['#신나는', '#성산']  제주특별자치도 서귀포시 표선면 가시리 3149-33
# 3                              ['#제주', '#승마']  제주특별자치도 서귀포시 표선면 가시리 3149-33
# 4                                          []  제주특별자치도 서귀포시 표선면 가시리 3149-33
# 5                                          []  제주특별자치도 서귀포시 표선면 가시리 3149-33
# 6                                          []  제주특별자치도 서귀포시 표선면 가시리 3149-33
#
# [273 rows x 4 columns]

# %%
df2['keyword'] = '레저/체험'

# %%
df2_col=["name","keyword","content","tags","address"]

# %%
df2=df2[df2_col]

# %%
df2
# Out:
#        name keyword                                            content  \
# 0    아침미소목장   레저/체험                                        #여름 #아침미소목장
# 1    아침미소목장   레저/체험  4박 제주 일정 중 가장 기억에 남는 TOP 3 중 하나 ㅋㅋ엄마가 송아지 먹이 주...
# 2    아침미소목장   레저/체험                                #6감만족 #제주여행 #아침미소목장
# 3    아침미소목장   레저/체험                                 #아침미소목장 #체험짱 #6감만족
# 4    아침미소목장   레저/체험                          #6감만족#제주체험#어린이체험#아기소우유먹이기
# ..      ...     ...                                                ...
# 2   조랑말체험공원   레저/체험  #신나는 말타기 #성산 조랑말타운\r\n선선한 10윌 선선한 제주 날씨와 더불어\r...
# 3   조랑말체험공원   레저/체험  #제주 에서 아이들과 #승마 를 했습니다. 너무 즐거워하는 아이들을 보니 제가 더 ...
# 4   조랑말체험공원   레저/체험  결혼 10주년 4번째 시간!\r\n와이프는 무서워해서 아들하고\r\n둘이서 조랑말 ...
# 5   조랑말체험공원   레저/체험  제주도에 가면 말을 타봐야죠\r\n아기가 무서워 할 줄 알았는데\r\n재밌다며 다리...
# 6   조랑말체험공원   레저/체험  2016 나의 가슴속에 있었던 버킷리스트를 이룬날-! 제주도 트레일러닝 18K. 제...
#
#                                          tags                       address
# 0                          ['#여름', '#아침미소목장']           제주특별자치도 제주시 월평동 155
# 1                ['#여름', '#체험', '#힐링', '#가족']           제주특별자치도 제주시 월평동 155
# 2               ['#6감만족', '#제주여행', '#아침미소목장']           제주특별자치도 제주시 월평동 155
# 3                ['#아침미소목장', '#체험짱', '#6감만족']           제주특별자치도 제주시 월평동 155
# 4   ['#6감만족', '#제주체험', '#어린이체험', '#아기소우유먹이기']           제주특별자치도 제주시 월평동 155
# ..                                        ...                           ...
# 2                             ['#신나는', '#성산']  제주특별자치도 서귀포시 표선면 가시리 3149-33
# 3                              ['#제주', '#승마']  제주특별자치도 서귀포시 표선면 가시리 3149-33
# 4                                          []  제주특별자치도 서귀포시 표선면 가시리 3149-33
# 5                                          []  제주특별자치도 서귀포시 표선면 가시리 3149-33
# 6                                          []  제주특별자치도 서귀포시 표선면 가시리 3149-33
#
# [273 rows x 5 columns]

# %%
df2.to_csv('Leisure experience.csv')

# %%
df3 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Nature.csv', encoding='cp949',index_col=0)
df3
# Out:
#                     name                                            content  \
# 0   성산일출봉(UNESCO 세계자연유산)  방문전에는 전화 등을 통해 이용방법을 미리 확인하라는 안내에 따라, 9월 15일 오...
# 1   성산일출봉(UNESCO 세계자연유산)                      유네스코 성산일출봉입니다 세계의중심 제주도 입니다??
# 2   성산일출봉(UNESCO 세계자연유산)  경치도 아름답고 자연도 좋고, 언제 가도 좋은 곳이긴 합니다. 하지만 이번 방문 때...
# 3   성산일출봉(UNESCO 세계자연유산)  성산일출봉 자체는 좋았는데.... 코로나라고 물품보관소는 도대체 왜 닫은 걸까요ㅠ ...
# 4   성산일출봉(UNESCO 세계자연유산)  매표소 여직원 너무 불친절 기분 나쁘네요 자연유산에서 일하는분이면 기본예의부터 배우...
# ..                   ...                                                ...
# 0         천아오름(틍낭오름,天娥岳)                                                NaN
# 0                 큰바리메오름                                        #산과오름#바리메오름
# 0                    통오름                         #제주풍경 #통오름 #짧은오름 #제주자연 #녹음
# 0       판포오름 (널개오름, 板浦岳)                                          판포에서 본 노을
# 0               행원육상양식단지  35년 공직생활 무사히 정년퇴임하고 애들이 보내주어 집사람과 단둘이 간 제주여행. ...
#
#                                                  tags  \
# 0                           ['#불친절', '#직원교육', '#여직원']
# 1                        ['#제주도', '#유네스코', '#세계문화유산']
# 2                            ['##여름', '##걷기', '##가족']
# 3                                ['#봄', '#힐링', '#혼자']
# 4         ['##성산 #직원 #교육이든 바꾸시든', '#여름', '#봄', '#걷기']
# ..                                                ...
# 0                                                  []
# 0                                 ['#산과오름', '#바리메오름']
# 0          ['#제주풍경', '#통오름', '#짧은오름', '#제주자연', '#녹음']
# 0                                                  []
# 0   ['#행원풍력발전단지바닷가', '#퇴직기념부부여행', '#해안가 빨간이층집', '#...
#
#                          adress
# 0        제주특별자치도 서귀포시 성산읍 성산리 1
# 1        제주특별자치도 서귀포시 성산읍 성산리 2
# 2        제주특별자치도 서귀포시 성산읍 성산리 3
# 3        제주특별자치도 서귀포시 성산읍 성산리 4
# 4        제주특별자치도 서귀포시 성산읍 성산리 5
# ..                          ...
# 0     제주특별자치도 제주시 애월읍 광령리 604-1
# 0       제주특별자치도 제주시 애월읍 어음리 산 3
# 0   제주특별자치도 서귀포시 성산읍 신산리 1754-1
# 0       제주특별자치도 제주시 한경면 판포리 934
# 0      제주특별자치도 제주시 구좌읍 행원리 1-33
#
# [9784 rows x 4 columns]

# %%
df3.rename(columns = {"adress": "address"}, inplace = True)  # 열이름 변경

# %%
df3['keyword'] = '자연'

# %%
df3_col=["name","keyword","content","tags","address"]

# %%
df3=df3[df3_col]

# %%
df3
# Out:
#                     name keyword  \
# 0   성산일출봉(UNESCO 세계자연유산)      자연
# 1   성산일출봉(UNESCO 세계자연유산)      자연
# 2   성산일출봉(UNESCO 세계자연유산)      자연
# 3   성산일출봉(UNESCO 세계자연유산)      자연
# 4   성산일출봉(UNESCO 세계자연유산)      자연
# ..                   ...     ...
# 0         천아오름(틍낭오름,天娥岳)      자연
# 0                 큰바리메오름      자연
# 0                    통오름      자연
# 0       판포오름 (널개오름, 板浦岳)      자연
# 0               행원육상양식단지      자연
#
#                                               content  \
# 0   방문전에는 전화 등을 통해 이용방법을 미리 확인하라는 안내에 따라, 9월 15일 오...
# 1                       유네스코 성산일출봉입니다 세계의중심 제주도 입니다??
# 2   경치도 아름답고 자연도 좋고, 언제 가도 좋은 곳이긴 합니다. 하지만 이번 방문 때...
# 3   성산일출봉 자체는 좋았는데.... 코로나라고 물품보관소는 도대체 왜 닫은 걸까요ㅠ ...
# 4   매표소 여직원 너무 불친절 기분 나쁘네요 자연유산에서 일하는분이면 기본예의부터 배우...
# ..                                                ...
# 0                                                 NaN
# 0                                         #산과오름#바리메오름
# 0                          #제주풍경 #통오름 #짧은오름 #제주자연 #녹음
# 0                                           판포에서 본 노을
# 0   35년 공직생활 무사히 정년퇴임하고 애들이 보내주어 집사람과 단둘이 간 제주여행. ...
#
#                                                  tags  \
# 0                           ['#불친절', '#직원교육', '#여직원']
# 1                        ['#제주도', '#유네스코', '#세계문화유산']
# 2                            ['##여름', '##걷기', '##가족']
# 3                                ['#봄', '#힐링', '#혼자']
# 4         ['##성산 #직원 #교육이든 바꾸시든', '#여름', '#봄', '#걷기']
# ..                                                ...
# 0                                                  []
# 0                                 ['#산과오름', '#바리메오름']
# 0          ['#제주풍경', '#통오름', '#짧은오름', '#제주자연', '#녹음']
# 0                                                  []
# 0   ['#행원풍력발전단지바닷가', '#퇴직기념부부여행', '#해안가 빨간이층집', '#...
#
#                         address
# 0        제주특별자치도 서귀포시 성산읍 성산리 1
# 1        제주특별자치도 서귀포시 성산읍 성산리 2
# 2        제주특별자치도 서귀포시 성산읍 성산리 3
# 3        제주특별자치도 서귀포시 성산읍 성산리 4
# 4        제주특별자치도 서귀포시 성산읍 성산리 5
# ..                          ...
# 0     제주특별자치도 제주시 애월읍 광령리 604-1
# 0       제주특별자치도 제주시 애월읍 어음리 산 3
# 0   제주특별자치도 서귀포시 성산읍 신산리 1754-1
# 0       제주특별자치도 제주시 한경면 판포리 934
# 0      제주특별자치도 제주시 구좌읍 행원리 1-33
#
# [9784 rows x 5 columns]

# %%
df3.to_csv('Nature.csv')

# %%
df4 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Theme.csv',index_col=0)
df4
# Out:
#                name                                            content  \
# 0             카멜리아힐                                            기대가 됩니다
# 1             카멜리아힐                                          친구들과 우정여행
# 2             카멜리아힐                                     친구들과 함께한 겨울 데주
# 3             카멜리아힐    태교여행으로 갔던 가을의 제주도예요. 카멜리아 힐은 가을에 가도 아름다운것 같아요 ~
# 4             카멜리아힐  태풍으로 항공편도 변경하고 일정도 미뤄서 어렵사리 다녀온 제주! 가을빛 가득한 제주...
# ..              ...                                                ...
# 0             지포뮤지엄  태양의 정기를 정면으로 받을 수 있는 정동향 방향을 안내해 주는 안내판은 라이터 박...
# 0         피규어뮤지엄 제주  제주마지막날 안개와 해무가 자욱한날 #피규어뮤지엄을 다녀왔어요 #베트맨 #스파이더맨...
# 0   한국야구명예전당(야구박물관)             야구가 같은 팀이 매어준 커플~~??ㅎ 요것이 한몫 했을 수도~~^^
# 0              한울랜드  아이와의 체험은 항상 좋은 기억을 남깁니다.\r\n여행에서의 체험은 무엇보다 훗날 ...
# 0            해거름전망대                                          나홀로 자전거여행
#
#                                                 tags  \
# 0                              ['#여름', '#미식', '#친구']
# 1                   ['#제주컬러어택', '#카멜리아힐', '#한겨울에핀꽃']
# 2                              ['#겨울', '#제주', '#동백']
# 3                ['#제주가을', '#카멜리아힐', '#핑크뮬리', '#억새']
# 4              ['#제주여행', '#카멜리아힐', '#가을여행', '#가을제주']
# ..                                               ...
# 0                                                 []
# 0   ['#피규어뮤지엄을', '#베트맨', '#스파이더맨', '#피규어가', '#피규어들']
# 0                                                 []
# 0                                                 []
# 0                                                 []
#
#                        address
# 0          제주 서귀포시 안덕면 병악로 166
# 1          제주 서귀포시 안덕면 병악로 167
# 2          제주 서귀포시 안덕면 병악로 168
# 3          제주 서귀포시 안덕면 병악로 169
# 4          제주 서귀포시 안덕면 병악로 170
# ..                         ...
# 0   제주특별자치도 서귀포시 성산읍 섭지코지로 107
# 0     제주특별자치도 서귀포시 안덕면 한창로 243
# 0      제주특별자치도 서귀포시 중산간서로 97-1
# 0      제주특별자치도 제주시 구좌읍 동백로 458
# 0    제주특별자치도 제주시 한경면 일주서로 4641
#
# [2888 rows x 4 columns]

# %%
df4['keyword'] = '테마관광'

# %%
df4_col=["name","keyword","content","tags","address"]

# %%
df4=df4[df4_col]

# %%
df4
# Out:
#                name keyword  \
# 0             카멜리아힐    테마관광
# 1             카멜리아힐    테마관광
# 2             카멜리아힐    테마관광
# 3             카멜리아힐    테마관광
# 4             카멜리아힐    테마관광
# ..              ...     ...
# 0             지포뮤지엄    테마관광
# 0         피규어뮤지엄 제주    테마관광
# 0   한국야구명예전당(야구박물관)    테마관광
# 0              한울랜드    테마관광
# 0            해거름전망대    테마관광
#
#                                               content  \
# 0                                             기대가 됩니다
# 1                                           친구들과 우정여행
# 2                                      친구들과 함께한 겨울 데주
# 3     태교여행으로 갔던 가을의 제주도예요. 카멜리아 힐은 가을에 가도 아름다운것 같아요 ~
# 4   태풍으로 항공편도 변경하고 일정도 미뤄서 어렵사리 다녀온 제주! 가을빛 가득한 제주...
# ..                                                ...
# 0   태양의 정기를 정면으로 받을 수 있는 정동향 방향을 안내해 주는 안내판은 라이터 박...
# 0   제주마지막날 안개와 해무가 자욱한날 #피규어뮤지엄을 다녀왔어요 #베트맨 #스파이더맨...
# 0              야구가 같은 팀이 매어준 커플~~??ㅎ 요것이 한몫 했을 수도~~^^
# 0   아이와의 체험은 항상 좋은 기억을 남깁니다.\r\n여행에서의 체험은 무엇보다 훗날 ...
# 0                                           나홀로 자전거여행
#
#                                                 tags  \
# 0                              ['#여름', '#미식', '#친구']
# 1                   ['#제주컬러어택', '#카멜리아힐', '#한겨울에핀꽃']
# 2                              ['#겨울', '#제주', '#동백']
# 3                ['#제주가을', '#카멜리아힐', '#핑크뮬리', '#억새']
# 4              ['#제주여행', '#카멜리아힐', '#가을여행', '#가을제주']
# ..                                               ...
# 0                                                 []
# 0   ['#피규어뮤지엄을', '#베트맨', '#스파이더맨', '#피규어가', '#피규어들']
# 0                                                 []
# 0                                                 []
# 0                                                 []
#
#                        address
# 0          제주 서귀포시 안덕면 병악로 166
# 1          제주 서귀포시 안덕면 병악로 167
# 2          제주 서귀포시 안덕면 병악로 168
# 3          제주 서귀포시 안덕면 병악로 169
# 4          제주 서귀포시 안덕면 병악로 170
# ..                         ...
# 0   제주특별자치도 서귀포시 성산읍 섭지코지로 107
# 0     제주특별자치도 서귀포시 안덕면 한창로 243
# 0      제주특별자치도 서귀포시 중산간서로 97-1
# 0      제주특별자치도 제주시 구좌읍 동백로 458
# 0    제주특별자치도 제주시 한경면 일주서로 4641
#
# [2888 rows x 5 columns]

# %%
df4.to_csv('Theme.csv')

# %%
df5 = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\0_2 crow-visit jeju\\2회차-주소추가\\Walking.csv',index_col=0)
df5
# Out:
#             name                                            content  \
# 0          사려니숲길  #사려니숲. #붉은오름 4/26방문자입니다~친구와 제주공항가는길에 마지막코스로 들렀...
# 1          사려니숲길  작년11월 예술치유 영상 작업을 위해 방문한 사려니숲^^넘 좋았습니다.치유악기 칼림...
# 2          사려니숲길                                여름의 시작과 끝을 함께하는 산수국
# 3          사려니숲길  몇년만에 함께한 가족여행, 제주도 사려니숲길에서 귀여운 빼꼼 가족사진을 찍어보았어요...
# 4          사려니숲길  처음만나 제주의 가을 사려니숲길은 나를 행복의 숲으로 인도하여 주었습니다. 기대하지...
# ..           ...                                                ...
# 0   서광리 곶자왈생태탐방로                                      서광리 곶자왈 생태탐방로
# 0      제주올레 12코스  제주 올레길 12코스 수월봉 화산쇄설층\r\n정상의 지형은 완만한 편이지만 해안 절...
# 0      제주올레 13코스  올레길 13코스를 꼬닥꼬닥 걸으며... 이날은 클린올레로 올레길을 청소해서 마음도 ...
# 0    제주올레 15-B코스              #올레길 #15-b #담장을 #벗삼아 #태양을 #바라보는 #난제주개
# 0    제주올레 18-1코스                              용듬벙에서 바로보는 나발론절벽과 하늘길
#
#                                                  tags  \
# 0                                ['#걷기', '#친구', '#봄']
# 1                         ['##예술치유', '##칼림바', '##힐링']
# 2                           ['#여름', '#산수국', '#사려니숲길']
# 3               ['#가족여행', '#사랑해요', '#사려니숲길', '#제주여행']
# 4    ['##여행', '##제주행', '##제주여행', '##제주가을', '##사려니숲길']
# ..                                                ...
# 0                                                  []
# 0                                                  []
# 0                                                  []
# 0   ['#올레길', '#15', '#담장을', '#벗삼아', '#태양을', '#바라보는...
# 0   ['#알파캠프', '#올레캠프본점알파캠프', '#제주', '#제주도', '#제주올레...
#
#                         address
# 0   제주특별자치도 제주시 조천읍 교래리 산 137-1
# 1   제주특별자치도 제주시 조천읍 교래리 산 137-2
# 2   제주특별자치도 제주시 조천읍 교래리 산 137-3
# 3   제주특별자치도 제주시 조천읍 교래리 산 137-4
# 4   제주특별자치도 제주시 조천읍 교래리 산 137-5
# ..                          ...
# 0          제주특별자치도 서귀포시 안덕면 서광리
# 0   제주특별자치도 서귀포시 대정읍 신도리 2883-2
# 0    제주특별자치도 제주시 한경면 조수리 2137-2
# 0     제주특별자치도 제주시 한림읍 한림해안로 192
# 0      제주특별자치도 제주시 추자면 묵리 산 133
#
# [1025 rows x 4 columns]

# %%
df5['keyword'] = '도보'

# %%
df5_col=["name","keyword","content","tags","address"]

# %%
df5=df5[df5_col]

# %%
df5
# Out:
#             name keyword                                            content  \
# 0          사려니숲길      도보  #사려니숲. #붉은오름 4/26방문자입니다~친구와 제주공항가는길에 마지막코스로 들렀...
# 1          사려니숲길      도보  작년11월 예술치유 영상 작업을 위해 방문한 사려니숲^^넘 좋았습니다.치유악기 칼림...
# 2          사려니숲길      도보                                여름의 시작과 끝을 함께하는 산수국
# 3          사려니숲길      도보  몇년만에 함께한 가족여행, 제주도 사려니숲길에서 귀여운 빼꼼 가족사진을 찍어보았어요...
# 4          사려니숲길      도보  처음만나 제주의 가을 사려니숲길은 나를 행복의 숲으로 인도하여 주었습니다. 기대하지...
# ..           ...     ...                                                ...
# 0   서광리 곶자왈생태탐방로      도보                                      서광리 곶자왈 생태탐방로
# 0      제주올레 12코스      도보  제주 올레길 12코스 수월봉 화산쇄설층\r\n정상의 지형은 완만한 편이지만 해안 절...
# 0      제주올레 13코스      도보  올레길 13코스를 꼬닥꼬닥 걸으며... 이날은 클린올레로 올레길을 청소해서 마음도 ...
# 0    제주올레 15-B코스      도보              #올레길 #15-b #담장을 #벗삼아 #태양을 #바라보는 #난제주개
# 0    제주올레 18-1코스      도보                              용듬벙에서 바로보는 나발론절벽과 하늘길
#
#                                                  tags  \
# 0                                ['#걷기', '#친구', '#봄']
# 1                         ['##예술치유', '##칼림바', '##힐링']
# 2                           ['#여름', '#산수국', '#사려니숲길']
# 3               ['#가족여행', '#사랑해요', '#사려니숲길', '#제주여행']
# 4    ['##여행', '##제주행', '##제주여행', '##제주가을', '##사려니숲길']
# ..                                                ...
# 0                                                  []
# 0                                                  []
# 0                                                  []
# 0   ['#올레길', '#15', '#담장을', '#벗삼아', '#태양을', '#바라보는...
# 0   ['#알파캠프', '#올레캠프본점알파캠프', '#제주', '#제주도', '#제주올레...
#
#                         address
# 0   제주특별자치도 제주시 조천읍 교래리 산 137-1
# 1   제주특별자치도 제주시 조천읍 교래리 산 137-2
# 2   제주특별자치도 제주시 조천읍 교래리 산 137-3
# 3   제주특별자치도 제주시 조천읍 교래리 산 137-4
# 4   제주특별자치도 제주시 조천읍 교래리 산 137-5
# ..                          ...
# 0          제주특별자치도 서귀포시 안덕면 서광리
# 0   제주특별자치도 서귀포시 대정읍 신도리 2883-2
# 0    제주특별자치도 제주시 한경면 조수리 2137-2
# 0     제주특별자치도 제주시 한림읍 한림해안로 192
# 0      제주특별자치도 제주시 추자면 묵리 산 133
#
# [1025 rows x 5 columns]

# %%
df5.to_csv('Walking.csv')

# %%
pd.set_option('display.max_columns', 100)                       # 출력할 열의 최대개수
pd.set_option('display.max_colwidth', 20)                      # 출력할 열의 너비
pd.set_option('display.unicode.east_asian_width', True)

# %%
df6 = pd.concat([df1,df2,df3,df4,df5],ignore_index=True)
print(df6)
# Out:
#                                  name keyword  \
# 0      더럭초등학교(구, 더럭분교)....    문화
# 1      더럭초등학교(구, 더럭분교)....    문화
# 2      더럭초등학교(구, 더럭분교)....    문화
# 3      더럭초등학교(구, 더럭분교)....    문화
# 4      더럭초등학교(구, 더럭분교)....    문화
# ...                               ...     ...
# 14929  서광리 곶자왈생태탐방로......     도보
# 14930      제주올레 12코스               도보
# 14931      제주올레 13코스               도보
# 14932    제주올레 15-B코스               도보
# 14933    제주올레 18-1코스               도보
#
#                                  content                         tags  \
# 0      초등학교 동창들과 함께한 가을...   ['#제주컬러어택', '#더럭...
# 1      무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 2      무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 3      알록달록 너무 예쁜 초등학교에...   ['##5월엔제주', '##더...
# 4      #제주도 #더럭분교 #연화못 ...      ['#제주도', '#더럭분교'...
# ...                              ...                             ...
# 14929  서광리 곶자왈 생태탐방로......                      []
# 14930  제주 올레길 12코스 수월봉 ...                       []
# 14931  올레길 13코스를 꼬닥꼬닥 걸...                      []
# 14932  #올레길 #15-b #담장을 ...          ['#올레길', '#15', ...
# 14933  용듬벙에서 바로보는 나발론절벽...  ['#알파캠프', '#올레캠프...
#
#                                  address
# 0      제주특별자치도 제주시 애월읍 ...
# 1      제주특별자치도 제주시 애월읍 ...
# 2      제주특별자치도 제주시 애월읍 ...
# 3      제주특별자치도 제주시 애월읍 ...
# 4      제주특별자치도 제주시 애월읍 ...
# ...                                 ...
# 14929  제주특별자치도 서귀포시 안덕면...
# 14930  제주특별자치도 서귀포시 대정읍...
# 14931  제주특별자치도 제주시 한경면 ...
# 14932  제주특별자치도 제주시 한림읍 ...
# 14933  제주특별자치도 제주시 추자면 ...
#
# [14934 rows x 5 columns]

# %%
df6
# Out:
#                                  name keyword  \
# 0      더럭초등학교(구, 더럭분교)....    문화
# 1      더럭초등학교(구, 더럭분교)....    문화
# 2      더럭초등학교(구, 더럭분교)....    문화
# 3      더럭초등학교(구, 더럭분교)....    문화
# 4      더럭초등학교(구, 더럭분교)....    문화
# ...                               ...     ...
# 14929  서광리 곶자왈생태탐방로......     도보
# 14930      제주올레 12코스               도보
# 14931      제주올레 13코스               도보
# 14932    제주올레 15-B코스               도보
# 14933    제주올레 18-1코스               도보
#
#                                  content                         tags  \
# 0      초등학교 동창들과 함께한 가을...   ['#제주컬러어택', '#더럭...
# 1      무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 2      무지개빛 아름다운 더럭초등학교...  ['##더럭초등학교', '##...
# 3      알록달록 너무 예쁜 초등학교에...   ['##5월엔제주', '##더...
# 4      #제주도 #더럭분교 #연화못 ...      ['#제주도', '#더럭분교'...
# ...                              ...                             ...
# 14929  서광리 곶자왈 생태탐방로......                      []
# 14930  제주 올레길 12코스 수월봉 ...                       []
# 14931  올레길 13코스를 꼬닥꼬닥 걸...                      []
# 14932  #올레길 #15-b #담장을 ...          ['#올레길', '#15', ...
# 14933  용듬벙에서 바로보는 나발론절벽...  ['#알파캠프', '#올레캠프...
#
#                                  address
# 0      제주특별자치도 제주시 애월읍 ...
# 1      제주특별자치도 제주시 애월읍 ...
# 2      제주특별자치도 제주시 애월읍 ...
# 3      제주특별자치도 제주시 애월읍 ...
# 4      제주특별자치도 제주시 애월읍 ...
# ...                                 ...
# 14929  제주특별자치도 서귀포시 안덕면...
# 14930  제주특별자치도 서귀포시 대정읍...
# 14931  제주특별자치도 제주시 한경면 ...
# 14932  제주특별자치도 제주시 한림읍 ...
# 14933  제주특별자치도 제주시 추자면 ...
#
# [14934 rows x 5 columns]

# %%
pd.DataFrame(df6).to_csv('jeju_Tourism.csv', header = True, index = False, encoding='utf-8-sig')

# %%
jeju = pd.read_csv('C:\\Users\\ui\Documents\\GitHub\\project3\\3-0 전처리(제주)\\jeju_Tourism.csv',encoding='UTF-8', index_col=0)
jeju
# Out:
#                               keyword                            content  \
# name
# 더럭초등학교(구, 더럭분교)...    문화  초등학교 동창들과 함께한 가을...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  알록달록 너무 예쁜 초등학교에...
# 더럭초등학교(구, 더럭분교)...    문화  #제주도 #더럭분교 #연화못 ...
# ...                               ...                               ...
# 서광리 곶자왈생태탐방로...       도보  서광리 곶자왈 생태탐방로......
# 제주올레 12코스                  도보  제주 올레길 12코스 수월봉 ...
# 제주올레 13코스                  도보  올레길 13코스를 꼬닥꼬닥 걸...
# 제주올레 15-B코스                도보  #올레길 #15-b #담장을 ...
# 제주올레 18-1코스                도보  용듬벙에서 바로보는 나발론절벽...
#
#                                                       tags  \
# name
# 더럭초등학교(구, 더럭분교)...  ['#제주컬러어택', '#더럭...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##5월엔제주', '##더...
# 더럭초등학교(구, 더럭분교)...  ['#제주도', '#더럭분교'...
# ...                                                 ...
# 서광리 곶자왈생태탐방로...                      []
# 제주올레 12코스                                 []
# 제주올레 13코스                                 []
# 제주올레 15-B코스              ['#올레길', '#15', ...
# 제주올레 18-1코스              ['#알파캠프', '#올레캠프...
#
#                                                          address
# name
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...
# ...                                                         ...
# 서광리 곶자왈생태탐방로...     제주특별자치도 서귀포시 안덕면...
# 제주올레 12코스                제주특별자치도 서귀포시 대정읍...
# 제주올레 13코스                제주특별자치도 제주시 한경면 ...
# 제주올레 15-B코스              제주특별자치도 제주시 한림읍 ...
# 제주올레 18-1코스              제주특별자치도 제주시 추자면 ...
#
# [14934 rows x 4 columns]

# %%
# jeju['address1'] = jeju.address.str.split(' ').str[2]

#jeju['address'].str.split(" ", expand=True).tail(100)

# %%
#jeju['address'].str.extract('( \w*도 )|( \w*시 )|( \w*동 )|( \w*읍 )')

# %%
#jeju['address1']=jeju['address'].str.extract('( \w*읍 | \w*면| \w*동 )')

jeju['address1']=jeju['address'].str.extract('( \w*읍 | \w*면 )')
#읍련테그

# %%
jeju
# Out:
#                               keyword                            content  \
# name
# 더럭초등학교(구, 더럭분교)...    문화  초등학교 동창들과 함께한 가을...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  알록달록 너무 예쁜 초등학교에...
# 더럭초등학교(구, 더럭분교)...    문화  #제주도 #더럭분교 #연화못 ...
# ...                               ...                               ...
# 서광리 곶자왈생태탐방로...       도보  서광리 곶자왈 생태탐방로......
# 제주올레 12코스                  도보  제주 올레길 12코스 수월봉 ...
# 제주올레 13코스                  도보  올레길 13코스를 꼬닥꼬닥 걸...
# 제주올레 15-B코스                도보  #올레길 #15-b #담장을 ...
# 제주올레 18-1코스                도보  용듬벙에서 바로보는 나발론절벽...
#
#                                                       tags  \
# name
# 더럭초등학교(구, 더럭분교)...  ['#제주컬러어택', '#더럭...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##5월엔제주', '##더...
# 더럭초등학교(구, 더럭분교)...  ['#제주도', '#더럭분교'...
# ...                                                 ...
# 서광리 곶자왈생태탐방로...                      []
# 제주올레 12코스                                 []
# 제주올레 13코스                                 []
# 제주올레 15-B코스              ['#올레길', '#15', ...
# 제주올레 18-1코스              ['#알파캠프', '#올레캠프...
#
#                                                          address  address1
# name
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# ...                                                         ...        ...
# 서광리 곶자왈생태탐방로...     제주특별자치도 서귀포시 안덕면...   안덕면
# 제주올레 12코스                제주특별자치도 서귀포시 대정읍...   대정읍
# 제주올레 13코스                제주특별자치도 제주시 한경면 ...    한경면
# 제주올레 15-B코스              제주특별자치도 제주시 한림읍 ...    한림읍
# 제주올레 18-1코스              제주특별자치도 제주시 추자면 ...    추자면
#
# [14934 rows x 5 columns]

# %%
jeju_dop_row = jeju.dropna(subset=["address1"])  # 읍면테그 안달린 행 삭제

# %%
jeju_dop_row
# Out:
#                               keyword                            content  \
# name
# 더럭초등학교(구, 더럭분교)...    문화  초등학교 동창들과 함께한 가을...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  알록달록 너무 예쁜 초등학교에...
# 더럭초등학교(구, 더럭분교)...    문화  #제주도 #더럭분교 #연화못 ...
# ...                               ...                               ...
# 서광리 곶자왈생태탐방로...       도보  서광리 곶자왈 생태탐방로......
# 제주올레 12코스                  도보  제주 올레길 12코스 수월봉 ...
# 제주올레 13코스                  도보  올레길 13코스를 꼬닥꼬닥 걸...
# 제주올레 15-B코스                도보  #올레길 #15-b #담장을 ...
# 제주올레 18-1코스                도보  용듬벙에서 바로보는 나발론절벽...
#
#                                                       tags  \
# name
# 더럭초등학교(구, 더럭분교)...  ['#제주컬러어택', '#더럭...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##5월엔제주', '##더...
# 더럭초등학교(구, 더럭분교)...  ['#제주도', '#더럭분교'...
# ...                                                 ...
# 서광리 곶자왈생태탐방로...                      []
# 제주올레 12코스                                 []
# 제주올레 13코스                                 []
# 제주올레 15-B코스              ['#올레길', '#15', ...
# 제주올레 18-1코스              ['#알파캠프', '#올레캠프...
#
#                                                          address  address1
# name
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# ...                                                         ...        ...
# 서광리 곶자왈생태탐방로...     제주특별자치도 서귀포시 안덕면...   안덕면
# 제주올레 12코스                제주특별자치도 서귀포시 대정읍...   대정읍
# 제주올레 13코스                제주특별자치도 제주시 한경면 ...    한경면
# 제주올레 15-B코스              제주특별자치도 제주시 한림읍 ...    한림읍
# 제주올레 18-1코스              제주특별자치도 제주시 추자면 ...    추자면
#
# [11254 rows x 5 columns]

# %%
jejunull=jeju[jeju['address1'].isnull()] # null값 있는 행만 가져오기

# %%
jejunull
# Out:
#                    keyword                             content  \
# name
# 관덕정                문화  별은 다섯개 주고 싶지만 누워...
# 관덕정                문화  제주의 척박한 삶.. 거친음식...
# 관덕정                문화  #제주43 #제주43사건 #관...
# 관덕정                문화  1448년이래로 지금까지 제주...
# 관덕정                문화  #관덕정 제주목관아 수문장교대...
# ...                    ...                            ...
# 숫모르편백나무숲길    도보  제주생태공원에서 절물자연휴양림...
# 숫모르편백나무숲길    도보         #숫모르숲길,
# 올레여행자센터        도보                  NaN
# 올레여행자센터        도보                  NaN
# 삼의악트레킹코스      도보  #산과오름 #삼의악오름......
#
#                                             tags  \
# name
# 관덕정              ['#관덕정', '#관리자',...
# 관덕정              ['#제주4', '#하멜표류기...
# 관덕정              ['#제주43', '#제주43...
# 관덕정                               []
# 관덕정                      ['#관덕정']
# ...                                 ...
# 숫모르편백나무숲길  ['#숫모르편백나무숲길', '...
# 숫모르편백나무숲길      ['#숫모르숲길']
# 올레여행자센터                       []
# 올레여행자센터                       []
# 삼의악트레킹코스    ['#산과오름', '#삼의악오...
#
#                                               address address1
# name
# 관덕정              제주특별자치도 제주시 관덕로 ...       NaN
# 관덕정              제주특별자치도 제주시 관덕로 ...       NaN
# 관덕정              제주특별자치도 제주시 관덕로 ...       NaN
# 관덕정              제주특별자치도 제주시 관덕로 ...       NaN
# 관덕정              제주특별자치도 제주시 관덕로 ...       NaN
# ...                                              ...       ...
# 숫모르편백나무숲길  제주특별자치도 제주시 516로...         NaN
# 숫모르편백나무숲길  제주특별자치도 제주시 516로...         NaN
# 올레여행자센터      제주특별자치도 서귀포시 중정로...      NaN
# 올레여행자센터      제주특별자치도 서귀포시 중정로...      NaN
# 삼의악트레킹코스    제주특별자치도 제주시 아라동 ...       NaN
#
# [3680 rows x 5 columns]

# %%
jejunull['address1'].isnull().sum()
# Out:
# 3680

# %%
jejunull['address1'] = jejunull.address.str.split(' ').str[1]
# Out:
# C:\Users\ui\AppData\Local\Temp/ipykernel_14584/568662585.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jejunull['address1'] = jejunull.address.str.split(' ').str[1]

# %%
jejunull
# Out:
#                    keyword                             content  \
# name
# 관덕정                문화  별은 다섯개 주고 싶지만 누워...
# 관덕정                문화  제주의 척박한 삶.. 거친음식...
# 관덕정                문화  #제주43 #제주43사건 #관...
# 관덕정                문화  1448년이래로 지금까지 제주...
# 관덕정                문화  #관덕정 제주목관아 수문장교대...
# ...                    ...                            ...
# 숫모르편백나무숲길    도보  제주생태공원에서 절물자연휴양림...
# 숫모르편백나무숲길    도보         #숫모르숲길,
# 올레여행자센터        도보                  NaN
# 올레여행자센터        도보                  NaN
# 삼의악트레킹코스      도보  #산과오름 #삼의악오름......
#
#                                             tags  \
# name
# 관덕정              ['#관덕정', '#관리자',...
# 관덕정              ['#제주4', '#하멜표류기...
# 관덕정              ['#제주43', '#제주43...
# 관덕정                               []
# 관덕정                      ['#관덕정']
# ...                                 ...
# 숫모르편백나무숲길  ['#숫모르편백나무숲길', '...
# 숫모르편백나무숲길      ['#숫모르숲길']
# 올레여행자센터                       []
# 올레여행자센터                       []
# 삼의악트레킹코스    ['#산과오름', '#삼의악오...
#
#                                               address  address1
# name
# 관덕정              제주특별자치도 제주시 관덕로 ...     제주시
# 관덕정              제주특별자치도 제주시 관덕로 ...     제주시
# 관덕정              제주특별자치도 제주시 관덕로 ...     제주시
# 관덕정              제주특별자치도 제주시 관덕로 ...     제주시
# 관덕정              제주특별자치도 제주시 관덕로 ...     제주시
# ...                                              ...        ...
# 숫모르편백나무숲길  제주특별자치도 제주시 516로...       제주시
# 숫모르편백나무숲길  제주특별자치도 제주시 516로...       제주시
# 올레여행자센터      제주특별자치도 서귀포시 중정로...  서귀포시
# 올레여행자센터      제주특별자치도 서귀포시 중정로...  서귀포시
# 삼의악트레킹코스    제주특별자치도 제주시 아라동 ...     제주시
#
# [3680 rows x 5 columns]

# %%
# jeju와 jejunull을 합치기

# %%
jeju_teg=pd.concat([jeju_dop_row,jejunull])

# %%
jeju_teg
# Out:
#                               keyword                             content  \
# name
# 더럭초등학교(구, 더럭분교)...    문화  초등학교 동창들과 함께한 가을...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  무지개빛 아름다운 더럭초등학교...
# 더럭초등학교(구, 더럭분교)...    문화  알록달록 너무 예쁜 초등학교에...
# 더럭초등학교(구, 더럭분교)...    문화  #제주도 #더럭분교 #연화못 ...
# ...                               ...                               ...
# 숫모르편백나무숲길               도보  제주생태공원에서 절물자연휴양림...
# 숫모르편백나무숲길               도보         #숫모르숲길,
# 올레여행자센터                   도보                  NaN
# 올레여행자센터                   도보                  NaN
# 삼의악트레킹코스                 도보  #산과오름 #삼의악오름......
#
#                                                        tags  \
# name
# 더럭초등학교(구, 더럭분교)...  ['#제주컬러어택', '#더럭...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##더럭초등학교', '##...
# 더럭초등학교(구, 더럭분교)...  ['##5월엔제주', '##더...
# 더럭초등학교(구, 더럭분교)...  ['#제주도', '#더럭분교'...
# ...                                                 ...
# 숫모르편백나무숲길             ['#숫모르편백나무숲길', '...
# 숫모르편백나무숲길                 ['#숫모르숲길']
# 올레여행자센터                                  []
# 올레여행자센터                                  []
# 삼의악트레킹코스               ['#산과오름', '#삼의악오...
#
#                                                          address  address1
# name
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# 더럭초등학교(구, 더럭분교)...  제주특별자치도 제주시 애월읍 ...    애월읍
# ...                                                         ...        ...
# 숫모르편백나무숲길             제주특별자치도 제주시 516로...       제주시
# 숫모르편백나무숲길             제주특별자치도 제주시 516로...       제주시
# 올레여행자센터                 제주특별자치도 서귀포시 중정로...  서귀포시
# 올레여행자센터                 제주특별자치도 서귀포시 중정로...  서귀포시
# 삼의악트레킹코스               제주특별자치도 제주시 아라동 ...     제주시
#
# [14934 rows x 5 columns]

# %%
jeju_teg=jeju_teg.reset_index()

# %%
jeju_teg
# Out:
#                                  name keyword  \
# 0      더럭초등학교(구, 더럭분교)....    문화
# 1      더럭초등학교(구, 더럭분교)....    문화
# 2      더럭초등학교(구, 더럭분교)....    문화
# 3      더럭초등학교(구, 더럭분교)....    문화
# 4      더럭초등학교(구, 더럭분교)....    문화
# ...                               ...     ...
# 14929   숫모르편백나무숲길               도보
# 14930   숫모르편백나무숲길               도보
# 14931       올레여행자센터               도보
# 14932       올레여행자센터               도보
# 14933     삼의악트레킹코스               도보
#
#                                   content                          tags  \
# 0      초등학교 동창들과 함께한 가을...    ['#제주컬러어택', '#더럭...
# 1      무지개빛 아름다운 더럭초등학교...   ['##더럭초등학교', '##...
# 2      무지개빛 아름다운 더럭초등학교...   ['##더럭초등학교', '##...
# 3      알록달록 너무 예쁜 초등학교에...    ['##5월엔제주', '##더...
# 4      #제주도 #더럭분교 #연화못 ...       ['#제주도', '#더럭분교'...
# ...                              ...                              ...
# 14929  제주생태공원에서 절물자연휴양림...  ['#숫모르편백나무숲길', '...
# 14930         #숫모르숲길,                     ['#숫모르숲길']
# 14931                  NaN                                  []
# 14932                  NaN                                  []
# 14933  #산과오름 #삼의악오름......         ['#산과오름', '#삼의악오...
#
#                                  address  address1
# 0      제주특별자치도 제주시 애월읍 ...    애월읍
# 1      제주특별자치도 제주시 애월읍 ...    애월읍
# 2      제주특별자치도 제주시 애월읍 ...    애월읍
# 3      제주특별자치도 제주시 애월읍 ...    애월읍
# 4      제주특별자치도 제주시 애월읍 ...    애월읍
# ...                                 ...        ...
# 14929  제주특별자치도 제주시 516로...       제주시
# 14930  제주특별자치도 제주시 516로...       제주시
# 14931  제주특별자치도 서귀포시 중정로...  서귀포시
# 14932  제주특별자치도 서귀포시 중정로...  서귀포시
# 14933  제주특별자치도 제주시 아라동 ...     제주시
#
# [14934 rows x 6 columns]

# %%
pd.DataFrame(jeju_teg).to_csv('jeju_Tourism1.csv', header = True, encoding='utf-8-sig')
