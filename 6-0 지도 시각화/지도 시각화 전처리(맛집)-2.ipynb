# %%
import json
import pandas as pd
import numpy as np
import os

# %%
first= pd.read_csv('./좌표/first(4326).csv', encoding='UTF8')

# %%
first
# Out:
#      Column1   name                          address   Latitude   Longitude  \
# 0          0    설레임  제주특별자치도 제주시 애월읍 일주서로 5999-1, 2층  33.447134  126.305766
# 1      82608    해물섬    제주특별자치도 제주시 애월읍 애월로11길 19, 1층  33.465968  126.320629
# 2      82696  엄지흑돼지    제주특별자치도 제주시 애월읍 일주서로 6701, 1층  33.471880  126.368180
# 3      82828    비금향      제주특별자치도 제주시 애월읍 항몽로 133, 1층  33.472562  126.409329
# 4      82842  우미노식탁   제주특별자치도 제주시 애월읍 금성5길 42-24, 1층  33.447877  126.301242
# ..       ...    ...                              ...        ...         ...
# 995   611801   돈플라이     제주특별자치도 제주시 연동7길 20, 1층 (연동)  33.488228  126.490608
# 996   611803   노형집밥    제주특별자치도 제주시 다랑곶1길 9, 1층 (노형동)  33.487583  126.478266
# 997   611813   훈남횟집      제주특별자치도 제주시 조천읍 함덕13길 7, 1층  33.542080  126.667929
# 998   611973  카페콩03  제주특별자치도 제주시 고산동산5길 4, 1층 (이도이동)  33.495536  126.533799
# 999   612037  서자매김밥  제주특별자치도 제주시 원노형로 41-1, 1층 (노형동)  33.485029  126.485236
#
#       상태
# 0    정좌표
# 1    정좌표
# 2    정좌표
# 3    정좌표
# ...

# %%
second= pd.read_csv('./좌표/second(4326).csv', encoding='UTF8')

# %%
second
# Out:
#      Column1              name                            address   Latitude  \
# 0     612047             외도아나고   제주특별자치도 제주시 우정로4길 3-5, 1층 (외도일동)  33.491708
# 1     612049              정실국수     제주특별자치도 제주시 아연로 208, 1층 (오라이동)  33.467786
# 2     612053              미쁨김밥   제주특별자치도 제주시 삼봉로 113-2, 1층 (도련일동)  33.511359
# 3     612063              제주공간       제주특별자치도 제주시 노연로 34, 2층 (노형동)  33.485835
# 4     612071               시쟈덕      제주특별자치도 제주시 신광로8길 20, 1층 (연동)  33.487058
# ..       ...               ...                                ...        ...
# 995   700093      서사라모이세해장국직영점  제주특별자치도 제주시 서광로5길 37, 101호 (용담일동)  33.503417
# 996   700113               컨츄리           제주특별자치도 제주시 만덕로 23 (건입동)  33.514522
# 997   700121       금커피별빙수제주일도점         제주특별자치도 제주시 동광로 112 (일도이동)  33.506245
# 998   700123         저팔계깡통숯불구이        제주특별자치도 제주시 조천읍 신북로 523, 1층  33.542035
# 999   700809  불타는여고24시떡볶이중앙여고점    제주특별자치도 제주시 구남동5길 14, 1층 (이도이동)  33.489918
#
#       Longitude   상태
# 0    126.430183  정좌표
# ...

# %%
third= pd.read_csv('./좌표/third(4326).csv', encoding='UTF8')

# %%
third
# Out:
#      Column1           name                                  address  \
# 0     700857           서프로와       제주특별자치도 제주시 테우해안로 132, 지하1층 (이호일동)
# 1     701426           오캄커피  제주특별자치도 제주시 광양11길 16, 101호 (이도이동, 희봉빌라)
# 2     701470           황소곱창                 제주특별자치도 제주시 삼무로3길 8 (연동)
# 3     701510           삼아갈비            제주특별자치도 제주시 서광로21길 4-1 (삼도일동)
# 4     701512      최가네옛날손두부집             제주특별자치도 제주시 사장2길 36, 1층 (연동)
# ..       ...            ...                                      ...
# 995   975256       동동차이나남원점     제주특별자치도 서귀포시 남원읍 태위로689번길 7, 1층 104호
# 996   975262             꼬란            제주특별자치도 서귀포시 동문동로 2, 1층 (서귀동)
# 997   975396  비비큐올리브치킨제주동홍점        제주특별자치도 서귀포시 동홍동로26번길 6, 1층 (동홍동)
# 998   975410           오또도넛               제주특별자치도 서귀포시 중문상로 87 (중문동)
# 999   976096         흑돼지스토리           제주특별자치도 서귀포시 남원읍 태위로 94-37, 1층
#
#      Latitude  Longitude   상태
# 0    33.49776   126.4480  정좌표
# 1    33.49954   126.5318  정좌표
# 2    33.49052   126.4951  정좌표
# ...

# %%
forth= pd.read_csv('./좌표/forth(4326).csv', encoding='UTF8')

# %%
forth
# Out:
#      Column1          name                                            address  \
# 0     976530       네네치킨남원점  제주특별자치도 서귀포시 남원읍 남원체육관로 342, 상가동 1층 103호 (서귀포남...
# 1     976602      시카고피자성산점                         제주특별자치도 서귀포시 성산읍 일주동로 4232
# 2     976666           푸른솔                            제주특별자치도 서귀포시 남원읍 남한로 11
# 3     976674       용머리해물정식                         제주특별자치도 서귀포시 성산읍 환해장성로 467
# 4     976694         흑돈플러스                         제주특별자치도 서귀포시 대포로 132 (대포동)
# ..       ...           ...                                                ...
# 995  1468849        금능포구횟집                            제주특별자치도 제주시 한림읍 금능9길 27
# 996  1468973  할리스커피협재해수욕장점                      제주특별자치도 제주시 한림읍 한림로 330, 1~2층
# 997  1469137      한치앞도모를바다                         제주특별자치도 제주시 한림읍 협재6길 9, 1층
# 998  1469363           드링콩                            제주특별자치도 제주시 한림읍 한림로 158
# 999  1469441           샤브왕                          제주특별자치도 제주시 한림읍 일주서로 5167
#
#      Latitude  Longitude   상태
# ...

# %%
fifth= pd.read_csv('./좌표/fifth(4326).csv', encoding='UTF8')

# %%
fifth
# Out:
#      Column1          name                               address  Latitude  \
# 0    1469461      낮에정식밤에갈비              제주특별자치도 제주시 한림읍 한림상로 158  33.41230
# 1    1469493      생고기통김치찌개              제주특별자치도 제주시 한림읍 한림로5길 11  33.41353
# 2    1469539         다람쥐식탁           제주특별자치도 제주시 한림읍 명월성로 10, 1층  33.40780
# 3    1469751        다시정한림점          제주특별자치도 제주시 한림읍 한림상로 231, 1층  33.41887
# 4    1469763       피자베이한림점          제주특별자치도 제주시 한림읍 한림중앙로 27, 1층  33.41218
# ..       ...           ...                                   ...       ...
# 995  1615557      아라주는엄마치킨        제주특별자치도 제주시 산천단동3길 13-2 (아라일동)  33.44905
# 996  1615576        빨간집연동점              제주특별자치도 제주시 신대로 126 (연동)  33.48617
# 997  1615588           도갈비  제주특별자치도 제주시 한라대학로 85 (노형동,프라임빌 102호)  33.47652
# 998  1615728       우도동굴도남점              제주특별자치도 제주시 도남로 6 (삼도일동)  33.49949
# 999  1615730  호야치킨앤닭강정 노형점            제주특별자치도 제주시 정존11길 22 (노형동)  33.48576
#
#      Longitude   상태
# 0     126.2689  정좌표
# 1     126.2609  정좌표
# ...

# %%
sixth= pd.read_csv('./좌표/sixth(4326).csv', encoding='UTF8')

# %%
sixth
# Out:
#      Column1        name                         address   Latitude  \
# 0    1615731    난타오천뜨란채점      제주특별자치도 제주시 정존11길 39 (노형동)  33.486633
# 1    1615738        보해국수       제주특별자치도 제주시 오복4길 6 (이도이동)  33.495540
# 2    1615741      두남자이야기         제주특별자치도 제주시 삼무로 77 (연동)  33.490025
# 3    1615853          도리   제주특별자치도 제주시 도공로 48, 2층 (도두일동)  33.502268
# 4    1615897          평산     제주특별자치도 제주시 정든로2길 14 (이도이동)  33.497534
# ..       ...         ...                             ...        ...
# 995  1718888  씨유제주동문로터리점    제주특별자치도 제주시 동문로 8, 1층 (일도일동)  33.512900
# 996  1718898       가든샐러드  제주특별자치도 제주시 남광로 123, 1층 (일도이동)  33.498357
# 997  1718900      호떡당아라점   제주특별자치도 제주시 구산로 70, 1층 (아라일동)  33.485053
# 998  1718922        루루비건    제주특별자치도 제주시 연북로 28, 2층 (노형동)  33.481661
# 999  1718938     먹쿠슬낭노형점  제주특별자치도 제주시 정존15길 33, 1층 (노형동)  33.487524
#
#       Longitude   상태
# 0    126.474028  정좌표
# 1    126.536322  정좌표
# 2    126.495053  정좌표
# 3    126.466377  정좌표
# 4    126.538639  정좌표
# ...

# %%
seventh= pd.read_csv('./좌표/seventh(4326).csv', encoding='UTF8')

# %%
seventh
# Out:
#      Column1          name                             address  Latitude  \
# 0    1718954     무우수커피로스터스          제주특별자치도 제주시 조천읍 조천11길 22-2  33.53780
# 1    1719034      더벤티제주노형점         제주특별자치도 제주시 월랑로 5, 1층 (노형동)  33.48669
# 2    1719062           베이크           제주특별자치도 제주시 우정로 60 (외도일동)  33.48752
# 3    1719085       노형로22번가        제주특별자치도 제주시 노형로 22, 2층 (해안동)  33.46162
# 4    1719087  앤티앤스프레즐제주시청점      제주특별자치도 제주시 중앙로 222, 1층 (이도이동)  33.49975
# ..       ...           ...                                 ...       ...
# 995  1897322    씨유제주회수사거리점        제주특별자치도 서귀포시 1100로 178 (회수동)  33.26304
# 996  1897383         남극노인성         제주특별자치도 서귀포시 하신상로 216 (상효동)  33.27583
# 997  1897395       피자헛서귀포점    제주특별자치도 서귀포시 일주동로 8590, 1층 (동홍동)  33.25497
# 998  1897444     씨유서귀포법환길점  제주특별자치도 서귀포시 이어도로 1041-1, 1층 (서호동)  33.24504
# 999  1897454        벙커 하우스  제주특별자치도 서귀포시 막숙포로41번길 66, 1층 (법환동)  33.24046
#
#      Longitude   상태
# 0     126.6384  정좌표
# 1     126.4783  정좌표
# 2     126.4307  정좌표
# ...

# %%
eighth= pd.read_csv('./좌표/eighth(4326).csv', encoding='UTF8')

# %%
eighth
# Out:
#      Column1          name                                           address  \
# 0    1897688      제주김만복성산점            제주특별자치도 서귀포시 성산읍 성산등용로17번길 55, 1층 108호
# 1    1900504       미르봉봉키즈빌                    제주특별자치도 서귀포시 서호중로 86, 2층 (서호동)
# 2    1900508     빽다방서귀포시청점                    제주특별자치도 서귀포시 중앙로 109, 1층 (서홍동)
# 3    1900536        랍다:즐겁다                  제주특별자치도 서귀포시 태평로 34-17, 2층 (호근동)
# 4    1900547        제이아일랜드                     제주특별자치도 서귀포시 성산읍 환해장성로 69, 1층
# ..       ...           ...                                               ...
# 306  1935011  지에스25서귀비석거리점                      제주특별자치도 서귀포시 일주동로 8541 (동홍동)
# 307  1935021     하은이네손만두김밥                   제주특별자치도 서귀포시 천제연로 223, 1층 (중문동)
# 308  1935055      씨유서귀라메르점             제주특별자치도 서귀포시 중정로5번길 15, 1층 101호 (서귀동)
# 309  1935064   지에스25서귀파인힐점  제주특별자치도 서귀포시 홍중로 119-2, 602동 204호 (서홍동, 서강파인힐6차)
# 310  1935071        한옥마루카페               제주특별자치도 서귀포시 성산읍 한도로 269-23, 부속동 1층
#
#      Latitude  Longitude   상태
# ...

# %%
result1 = pd.concat([first,second,third,forth,fifth,sixth,seventh,eighth])

# %%
result1
# Out:
#      Column1          name                                           address  \
# 0          0           설레임                   제주특별자치도 제주시 애월읍 일주서로 5999-1, 2층
# 1      82608           해물섬                     제주특별자치도 제주시 애월읍 애월로11길 19, 1층
# 2      82696         엄지흑돼지                     제주특별자치도 제주시 애월읍 일주서로 6701, 1층
# 3      82828           비금향                       제주특별자치도 제주시 애월읍 항몽로 133, 1층
# 4      82842         우미노식탁                    제주특별자치도 제주시 애월읍 금성5길 42-24, 1층
# ..       ...           ...                                               ...
# 306  1935011  지에스25서귀비석거리점                      제주특별자치도 서귀포시 일주동로 8541 (동홍동)
# 307  1935021     하은이네손만두김밥                   제주특별자치도 서귀포시 천제연로 223, 1층 (중문동)
# 308  1935055      씨유서귀라메르점             제주특별자치도 서귀포시 중정로5번길 15, 1층 101호 (서귀동)
# 309  1935064   지에스25서귀파인힐점  제주특별자치도 서귀포시 홍중로 119-2, 602동 204호 (서홍동, 서강파인힐6차)
# 310  1935071        한옥마루카페               제주특별자치도 서귀포시 성산읍 한도로 269-23, 부속동 1층
#
#       Latitude   Longitude   상태
# ...

# %%
result1 .reset_index(drop=True)
# Out:
#       Column1          name                                           address  \
# 0           0           설레임                   제주특별자치도 제주시 애월읍 일주서로 5999-1, 2층
# 1       82608           해물섬                     제주특별자치도 제주시 애월읍 애월로11길 19, 1층
# 2       82696         엄지흑돼지                     제주특별자치도 제주시 애월읍 일주서로 6701, 1층
# 3       82828           비금향                       제주특별자치도 제주시 애월읍 항몽로 133, 1층
# 4       82842         우미노식탁                    제주특별자치도 제주시 애월읍 금성5길 42-24, 1층
# ...       ...           ...                                               ...
# 7306  1935011  지에스25서귀비석거리점                      제주특별자치도 서귀포시 일주동로 8541 (동홍동)
# 7307  1935021     하은이네손만두김밥                   제주특별자치도 서귀포시 천제연로 223, 1층 (중문동)
# 7308  1935055      씨유서귀라메르점             제주특별자치도 서귀포시 중정로5번길 15, 1층 101호 (서귀동)
# 7309  1935064   지에스25서귀파인힐점  제주특별자치도 서귀포시 홍중로 119-2, 602동 204호 (서홍동, 서강파인힐6차)
# 7310  1935071        한옥마루카페               제주특별자치도 서귀포시 성산읍 한도로 269-23, 부속동 1층
#
#        Latitude   Longitude   상태
# ...

# %%
result1 .to_csv('result1.csv',mode="w",encoding='utf-8')
