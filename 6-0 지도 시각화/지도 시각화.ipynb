# %%
import json
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv('./d.csv',encoding='UTF8', index_col=0)

# %%
data
# Out:
#                   name keyword  \
# 0      더럭초등학교(구, 더럭분교)      문화
# 1      더럭초등학교(구, 더럭분교)      문화
# 2      더럭초등학교(구, 더럭분교)      문화
# 3      더럭초등학교(구, 더럭분교)      문화
# 4      더럭초등학교(구, 더럭분교)      문화
# ...                ...     ...
# 13063    누웨마루거리(구 바오젠)      도보
# 13064    누웨마루거리(구 바오젠)      도보
# 13065        숫모르편백나무숲길      도보
# 13066        숫모르편백나무숲길      도보
# 13067         삼의악트레킹코스      도보
#
#                                                  content  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                       무지개빛 아름다운 더럭초등학교
# 2                                       무지개빛 아름다운 더럭초등학교
# 3              알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4      #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                                                  ...
# 13063                              #바오젠거리 #신라스테이제주 #돌하루방
# 13064                        중국인들이 많이 찾는다는 제주시 연동 바오젠거리.
# 13065  제주생태공원에서 절물자연휴양림으로 이어지는 걷기 좋은 길이다.  #숫모르편백나무숲길...
# ...

# %%
point= pd.read_csv('./point.csv', encoding='cp949')

# %%
point
# Out:
#       No  Column1             name keyword  \
# 0      1        0  더럭초등학교(구, 더럭분교)      문화
# 1      2      101             방주교회      문화
# 2      3      297       김영갑갤러리 두모악      문화
# 3      4      391      너븐숭이 4.3기념관      문화
# 4      5      431            제주민속촌      문화
# ..   ...      ...              ...     ...
# 321  322    14926             볼레낭길      도보
# 322  323    14930        제주올레 12코스      도보
# 323  324    14931        제주올레 13코스      도보
# 324  325    14932      제주올레 15-B코스      도보
# 325  326    14933      제주올레 18-1코스      도보
#
#                                                content  \
# 0                    초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                            좋아요좋아요좋아요
# 2        오렌지빛 가득한 김영갑갤러리두모악. 그는 가도 그의 영혼은 생기있게 빛나고 있다.
# 3    운영시간이 6시까진데 미리 알아보지 못하고 5시 58분에 도착했습니다 아쉽게도 발걸...
# 4    친동생 군입대와 가족여행 겸 다녀온 제주여행입니다. 입대로 인한 슬픔과 가족여행이라...
# ..                                                 ...
# ...

# %%
point=point.drop(['No'],axis=1)

# %%
point
# Out:
#      Column1             name keyword  \
# 0          0  더럭초등학교(구, 더럭분교)      문화
# 1        101             방주교회      문화
# 2        297       김영갑갤러리 두모악      문화
# 3        391      너븐숭이 4.3기념관      문화
# 4        431            제주민속촌      문화
# ..       ...              ...     ...
# 321    14926             볼레낭길      도보
# 322    14930        제주올레 12코스      도보
# 323    14931        제주올레 13코스      도보
# 324    14932      제주올레 15-B코스      도보
# 325    14933      제주올레 18-1코스      도보
#
#                                                content  \
# 0                    초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                            좋아요좋아요좋아요
# 2        오렌지빛 가득한 김영갑갤러리두모악. 그는 가도 그의 영혼은 생기있게 빛나고 있다.
# 3    운영시간이 6시까진데 미리 알아보지 못하고 5시 58분에 도착했습니다 아쉽게도 발걸...
# 4    친동생 군입대와 가족여행 겸 다녀온 제주여행입니다. 입대로 인한 슬픔과 가족여행이라...
# ..                                                 ...
# 321                     #볼레낭길 #박수기정길 #박수기정 #올레9코스 #기정길
# ...

# %%
data.merge(point, on='address', how='left')
# Out:
#                 name_x keyword_x  \
# 0      더럭초등학교(구, 더럭분교)        문화
# 1      더럭초등학교(구, 더럭분교)        문화
# 2      더럭초등학교(구, 더럭분교)        문화
# 3      더럭초등학교(구, 더럭분교)        문화
# 4      더럭초등학교(구, 더럭분교)        문화
# ...                ...       ...
# 13561    누웨마루거리(구 바오젠)        도보
# 13562    누웨마루거리(구 바오젠)        도보
# 13563        숫모르편백나무숲길        도보
# 13564        숫모르편백나무숲길        도보
# 13565         삼의악트레킹코스        도보
#
#                                                content_x  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                       무지개빛 아름다운 더럭초등학교
# 2                                       무지개빛 아름다운 더럭초등학교
# 3              알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4      #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                                                  ...
# 13561                              #바오젠거리 #신라스테이제주 #돌하루방
# 13562                        중국인들이 많이 찾는다는 제주시 연동 바오젠거리.
# ...
