# %%
conda install geopandas
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# Note: you may need to restart the kernel to use updated packages.
# Building graph of deps:   0%|          | 0/348 [00:00<?, ?it/s]
# Examining nose:   0%|          | 0/348 [00:00<?, ?it/s]
# Examining sphinxcontrib-jsmath:   0%|          | 1/348 [00:00<00:36,  9.55it/s]
# Examining sphinxcontrib-jsmath:   1%|          | 2/348 [00:00<00:18, 19.10it/s]
# Examining chardet:   1%|          | 2/348 [00:00<00:18, 19.10it/s]
# Examining wincertstore:   1%|          | 3/348 [00:00<00:18, 19.10it/s]
# Examining brotli:   1%|1         | 4/348 [00:00<00:18, 19.10it/s]
# Examining flake8:   1%|1         | 5/348 [00:00<00:17, 19.10it/s]
# Examining ipykernel:   2%|1         | 6/348 [00:00<00:17, 19.10it/s]
# Examining ipykernel:   2%|2         | 7/348 [00:00<00:31, 10.68it/s]
# Examining xmltodict:   2%|2         | 7/348 [00:02<00:31, 10.68it/s]
# Examining jupyter_server:   2%|2         | 8/348 [00:02<00:31, 10.68it/s]
# Examining jupyter_server:   3%|2         | 9/348 [00:02<01:47,  3.15it/s]
# Examining statsmodels:   3%|2         | 9/348 [00:02<01:47,  3.15it/s]
# Examining statsmodels:   3%|2         | 10/348 [00:02<01:34,  3.58it/s]
# Examining pywin32:   3%|2         | 10/348 [00:03<01:34,  3.58it/s]
# Examining pywin32:   3%|3         | 11/348 [00:03<02:40,  2.10it/s]
# Examining babel:   3%|3         | 11/348 [00:03<02:40,  2.10it/s]
# Examining jupyter:   3%|3         | 12/348 [00:03<02:40,  2.10it/s]
# Examining numexpr:   4%|3         | 13/348 [00:05<02:39,  2.10it/s]
# Examining numexpr:   4%|4         | 14/348 [00:05<02:41,  2.06it/s]
# Examining libtiff:   4%|4         | 14/348 [00:06<02:41,  2.06it/s]
# Examining libtiff:   4%|4         | 15/348 [00:06<03:19,  1.67it/s]
# Examining backports.tempfile:   4%|4         | 15/348 [00:06<03:19,  1.67it/s]
# Examining python-jsonrpc-server:   5%|4         | 16/348 [00:06<03:18,  1.67it/s]
# Examining _ipyw_jlab_nb_ext_conf:   5%|4         | 17/348 [00:06<03:18,  1.67it/s]
# Examining libiconv:   5%|5         | 18/348 [00:06<03:17,  1.67it/s]
# Examining libiconv:   5%|5         | 19/348 [00:06<01:48,  3.03it/s]
# Examining more-itertools:   5%|5         | 19/348 [00:06<01:48,  3.03it/s]
# Examining cloudpickle:   6%|5         | 20/348 [00:06<01:48,  3.03it/s]
# Examining openpyxl:   6%|6         | 21/348 [00:06<01:48,  3.03it/s]
# Examining openpyxl:   6%|6         | 22/348 [00:06<01:18,  4.16it/s]
# Examining typing_extensions:   6%|6         | 22/348 [00:06<01:18,  4.16it/s]
# Examining typing_extensions:   7%|6         | 23/348 [00:06<01:14,  4.36it/s]
# Examining clyent:   7%|6         | 23/348 [00:06<01:14,  4.36it/s]
# Examining m2w64-libwinpthread-git:   7%|6         | 24/348 [00:07<01:14,  4.36it/s]
# Examining m2w64-libwinpthread-git:   7%|7         | 25/348 [00:07<01:00,  5.33it/s]
# Examining backcall:   7%|7         | 25/348 [00:07<01:00,  5.33it/s]
# Examining et_xmlfile:   7%|7         | 26/348 [00:07<01:00,  5.33it/s]
# Examining cffi:   8%|7         | 27/348 [00:07<01:00,  5.33it/s]
# Examining sphinxcontrib-websupport:   8%|8         | 28/348 [00:07<01:00,  5.33it/s]
# Examining sphinxcontrib-websupport:   8%|8         | 29/348 [00:07<00:39,  8.02it/s]
# Examining jupyterlab_widgets:   8%|8         | 29/348 [00:07<00:39,  8.02it/s]
# Examining tornado:   9%|8         | 30/348 [00:07<00:39,  8.02it/s]
# Examining snowballstemmer:   9%|8         | 31/348 [00:07<00:39,  8.02it/s]
# Examining snowballstemmer:   9%|9         | 32/348 [00:07<00:32,  9.77it/s]
# Examining paramiko:   9%|9         | 32/348 [00:07<00:32,  9.77it/s]
# Examining @/win-64::__win==0=0:   9%|9         | 33/348 [00:07<00:32,  9.77it/s]
# Examining @/win-64::__win==0=0:  10%|9         | 34/348 [00:07<00:37,  8.42it/s]
# Examining openssl:  10%|9         | 34/348 [00:07<00:37,  8.42it/s]
# Examining ipywidgets:  10%|#         | 35/348 [00:07<00:37,  8.42it/s]
# Examining astropy:  10%|#         | 36/348 [00:09<00:37,  8.42it/s]
# Examining astropy:  11%|#         | 37/348 [00:09<01:30,  3.45it/s]
# Examining jpeg:  11%|#         | 37/348 [00:14<01:30,  3.45it/s]
# Examining jpeg:  11%|#         | 38/348 [00:14<04:25,  1.17it/s]
# Examining notebook:  11%|#         | 38/348 [00:14<04:25,  1.17it/s]
# Examining sphinx:  11%|#1        | 39/348 [00:18<04:24,  1.17it/s]
# Examining sphinx:  11%|#1        | 40/348 [00:18<06:21,  1.24s/it]
# Examining beautifulsoup4:  11%|#1        | 40/348 [00:20<06:21,  1.24s/it]
# Examining beautifulsoup4:  12%|#1        | 41/348 [00:20<06:39,  1.30s/it]
# Examining conda-package-handling:  12%|#1        | 41/348 [00:20<06:39,  1.30s/it]
# Examining conda-package-handling:  12%|#2        | 42/348 [00:20<05:27,  1.07s/it]
# Examining jupyterlab_pygments:  12%|#2        | 42/348 [00:20<05:27,  1.07s/it]
# Examining jupyterlab_pygments:  12%|#2        | 43/348 [00:20<04:33,  1.11it/s]
# Examining atomicwrites:  12%|#2        | 43/348 [00:20<04:33,  1.11it/s]
# Examining sip:  13%|#2        | 44/348 [00:20<04:32,  1.11it/s]
# Examining backports.functools_lru_cache:  13%|#2        | 45/348 [00:20<04:31,  1.11it/s]
# Examining backports.functools_lru_cache:  13%|#3        | 46/348 [00:20<02:26,  2.06it/s]
# Examining intervaltree:  13%|#3        | 46/348 [00:20<02:26,  2.06it/s]
# Examining mccabe:  14%|#3        | 47/348 [00:20<02:25,  2.06it/s]
# Examining mccabe:  14%|#3        | 48/348 [00:20<01:46,  2.81it/s]
# Examining zstd:  14%|#3        | 48/348 [00:20<01:46,  2.81it/s]
# Examining mkl_fft:  14%|#4        | 49/348 [00:20<01:46,  2.81it/s]
# Examining pyopenssl:  14%|#4        | 50/348 [00:22<01:46,  2.81it/s]
# Examining pyopenssl:  15%|#4        | 51/348 [00:22<02:03,  2.40it/s]
# Examining sortedcontainers:  15%|#4        | 51/348 [00:22<02:03,  2.40it/s]
elock ujson backcall et_xmlfile menuinst backports.shutil_get_terminal_size asgiref cffi regex sphinxcontrib-websupport sympy argon2-cffi toml conda-repo-cli pandas jupyterlab_widgets rtree xlrd tornado snowballstemmer pep8 importlib_metadata pyyaml nest-asyncio paramiko jupyterlab_server asn1crypto sphinxcontrib-htmlhelp ipywidgets contextlib2 pyparsing numpy-base pillow astropy dask notebook sphinx qtpy qdarkstyle comtypes jdcal cryptography lxml conda win_unicode_console olefile lazy-object-proxy markupsafe beautifulsoup4 conda-package-handling psycopg2 jupyterlab_pygments three-merge traitlets conda-build alabaster zope.interface cython atomicwrites future ipython sip backports.functools_lru_cache pyflakes docutils intervaltree colorama mccabe entrypoints cytoolz numpy mkl_random py-lief pycparser sphinxcontrib-devhelp mkl_fft xlsxwriter pandocfilters pyopenssl pyzmq parso pywinpty defusedxml scikit-learn sortedcontainers backports boto packaging console_shortcut python-language-server urllib3 mpmath pytz nbclassic prompt_toolkit mistune fsspec partd gevent decorator pywavelets anyio bottleneck backports.weakref pytables locket zipp python-dateutil nbconvert black sphinxcontrib jedi xlwt path nbclient anaconda toolz get_terminal_size numpydoc simplegeneric matplotlib-base zope pysocks idna tifffile zope.event fastcache pycodestyle pickleshare qtconsole bcrypt pluggy sphinxcontrib-applehelp anaconda-navigator pexpect conda-content-trust nbformat greenlet jupyter_console navigator-updater llvmlite pip pyrsistent requests jupyter_core typed-ast unicodecsv pytest win_inet_pton json5 joblib wcwidth flask pycosat jupyter-packaging pyreadline imageio watchdog conda-token autopep8 bleach click psutil mock path.py ipython_genutils pyls-spyder sphinxcontrib-serializinghtml jinja2 pydocstyle scipy zict mkl-service scikit-image glob2 iniconfig threadpoolctl astroid sqlparse soupsieve jupyter_client sphinxcontrib-qthelp anaconda-project seaborn pynacl sortedcollections pathlib2 widgetsnbextension powershell_shortcut matplotlib sniffio pyerfa pywin32-ctypes send2trash heapdict setuptools geopandas qtawesome:   0%|          | 1/348 [00:00<00:16, 20.83it/s]
# Examining conflict for keyring h5py nose mypy_extensions networkx django jupyterlab itsdangerous rope sphinxcontrib-jsmath tblib chardet certifi brotlipy pyodbc html5lib pkginfo wincertstore webencodings singledispatch bokeh flake8 pathspec ipykernel werkzeug async_generator attrs sqlalchemy diff-match-patch distributed xmltodict pycurl libpq pyqt libarchive terminado importlib-metadata jsonschema conda-verify argh imagesize patsy wrapt jupyter_server imagecodecs kiwisolver nltk ply bkcharts tqdm textdistance anaconda-client wheel dask-core statsmodels testpath python curl ptyprocess py pywin32 python-libarchive-c ruamel_yaml babel jupyter numexpr xlwings spyder yapf cycler pylint bitarray pygments backports.tempfile python-jsonrpc-server multipledispatch appdirs prompt-toolkit numba six _ipyw_jlab_nb_ext_conf msgpack-python isort spyder-kernels more-itertools cloudpickle prometheus_client openpyxl typing_extensions libcurl clyent filelock ujson backcall et_xmlfile menuinst backports.shutil_get_terminal_size asgiref cffi regex sphinxcontrib-websupport sympy argon2-cffi toml conda-repo-cli pandas jupyterlab_widgets rtree xlrd tornado snowballstemmer pep8 importlib_metadata pyyaml nest-asyncio paramiko jupyterlab_server asn1crypto openssl ipywidgets contextlib2 pyparsing numpy-base pillow astropy dask notebook sphinx qtpy qdarkstyle comtypes jdcal cryptography lxml conda win_unicode_console olefile lazy-object-proxy markupsafe beautifulsoup4 conda-package-handling psycopg2 jupyterlab_pygments three-merge traitlets conda-build alabaster zope.interface cython atomicwrites future ipython sip backports.functools_lru_cache pyflakes docutils intervaltree colorama mccabe entrypoints cytoolz numpy mkl_random py-lief pycparser sphinxcontrib-devhelp mkl_fft xlsxwriter pandocfilters pyopenssl pyzmq parso pywinpty defusedxml scikit-learn sortedcontainers backports boto packaging console_shortcut python-language-server urllib3 mpmath pytz nbclassic prompt_toolkit mistune fsspec partd gevent decorator pywavelets anyio bottleneck backports.weakref pytables locket zipp python-dateutil nbconvert black sphinxcontrib jedi xlwt qt path nbclient anaconda toolz numpydoc simplegeneric matplotlib-base zope pysocks idna tifffile zope.event fastcache pycodestyle pickleshare qtconsole bcrypt pluggy sphinxcontrib-applehelp anaconda-navigator pexpect conda-content-trust nbformat greenlet jupyter_console navigator-updater llvmlite pip pyrsistent requests jupyter_core typed-ast unicodecsv pytest win_inet_pton json5 joblib wcwidth flask pycosat jupyter-packaging pyreadline imageio watchdog conda-token autopep8 bleach click psutil mock path.py ipython_genutils pyls-spyder sphinxcontrib-serializinghtml jinja2 pydocstyle scipy libssh2 mkl-service zict scikit-image iniconfig krb5 glob2 threadpoolctl astroid sqlparse soupsieve jupyter_client sphinxcontrib-qthelp anaconda-project seaborn pynacl sortedcollections pathlib2 widgetsnbextension sphinxcontrib-htmlhelp powershell_shortcut matplotlib sniffio pyerfa pywin32-ctypes send2trash heapdict setuptools geopandas qtawesome:   1%|          | 2/348 [00:22<1:05:29, 11.36s/it]
# Examining conflict for keyring h5py nose mypy_extensions networkx django jupyterlab itsdangerous rope sphinxcontrib-jsmath tblib chardet certifi brotlipy pyodbc html5lib pkginfo wincertstore webencodings singledispatch bokeh flake8 pathspec ipykernel werkzeug async_generator attrs sqlalchemy diff-match-patch distributed xmltodict pycurl libpq pyqt libarchive terminado importlib-metadata jsonschema conda-verify argh imagesize patsy wrapt jupyter_server imagecodecs kiwisolver nltk ply bkcharts tqdm textdistance anaconda-client wheel dask-core statsmodels testpath python curl ptyprocess py pywin32 python-libarchive-c ruamel_yaml babel jupyter numexpr xlwings spyder yapf cycler pylint bitarray pygments backports.tempfile python-jsonrpc-server multipledispatch appdirs prompt-toolkit numba six _ipyw_jlab_nb_ext_conf msgpack-python isort spyder-kernels more-itertools cloudpickle prometheus_client openpyxl typing_extensions libcurl clyent filelock ujson backcall et_xmlfile menuinst backports.shutil_get_terminal_size asgiref cffi regex sphinxcontrib-websupport sympy argon2-cffi toml conda-repo-cli pandas jupyterlab_widgets rtree xlrd tornado snowballstemmer pep8 importlib_metadata pyyaml nest-asyncio paramiko jupyterlab_server asn1crypto openssl ipywidgets contextlib2 pyparsing numpy-base pillow astropy dask notebook sphinx qtpy qdarkstyle comtypes jdcal cryptography lxml conda win_unicode_console olefile lazy-object-proxy markupsafe beautifulsoup4 conda-package-handling psycopg2 jupyterlab_pygments three-merge traitlets conda-build alabaster zope.interface cython atomicwrites future ipython sip backports.functools_lru_cache pyflakes docutils intervaltree colorama mccabe entrypoints cytoolz numpy mkl_random py-lief pycparser sphinxcontrib-devhelp mkl_fft xlsxwriter pandocfilters pyopenssl pyzmq parso pywinpty defusedxml scikit-learn sortedcontainers backports boto packaging console_shortcut python-language-server urllib3 mpmath pytz nbclassic prompt_toolkit mistune fsspec partd gevent decorator pywavelets anyio bottleneck backports.weakref pytables locket zipp python-dateutil nbconvert black sphinxcontrib jedi xlwt qt path nbclient anaconda toolz numpydoc simplegeneric matplotlib-base zope pysocks idna tifffile zope.event fastcache pycodestyle pickleshare qtconsole bcrypt pluggy sphinxcontrib-applehelp anaconda-navigator pexpect conda-content-trust nbformat greenlet jupyter_console navigator-updater llvmlite pip pyrsistent requests jupyter_core typed-ast unicodecsv pytest win_inet_pton json5 joblib wcwidth flask pycosat jupyter-packaging pyreadline imageio watchdog conda-token autopep8 bleach click psutil mock path.py ipython_genutils pyls-spyder sphinxcontrib-serializinghtml jinja2 pydocstyle scipy libssh2 mkl-service zict scikit-image iniconfig krb5 glob2 threadpoolctl astroid sqlparse soupsieve jupyter_client sphinxcontrib-qthelp anaconda-project seaborn pynacl sortedcollections pathlib2 widgetsnbextension sphinxcontrib-htmlhelp powershell_shortcut matplotlib sniffio pyerfa pywin32-ctypes send2trash heapdict setuptools geopandas qtawesome:   1%|          | 3/348 [00:22<43:32,  7.57s/it]
# Examining conflict for keyring h5py nose mypy_extensions networkx django jupyterlab itsdangerous rope sphinxcontrib-jsmath tblib chardet certifi brotlipy pyodbc html5lib pkginfo wincertstore webencodings singledispatch bokeh flake8 pathspec ipykernel werkzeug async_generator attrs sqlalchemy diff-match-patch distributed xmltodict pycurl pyqt terminado importlib-metadata jsonschema conda-verify argh imagesize patsy wrapt jupyter_server imagecodecs kiwisolver nltk ply bkcharts tqdm textdistance anaconda-client wheel dask-core statsmodels testpath ptyprocess py pywin32 python-libarchive-c ruamel_yaml babel jupyter numexpr xlwings spyder yapf cycler pylint bitarray pygments backports.tempfile python-jsonrpc-server multipledispatch appdirs prompt-toolkit numba six _ipyw_jlab_nb_ext_conf msgpack-python isort spyder-kernels more-itertools cloudpickle prometheus_client openpyxl typing_extensions clyent filelock ujson backcall et_xmlfile menuinst backports.shutil_get_terminal_size asgiref cffi regex sphinxcontrib-websupport sympy argon2-cffi toml conda-repo-cli pandas jupyterlab_widgets rtree xlrd tornado snowballstemmer pep8 pyyaml jupyterlab_server nest-asyncio paramiko asn1crypto sphinxcontrib-htmlhelp pyparsing ipywidgets contextlib2 numpy-base pillow astropy dask notebook sphinx qtpy qdarkstyle comtypes jdcal cryptography lxml conda win_unicode_console olefile lazy-object-proxy markupsafe beautifulsoup4 conda-package-handling psycopg2 jupyterlab_pygments three-merge traitlets conda-build alabaster zope.interface cython atomicwrites future ipython sip backports.functools_lru_cache pyflakes docutils intervaltree colorama mccabe entrypoints cytoolz numpy mkl_random py-lief pycparser sphinxcontrib-devhelp mkl_fft xlsxwriter pandocfilters pyopenssl pyzmq parso pywinpty defusedxml scikit-learn sortedcontainers backports boto packaging console_shortcut python-language-server urllib3 mpmath pytz nbclassic prompt_toolkit mistune fsspec partd gevent decorator pywavelets anyio bottleneck backports.weakref pytables locket zipp python-dateutil nbconvert black sphinxcontrib jedi xlwt path nbclient anaconda toolz numpydoc simplegeneric matplotlib-base zope pysocks idna tifffile zope.event fastcache pycodestyle pickleshare qtconsole bcrypt pluggy sphinxcontrib-applehelp anaconda-navigator pexpect conda-content-trust nbformat greenlet jupyter_console navigator-updater llvmlite pip pyrsistent requests jupyter_core typed-ast unicodecsv pytest win_inet_pton json5 joblib wcwidth flask pycosat jupyter-packaging pyreadline imageio watchdog conda-token autopep8 bleach click psutil mock path.py ipython_genutils pyls-spyder sphinxcontrib-serializinghtml jinja2 pydocstyle scipy zict mkl-service scikit-image glob2 iniconfig threadpoolctl astroid sqlparse soupsieve jupyter_client sphinxcontrib-qthelp anaconda-project seaborn pynacl sortedcollections pathlib2 widgetsnbextension powershell_shortcut matplotlib sniffio pyerfa pywin32-ctypes send2trash heapdict setuptools geopandas qtawesome:   1%|          | 3/348 [00:48<43:32,  7.57s/it]
# Examining conflict for keyring h5py nose mypy_extensions networkx django jupyterlab itsdangerous rope sphinxcontrib-jsmath tblib chardet certifi brotlipy pyodbc html5lib pkginfo wincertstore webencodings singledispatch bokeh flake8 pathspec ipykernel werkzeug async_generator attrs sqlalchemy diff-match-patch distributed xmltodict pycurl pyqt terminado importlib-metadata jsonschema conda-verify argh imagesize patsy wrapt jupyter_server imagecodecs kiwisolver nltk ply bkcharts tqdm textdistance anaconda-client wheel dask-core statsmodels testpath ptyprocess py pywin32 python-libarchive-c ruamel_yaml babel jupyter numexpr xlwings spyder yapf cycler pylint bitarray pygments backports.tempfile python-jsonrpc-server multipledispatch appdirs prompt-toolkit numba six _ipyw_jlab_nb_ext_conf msgpack-python isort spyder-kernels more-itertools cloudpickle prometheus_client openpyxl typing_extensions clyent filelock ujson backcall et_xmlfile menuinst backports.shutil_get_terminal_size asgiref cffi regex sphinxcontrib-websupport sympy argon2-cffi toml conda-repo-cli pandas jupyterlab_widgets rtree xlrd tornado snowballstemmer pep8 pyyaml jupyterlab_server nest-asyncio paramiko asn1crypto sphinxcontrib-htmlhelp pyparsing ipywidgets contextlib2 numpy-base pillow astropy dask notebook sphinx qtpy qdarkstyle comtypes jdcal cryptography lxml conda win_unicode_console olefile lazy-object-proxy markupsafe beautifulsoup4 conda-package-handling psycopg2 jupyterlab_pygments three-merge traitlets conda-build alabaster zope.interface cython atomicwrites future ipython sip backports.functools_lru_cache pyflakes docutils intervaltree colorama mccabe entrypoints cytoolz numpy mkl_random py-lief pycparser sphinxcontrib-devhelp mkl_fft xlsxwriter pandocfilters pyopenssl pyzmq parso pywinpty defusedxml scikit-learn sortedcontainers backports boto packaging console_shortcut python-language-server urllib3 mpmath pytz nbclassic prompt_toolkit mistune fsspec partd gevent decorator pywavelets anyio bottleneck backports.weakref pytables locket zipp python-dateutil nbconvert black sphinxcontrib jedi xlwt path nbclient anaconda toolz numpydoc simplegeneric matplotlib-base zope pysocks idna tifffile zope.event fastcache pycodestyle pickleshare qtconsole bcrypt pluggy sphinxcontrib-applehelp anaconda-navigator pexpect conda-content-trust nbformat greenlet jupyter_console navigator-updater llvmlite pip pyrsistent requests jupyter_core typed-ast unicodecsv pytest win_inet_pton json5 joblib wcwidth flask pycosat jupyter-packaging pyreadline imageio watchdog conda-token autopep8 bleach click psutil mock path.py ipython_genutils pyls-spyder sphinxcontrib-serializinghtml jinja2 pydocstyle scipy zict mkl-service scikit-image glob2 iniconfig threadpoolctl astroid sqlparse soupsieve jupyter_client sphinxcontrib-qthelp anaconda-project seaborn pynacl sortedcollections pathlib2 widgetsnbextension powershell_shortcut matplotlib sniffio pyerfa pywin32-ctypes send2trash heapdict setuptools geopandas qtawesome:   1%|1         | 4/348 [00:48<1:16:20, 13.32s/it]
# Examining conflict for ipython backports.functools_lru_cache pyflakes zope.event numba anaconda-navigator nose networkx isort jupyterlab pip certifi requests pytest joblib clyent bokeh flake8 distributed ipykernel jupyter-packaging pywinpty sympy bleach terminado conda-repo-cli jsonschema python-language-server urllib3 tornado nltk jinja2 jupyterlab_server scikit-image anaconda-client gevent wheel astropy sphinx notebook astroid jupyter_client anaconda-project conda setuptools matplotlib spyder anaconda conda-build zope.interface cython matplotlib-base geopandas pygments:   1%|1         | 4/348 [01:08<1:16:20, 13.32s/it]
# Examining conflict for ipython backports.functools_lru_cache pyflakes zope.event numba anaconda-navigator nose networkx isort jupyterlab pip certifi requests pytest joblib clyent bokeh flake8 distributed ipykernel jupyter-packaging pywinpty sympy bleach terminado conda-repo-cli jsonschema python-language-server urllib3 tornado nltk jinja2 jupyterlab_server scikit-image anaconda-client gevent wheel astropy sphinx notebook astroid jupyter_client anaconda-project conda setuptools matplotlib spyder anaconda conda-build zope.interface cython matplotlib-base geopandas pygments:   1%|1         | 5/348 [01:08<1:29:43, 15.70s/it]
# Examining conflict for keyring h5py nose mypy_extensions networkx django jupyterlab itsdangerous rope sphinxcontrib-jsmath tblib chardet certifi brotlipy pyodbc html5lib pkginfo wincertstore webencodings singledispatch bokeh flake8 pathspec ipykernel werkzeug async_generator attrs sqlalchemy diff-match-patch distributed xmltodict pycurl pyqt terminado importlib-metadata jsonschema conda-verify argh imagesize patsy wrapt jupyter_server imagecodecs kiwisolver nltk ply bkcharts tqdm textdistance anaconda-client wheel dask-core statsmodels testpath python ptyprocess py pywin32 python-libarchive-c ruamel_yaml babel jupyter numexpr xlwings spyder yapf cycler pylint bitarray pygments backports.tempfile python-jsonrpc-server multipledispatch appdirs prompt-toolkit numba six _ipyw_jlab_nb_ext_conf msgpack-python isort spyder-kernels more-itertools cloudpickle prometheus_client openpyxl typing_extensions clyent filelock ujson backcall et_xmlfile menuinst backports.shutil_get_terminal_size asgiref cffi regex sphinxcontrib-websupport sympy argon2-cffi toml conda-repo-cli pandas jupyterlab_widgets rtree sqlite xlrd tornado snowballstemmer pep8 importlib_metadata pyyaml nest-asyncio paramiko jupyterlab_server asn1crypto sphinxcontrib-htmlhelp ipywidgets contextlib2 pyparsing numpy-base pillow astropy dask notebook sphinx qtpy qdarkstyle comtypes jdcal cryptography lxml conda win_unicode_console olefile lazy-object-proxy markupsafe beautifulsoup4 conda-package-handling psycopg2 jupyterlab_pygments three-merge traitlets conda-build alabaster zope.interface cython atomicwrites future ipython sip backports.functools_lru_cache pyflakes docutils intervaltree colorama mccabe entrypoints cytoolz numpy mkl_random py-lief pycparser sphinxcontrib-devhelp mkl_fft xlsxwriter pandocfilters pyopenssl pyzmq parso pywinpty defusedxml scikit-learn sortedcontainers backports boto packaging console_shortcut python-language-server urllib3 mpmath pytz nbclassic prompt_toolkit mistune fsspec partd gevent decorator pywavelets anyio bottleneck backports.weakref pytables locket zipp python-dateutil nbconvert black sphinxcontrib jedi xlwt qt path nbclient anaconda toolz numpydoc simplegeneric matplotlib-base zope pysocks idna tifffile zope.event fastcache pycodestyle pickleshare qtconsole bcrypt pluggy sphinxcontrib-applehelp anaconda-navigator pexpect conda-content-trust nbformat greenlet jupyter_console navigator-updater llvmlite pip pyrsistent requests jupyter_core typed-ast unicodecsv pytest win_inet_pton json5 joblib wcwidth flask pycosat jupyter-packaging pyreadline imageio watchdog conda-token autopep8 bleach click psutil mock path.py ipython_genutils pyls-spyder sphinxcontrib-serializinghtml jinja2 pydocstyle scipy zict mkl-service scikit-image glob2 iniconfig threadpoolctl astroid sqlparse soupsieve jupyter_client sphinxcontrib-qthelp anaconda-project seaborn pynacl sortedcollections pathlib2 widgetsnbextension powershell_shortcut matplotlib sniffio pyerfa pywin32-ctypes send2trash heapdict setuptools geopandas qtawesome:   1%|1         | 5/348 [01:19<1:29:43, 15.70s/it]
# Examining conflict for keyring h5py nose mypy_extensions networkx django jupyterlab itsdangerous rope sphinxcontrib-jsmath tblib chardet certifi brotlipy pyodbc html5lib pkginfo wincertstore webencodings singledispatch bokeh flake8 pathspec ipykernel werkzeug async_generator attrs sqlalchemy diff-match-patch distributed xmltodict pycurl pyqt terminado importlib-metadata jsonschema conda-verify argh imagesize patsy wrapt jupyter_server imagecodecs kiwisolver nltk ply bkcharts tqdm textdistance anaconda-client wheel dask-core statsmodels testpath python ptyprocess py pywin32 python-libarchive-c ruamel_yaml babel jupyter numexpr xlwings spyder yapf cycler pylint bitarray pygments backports.tempfile python-jsonrpc-server multipledispatch appdirs prompt-toolkit numba six _ipyw_jlab_nb_ext_conf msgpack-python isort spyder-kernels more-itertools cloudpickle prometheus_client openpyxl typing_extensions clyent filelock ujson backcall et_xmlfile menuinst backports.shutil_get_terminal_size asgiref cffi regex sphinxcontrib-websupport sympy argon2-cffi toml conda-repo-cli pandas jupyterlab_widgets rtree sqlite xlrd tornado snowballstemmer pep8 importlib_metadata pyyaml nest-asyncio paramiko jupyterlab_server asn1crypto sphinxcontrib-htmlhelp ipywidgets contextlib2 pyparsing numpy-base pillow astropy dask notebook sphinx qtpy qdarkstyle comtypes jdcal cryptography lxml conda win_unicode_console olefile lazy-object-proxy markupsafe beautifulsoup4 conda-package-handling psycopg2 jupyterlab_pygments three-merge traitlets conda-build alabaster zope.interface cython atomicwrites future ipython sip backports.functools_lru_cache pyflakes docutils intervaltree colorama mccabe entrypoints cytoolz numpy mkl_random py-lief pycparser sphinxcontrib-devhelp mkl_fft xlsxwriter pandocfilters pyopenssl pyzmq parso pywinpty defusedxml scikit-learn sortedcontainers backports boto packaging console_shortcut python-language-server urllib3 mpmath pytz nbclassic prompt_toolkit mistune fsspec partd gevent decorator pywavelets anyio bottleneck backports.weakref pytables locket zipp python-dateutil nbconvert black sphinxcontrib jedi xlwt qt path nbclient anaconda toolz numpydoc simplegeneric matplotlib-base zope pysocks idna tifffile zope.event fastcache pycodestyle pickleshare qtconsole bcrypt pluggy sphinxcontrib-applehelp anaconda-navigator pexpect conda-content-trust nbformat greenlet jupyter_console navigator-updater llvmlite pip pyrsistent requests jupyter_core typed-ast unicodecsv pytest win_inet_pton json5 joblib wcwidth flask pycosat jupyter-packaging pyreadline imageio watchdog conda-token autopep8 bleach click psutil mock path.py ipython_genutils pyls-spyder sphinxcontrib-serializinghtml jinja2 pydocstyle scipy zict mkl-service scikit-image glob2 iniconfig threadpoolctl astroid sqlparse soupsieve jupyter_client sphinxcontrib-qthelp anaconda-project seaborn pynacl sortedcollections pathlib2 widgetsnbextension powershell_shortcut matplotlib sniffio pyerfa pywin32-ctypes send2trash heapdict setuptools geopandas qtawesome:   2%|1         | 6/348 [01:19<1:21:05, 14.23s/it]
# Examining conflict for nose sphinxcontrib-jsmath chardet wincertstore brotli flake8 ipykernel xmltodict jupyter_server statsmodels pywin32 babel jupyter numexpr libtiff backports.tempfile python-jsonrpc-server _ipyw_jlab_nb_ext_conf libiconv more-itertools cloudpickle openpyxl typing_extensions clyent backcall et_xmlfile cffi sphinxcontrib-websupport jupyterlab_widgets tornado snowballstemmer paramiko openssl ipywidgets astropy jpeg notebook sphinx beautifulsoup4 conda-package-handling jupyterlab_pygments atomicwrites sip backports.functools_lru_cache intervaltree mccabe zstd mkl_fft pyopenssl sortedcontainers backports console_shortcut python-language-server nbclassic prompt_toolkit mistune partd anyio bottleneck pytables python-dateutil toolz fastcache pickleshare qtconsole icu conda-content-trust navigator-updater typed-ast pytest watchdog tbb psutil mock vc scipy mkl-service iniconfig jupyter_client sphinxcontrib-qthelp seaborn pynacl sortedcollections powershell_shortcut matplotlib pywin32-ctypes heapdict geopandas qtawesome keyring mypy_extensions jupyterlab itsdangerous rope tblib pyodbc pathspec werkzeug pycurl terminado importlib-metadata freetype patsy wrapt bkcharts anaconda-client dask-core python curl liblief python-libarchive-c spyder cycler bitarray appdirs tk yaml spyder-kernels libxslt prometheus_client libcurl ujson menuinst backports.shutil_get_terminal_size sympy pandas pep8 importlib_metadata pyyaml libzopfli nest-asyncio pillow dask cryptography conda win_unicode_console olefile markupsafe libdeflate three-merge traitlets mkl_random py-lief pandocfilters defusedxml packaging urllib3 mpmath gevent decorator black sphinxcontrib nbclient sphinxcontrib-applehelp llvmlite win_inet_pton joblib wcwidth pyreadline click path.py ipython_genutils pyls-spyder jinja2 pydocstyle libssh2 zict scikit-image krb5 astroid sqlparse pathlib2 widgetsnbextension certifi html5lib hdf5 lzo webencodings bokeh async_generator attrs sqlalchemy diff-match-patch jsonschema conda-verify imagesize imagecodecs kiwisolver ply ptyprocess xlwings pylint libxml2 msgpack-python lz4-c filelock asgiref regex rtree sqlite xlrd jupyterlab_server asn1crypto contextlib2 qtpy qdarkstyle comtypes charls lxml lazy-object-proxy conda-build alabaster zope.interface pyflakes docutils colorama snappy numpy sphinxcontrib-devhelp xlsxwriter pyzmq pywinpty zlib boto pywavelets locket zipp jedi qt path anaconda numpydoc matplotlib-base zope pysocks tifffile zope.event bcrypt pexpect pip requests libspatialindex unicodecsv json5 pycosat jupyter-packaging bleach glob2 soupsieve anaconda-project zeromq sniffio h5py networkx django lerc lcms2 brotlipy pkginfo singledispatch distributed libpq pyqt libarchive openjpeg argh nltk winpty tqdm textdistance wheel testpath py ruamel_yaml yapf pygments multipledispatch prompt-toolkit numba six isort zfp argon2-cffi toml conda-repo-cli sphinxcontrib-htmlhelp pyparsing numpy-base libpng libsodium jdcal psycopg2 cython future ipython entrypoints cytoolz pycparser parso scikit-learn pytz fsspec backports.weakref nbconvert xlwt simplegeneric idna pycodestyle pluggy anaconda-navigator nbformat greenlet jupyter_console pyrsistent jupyter_core bzip2 flask blosc imageio conda-token autopep8 sphinxcontrib-serializinghtml threadpoolctl giflib libaec xz pyerfa send2trash setuptools:   2%|1         | 6/348 [01:44<1:21:05, 14.23s/it]
# ...
# anaconda==2021.05 -> dask==2021.4.0=pyhd3eb1b0_0 -> distributed[version='>=2021.4.0']
# anaconda==2021.05 -> distributed==2021.4.0[build='py38haa95532_0|py39haa95532_0|py37haa95532_0']
# scikit-image -> dask[version='>=0.5'] -> distributed[version='2021.4.1.*|2021.5.0.*|2021.5.1.*|2021.6.0.*|2021.6.1.*|2021.6.2.*|2021.7.0.*|2021.7.2.*|2021.8.0.*|2021.8.1.*|2021.9.1.*|>=2021.4.0|>=2021.3.1|>=2021.3.0|>=2021.2.0|>=2021.1.1|>=2021.1.0|>=2020.12.0|>=2.30.0|>=2.29.0|>=2.27.0|>=2.26.0|>=2.25.0|>=2.24.0|>=2.23.0|>=2.22.0|>=2.20.0|>=2.19.0|>=2.18.0|>=2.17.0|>=2.16.0|>=2.15.0|>=2.14.0|>=2.13.0|>=2.12.0|>=2.11.0|>=2.10.0|>=2.9.2|>=2.9.1|>=2.9.0|>=2.8.1|>=2.8.0|>=2.7.0|>=2.6.0|>=2.5.2|>=2.5.0|>=2.4.0|>=2.3.0|>=2.2.0|>=2|>=1.28.0|>=1.27.0|>=1.26.1|>=1.26.0|>=1.25.3|>=1.25.0|>=1.24.2|>=1.23.3|>=1.23.2|>=1.23.1|>=1.23.0|>=1.22.0|>=1.21.0|>=1.21.1|>=1.20.0|>=1.19.0|>=1.16.0']
#
# Package mistune conflicts for:
# spyder -> nbconvert[version='>=4.0'] -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# jupyter -> nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# jupyter_server -> nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# notebook -> nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# anaconda==2021.05 -> nbconvert==6.0.7=py38_0 -> mistune[version='>=0.8.1']
# anaconda==2021.05 -> mistune==0.8.4[build='py38he774522_1000|py39h2bbff1b_1000|py37hfa6e2cd_1001']
#
# Package python-language-server conflicts for:
# spyder -> python-language-server[version='>=0.31.2,<0.32.0|>=0.31.9,<0.32.0|>=0.34.0,<1.0.0|>=0.36.1,<1.0.0|>=0.36.2,<1.0.0']
# spyder -> pyls-black[version='>=0.4.6'] -> python-language-server[version='>=0.36.2']
# anaconda==2021.05 -> pyls-black==0.4.6=hd3eb1b0_0 -> python-language-server[version='>=0.36.2|>=0.36.2,<1.0.0']
# pyls-spyder -> python-language-server[version='>=0.36.2']
# pyls-black -> python-language-server
# anaconda==2021.05 -> python-language-server==0.36.2=pyhd3eb1b0_0
#
# Package sqlalchemy conflicts for:
# anaconda==2021.05 -> sqlalchemy==1.4.7[build='py37h2bbff1b_0|py39h2bbff1b_0|py38h2bbff1b_0']
# geopandas -> sqlalchemy
#
# Package jaraco.itertools conflicts for:
# zipp -> jaraco.itertools
# importlib_metadata -> zipp[version='>=0.5'] -> jaraco.itertools
# importlib-metadata -> zipp[version='>=0.5'] -> jaraco.itertools
#
# Package fonttools conflicts for:
# geopandas -> matplotlib-base -> fonttools[version='>=4.22.0']
# scikit-image -> matplotlib-base[version='>=2.0.0'] -> fonttools[version='>=4.22.0']
# matplotlib-base -> fonttools[version='>=4.22.0']
# matplotlib -> matplotlib-base[version='>=3.4.3,<3.4.4.0a0'] -> fonttools[version='>=4.22.0']
#
# Package filelock conflicts for:
# anaconda==2021.05 -> filelock==3.0.12=pyhd3eb1b0_1
# conda-build -> filelock
#
# Package et_xmlfile conflicts for:
# anaconda==2021.05 -> openpyxl==3.0.7=pyhd3eb1b0_0 -> et_xmlfile
# openpyxl -> et_xmlfile
# anaconda==2021.05 -> et_xmlfile==1.0.1=py_1001
#
# Package coverage conflicts for:
# geopandas -> pysal -> coverage
# attrs -> hypothesis -> coverage
#
# Package beautifulsoup4 conflicts for:
# anaconda==2021.05 -> soupsieve==2.2.1=pyhd3eb1b0_0 -> beautifulsoup4
# anaconda==2021.05 -> beautifulsoup4==4.9.3=pyha847dfd_0
# soupsieve -> beautifulsoup4
# conda-build -> beautifulsoup4
#
# Package hypothesis conflicts for:
# astropy -> pytest-astropy -> hypothesis[version='>=5.1']
# attrs -> hypothesis
# pytest -> attrs[version='>=17.2.0'] -> hypothesis
#
# Package lazy-object-proxy conflicts for:
# astroid -> lazy-object-proxy[version='1.4.*|>=1.4,<2|>=1.4.0']
# pylint -> astroid[version='>=2.6.5,<=2.7'] -> lazy-object-proxy[version='1.4.*|>=1.4,<2|>=1.4.0']
# anaconda==2021.05 -> lazy-object-proxy==1.6.0[build='py37h2bbff1b_0|py39h2bbff1b_0|py38h2bbff1b_0']
# anaconda==2021.05 -> astroid==2.5=py38haa95532_1 -> lazy-object-proxy[version='>=1.4,<2']
#
# Package immutables conflicts for:
# sniffio -> contextvars[version='>=2.1'] -> immutables[version='>=0.9']
# distributed -> contextvars -> immutables[version='>=0.9']
#
# Package libdeflate conflicts for:
# anaconda==2021.05 -> imagecodecs==2021.3.31=py38h5da4933_0 -> libdeflate[version='>=1.7,<1.8.0a0']
# anaconda==2021.05 -> libdeflate==1.7=h2bbff1b_5
# tifffile -> imagecodecs[version='>=2021.4.28'] -> libdeflate[version='>=1.7,<1.8.0a0|>=1.8,<1.9.0a0']
# imagecodecs -> libdeflate[version='>=1.7,<1.8.0a0|>=1.8,<1.9.0a0']
#
# Package backports.shutil_which conflicts for:
# pywinpty -> backports.shutil_which
# terminado -> pywinpty -> backports.shutil_which
#
# Package qtconsole conflicts for:
# anaconda==2021.05 -> jupyter==1.0.0=py38_7 -> qtconsole[version='>=5.0.3']
# spyder -> qtconsole[version='>=4.2|>=4.6.0|>=4.7.7|>=5.0.1|>=5.0.3|>=5.1.0']
# jupyter -> qtconsole
# anaconda==2021.05 -> qtconsole==5.0.3=pyhd3eb1b0_0
#
# Package numpydoc conflicts for:
# jedi -> numpydoc
# spyder -> numpydoc[version='>=0.6.0']
# anaconda==2021.05 -> spyder==4.2.5=py38haa95532_0 -> numpydoc[version='>=0.6.0']
# anaconda==2021.05 -> numpydoc==1.1.0=pyhd3eb1b0_1
# ipython -> jedi[version='>=0.10,<0.18'] -> numpydoc
#
# Package win_inet_pton conflicts for:
# anaconda==2021.05 -> win_inet_pton==1.1.0[build='py38haa95532_0|py39haa95532_0|py37haa95532_0']
# pysocks -> win_inet_pton
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7'] -> win_inet_pton
# anaconda==2021.05 -> pysocks==1.7.1=py38haa95532_0 -> win_inet_pton
#
# Package m2w64-gcc-libgfortran conflicts for:
# anaconda==2021.05 -> m2w64-gcc-libgfortran==5.3.0=6
# anaconda==2021.05 -> m2w64-gcc-libs==5.3.0=7 -> m2w64-gcc-libgfortran
# pywinpty -> m2w64-gcc-libs -> m2w64-gcc-libgfortran
# m2w64-gcc-libs -> m2w64-gcc-libgfortran
#
# Package html5lib conflicts for:
# pip -> html5lib
# python=3.8 -> pip -> html5lib
# bcrypt -> pip -> html5lib
# anaconda==2021.05 -> html5lib==1.1=py_0
# bleach -> html5lib[version='>=0.99999999|>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']
# nbconvert -> bleach -> html5lib[version='>=0.99999999|>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']
#
# Package statsmodels conflicts for:
# seaborn -> statsmodels[version='>=0.5.0']
# anaconda==2021.05 -> statsmodels==0.12.2[build='py37h2bbff1b_0|py39h2bbff1b_0|py38h2bbff1b_0']
#
# Package krb5 conflicts for:
# libcurl -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0']
# libpq -> krb5[version='>=1.14.2,<1.15.0a0|>=1.16,<1.17.0a0|>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0']
# anaconda==2021.05 -> krb5==1.18.2=hc04afaa_0
# anaconda==2021.05 -> curl==7.71.1=h2a8f88b_1 -> krb5[version='>=1.18.2,<1.19.0a0']
# psycopg2 -> libpq[version='>=12.2,<13.0a0'] -> krb5[version='>=1.14.2,<1.15.0a0|>=1.16,<1.17.0a0|>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0']
# pycurl -> libcurl[version='>=7.71.1,<8.0a0'] -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0|>=1.19.2,<1.20.0a0']
# curl -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0|>=1.19.2,<1.20.0a0']
#
# Package jupyterlab_widgets conflicts for:
# anaconda==2021.05 -> jupyterlab_widgets==1.0.0=pyhd3eb1b0_1
# ipywidgets -> jupyterlab_widgets[version='>=1.0.0']
# jupyter -> ipywidgets -> jupyterlab_widgets[version='>=1.0.0']
# anaconda==2021.05 -> ipywidgets==7.6.3=pyhd3eb1b0_1 -> jupyterlab_widgets[version='>=1.0.0']
# _ipyw_jlab_nb_ext_conf -> ipywidgets -> jupyterlab_widgets[version='>=1.0.0']
#
# Package pexpect conflicts for:
# anaconda==2021.05 -> spyder==4.2.5=py38haa95532_0 -> pexpect[version='>=4.4.0']
# spyder -> pexpect[version='>=4.4.0']
# anaconda==2021.05 -> pexpect==4.8.0=pyhd3eb1b0_3
#
# Package tbb4py conflicts for:
# numpy-base -> tbb4py
# mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> tbb4py
# numpy -> numpy-base==1.15.4=py27h2753ae9_0 -> tbb4py
# mkl_fft -> numpy-base[version='>=1.0.6,<2.0a0'] -> tbb4py
#
# Package libiconv conflicts for:
# conda-build -> libarchive -> libiconv[version='>=1.15,<2.0a0']
# conda-package-handling -> libarchive[version='>=3.3.3'] -> libiconv[version='>=1.15,<2.0a0']
# python-libarchive-c -> libarchive -> libiconv[version='>=1.15,<2.0a0']
# lxml -> libxml2[version='>=2.9.10,<2.10.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# anaconda==2021.05 -> libarchive==3.4.2=h5e25573_0 -> libiconv[version='>=1.15,<2.0a0']
# anaconda==2021.05 -> libiconv==1.15=h1df5818_7
# libarchive -> libiconv[version='>=1.15,<2.0a0']
# libarchive -> libxml2[version='>=2.9.4,<2.10.0a0'] -> libiconv
# libxslt -> libxml2[version='>=2.9.10,<2.10.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# libxml2 -> libiconv[version='>=1.15,<2.0a0']
#
# Package conda-package-handling conflicts for:
# conda-verify -> conda-package-handling[version='>=1.0.4|>=1.1']
# conda[version='>=4.10.3'] -> conda-package-handling[version='>=1.3.0']
# conda-build -> conda-package-handling[version='>=1.1|>=1.3']
# conda-token -> conda[version='>=4.3'] -> conda-package-handling[version='>=1.3.0']
# conda-build -> conda[version='>=4.5'] -> conda-package-handling[version='>=1.0.4|>=1.3.0']
#
# Package heapdict conflicts for:
# zict -> heapdict
# anaconda==2021.05 -> heapdict==1.0.1=py_0
# distributed -> zict[version='>=0.1.3'] -> heapdict
# anaconda==2021.05 -> zict==2.0.0=pyhd3eb1b0_0 -> heapdict
#
# Package psycopg2 conflicts for:
# django -> psycopg2
# geopandas -> psycopg2
#
# Package libspatialindex conflicts for:
# anaconda==2021.05 -> libspatialindex==1.9.3=h6c2663c_0
# rtree -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# spyder -> rtree[version='>=0.9.7'] -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# anaconda==2021.05 -> rtree==0.9.7=py38h2eaa2aa_1 -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# geopandas -> rtree -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
#
# Package cfitsio conflicts for:
# imagecodecs -> cfitsio[version='>=3.470,<3.471.0a0']
# tifffile -> imagecodecs[version='>=2021.4.28'] -> cfitsio[version='>=3.470,<3.471.0a0']
#
# Package async_generator conflicts for:
# nbconvert -> nbclient[version='>=0.5.0,<0.6.0'] -> async_generator
# anaconda==2021.05 -> nbclient==0.5.3=pyhd3eb1b0_0 -> async_generator
# anaconda==2021.05 -> async_generator==1.10[build='pyhd3eb1b0_0|py37h28b3542_0']
# anyio -> async_generator
# jupyter_server -> anyio[version='>=2.0.2'] -> async_generator
# nbclient -> async_generator
#
# Package py-lief conflicts for:
# anaconda==2021.05 -> py-lief==0.10.1[build='py38ha925a31_0|py39hd77b12b_1|py37ha925a31_0']
# conda-build -> py-lief
#
# Package bokeh conflicts for:
# anaconda==2021.05 -> dask==2021.4.0=pyhd3eb1b0_0 -> bokeh[version='>=1.0.0,!=2.0.0']
# scikit-image -> dask[version='>=0.5'] -> bokeh[version='>=0.13.0|>=1.0.0|>=1.0.0,!=2.0.0']
# dask -> bokeh[version='>=0.13.0|>=1.0.0|>=1.0.0,!=2.0.0']
# anaconda==2021.05 -> bokeh==2.3.2[build='py38haa95532_0|py39haa95532_0|py37haa95532_0']
#
# Package pywin32-ctypes conflicts for:
# anaconda==2021.05 -> pywin32-ctypes==0.2.0[build='py39haa95532_1000|py38_1000|py37_1001']
# keyring -> pywin32-ctypes[version='!=0.1.0,!=0.1.1']
# anaconda==2021.05 -> keyring==22.3.0=py38haa95532_0 -> pywin32-ctypes
# spyder -> keyring[version='>=17.0.0'] -> pywin32-ctypes[version='!=0.1.0,!=0.1.1']
#
# Package docutils conflicts for:
# anaconda==2021.05 -> sphinx==4.0.1=pyhd3eb1b0_0 -> docutils[version='>=0.14,<0.18']
# spyder -> sphinx[version='>=0.6.6'] -> docutils[version='>=0.11|>=0.12|>=0.12,<0.17|>=0.14,<0.18']
# numpydoc -> sphinx -> docutils[version='>=0.11|>=0.12|>=0.12,<0.17|>=0.14,<0.18']
# sphinx -> docutils[version='>=0.11|>=0.12|>=0.12,<0.17|>=0.14,<0.18']
# anaconda==2021.05 -> docutils==0.17[build='py37haa95532_1|py38haa95532_1|py39haa95532_1']
#
# Package argh conflicts for:
# spyder -> watchdog[version='>=0.10.3'] -> argh[version='>=0.24.1']
# anaconda==2021.05 -> argh==0.26.2[build='py37_0|py38_0|py39haa95532_0']
# watchdog -> argh[version='>=0.24.1']
# anaconda==2021.05 -> watchdog==1.0.2=py38haa95532_1 -> argh[version='>=0.24.1']
#
# Package anaconda-project conflicts for:
# anaconda==2021.05 -> anaconda-project==0.9.1=pyhd3eb1b0_1
# anaconda-navigator -> anaconda-project[version='>=0.4']
#
# Package cryptography-vectors conflicts for:
# paramiko -> cryptography[version='>=1.5'] -> cryptography-vectors=2.3
# urllib3 -> cryptography[version='>=1.3.4'] -> cryptography-vectors=2.3
# conda-content-trust -> cryptography -> cryptography-vectors=2.3
# cryptography -> cryptography-vectors=2.3
# pyopenssl -> cryptography[version='>=2.2.1'] -> cryptography-vectors=2.3
#
# Package conda-content-trust conflicts for:
# anaconda-navigator -> conda-token -> conda-content-trust
# conda-token -> conda-content-trust
#
# Package mypy_extensions conflicts for:
# anaconda==2021.05 -> mypy_extensions[version='0.4.1|0.4.3|0.4.3',build='py37_0|py38_0|py39haa95532_0']
# black -> mypy_extensions
# anaconda==2021.05 -> black==19.10b0=py_0 -> mypy_extensions
# pyls-black -> black -> mypy_extensions
#
# Package typing-extensions conflicts for:
# pylint -> astroid[version='>=2.6.5,<=2.7'] -> typing-extensions[version='>=3.7.4']
# astroid -> typing-extensions[version='>=3.7.4']
#
# Package qtawesome conflicts for:
# anaconda==2021.05 -> spyder==4.2.5=py38haa95532_0 -> qtawesome[version='>=0.5.7']
# anaconda==2021.05 -> qtawesome==1.0.2=pyhd3eb1b0_0
# spyder -> qtawesome[version='>=0.4.1|>=0.5.7|>=1.0.2']
#
# Package cython conflicts for:
# anaconda==2021.05 -> cython==0.29.23[build='py37hd77b12b_0|py38hd77b12b_0|py39hd77b12b_0']
# nltk -> gensim -> cython==0.29.23
#
# Package llvmlite conflicts for:
# anaconda==2021.05 -> numba==0.53.1=py38hf11a4ad_0 -> llvmlite[version='>=0.36.0,<0.37.0a0']
# anaconda==2021.05 -> llvmlite==0.36.0[build='py37h34b8924_4|py38h34b8924_4|py39h34b8924_4']
# numba -> llvmlite[version='0.20.*|0.21.*|0.22.*|0.23.*|0.24.*|>=0.25.0,<0.26.0a0|>=0.26.0,<0.27.0a0|>=0.27.0,<0.28.0a0|>=0.28.0,<0.29.0a0|>=0.29.0,<0.30.0a0|>=0.29.0|>=0.30.0,<0.31.0a0|>=0.30.0|>=0.31.0,<0.32.0a0|>=0.31.0|>=0.32.0,<0.33.0a0|>=0.32.0|>=0.32.1,<0.33.0a0|>=0.32.1|>=0.33.0,<0.34.0a0|>=0.33.0|>=0.34.0,<0.35|>=0.35.0,<0.36.0a0|>=0.36.0,<0.37.0a0']
#
# Package watchdog conflicts for:
# anaconda==2021.05 -> spyder==4.2.5=py38haa95532_0 -> watchdog[version='>=0.10.3,<2.0.0']
# anaconda==2021.05 -> watchdog==1.0.2[build='py37haa95532_1|py38haa95532_1|py39haa95532_1']
# spyder -> watchdog[version='>=0.10.3|>=0.10.3,<2.0.0']
#
# Package libpq conflicts for:
# geopandas -> psycopg2 -> libpq[version='>=10.3,<11.0a0|>=10.4,<11.0a0|>=11.1,<12.0a0|>=11.2,<12.0a0|>=12.2,<13.0a0|>=9.6.6']
# django -> psycopg2 -> libpq[version='>=10.3,<11.0a0|>=10.4,<11.0a0|>=11.1,<12.0a0|>=11.2,<12.0a0|>=12.2,<13.0a0|>=9.6.6']
# psycopg2 -> libpq[version='>=10.3,<11.0a0|>=10.4,<11.0a0|>=11.1,<12.0a0|>=11.2,<12.0a0|>=12.2,<13.0a0|>=9.6.6']
#
# Package pathtools conflicts for:
# spyder -> watchdog[version='>=0.10.3'] -> pathtools[version='>=0.1.1']
# watchdog -> pathtools[version='>=0.1.1']
#
# Package black conflicts for:
# anaconda==2021.05 -> black==19.10b0=py_0
# pyls-black -> black
# attrs -> hypothesis -> black[version='>=19.10b0']
# anaconda==2021.05 -> pyls-black==0.4.6=hd3eb1b0_0 -> black
# spyder -> python-lsp-black[version='>=1.0.0'] -> black
#
# Package pkginfo conflicts for:
# conda-build -> pkginfo
# anaconda==2021.05 -> pkginfo==1.7.0[build='py38haa95532_0|py39haa95532_0|py37haa95532_0']
#
# Package conda-env conflicts for:
# conda-token -> conda[version='>=4.3'] -> conda-env[version='>=2.6']
# conda-build -> conda[version='>=4.5'] -> conda-env[version='>=2.6']
#
# Package dask conflicts for:
# anaconda==2021.05 -> dask==2021.4.0=pyhd3eb1b0_0
# scikit-image -> dask[version='>=0.5']
#
# Package intervaltree conflicts for:
# anaconda==2021.05 -> intervaltree==3.1.0=py_0
# anaconda==2021.05 -> spyder==4.2.5=py38haa95532_0 -> intervaltree[version='>=3.0.2']
# spyder -> intervaltree[version='>=3.0.2']
#
# Package conda-pack conflicts for:
# anaconda-project -> conda-pack
# anaconda-navigator -> anaconda-project -> conda-pack
#
# Package keyring conflicts for:
# anaconda==2021.05 -> spyder==4.2.5=py38haa95532_0 -> keyring[version='>=17.0.0']
# anaconda==2021.05 -> keyring==22.3.0[build='py38haa95532_0|py39haa95532_0|py37haa95532_0']
# spyder -> keyring[version='>=17.0.0']

# %%
# 라이브러리 추가
import requests; from urllib.parse import urlparse
import pandas as pd
import geopandas

# %%
# 라이브러리 추가
import requests; from urllib.parse import urlparse
import pandas as pd
import geopandas

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp38-cp38-win_amd64.whl (6.2 MB)
# Requirement already satisfied: pandas>=0.25.0 in c:\users\ui\anaconda3\lib\site-packages (from geopandas) (1.2.4)
# Collecting shapely>=1.6
#   Downloading Shapely-1.7.1-cp38-cp38-win_amd64.whl (1.0 MB)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.20.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.19.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.18.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.17.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.16.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.15.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.14.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.13.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.12.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.11.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.10.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.9.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.8.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.7.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.6.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.5.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.4.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.3.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.2.tar.gz (1.2 MB)
# Note: you may need to restart the kernel to use updated packages.  Downloading Fiona-1.8.1.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.0.tar.gz (1.4 MB)
# Collecting geopandas
#   Downloading geopandas-0.10.1-py2.py3-none-any.whl (1.0 MB)
#   Downloading geopandas-0.10.0-py2.py3-none-any.whl (1.0 MB)
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#   Downloading geopandas-0.8.2-py2.py3-none-any.whl (962 kB)
# Collecting fiona
#   Downloading Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ui\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ui\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ui\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (2.8.1)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_8ea283ca240b44169fbf5cbb0fba9a42\\setup.py'"'"'; __file__='"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_8ea283ca240b44169fbf5cbb0fba9a42\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ui\AppData\Local\Temp\pip-pip-egg-info-grwqf1h2'
#          cwd: C:\Users\ui\AppData\Local\Temp\pip-install-b955165u\fiona_8ea283ca240b44169fbf5cbb0fba9a42\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ec/f7/093890341a7e8fbfcdfa04caf4dfb588ebab32c13ceaa6a3819da79ea106/Fiona-1.8.20.tar.gz#sha256=a70502d2857b82f749c09cb0dea3726787747933a2a1599b5ab787d74e3c143b (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_024cfe39c3c44a81994d256fdc71c9be\\setup.py'"'"'; __file__='"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_024cfe39c3c44a81994d256fdc71c9be\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ui\AppData\Local\Temp\pip-pip-egg-info-9rgkffz6'
#          cwd: C:\Users\ui\AppData\Local\Temp\pip-install-b955165u\fiona_024cfe39c3c44a81994d256fdc71c9be\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a0/d9/6042aeb073d11341f7726de0586ff71c13117c34959dcf07bd4ee6d4b93e/Fiona-1.8.19.tar.gz#sha256=b9059e0b29c2e9e6b817e53f941e77e1aca7075f986005d38db307067b60458f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_834822fbab7141c688af15dfe0d2b951\\setup.py'"'"'; __file__='"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_834822fbab7141c688af15dfe0d2b951\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ui\AppData\Local\Temp\pip-pip-egg-info-f0mimvdo'
#          cwd: C:\Users\ui\AppData\Local\Temp\pip-install-b955165u\fiona_834822fbab7141c688af15dfe0d2b951\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9f/e8/401cdaa58d862a25c4b3365acf7d2bd7ac77191e3dc9acdcdac0eff20ff0/Fiona-1.8.18.tar.gz#sha256=b732ece0ff8886a29c439723a3e1fc382718804bb057519d537a81308854967a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_64007dc400d747739dba086a7a344cd5\\setup.py'"'"'; __file__='"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_64007dc400d747739dba086a7a344cd5\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ui\AppData\Local\Temp\pip-pip-egg-info-xzujp0l6'
#          cwd: C:\Users\ui\AppData\Local\Temp\pip-install-b955165u\fiona_64007dc400d747739dba086a7a344cd5\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/88/62/69347ba2c41b526e1953c4cb66d51170b2869808863c03af202ba0121670/Fiona-1.8.17.tar.gz#sha256=716201c21246587f374785bec6d6a20a984fe1f6c2b0e83bf15127eb8f724d0c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Requirement already satisfied: certifi in c:\users\ui\anaconda3\lib\site-packages (from pyproj>=2.2.0->geopandas) (2020.12.5)
# Requirement already satisfied: six>=1.5 in c:\users\ui\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.0->geopandas) (1.15.0)
# Collecting cligj>=0.4
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: click>=4.0 in c:\users\ui\anaconda3\lib\site-packages (from cligj>=0.4->fiona->geopandas) (7.1.2)
# Building wheels for collected packages: fiona
#   Building wheel for fiona (setup.py): started
#   Building wheel for fiona (setup.py): finished with status 'error'
#   Running setup.py clean for fiona
# Failed to build fiona
# Installing collected packages: munch, cligj, click-plugins, shapely, pyproj, fiona, geopandas
#     Running setup.py install for fiona: started
#     Running setup.py install for fiona: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_a461748145d0469892a0b183e9adea2f\\setup.py'"'"'; __file__='"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_a461748145d0469892a0b183e9adea2f\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ui\AppData\Local\Temp\pip-pip-egg-info-xt3ujl6t'
#          cwd: C:\Users\ui\AppData\Local\Temp\pip-install-b955165u\fiona_a461748145d0469892a0b183e9adea2f\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/1e/60/dfc6115a11338d8aa96cacd8c60635223d9c97d61d556c90acc5dfd663fa/Fiona-1.8.16.tar.gz#sha256=fd6dfb65959becc916e9f6928618bfd59c16cdbc413ece0fbac61489cd11255f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_d1ad29ac717e4b278cf75e9e73c83270\\setup.py'"'"'; __file__='"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_d1ad29ac717e4b278cf75e9e73c83270\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ui\AppData\Local\Temp\pip-pip-egg-info-megucneq'
#          cwd: C:\Users\ui\AppData\Local\Temp\pip-install-b955165u\fiona_d1ad29ac717e4b278cf75e9e73c83270\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/55/2f/17450ec2c8fcc720a8a3e4d9a383499508475c7cfb90f7eca9fb585ac598/Fiona-1.8.15.tar.gz#sha256=3b1c9b5c834fae2fe947cfaea176db890bc6750d1a6ba9f54d969c19ffcd191e (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_5e7fedc8f400459482aff6a6fe4c4811\\setup.py'"'"'; __file__='"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_5e7fedc8f400459482aff6a6fe4c4811\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ui\AppData\Local\Temp\pip-pip-egg-info-ncmo3_wd'
#          cwd: C:\Users\ui\AppData\Local\Temp\pip-install-b955165u\fiona_5e7fedc8f400459482aff6a6fe4c4811\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5c/fd/5ec54f2d9b3d5dd23dd443fad5630d6b872e2664814c68b856c47e0d65af/Fiona-1.8.14.tar.gz#sha256=6eac038206c89d2cf5f99ea38b81cc228dc21eac5f47870a9a32d453b0007f4d (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_598179b7759e475bb527aeb67eef6ca0\\setup.py'"'"'; __file__='"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_598179b7759e475bb527aeb67eef6ca0\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ui\AppData\Local\Temp\pip-pip-egg-info-p7so0w7k'
#          cwd: C:\Users\ui\AppData\Local\Temp\pip-install-b955165u\fiona_598179b7759e475bb527aeb67eef6ca0\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6d/42/f4a7cac53b28fa70e9a93d0e89a24d33e14826dad6644b699362ad84dde0/Fiona-1.8.13.post1.tar.gz#sha256=1a432bf9fd56f089256c010da009c90d4a795c531a848132c965052185336600 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_7ae8b309f653491fa42a8328ecba0deb\\setup.py'"'"'; __file__='"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_7ae8b309f653491fa42a8328ecba0deb\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ui\AppData\Local\Temp\pip-pip-egg-info-x2gye_mg'
#          cwd: C:\Users\ui\AppData\Local\Temp\pip-install-b955165u\fiona_7ae8b309f653491fa42a8328ecba0deb\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/be/04/31d0a6f03943b1684f32c9b861be40c1fd282468fa6bd54ddf4a774e6b0f/Fiona-1.8.13.tar.gz#sha256=5ec34898c8b983a723fb4e949dd3e0ed7e691c303e51f6bfd61e52ac9ac813ae (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_82c4d94e0b57432b885f78ad7fcf606c\\setup.py'"'"'; __file__='"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_82c4d94e0b57432b885f78ad7fcf606c\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ui\AppData\Local\Temp\pip-pip-egg-info-3omgn5sz'
#          cwd: C:\Users\ui\AppData\Local\Temp\pip-install-b955165u\fiona_82c4d94e0b57432b885f78ad7fcf606c\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/97/d8/feab39987296437fbdc3029fb39752a14355d217d73b93471010b8dd63a3/Fiona-1.8.12.tar.gz#sha256=c9266ddf6ae2a64fcea20014ddf27f800ac07584f2fdb09c2a02f3b3a52e371c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_ad599757b87c48fd83483c9add2044fa\\setup.py'"'"'; __file__='"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona_ad599757b87c48fd83483c9add2044fa\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ui\AppData\Local\Temp\pip-pip-egg-info-eyhw027z'
#          cwd: C:\Users\ui\AppData\Local\Temp\pip-install-b955165u\fiona_ad599757b87c48fd83483c9add2044fa\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9d/f4/0a0ddc6174c4a93679b5f1dd3535e7ef8989828e6d5f86112de681f8c87b/Fiona-1.8.11.tar.gz#sha256=1e7ca9e051f5bffa1c43c70d573da9ca223fc076b84fa73380614fc02b9eb7f6 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ui\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ui\\AppData\\Local\\Temp\\pip-install-b955165u\\fiona