# %%
import json
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv('./d.csv',encoding='UTF8', index_col=0)

# %%
data
# Out:
#                   name keyword  \
# 0      더럭초등학교(구, 더럭분교)      문화
# 1      더럭초등학교(구, 더럭분교)      문화
# 2      더럭초등학교(구, 더럭분교)      문화
# 3      더럭초등학교(구, 더럭분교)      문화
# 4      더럭초등학교(구, 더럭분교)      문화
# ...                ...     ...
# 13063    누웨마루거리(구 바오젠)      도보
# 13064    누웨마루거리(구 바오젠)      도보
# 13065        숫모르편백나무숲길      도보
# 13066        숫모르편백나무숲길      도보
# 13067         삼의악트레킹코스      도보
#
#                                                  content  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                       무지개빛 아름다운 더럭초등학교
# 2                                       무지개빛 아름다운 더럭초등학교
# 3              알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4      #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                                                  ...
# 13063                              #바오젠거리 #신라스테이제주 #돌하루방
# 13064                        중국인들이 많이 찾는다는 제주시 연동 바오젠거리.
# 13065  제주생태공원에서 절물자연휴양림으로 이어지는 걷기 좋은 길이다.  #숫모르편백나무숲길...
# ...

# %%
data .isnull().sum()
# Out:
# name        0
# keyword     0
# content     0
# tags        0
# address     0
# address1    0
# dtype: int64

# %%
data1=data.groupby(['name']).count()

# %%
data1  #479
# Out:
#              keyword  content  tags  address  address1
# name
# 1100고지(휴게소)       11       11    11       11        11
# 1100고지습지          13       13    13       13        13
# 5.16도로숲터널          3        3     3        3         3
# 9.81 파크            1        1     1        1         1
# 가뫼물                9        9     9        9         9
# ...              ...      ...   ...      ...       ...
# 화조원                2        2     2        2         2
# 환상숲 곶자왈공원         50       50    50       50        50
# 황우지해안             49       49    49       49        49
# 황우지해안 열두굴          3        3     3        3         3
# 휴애리 자연생활공원        69       69    69       69        69
#
# [479 rows x 5 columns]

# %%
data1 .isnull().sum()
# Out:
# keyword     0
# content     0
# tags        0
# address     0
# address1    0
# dtype: int64

# %%
data2=data.drop_duplicates(['name'])

# %%
data2
# Out:
#                   name keyword  \
# 0      더럭초등학교(구, 더럭분교)      문화
# 78                방주교회      문화
# 148         김영갑갤러리 두모악      문화
# 185        너븐숭이 4.3기념관      문화
# 225              제주민속촌      문화
# ...                ...     ...
# 13047         제주올레 6코스      도보
# 13055        제주올레 17코스      도보
# 13061    누웨마루거리(구 바오젠)      도보
# 13065        숫모르편백나무숲길      도보
# 13067         삼의악트레킹코스      도보
#
#                                                  content  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 78                                             좋아요좋아요좋아요
# 148        오렌지빛 가득한 김영갑갤러리두모악. 그는 가도 그의 영혼은 생기있게 빛나고 있다.
# 185    운영시간이 6시까진데 미리 알아보지 못하고 5시 58분에 도착했습니다 아쉽게도 발걸...
# 225    친동생 군입대와 가족여행 겸 다녀온 제주여행입니다. 입대로 인한 슬픔과 가족여행이라...
# ...                                                  ...
# 13047  #제주가을#올레6코스#제주올레걷기축제#참가#하효항#서귀포칠십리시공원#소천지#이중섭길...
# 13055  #제주보리  #도두마을  #올레길17코스  도두마을을 걷노라면 즐겁다  벽화구경을 ...
# 13061                                   #먹거리 연동바오젠거리 킹크랩
# ...

# %%
data2 .isnull().sum()
# Out:
# name        0
# keyword     0
# content     0
# tags        0
# address     0
# address1    0
# dtype: int64

# %%
data2.to_csv('duplicates.csv',mode="w",encoding='utf-8')

# %%
latitude=data[['name','address']]

# %%
latitude
# Out:
#                   name                  address
# 0      더럭초등학교(구, 더럭분교)  제주특별자치도 제주시 애월읍 하가로 195
# 1      더럭초등학교(구, 더럭분교)  제주특별자치도 제주시 애월읍 하가로 196
# 2      더럭초등학교(구, 더럭분교)  제주특별자치도 제주시 애월읍 하가로 197
# 3      더럭초등학교(구, 더럭분교)  제주특별자치도 제주시 애월읍 하가로 198
# 4      더럭초등학교(구, 더럭분교)  제주특별자치도 제주시 애월읍 하가로 199
# ...                ...                      ...
# 13063    누웨마루거리(구 바오젠)       제주특별자치도 제주시 신광로 47
# 13064    누웨마루거리(구 바오젠)       제주특별자치도 제주시 신광로 47
# 13065        숫모르편백나무숲길    제주특별자치도 제주시 516로 2596
# 13066        숫모르편백나무숲길    제주특별자치도 제주시 516로 2596
# 13067         삼의악트레킹코스   제주특별자치도 제주시 아라동 산 24-2
#
# [13068 rows x 2 columns]

# %%
latitude.to_csv('latitude.csv',mode="w",encoding='utf-8')

# %%
# 구글지오코드 나 #카카오 api로 활용하기  파일 제목은 point1으로 저장하기

# %%
point= pd.read_csv('./point.csv', encoding='UTF8')

# %%
point
# Out:
#                 name                         address   Latitude   Longitude
# 0    더럭초등학교(구, 더럭분교)         제주특별자치도 제주시 애월읍 하가로 195  33.453459  126.345275
# 1               방주교회  제주특별자치도 서귀포시 안덕면 산록남로762번길 113  33.305073  126.387664
# 2         김영갑갤러리 두모악        제주특별자치도 서귀포시 성산읍 삼달로 137  33.372065  126.854180
# 3        너븐숭이 4.3기념관          제주특별자치도 제주시 조천읍 북촌3길 3  33.545988  126.688764
# 4              제주민속촌   제주특별자치도 서귀포시 표선면 민속해안로 631-34  33.322345  126.841487
# ..               ...                             ...        ...         ...
# 474         제주올레 6코스         제주특별자치도 서귀포시 보목동 1377-4  33.237120  126.596068
# 475        제주올레 17코스         제주특별자치도 제주시 도두1동 2612-1  33.505224  126.467967
# 476    누웨마루거리(구 바오젠)              제주특별자치도 제주시 신광로 47  33.487738  126.490340
# 477        숫모르편백나무숲길           제주특별자치도 제주시 516로 2596  33.430924  126.595761
# 478         삼의악트레킹코스          제주특별자치도 제주시 아라동 산 24-2  33.440020  126.561964
#
# [479 rows x 4 columns]

# %%
point.isnull().sum()
# Out:
# name         0
# address      0
# Latitude     0
# Longitude    0
# dtype: int64

# %%
data
# Out:
#                   name keyword  \
# 0      더럭초등학교(구, 더럭분교)      문화
# 1      더럭초등학교(구, 더럭분교)      문화
# 2      더럭초등학교(구, 더럭분교)      문화
# 3      더럭초등학교(구, 더럭분교)      문화
# 4      더럭초등학교(구, 더럭분교)      문화
# ...                ...     ...
# 13063    누웨마루거리(구 바오젠)      도보
# 13064    누웨마루거리(구 바오젠)      도보
# 13065        숫모르편백나무숲길      도보
# 13066        숫모르편백나무숲길      도보
# 13067         삼의악트레킹코스      도보
#
#                                                  content  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                       무지개빛 아름다운 더럭초등학교
# 2                                       무지개빛 아름다운 더럭초등학교
# 3              알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4      #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                                                  ...
# 13063                              #바오젠거리 #신라스테이제주 #돌하루방
# 13064                        중국인들이 많이 찾는다는 제주시 연동 바오젠거리.
# 13065  제주생태공원에서 절물자연휴양림으로 이어지는 걷기 좋은 길이다.  #숫모르편백나무숲길...
# ...

# %%
data2
# Out:
#                   name keyword  \
# 0      더럭초등학교(구, 더럭분교)      문화
# 78                방주교회      문화
# 148         김영갑갤러리 두모악      문화
# 185        너븐숭이 4.3기념관      문화
# 225              제주민속촌      문화
# ...                ...     ...
# 13047         제주올레 6코스      도보
# 13055        제주올레 17코스      도보
# 13061    누웨마루거리(구 바오젠)      도보
# 13065        숫모르편백나무숲길      도보
# 13067         삼의악트레킹코스      도보
#
#                                                  content  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 78                                             좋아요좋아요좋아요
# 148        오렌지빛 가득한 김영갑갤러리두모악. 그는 가도 그의 영혼은 생기있게 빛나고 있다.
# 185    운영시간이 6시까진데 미리 알아보지 못하고 5시 58분에 도착했습니다 아쉽게도 발걸...
# 225    친동생 군입대와 가족여행 겸 다녀온 제주여행입니다. 입대로 인한 슬픔과 가족여행이라...
# ...                                                  ...
# 13047  #제주가을#올레6코스#제주올레걷기축제#참가#하효항#서귀포칠십리시공원#소천지#이중섭길...
# 13055  #제주보리  #도두마을  #올레길17코스  도두마을을 걷노라면 즐겁다  벽화구경을 ...
# 13061                                   #먹거리 연동바오젠거리 킹크랩
# ...

# %%
point
# Out:
#                 name                         address   Latitude   Longitude
# 0    더럭초등학교(구, 더럭분교)         제주특별자치도 제주시 애월읍 하가로 195  33.453459  126.345275
# 1               방주교회  제주특별자치도 서귀포시 안덕면 산록남로762번길 113  33.305073  126.387664
# 2         김영갑갤러리 두모악        제주특별자치도 서귀포시 성산읍 삼달로 137  33.372065  126.854180
# 3        너븐숭이 4.3기념관          제주특별자치도 제주시 조천읍 북촌3길 3  33.545988  126.688764
# 4              제주민속촌   제주특별자치도 서귀포시 표선면 민속해안로 631-34  33.322345  126.841487
# ..               ...                             ...        ...         ...
# 474         제주올레 6코스         제주특별자치도 서귀포시 보목동 1377-4  33.237120  126.596068
# 475        제주올레 17코스         제주특별자치도 제주시 도두1동 2612-1  33.505224  126.467967
# 476    누웨마루거리(구 바오젠)              제주특별자치도 제주시 신광로 47  33.487738  126.490340
# 477        숫모르편백나무숲길           제주특별자치도 제주시 516로 2596  33.430924  126.595761
# 478         삼의악트레킹코스          제주특별자치도 제주시 아라동 산 24-2  33.440020  126.561964
#
# [479 rows x 4 columns]

# %%
outer=pd.merge(data2,point,on='name', how='outer')

# %%
outer
# Out:
#                 name keyword  \
# 0    더럭초등학교(구, 더럭분교)      문화
# 1               방주교회      문화
# 2         김영갑갤러리 두모악      문화
# 3        너븐숭이 4.3기념관      문화
# 4              제주민속촌      문화
# ..               ...     ...
# 474         제주올레 6코스      도보
# 475        제주올레 17코스      도보
# 476    누웨마루거리(구 바오젠)      도보
# 477        숫모르편백나무숲길      도보
# 478         삼의악트레킹코스      도보
#
#                                                content  \
# 0                    초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                            좋아요좋아요좋아요
# 2        오렌지빛 가득한 김영갑갤러리두모악. 그는 가도 그의 영혼은 생기있게 빛나고 있다.
# 3    운영시간이 6시까진데 미리 알아보지 못하고 5시 58분에 도착했습니다 아쉽게도 발걸...
# 4    친동생 군입대와 가족여행 겸 다녀온 제주여행입니다. 입대로 인한 슬픔과 가족여행이라...
# ..                                                 ...
# 474  #제주가을#올레6코스#제주올레걷기축제#참가#하효항#서귀포칠십리시공원#소천지#이중섭길...
# 475  #제주보리  #도두마을  #올레길17코스  도두마을을 걷노라면 즐겁다  벽화구경을 ...
# 476                                   #먹거리 연동바오젠거리 킹크랩
# ...

# %%
outer=outer.rename(columns={'address_x':'address'})

# %%
outer=outer.drop(['address_y'],axis=1)

# %%
outer
# Out:
#                 name keyword  \
# 0    더럭초등학교(구, 더럭분교)      문화
# 1               방주교회      문화
# 2         김영갑갤러리 두모악      문화
# 3        너븐숭이 4.3기념관      문화
# 4              제주민속촌      문화
# ..               ...     ...
# 474         제주올레 6코스      도보
# 475        제주올레 17코스      도보
# 476    누웨마루거리(구 바오젠)      도보
# 477        숫모르편백나무숲길      도보
# 478         삼의악트레킹코스      도보
#
#                                                content  \
# 0                    초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                            좋아요좋아요좋아요
# 2        오렌지빛 가득한 김영갑갤러리두모악. 그는 가도 그의 영혼은 생기있게 빛나고 있다.
# 3    운영시간이 6시까진데 미리 알아보지 못하고 5시 58분에 도착했습니다 아쉽게도 발걸...
# 4    친동생 군입대와 가족여행 겸 다녀온 제주여행입니다. 입대로 인한 슬픔과 가족여행이라...
# ..                                                 ...
# 474  #제주가을#올레6코스#제주올레걷기축제#참가#하효항#서귀포칠십리시공원#소천지#이중섭길...
# 475  #제주보리  #도두마을  #올레길17코스  도두마을을 걷노라면 즐겁다  벽화구경을 ...
# 476                                   #먹거리 연동바오젠거리 킹크랩
# ...

# %%
out=pd.merge(data,outer,on='name',how='outer')

# %%
out
# Out:
#                   name keyword_x  \
# 0      더럭초등학교(구, 더럭분교)        문화
# 1      더럭초등학교(구, 더럭분교)        문화
# 2      더럭초등학교(구, 더럭분교)        문화
# 3      더럭초등학교(구, 더럭분교)        문화
# 4      더럭초등학교(구, 더럭분교)        문화
# ...                ...       ...
# 13063    누웨마루거리(구 바오젠)        도보
# 13064    누웨마루거리(구 바오젠)        도보
# 13065        숫모르편백나무숲길        도보
# 13066        숫모르편백나무숲길        도보
# 13067         삼의악트레킹코스        도보
#
#                                                content_x  \
# 0                      초등학교 동창들과 함께한 가을 여행 속 방문한 애월 더럭분교
# 1                                       무지개빛 아름다운 더럭초등학교
# 2                                       무지개빛 아름다운 더럭초등학교
# 3              알록달록 너무 예쁜 초등학교에서 아내와 함께 좋은 추억과 사진을 남겼어요!
# 4      #제주도 #더럭분교 #연화못 #연꽃마을 정말 뭔가 작은 추억이 자꾸 생각나고 웃음이...
# ...                                                  ...
# 13063                              #바오젠거리 #신라스테이제주 #돌하루방
# 13064                        중국인들이 많이 찾는다는 제주시 연동 바오젠거리.
# ...

# %%
out.to_csv('out.csv',mode="w",encoding='utf-8')
